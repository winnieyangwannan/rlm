# %% [markdown]
# # LOG:
#
# /checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/summarization/gpt-5_summarization_513_xray_2026-02-08_23-35-35_c4318c42.jsonl

# %%
import sys
import importlib


sys.path.append('/home/winnieyangwn/rlm/analysis')
import rlm_log_utils
importlib.reload(rlm_log_utils)
from rlm_log_utils import *

# %% [markdown]
# ## Usage Example
#
# Load the log file and extract key information:

# %% [markdown]
# # Load

# %%
import glob
import os

run_id = 513
model_name = "gpt-5"
task_name = "dogs-vs-cats-redux-kernels-edition"
log_dir = "/checkpoint/maui_sft/winnieyangwn/rlm_dumps"
codebase_extensions = [".py", ".md", ".yaml"]

# Option 1: Provide a specific log name to load directly
log_name = None  # e.g., "gpt-5_summarization_513_20260208_123456.jsonl"

if log_name:
    # Directly load the specified log file
    LOG_PATH = os.path.join(log_dir, log_name)
    if not os.path.exists(LOG_PATH):
        raise FileNotFoundError(f"Specified log file not found: {LOG_PATH}")
    print(f"Loading specified log: {LOG_PATH}")
else:
    # Use underscore after run_id to avoid matching "summarization_comparison_*" logs
    LOG_PATH_PREFIX = f"{log_dir}/{model_name}_summarization_{run_id}_{task_name}"

    # Find all log files matching the prefix pattern
    matching_logs = glob.glob(f"{LOG_PATH_PREFIX}*")

    if not matching_logs:
        raise FileNotFoundError(f"No log files found matching prefix: {LOG_PATH_PREFIX}")

    # Get the most recent log file by modification time
    LOG_PATH = max(matching_logs, key=os.path.getmtime)
    print(f"Found {len(matching_logs)} matching log file(s)")
    print(f"Loading most recent: {LOG_PATH}")

# Load the log - first entry is metadata, rest are iterations
entries = load_rlm_log(LOG_PATH)
metadata = entries[0]
iterations = entries[1:]

print(f"Loaded {len(iterations)} iterations")
# Out:
# Found 1 matching log file(s)
# Loading most recent: /checkpoint/maui_sft/winnieyangwn/rlm_dumps/gpt-5_summarization_513_dogs-vs-cats-redux-kernels-edition_2026-02-09_08-57-46_2639bd10.jsonl
# Loaded 2 iterations

# %% [markdown]
# # Metadata

# %%
# View metadata
print("=== METADATA ===")
for k, v in metadata.items():
    if k != "backend_kwargs":
        print(f"{k}: {v}")
# Out:
# === METADATA ===
# type: metadata
# timestamp: 2026-02-09T08:57:46.474802
# root_model: gpt-5
# max_depth: 2
# max_iterations: 10
# backend: azure_openai
# environment_type: local
# environment_kwargs: {'setup_code': '\nimport pandas as pd\n\n# Load rollout data as DataFrame\nrollout_df = pd.read_json(\'/checkpoint/maui_sft/winnieyangwn/amaia_dumps/513/trajectories/513_metadata.jsonl\', lines=True)\nprint(f"Loaded {len(rollout_df)} total rollouts")\n\n# Filter to specific task\nrollout_df = rollout_df[rollout_df[\'task_name\'] == \'dogs-vs-cats-redux-kernels-edition\']\nprint(f"Filtered to {len(rollout_df)} rollouts for task: dogs-vs-cats-redux-kernels-edition")\n'}
# other_backends: None

# %%
# Compare with timestamp-based runtime
runtime = get_total_runtime(entries)
print(f"Timestamp-based runtime: {runtime.total_seconds():.2f}s")
# Out:
# Timestamp-based runtime: 1404.62s

# %%
# Check number of iterations actually taken by model
num_iterations = len(iterations)
print(f"Number of iterations taken: {num_iterations}")

# You can also use extract_all for a comprehensive summary
summary = extract_all(LOG_PATH)
print(f"Number of iterations (from extract_all): {summary['num_iterations']}")
# Out:
# Number of iterations taken: 2
# Number of iterations (from extract_all): 2

# %% [markdown]
# # Final Answer

# %%
# Get the final answer
final_answer = get_final_answer(iterations)
print("=== FINAL ANSWER ===")
print(final_answer if final_answer else "No final answer found")
# print(f"\n(Total length: {len(final_answer) if final_answer else 0} chars)")
# Out:
# === FINAL ANSWER ===
# Part 0: Task Analysis
# 1. Problem Type
# - Binary image classification (dog vs. cat)
#
# 2. Domain
# - Computer vision; animal identification in photographs
#
# 3. Input Format
# - Train: 25,000 images with labels embedded in filenames (e.g., indicating dog or cat)
# - Test: 12,500 images named by numeric id
# - Submission: CSV with header id,label where label is the predicted probability the image is a dog (1 = dog, 0 = cat)
#
# 4. Evaluation Metric
# - Log Loss (binary cross-entropy); smaller is better
#
# 5. Key Challenges
# - Producing well-calibrated probability estimates to minimize log loss (avoiding overconfident errors)
# - High variability in images (sizes, lighting, backgrounds, poses, breeds)
# - Risk of overfitting given dataset size relative to modern deep models; need augmentation/regularization
# - Correctly parsing labels from filenames and consistent preprocessing/resizing
# - Ensuring robust generalization to test images without explicit labels
#
# Part 1: Individual Solution Summaries
# 1. Data Preprocessing
# - Data loading and splitting approaches: Images are listed from TRAIN_DIR and TEST_DIR using a custom list_images function that filters by common image extensions. A custom PyTorch Dataset (CatsDogsDataset) loads images via PIL, converts to RGB, applies transforms, and infers labels from filenames (dog.=1, cat.=0) with a fallback to parent folder names. The train/validation split is stratified by filename prefix (“cat.”/“dog.”); if that structure isn’t present, it falls back to a random split with a 10% validation fraction.
# - Cleaning strategies (missing values, outliers, filtering): No cleaning is performed. The code raises an error if no training or test images are found but does not handle missing values, outliers, or perform filtering beyond extension checks.
# - Transformations applied (scaling, encoding, type conversions): Images are converted to tensors and normalized using ImageNet mean/std. For training: RandomResizedCrop(224, scale=(0.7, 1.0), ratio=(0.75, 1.33)), RandomHorizontalFlip, ColorJitter(0.1, 0.1, 0.1, 0.05), ToTensor, Normalize. For validation/test: Resize(256), CenterCrop(224), ToTensor, Normalize. No label encoding beyond binary inference (0/1).
# - Data augmentation techniques (if any): Yes. Training augmentation includes random resized crop, horizontal flip, and color jitter. Inference uses simple test-time augmentation (TTA): average of original and horizontally flipped predictions.
# - Other preprocessing steps: Test images are sorted by numeric id extracted from filenames to match Kaggle submission expectations. Reproducibility is set via random and torch seeds. FAST_DEV mode (optional) limits training data to a 2000-image subset and reduces epochs/batch size. DataLoader uses pin_memory and multiple workers for performance.
#
# 2. Feature Engineering
# - New features that were created and their derivation: None. The model consumes raw images with standard image transforms; no auxiliary features are engineered.
# - Feature selection or dimensionality reduction methods: None applied outside of the model’s learned representations.
# - Domain-specific transformations: Standard image preprocessing/augmentation (ImageNet normalization, cropping, flipping, color jitter) are used; these are preprocessing steps rather than engineered features.
# - When no feature engineering was performed, note explicitly: No explicit feature engineering was performed.
#
# 3. Model Selection
# - The primary algorithm(s) used (exact model class/function): torchvision.models.resnet18 (ResNet-18) with ResNet18_Weights.IMAGENET1K_V1 (pretrained on ImageNet). The final fully-connected layer is replaced with nn.Linear(in_features, 1) for binary logits. Loss is nn.BCEWithLogitsLoss with pos_weight. Optimizer is torch.optim.AdamW.
# - Model hyperparameters (learning rate, depth, n_estimators, etc.): ResNet-18 depth. Initial learning rate 5e-4 with cosine decay per epoch. Weight decay 1e-4. Batch size default 64 (FAST_DEV: 32). Epochs default 5 (FAST_DEV: 1). Image size 224 for model input. BCEWithLogitsLoss pos_weight computed as max(1.0, n_neg / max(1, n_pos)) from training split class counts.
# - Ensemble architecture (if any): None. A single model is trained. Inference uses simple TTA by averaging predictions from original and horizontally flipped inputs; this is not a multi-model ensemble.
# - Number of models in the ensemble (if applicable): Not applicable; 1 trained model. TTA averages 2 predictions per image (original + flip).
# - Pretrained models: which ones and how they were used (feature extraction, fine-tuning, etc.): ResNet-18 pretrained on ImageNet is fine-tuned end-to-end (no layer freezing). The final layer is replaced for binary classification. At inference, the model is instantiated without pretrained weights and the trained state dict is loaded.
#
# 4. Training Methodology
# - Hyperparameter selection method (if any): None. Hyperparameters are fixed in code; no search or cross-validation is implemented.
# - Training configuration (relevant parameters for the model type): AdamW optimizer (lr=5e-4, weight_decay=1e-4), BCEWithLogitsLoss with class-balancing pos_weight, mixed precision training via torch.cuda.amp.GradScaler when CUDA is available, cosine learning rate schedule across epochs, batch size 64 by default, DataLoader with multiple workers and pin_memory. Full fine-tuning of the network (no frozen layers).
# - Other important training details (early stopping, regularization, etc.): Best checkpoint is saved based on validation log loss computed from sigmoid probabilities. Cosine LR scheduling is applied after each epoch. Early stopping is only present as a “gentle safeguard” in FAST_DEV mode (stops after 1 epoch). Weight decay provides regularization. Seeds are set for reproducibility.
#
# 5. Evaluation & Submission
# - Final prediction method (mean, median, weighted average, etc.): For each test image, the final probability is the mean of sigmoid(logits) from the original image and its horizontally flipped version (simple TTA average).
# - Post-processing of predictions: Submission DataFrame with columns “id” and “label” is sorted by id and written to CSV. No thresholding or additional post-processing is applied to probabilities.
#
# 6. Notable Implementation Details
# - Computational considerations (GPU usage, runtime optimizations): GPU is used if available; mixed precision (autocast + GradScaler) reduces computation and memory usage. DataLoader uses pin_memory and a bounded number of workers (up to 8). FAST_DEV mode reduces dataset size and epochs for quicker iterations. PIL is used for image loading for speed and transform compatibility.
# - Other unique approaches or novel techniques: Automatic installation of torchvision if import fails improves robustness of the environment. Label inference includes a fallback for directory-structured datasets (train/<class>/<id>.jpg).
# - Other significant aspects of the solution's approach: Validation metric is log loss computed from probabilities (custom compute_log_loss with clamping for numerical stability). Best model checkpoint is selected by validation log loss. Test images are sorted by numeric id extracted from filenames to conform to Kaggle submission ordering.
#
# Solution ID: 316
# Score Percentile: 1.000000
#
# 1. Data Preprocessing
# - Data loading and splitting approaches
#   - Training images are listed from TRAIN_DIR; labels inferred from filename prefixes: cat.* -> 0, dog.* -> 1; non-image files and unexpected naming are skipped.
#   - Test images are listed from TEST_DIR without labels.
#   - Stratified train/validation split: cats and dogs are separated, shuffled, and a fixed fraction is taken for validation (10% in full run, 20% in fast dev); the remaining form the training set. Both splits are shuffled post-split.
#   - FAST_DEV_RUN option caps per-class training size and caps the number of test images for quicker pipeline validation.
# - Cleaning strategies (missing values, outliers, filtering)
#   - If an image fails to load, a black RGB image of size 224×224 is substituted to avoid crashes.
#   - Non-image files are skipped; filenames without expected prefixes are ignored.
#   - No explicit handling of outliers, duplicates, or additional filtering beyond filename checks.
# - Transformations applied (scaling, encoding, type conversions)
#   - Images converted to RGB via PIL and then to tensors.
#   - Normalization to ImageNet mean and std: mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225].
#   - Validation/test transforms: Resize to img_size + 32, CenterCrop to img_size, ToTensor, Normalize.
#   - Labels encoded as float tensors of shape [1] for BCEWithLogitsLoss.
# - Data augmentation techniques (if any)
#   - Training-time augmentation: RandomResizedCrop (scale=(0.7, 1.0), ratio=(0.75, 1.3333)), RandomHorizontalFlip, ColorJitter (brightness=0.1, contrast=0.1, saturation=0.1, hue=0.05).
#   - Test-time augmentation (TTA): horizontal flip; final probability is the average of original and flipped predictions.
# - Other preprocessing steps
#   - Fixed image size parameter: img_size=224.
#   - DataLoader settings: batch_size=128 if CUDA and not in fast dev, else 32; num_workers=min(8, os.cpu_count()); pin_memory=True; shuffle=True for training, False for validation/test.
#   - Reproducibility: SEED=42 for Python, NumPy, and Torch; CUDA seeds set if available.
#
# 2. Feature Engineering
# - New features that were created and their derivation
#   - None; images are fed directly to CNN models without handcrafted feature creation.
# - Feature selection or dimensionality reduction methods
#   - None; the approach relies on end-to-end deep learning with convolutional networks.
# - Domain-specific transformations
#   - ImageNet-standard normalization; image resizing/cropping; color jitter and horizontal flips as augmentations.
# - When no feature engineering was performed, note explicitly
#   - No traditional feature engineering was performed.
#
# 3. Model Selection
# - The primary algorithm(s) used (exact model class/function)
#   - Primary: torchvision.models.efficientnet_b0 with EfficientNet_B0_Weights.IMAGENET1K_V1; classifier head replaced with nn.Linear(in_features, 1).
#   - Fallback 1: torchvision.models.resnet50 with ResNet50_Weights.IMAGENET1K_V2; backbone.fc replaced with nn.Linear(in_features, 1).
#   - Fallback 2: A minimal custom CNN defined inline if pretrained models are unavailable.
# - Model hyperparameters (learning rate, depth, n_estimators, etc.)
#   - Optimizer: AdamW with lr=1e-4, weight_decay=1e-4.
#   - Scheduler: CosineAnnealingLR with T_max=epochs.
#   - Loss: binary cross-entropy with logits (BCEWithLogitsLoss).
#   - Epochs: 6 in full run; 1 in fast dev run.
#   - Batch size: 128 if CUDA and not fast dev; otherwise 32.
#   - Mixed precision: torch.cuda.amp autocast and GradScaler enabled when CUDA is available.
# - Ensemble architecture (if any): stacking, blending, voting, etc.
#   - None; a single model is trained.
# - Number of models in the ensemble (if applicable)
#   - Not applicable.
# - Pretrained models: which ones and how they were used (feature extraction, fine-tuning, etc.)
#   - EfficientNet_B0 and ResNet50 initialized with ImageNet pretrained weights and fine-tuned end-to-end (no layer freezing); classifier head replaced for binary output.
#
# 4. Training Methodology
# - Hyperparameter selection method (if any)
#   - None; hyperparameters are fixed and not tuned via search.
# - Training configuration (relevant parameters for the model type)
#   - Data augmentations for training; center-crop evaluation for validation/test.
#   - Optimizer: AdamW (lr=1e-4, weight_decay=1e-4).
#   - Scheduler: CosineAnnealingLR (T_max=epochs).
#   - Loss: BCEWithLogitsLoss (via F.binary_cross_entropy_with_logits on logits/view(-1)).
#   - Mixed precision training enabled on CUDA via autocast and GradScaler.
#   - Device selection: CUDA if available, else CPU.
# - Other important training details (early stopping, regularization, etc.)
#   - Early stopping: training stops if no new best validation loss for 3 consecutive epochs (epoch - best_epoch >= 3) in full run.
#   - Checkpointing: best model by validation loss is saved to CKPT_PATH and reloaded for inference.
#   - Weight decay used for regularization via AdamW.
#   - CUDNN performance: torch.backends.cudnn.benchmark = True.
#   - Reproducible seeds set for Python, NumPy, Torch, and CUDA.
#
# 5. Evaluation & Submission
# - Final prediction method (mean, median, weighted average, etc.)
#   - Sigmoid applied to logits to get probabilities; when TTA is enabled, final probability is the mean of original and horizontally flipped predictions.
# - Post-processing of predictions
#   - Probabilities clipped to [0, 1].
#   - Test IDs extracted from filenames (numeric conversion; fallback by stripping non-digits), sorted ascending.
#   - Submission CSV written with header "id,label" to OUT_PATH.
#   - If the pipeline errors out, a fallback submission of constant 0.5 probabilities is generated.
#
# 6. Notable Implementation Details
# - Computational considerations (GPU usage, runtime optimizations)
#   - Automatic CUDA detection; mixed precision training/inference to accelerate and reduce memory usage.
#   - DataLoader optimizations: pin_memory=True and non_blocking transfers.
#   - num_workers dynamically chosen: min(8, CPU count).
#   - Larger batch size when CUDA is available; FAST_DEV_RUN mode for quick iteration with reduced data and epochs.
# - Other unique approaches or novel techniques
#   - Robust model construction: attempts EfficientNet_B0 first, then ResNet50, finally a minimal custom CNN if necessary.
#   - Environmental robustness: attempts to pip-install torchvision (and torch) on-the-fly if import fails, specifying the CUDA 12.1 index.
#   - Image load failure handling by substituting a black image to prevent crashing.
#   - Test-time augmentation via simple horizontal flip averaging.
# - Other significant aspects of the solution's approach
#   - Best-model checkpointing by validation loss and reload before inference.
#   - Careful ID parsing and sorting for Kaggle’s expected submission format.
#   - Clear separation of train/val/test transforms and stratified splitting by class.
#
# Solution ID: 317
# Score Percentile: 1.000000
#
# 1. Data Preprocessing
# - Data loading and splitting approaches
#   - Training files loaded from /root/data/train by listing image files with extensions .jpg/.png/.jpeg.
#   - Labels inferred from filenames: 'cat' → 0, 'dog' → 1.
#   - Stratified train/validation split with 5% validation via separate shuffling of cats and dogs, then concatenation.
#   - Test files loaded from /root/data/test; numeric IDs extracted from filenames; items sorted by ID for deterministic ordering.
#   - Optional fast-dev subset (if FAST_DEV_RUN=1): balanced subset of up to 2000 cats and 2000 dogs.
# - Cleaning strategies (missing values, outliers, filtering)
#   - If an image fails to open (corrupt/missing), a blank 224×224 black RGB image is used as a fallback.
#   - No handling of missing labels (not applicable).
#   - No explicit outlier detection or filtering beyond file extension filtering.
# - Transformations applied (scaling, encoding, type conversions)
#   - Image normalization with ImageNet mean [0.485, 0.456, 0.406] and std [0.229, 0.224, 0.225].
#   - Train labels cast to float32 tensors with shape [1] to match BCEWithLogits.
#   - Evaluation/test transforms: Resize(256) → CenterCrop(224) → ToTensor → Normalize.
#   - No categorical encoding or numeric feature scaling beyond image normalization.
# - Data augmentation techniques (if any)
#   - Training augmentations: RandomResizedCrop(224, scale=(0.7, 1.0)), RandomHorizontalFlip, ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1).
# - Other preprocessing steps
#   - Test ID extraction via regex (last numeric group in filename); fallback strips non-digits; final sort by ID.
#   - DataLoaders use pin_memory (on CUDA) and persistent_workers for speed; num_workers up to min(12, CPU count).
#
# 2. Feature Engineering
# - New features that were created and their derivation
#   - None; images are fed directly to the CNN after augmentation/normalization.
# - Feature selection or dimensionality reduction methods
#   - None outside the model’s inherent architecture.
# - Domain-specific transformations
#   - Standard CNN preprocessing: ImageNet normalization, random crops/flips/color jitter for robustness.
# - When no feature engineering was performed, note explicitly
#   - No explicit feature engineering beyond standard image augmentations and normalization.
#
# 3. Model Selection
# - The primary algorithm(s) used (exact model class/function)
#   - torchvision.models.resnet50 (ResNet-50).
# - Model hyperparameters (learning rate, depth, n_estimators, etc.)
#   - Final layer replaced with nn.Linear(in_features, 1) for binary logits.
#   - Optimizer: AdamW (lr=3e-4, weight_decay=1e-4).
#   - Scheduler: CosineAnnealingLR(T_max=epochs).
#   - Batch size: 64 (with fallback to smaller if DataLoader init fails).
#   - Image size: 224×224.
#   - Epochs: 5 (or 1 if FAST_DEV_RUN=1).
#   - Mixed precision enabled on CUDA via torch.cuda.amp.
# - Ensemble architecture (if any): stacking, blending, voting, etc.
#   - None.
# - Number of models in the ensemble (if applicable)
#   - Not applicable (single model).
# - Pretrained models: which ones and how they were used (feature extraction, fine-tuning, etc.)
#   - ResNet50 with ResNet50_Weights.IMAGENET1K_V2 pretrained weights; full-network fine-tuning (no layers frozen). Falls back to random init if weights cannot be loaded.
#
# 4. Training Methodology
# - Hyperparameter selection method (if any)
#   - None; fixed configuration (no search/CV for hyperparameters).
# - Training configuration (relevant parameters for the model type)
#   - Loss: binary_cross_entropy_with_logits.
#   - Train/val split: 95/5 with stratification by class.
#   - DataLoader: shuffle on train, no shuffle on val/test; pin_memory and persistent_workers used.
#   - Seed setting (random, NumPy, PyTorch); cudnn.benchmark=True, deterministic=False.
# - Other important training details (early stopping, regularization, etc.)
#   - Early stopping on validation loss with patience=2 (min delta 1e-4).
#   - Best checkpoint saving and reload before inference.
#   - AMP gradient scaling via GradScaler.
#   - Weight decay via AdamW; no dropout/layer freezing/label smoothing.
#
# 5. Evaluation & Submission
# - Final prediction method (mean, median, weighted average, etc.)
#   - Direct model predictions on test set: sigmoid(logits) as probability of class 1 (dog).
#   - No ensembling or test-time augmentation; single pass inference.
# - Post-processing of predictions
#   - Pair (id, prob), sort by id.
#   - Output DataFrame columns: id, label; sorted by id; saved to /workspace/submission.csv.
#   - No thresholding applied for submission (probabilities submitted as required by competition).
#
# 6. Notable Implementation Details
# - Computational considerations (GPU usage, runtime optimizations)
#   - Automatic CUDA usage if available; mixed precision for speed.
#   - pin_memory, persistent_workers, and up to 12 workers to optimize data loading.
#   - OOM-safe DataLoader fallback by halving batch size (min 16).
#   - cudnn.benchmark=True to optimize convolution algorithms.
# - Other unique approaches or novel techniques
#   - Robust test ID extraction from filenames via regex with fallbacks; items sorted by ID at multiple stages for determinism.
#   - Graceful handling of corrupt images by substituting a blank image to avoid crashes.
#   - Auto-install of torchvision if import fails (environment robustness).
# - Other significant aspects of the solution's approach
#   - Simple, strong baseline: fine-tuned pretrained ResNet-50 with standard augmentations and early stopping.
#   - No cross-validation or ensemble complexity; relies on ImageNet transfer learning effectiveness.
#
# Solution ID: 325
# Score Percentile: 1.000000
#
# 1. Data Preprocessing
# - Data loading and splitting approaches
#   - Training images loaded from /root/data/train with labels inferred from filename prefixes: cat.* -> 0, dog.* -> 1. Non-image files are skipped.
#   - Test images loaded from /root/data/test; numeric id parsed from filename (fallback extracts digits; if none found, id set to -1). Test items are sorted by id.
#   - Stratified train/validation split by class with default val_frac=0.1, shuffling within each class. Random seeds set (Python, NumPy, PyTorch) for reproducibility.
#   - DataLoader settings: train loader shuffles; val/test loaders do not. pin_memory=True, num_workers default 8, drop_last=False.
# - Cleaning strategies (missing values, outliers, filtering)
#   - No explicit cleaning for missing values/outliers.
#   - If image open fails (after 2 attempts), a placeholder gray RGB image (256x256) is substituted.
#   - Files not starting with cat. or dog. in train are skipped; non-image extensions are filtered out.
# - Transformations applied (scaling, encoding, type conversions)
#   - Images converted to RGB via PIL.
#   - Tensors: ToTensor() converts to float tensors.
#   - Normalization with ImageNet statistics: mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225].
#   - Labels converted to torch.long tensors.
# - Data augmentation techniques (if any)
#   - Training: RandomResizedCrop(img_size, scale=(0.7, 1.0), ratio=(0.75, 1.33)), RandomHorizontalFlip(p=0.5), ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.05).
#   - Validation/Test: Resize to 1.15×img_size then CenterCrop(img_size).
# - Other preprocessing steps
#   - Mixed precision is used during training (not a preprocessing step per se).
#   - Test predictions are aligned and sorted by id before writing submission.
#
# 2. Feature Engineering
# - New features that were created and their derivation
#   - None. No handcrafted features; model learns features directly from images.
# - Feature selection or dimensionality reduction methods
#   - None.
# - Domain-specific transformations
#   - Image augmentations appropriate for image classification (random resized crop, horizontal flip, color jitter).
#   - Normalization with ImageNet statistics to match pretrained model expectations.
# - When no feature engineering was performed, note explicitly
#   - No explicit feature engineering beyond standard image augmentations and normalization.
#
# 3. Model Selection
# - The primary algorithm(s) used (exact model class/function)
#   - Primary: timm.create_model('convnext_tiny', pretrained=True, num_classes=2).
#   - Fallback: torchvision.models.resnet50 with pretrained weights (ResNet50_Weights.IMAGENET1K_V1), final fc replaced with nn.Linear(in_features, 2).
#   - Secondary fallback: torchvision.models.resnet50 without pretrained weights if pretrained weights unavailable.
# - Model hyperparameters (learning rate, depth, n_estimators, etc.)
#   - Optimizer: AdamW(lr=3e-4 by default, weight_decay=1e-4).
#   - Batch size: 64 (configurable via BATCH_SIZE).
#   - Epochs: 6 (configurable via EPOCHS).
#   - Image size for transforms: 224 (configurable via IMG_SIZE).
#   - Scheduler: OneCycleLR(max_lr=lr, epochs=epochs, steps_per_epoch=len(train_loader)) configured (see Training Methodology for stepping detail).
#   - Loss: CrossEntropyLoss.
#   - Mixed precision: torch.cuda.amp autocast with GradScaler.
#   - Random seed: 42 for Python, NumPy, and PyTorch (including CUDA).
# - Ensemble architecture (if any): stacking, blending, voting, etc.
#   - None. Single-model approach.
# - Number of models in the ensemble (if applicable)
#   - Not applicable (single model).
# - Pretrained models: which ones and how they were used (feature extraction, fine-tuning, etc.)
#   - convnext_tiny pretrained on ImageNet (via timm), fine-tuned end-to-end (no layers frozen).
#   - Fallback: ResNet50 pretrained on ImageNet, final layer adjusted to 2 classes and fine-tuned end-to-end.
#   - Last-resort fallback: ResNet50 without pretrained weights, trained from scratch.
#
# 4. Training Methodology
# - Hyperparameter selection method (if any)
#   - None automated. Hyperparameters are fixed defaults with optional overrides via environment variables; no search or cross-validation.
# - Training configuration (relevant parameters for the model type)
#   - Optimizer: AdamW with lr=3e-4 (default), weight_decay=1e-4.
#   - Scheduler: OneCycleLR configured but stepped only once per epoch (see next bullet).
#   - Loss: Cross-entropy on logits.
#   - AMP: autocast enabled and GradScaler used when CUDA is available.
#   - DataLoader: shuffle for train; pin_memory=True; num_workers default 8; non_blocking tensor transfers.
#   - Logging: training loss logged every 50 steps.
#   - Validation: run each epoch; metrics reported: val_loss and val_acc.
#   - Checkpointing: best model by val_loss saved to /workspace/checkpoints/best.pt; reloaded before test inference.
#   - CUDNN: benchmark=True.
# - Other important training details (early stopping, regularization, etc.)
#   - Early stopping: Not used; training runs for all epochs, but best checkpoint by val_loss is tracked.
#   - Regularization: weight decay (1e-4) and data augmentation; no label smoothing or dropout adjustments configured explicitly.
#   - Scheduler usage caveat: OneCycleLR is typically stepped per batch, but here scheduler.step() is called once per epoch, which is non-standard and likely prevents the intended one-cycle schedule.
#   - Fast development mode: FAST_DEV_RUN=1 limits train to 2000 samples, val to 500, and runs 1 epoch; disables the scheduler.
#
# 5. Evaluation & Submission
# - Final prediction method (mean, median, weighted average, etc.)
#   - Single-model, single-pass inference using center-cropped images. Softmax probabilities computed; probability of class 1 (dog) is used as the label.
# - Post-processing of predictions
#   - Predictions paired with ids are sorted by id to match expected submission order.
#   - No calibration, ensembling, thresholding, or clipping. Probabilities are written with six decimal places.
#
# 6. Notable Implementation Details
# - Computational considerations (GPU usage, runtime optimizations)
#   - GPU used if available; mixed precision for speed and memory efficiency.
#   - pin_memory and non_blocking transfers used to optimize input pipeline.
#   - num_workers default 8 to parallelize data loading.
#   - cudnn.benchmark=True to optimize convolution algorithms for input sizes.
#   - Best checkpoint saving/loading to avoid overfitting across epochs.
#   - Self-contained dependency management: attempts to install timm and Pillow/torchvision at runtime if missing.
# - Other unique approaches or novel techniques
#   - Robust image loading: on repeated read failure, substitutes a neutral gray image to avoid hard crashes.
#   - Flexible configuration via environment variables: MODEL_NAME, IMG_SIZE, BATCH_SIZE, EPOCHS, LR, VAL_FRAC, NUM_WORKERS, FAST_DEV_RUN.
#   - Test ID parsing robust to non-numeric filenames by extracting digits.
# - Other significant aspects of the solution's approach
#   - Standard transfer learning pipeline with convnext_tiny fine-tuned end-to-end.
#   - Validation split is stratified by class to maintain class balance.
#   - No test-time augmentation; deterministic center-crop used for eval/inference.
#   - The OneCycleLR stepping pattern is non-standard (per-epoch instead of per-batch), which effectively reduces scheduler impact.
#
# Solution ID: 334
# Score Percentile: 0.970342
#
# 1. Data Preprocessing
# - Data loading and splitting approaches
#   - Training images are listed from /root/data/train by file extension (.jpg, .jpeg, .png).
#   - Labels are inferred from filenames: prefixed with “dog” -> 1, “cat” -> 0; otherwise presence of “dog”/“cat” in the name; unknowns are skipped.
#   - Stratified train/validation split by label using a custom function with val_ratio (default 0.1) and fixed seed, preserving class balance.
#   - Test images are listed from /root/data/test by file extension; numeric IDs are parsed from filenames (fallback to digits-only extraction if needed).
#   - DataLoaders: training uses shuffle=True; validation and test use shuffle=False. pin_memory=True; non_blocking GPU transfers.
# - Cleaning strategies (missing values, outliers, filtering)
#   - No explicit handling of missing values or outliers beyond skipping files that cannot be labeled by name.
#   - No checks for corrupted images (Image.open is called without try/except in normal flow).
#   - No duplicate removal or additional filtering.
# - Transformations applied (scaling, encoding, type conversions)
#   - Images loaded via PIL and converted to RGB.
#   - Tensors normalized to ImageNet mean and std: mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225].
#   - Validation/test: Resize to int(1.14 * img_size), then CenterCrop to img_size, ToTensor, Normalize.
#   - Labels converted to float32 tensors (0 or 1).
# - Data augmentation techniques (if any)
#   - Training augmentation: RandomResizedCrop(img_size, scale=(0.7, 1.0), ratio=(0.75, 1.3333)), RandomHorizontalFlip, ColorJitter (brightness/contrast/saturation=0.2, hue=0.02).
# - Other preprocessing steps
#   - Determinism/config: seeds set (Python, torch, PYTHONHASHSEED); cuDNN set to benchmark=True and deterministic=False.
#   - FAST_DEV mode optionally limits dataset size (first 2000 train images, first 500 test images) and reduces epochs/workers for quick runs.
#
# 2. Feature Engineering
# - New features that were created and their derivation
#   - None; model consumes raw image tensors after augmentation/normalization.
# - Feature selection or dimensionality reduction methods
#   - None.
# - Domain-specific transformations
#   - ImageNet-style normalization; augmentation tailored for image classification (random resized cropping, horizontal flip, color jitter).
#   - Validation preprocessing with resize+center crop commonly used for CNN evaluation.
# - When no feature engineering was performed, note explicitly
#   - No hand-crafted feature engineering was performed.
#
# 3. Model Selection
# - The primary algorithm(s) used (exact model class/function)
#   - torchvision.models.resnet50 with final fully connected layer replaced by nn.Linear(in_features, 1) for binary classification.
#   - Loss: nn.BCEWithLogitsLoss.
# - Model hyperparameters (learning rate, depth, n_estimators, etc.)
#   - Learning rate: 3e-4 (configurable via env).
#   - Weight decay: 0.01.
#   - Batch size: 64 for train; validation uses batch_size*2.
#   - Epochs: 6 (FAST_DEV sets to 1).
#   - Image size: 224.
#   - Num workers: 8.
#   - Validation split ratio: 0.1.
#   - Label smoothing: 0.05 applied to training labels.
#   - Optimizer: AdamW.
#   - Scheduler: CosineAnnealingLR with T_max=epochs and eta_min=lr*0.1.
# - Ensemble architecture (if any): stacking, blending, voting, etc.
#   - None; single-model approach.
# - Number of models in the ensemble (if applicable)
#   - Not applicable; only one model.
# - Pretrained models: which ones and how they were used (feature extraction, fine-tuning, etc.)
#   - ResNet50 with ResNet50_Weights.IMAGENET1K_V2 pretrained weights loaded when available; final layer replaced and the entire network fine-tuned (no layer freezing).
#   - Fallback to random initialization if pretrained weights fail to load.
#
# 4. Training Methodology
# - Hyperparameter selection method (if any)
#   - None; hyperparameters are fixed or set via environment variables. No grid/random search or cross-validation.
# - Training configuration (relevant parameters for the model type)
#   - Mixed precision training via torch.cuda.amp (autocast + GradScaler).
#   - Dataloaders with pin_memory and non_blocking transfers to device.
#   - BCEWithLogitsLoss on logits; sigmoid used only for metrics and inference.
#   - Label smoothing in training: labels = labels*(1 - ε) + 0.5*ε with ε=0.05.
#   - Scheduler stepped once per epoch.
# - Other important training details (early stopping, regularization, etc.)
#   - Regularization via weight decay (0.01).
#   - Best checkpoint saved by lowest validation logloss; training runs for the full number of epochs (no early stopping), then best model is reloaded for inference.
#   - Validation metrics reported each epoch: loss, logloss (custom), accuracy, runtime.
#
# 5. Evaluation & Submission
# - Final prediction method (mean, median, weighted average, etc.)
#   - Direct sigmoid probabilities from model logits for each test image; no ensembling or averaging.
# - Post-processing of predictions
#   - None beyond sorting by ID and formatting to 6 decimal places in CSV with headers [id, label].
#   - Fallback behavior: if no training data or on fatal error, writes 0.5 probability for all test IDs.
#
# 6. Notable Implementation Details
# - Computational considerations (GPU usage, runtime optimizations)
#   - GPU used if available; mixed precision to speed up and reduce memory.
#   - cuDNN benchmark enabled for performance; DataLoader pin_memory and non_blocking transfers.
#   - Cosine annealing LR schedule for stable training; pretrained backbone accelerates convergence.
#   - FAST_DEV mode reduces dataset size and epochs for rapid iteration.
# - Other unique approaches or novel techniques
#   - Label smoothing applied to a binary classification task with BCEWithLogitsLoss.
#   - Custom validation logloss computation using probabilities and manual clamp to avoid numerical issues.
# - Other significant aspects of the solution's approach
#   - Robust ID parsing from test filenames (digits-only fallback) and deterministic stratified splitting by label.
#   - Best model checkpoint reloaded before inference; graceful fallbacks to ensure a submission is produced.
#
# Solution ID: 336
# Score Percentile: 1.000000
#
# 1. Data Preprocessing
# - Data loading and splitting approaches
#   - Loads training images from /root/data/train; includes files with extensions [.jpg, .jpeg, .png, .bmp] whose names start with cat. or dog.
#   - Labels are parsed from filenames: cat. -> 0, dog. -> 1.
#   - Loads test images from /root/data/test; sorts by numeric id parsed from filename stem.
#   - Random holdout split: shuffles all train paths once, then uses first VAL_SPLIT fraction (default 0.05; 0.10 if FAST_DEV=1) as validation and the rest as training.
#   - DataLoaders: train uses shuffle=True; val/test shuffle=False; pin_memory=True; num_workers configurable (default up to 8).
# - Cleaning strategies (missing values, outliers, filtering)
#   - Filters files by valid image extensions and expected filename prefixes for train.
#   - No explicit handling of missing values, corrupt images, or outliers beyond Image.open(...).convert('RGB').
# - Transformations applied (scaling, encoding, type conversions)
#   - Images converted to RGB and then to tensors.
#   - Normalization with ImageNet mean/std: mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225].
#   - Labels are float32 tensors shaped [1] for BCEWithLogitsLoss.
# - Data augmentation techniques (if any)
#   - Train-time: RandomResizedCrop(224, scale=(0.7, 1.0)), RandomHorizontalFlip, RandomAutocontrast, ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.05).
#   - Val/Test-time: Resize(256), CenterCrop(224), normalization only (no augmentation).
# - Other preprocessing steps
#   - Seeds set for Python, OS hash, torch, and CUDA (if available) for reproducibility.
#   - FAST_DEV mode optionally subsamples data (up to 2000 train and 200 test images) for quicker runs.
#   - Test predictions are sorted by id before writing the submission.
#   - Probability clipping to [1e-6, 1 - 1e-6] at writeout.
#
# 2. Feature Engineering
# - New features that were created and their derivation
#   - None; the approach uses end-to-end CNN feature learning.
# - Feature selection or dimensionality reduction methods
#   - Not applicable.
# - Domain-specific transformations
#   - ImageNet-style normalization and common image augmentations (crop, flip, contrast, color jitter).
# - When no feature engineering was performed, note explicitly
#   - No handcrafted feature engineering beyond image augmentations and normalization.
#
# 3. Model Selection
# - The primary algorithm(s) used (exact model class/function)
#   - torchvision.models.resnet50(weights=torchvision.models.ResNet50_Weights.IMAGENET1K_V2).
#   - Final layer replaced with nn.Linear(in_features, 1) for binary classification.
# - Model hyperparameters (learning rate, depth, n_estimators, etc.)
#   - Learning rate: env LR (default 1e-4).
#   - Weight decay: env WEIGHT_DECAY (default 1e-4).
#   - Batch size: env BATCH_SIZE (default 64).
#   - Epochs: env EPOCHS (default 3).
#   - Loss: nn.BCEWithLogitsLoss.
# - Ensemble architecture (if any): stacking, blending, voting, etc.
#   - None.
# - Number of models in the ensemble (if applicable)
#   - Single model.
# - Pretrained models: which ones and how they were used (feature extraction, fine-tuning, etc.)
#   - Pretrained ResNet-50 (ImageNet1K V2 weights) fine-tuned end-to-end (no layers frozen).
#
# 4. Training Methodology
# - Hyperparameter selection method (if any)
#   - None; fixed hyperparameters (optionally via environment variables). No search or CV.
# - Training configuration (relevant parameters for the model type)
#   - Optimizer: AdamW over all model parameters.
#   - Scheduler: CosineAnnealingLR with T_max set to total_steps = ceil(len(train_loader) * EPOCHS), but stepped once per epoch (see note below).
#   - Mixed precision: torch.cuda.amp.autocast and GradScaler when CUDA is available.
#   - Dataloading: pin_memory, non_blocking transfers, multi-worker.
# - Other important training details (early stopping, regularization, etc.)
#   - Regularization via weight decay and data augmentation.
#   - Checkpointing: saves best model by lowest validation loss; training continues for all epochs (no early stopping).
#   - Seeded for reproducibility.
#   - Note: The CosineAnnealingLR is configured with T_max equal to the estimated number of training steps, but scheduler.step() is called per epoch, not per batch. This effectively makes the cosine schedule progress much slower than intended (nearly flat over a few epochs).
#
# 5. Evaluation & Submission
# - Final prediction method (mean, median, weighted average, etc.)
#   - Direct sigmoid of model logits; no ensembling or averaging (single-model predictions).
# - Post-processing of predictions
#   - Predictions sorted by id and probabilities clipped to [1e-6, 1 - 1e-6] for numerical stability.
#   - Submission CSV columns: id,label.
#
# 6. Notable Implementation Details
# - Computational considerations (GPU usage, runtime optimizations)
#   - Automatic mixed precision (train and inference) for speed and memory savings.
#   - Uses GPU if available; seeds CUDA for determinism.
#   - pin_memory=True and non_blocking=True to speed host-to-device transfers.
#   - NUM_WORKERS configurable; default capped at min(8, CPU count).
#   - FAST_DEV mode for rapid iteration on subsets of the data.
# - Other unique approaches or novel techniques
#   - None beyond standard transfer learning with a pretrained ResNet-50 and common augmentations.
# - Other significant aspects of the solution's approach
#   - Simple, single-model fine-tuning pipeline with a small validation split and best-checkpoint selection.
#   - Minor scheduler configuration mismatch (T_max vs step frequency) noted above.
#
# Solution ID: 355
# Score Percentile: 1.000000
#
# 1. Data Preprocessing
# - Data loading and splitting approaches
#   - Loads images from /root/data/train and /root/data/test using custom PyTorch Dataset classes (CatsDogsDataset for train/val with labels, TestDataset for test without labels).
#   - Labels are derived from filenames: cat.*.jpg mapped to 0, dog.*.jpg mapped to 1.
#   - Train/validation split via get_train_val_split with class-wise shuffling (seed=42) and a fixed val_ratio=0.1, selecting separate portions from cats and dogs to form validation and the remainder for training.
#   - When limiting dataset size (FAST_DEV_RUN), selection keeps approximate class balance by taking half from each class.
#   - DataLoaders: train uses shuffle=True; validation and test use shuffle=False. num_workers up to 8; pin_memory=True.
# - Cleaning strategies (missing values, outliers, filtering)
#   - No explicit cleaning of images or labels is performed.
#   - Robust ID parsing in TestDataset: attempts int(path.stem), falls back to stripping non-digits if necessary.
#   - If a runtime error occurs, a baseline submission is generated to avoid invalid submissions, but this is not data cleaning.
# - Transformations applied (scaling, encoding, type conversions)
#   - Train transforms: RandomResizedCrop(224), RandomHorizontalFlip(0.5), ColorJitter(0.2, 0.2, 0.2, 0.1), RandomAffine(degrees=15, translate=(0.1, 0.1)), ToTensor, Normalize with ImageNet mean [0.485, 0.456, 0.406] and std [0.229, 0.224, 0.225].
#   - Validation/test transforms: Resize to 1.15 × 224, CenterCrop(224), ToTensor, Normalize with ImageNet statistics.
#   - Type conversions: PIL Image opened and converted to RGB; transformed to PyTorch tensors. Labels converted to torch.float32 for BCEWithLogitsLoss.
# - Data augmentation techniques (if any)
#   - Yes: RandomResizedCrop, RandomHorizontalFlip, ColorJitter, RandomAffine applied in training.
# - Other preprocessing steps
#   - Test images are sorted by numeric ID before inference to align with submission format.
#   - Global seeds set for reproducibility (Python’s random, torch, torch.cuda).
#   - Optional FAST_DEV_RUN mode to limit dataset sizes and epochs for quick iterations (limit_train=1000, limit_val=200, limit_test=500, epochs=1, batch_size=16).
#
# 2. Feature Engineering
# - New features that were created and their derivation
#   - None. The model uses raw image pixels with standard augmentation and normalization.
# - Feature selection or dimensionality reduction methods
#   - None.
# - Domain-specific transformations
#   - Standard computer vision augmentations and ImageNet normalization; no handcrafted features.
# - When no feature engineering was performed, note explicitly
#   - No explicit feature engineering beyond image augmentations and normalization.
#
# 3. Model Selection
# - The primary algorithm(s) used (exact model class/function)
#   - torchvision.models.resnet50 with the final fully connected layer replaced by nn.Linear(in_features, 1) for binary classification, trained with nn.BCEWithLogitsLoss.
# - Model hyperparameters (learning rate, depth, n_estimators, etc.)
#   - Learning rate: 1e-3.
#   - Weight decay: 1e-4.
#   - Epochs: 6 (or 1 in FAST_DEV_RUN).
#   - Batch size: 64 (or 16 in FAST_DEV_RUN).
#   - Optimizer: AdamW.
#   - LR scheduler: CosineAnnealingLR with T_max = epochs × number of training batches, stepped every batch.
# - Ensemble architecture (if any): stacking, blending, voting, etc.
#   - None; a single model is used.
# - Number of models in the ensemble (if applicable)
#   - Not applicable.
# - Pretrained models: which ones and how they were used (feature extraction, fine-tuning, etc.)
#   - ResNet50 initialized with weights=models.ResNet50_Weights.IMAGENET1K_V2 if available; falls back to randomly initialized weights if loading fails.
#   - Full fine-tuning (no layers are frozen).
#
# 4. Training Methodology
# - Hyperparameter selection method (if any)
#   - None; fixed hyperparameters are used (with optional FAST_DEV_RUN overrides).
# - Training configuration (relevant parameters for the model type)
#   - Loss: BCEWithLogitsLoss for binary classification.
#   - Optimizer: AdamW with lr=1e-3, weight_decay=1e-4.
#   - Scheduler: CosineAnnealingLR stepped each batch; T_max based on total training steps.
#   - Mixed precision: torch.cuda.amp autocast and GradScaler enabled when using CUDA.
#   - DataLoader settings: shuffle=True for training; num_workers up to 8; pin_memory=True.
# - Other important training details (early stopping, regularization, etc.)
#   - Early stopping with patience=2 based on validation loss; best model checkpoint saved to /workspace/best_model.pth and reloaded after training.
#   - Validation metrics: computes loss and accuracy using a 0.5 threshold on sigmoid probabilities.
#   - Regularization via weight decay only; no dropout or other explicit regularization.
#   - Reproducibility: random seeds set for Python, torch, and CUDA.
#
# 5. Evaluation & Submission
# - Final prediction method (mean, median, weighted average, etc.)
#   - Direct sigmoid outputs used as predicted probabilities for “dog” class; one prediction per test image.
# - Post-processing of predictions
#   - Predictions are clamped to [1e-6, 1 - 1e-6] for numerical stability before writing CSV.
#   - Submission rows sorted by ascending ID; CSV header “id,label”.
#   - Fallback: if an error occurs, writes a baseline submission with label=0.5 for all test IDs.
#
# 6. Notable Implementation Details
# - Computational considerations (GPU usage, runtime optimizations)
#   - Automatic CUDA device selection; AMP mixed precision to speed up and reduce memory on GPU.
#   - DataLoader parallelism with up to 8 workers and pinned memory to improve throughput.
#   - FAST_DEV_RUN mode for rapid iteration with smaller datasets and fewer epochs.
#   - CosineAnnealingLR configured over total training steps and stepped per batch for smooth LR decay.
# - Other unique approaches or novel techniques
#   - Robust test ID parsing that handles non-numeric stems.
#   - Defensive coding: baseline submission generated on exceptions to avoid failing the competition submission step.
# - Other significant aspects of the solution's approach
#   - Class-aware splitting ensures both cats and dogs appear in train and validation sets; balancing preserved when subsampling.
#   - Pretrained ResNet50 fine-tuning with a simple binary head; validation/test transforms use resize + center crop for consistent evaluation.
#
# Solution ID: 356
# Score Percentile: 1.000000
#
# 1. Data Preprocessing
# - Data loading and splitting approaches
#   - Training images loaded by listing .jpg files in train_dir, sorted for reproducibility.
#   - Test images loaded by listing .jpg files in test_dir, parsing numeric IDs from filenames, sorted by ID.
#   - Random 90/10 train/validation split using val_frac=0.1 after seeding for reproducibility.
#   - PyTorch DataLoader used with shuffle=True for train, shuffle=False for val/test; num_workers=8, pin_memory=True.
# - Cleaning strategies (missing values, outliers, filtering)
#   - No explicit cleaning for missing values, outliers, or filtering beyond file extension checks.
#   - PIL configured to allow loading truncated images (ImageFile.LOAD_TRUNCATED_IMAGES=True).
# - Transformations applied (scaling, encoding, type conversions)
#   - Images converted to RGB via PIL.
#   - Training transforms: RandomResizedCrop(size derived from ResNet50 weights, scale=(0.8, 1.0)), RandomHorizontalFlip, ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.05), ToTensor, Normalize with ResNet50 IMAGENET1K_V2 mean/std.
#   - Validation/Test transforms: Resize(256), CenterCrop(size), ToTensor, Normalize with ResNet50 IMAGENET1K_V2 mean/std.
#   - Labels derived from filenames: 'dog' -> 1.0, else 0.0, stored as float32 tensors with shape [1].
# - Data augmentation techniques (if any)
#   - Training augmentation: random resized crop, horizontal flip, color jitter.
#   - Test-time augmentation (TTA): horizontal flip; final prediction is mean of original and flipped probabilities.
# - Other preprocessing steps
#   - Global seeding for reproducibility (random, PYTHONHASHSEED, torch, cuda).
#   - Consistent image size and normalization taken from pretrained weights’ recommended transforms.
#   - File listing order sorted to ensure reproducible splits.
#
# 2. Feature Engineering
# - New features that were created and their derivation
#   - None; raw images used directly with CNN.
# - Feature selection or dimensionality reduction methods
#   - None.
# - Domain-specific transformations
#   - Imagenet-style normalization and size/crop consistent with ResNet50 pretrained weights.
# - When no feature engineering was performed, note explicitly
#   - No feature engineering beyond standard image transforms.
#
# 3. Model Selection
# - The primary algorithm(s) used (exact model class/function)
#   - torchvision.models.resnet50 (ResNet-50).
#   - Final fully connected layer replaced with nn.Linear(in_features, 1) for binary classification.
#   - Loss: nn.BCEWithLogitsLoss.
# - Model hyperparameters (learning rate, depth, n_estimators, etc.)
#   - Architecture depth: ResNet-50.
#   - Learning rate: 3e-4.
#   - Weight decay: 1e-4.
#   - Batch size: 64 (reduced in fast_dev_run).
#   - Epochs: warmup=1 (freeze backbone), full=4 (fine-tune all).
#   - Scheduler: CosineAnnealingLR(T_max=epochs_full).
#   - Data augmentation parameters: crop scale (0.8, 1.0), flip probability default (0.5), ColorJitter as specified.
# ...
# - Data augmentation techniques (if any): Training uses RandomResizedCrop(scale=(0.8,1.0)), RandomHorizontalFlip, ColorJitter (0.1,0.1,0.1,0.05), and RandomRotation(10). Test-time augmentation (TTA) averages predictions from the base transform and a forced horizontal flip when tta >= 2.
# - Other preprocessing steps: Test files are sorted by numeric ID before inference. Reproducibility seeds are set for Python’s random and Torch (CPU/GPU). A fast_dev_run option limits data to a small subset and reduces epochs for quick iteration.
#
# 2. Feature Engineering
# - New features that were created and their derivation: None; the model learns features directly from images.
# - Feature selection or dimensionality reduction methods: None.
# - Domain-specific transformations: Standard vision augmentations and ImageNet normalization are applied; no custom domain-specific feature transforms beyond this.
# - When no feature engineering was performed, note explicitly: No manual feature engineering was performed.
#
# 3. Model Selection
# - The primary algorithm(s) used (exact model class/function): A timm vision backbone created via timm.create_model(cfg.model_name, num_classes=1). Default backbone is tf_efficientnet_b0_ns.
# - Model hyperparameters (learning rate, depth, n_estimators, etc.): AdamW optimizer with lr=2e-4 and weight_decay=1e-4; batch_size=64; image_size=224; epochs=10; warmup_epochs=1; amp=True (mixed precision); val_ratio=0.1; tta=2. CosineAnnealingLR scheduler with T_max set to total epochs (and reconfigured after unfreezing).
# - Ensemble architecture (if any): None; a single model is trained. TTA averages two augmented predictions at inference but does not constitute a model ensemble.
# - Number of models in the ensemble (if applicable): Not applicable (single model).
# - Pretrained models: which ones and how they were used (feature extraction, fine-tuning, etc.): Uses pretrained weights for tf_efficientnet_b0_ns when available. The classification head is set to output one logit (num_classes=1). Backbone is frozen for the warmup phase (head-only training), then the entire model is unfrozen for fine-tuning.
#
# 4. Training Methodology
# - Hyperparameter selection method (if any): None; hyperparameters are fixed from the Config.
# - Training configuration (relevant parameters for the model type): Binary classification trained with BCEWithLogits loss. Mixed precision training via torch.cuda.amp with GradScaler. Warmup phase trains only the head; after warmup, all parameters are unfrozen, and the optimizer/scheduler are reinitialized. DataLoaders use pin_memory and multiple workers.
# - Other important training details (early stopping, regularization, etc.): Regularization via weight_decay=1e-4 (AdamW). CosineAnnealingLR scheduling. Best checkpoint selection based on validation log loss (saved whenever val_loss improves); no explicit early stopping—training runs all epochs. Reproducibility seeds are set. Validation metrics include log loss and accuracy.
#
# 5. Evaluation & Submission
# - Final prediction method (mean, median, weighted average, etc.): For each test image, probabilities from base transform (center-crop pipeline) and an explicit horizontal flip version are averaged (simple mean) when tta>=2; otherwise, a single prediction is used.
# - Post-processing of predictions: Sigmoid applied to logits to obtain probabilities. Predictions are written directly to CSV (id,label) with test files sorted by numeric ID. A fallback mechanism writes 0.5 for all test IDs if an unrecoverable error occurs.
#
# 6. Notable Implementation Details
# - Computational considerations (GPU usage, runtime optimizations): Automatic device selection (CUDA if available). Mixed precision (autocast + GradScaler) reduces memory and speeds training/inference. pin_memory and multi-worker DataLoaders improve throughput. Backbone freezing during warmup reduces compute initially. Fast-dev mode enables rapid iteration by limiting data and epochs.
# - Other unique approaches or novel techniques: Manual per-class validation split ensures class balance in validation. Simple, robust freezing/unfreezing strategy keyed on parameter names ('classifier'/'fc') to keep the head trainable initially. Test-time augmentation via horizontal flip averaging.
# - Other significant aspects of the solution's approach: Uses ImageNet normalization and common augmentation schemes appropriate for transfer learning. Saves and reloads the best checkpoint by validation log loss. No cross-validation, stacking, or external data; straightforward fine-tuning pipeline focused on a strong pretrained backbone.
#
# Part 2: Performance Analysis
# High-Scoring Solutions (percentile ≥ 0.7)
# Below is a concise breakdown for each listed high-scoring solution. For each, I highlight concrete technical choices, the key strengths they confer, and how well they align with the task’s metric (log loss) and practical challenges (small dataset, calibration, robustness, submission schema).
#
# Solution 304
# - Why it works (technical choices)
#   - Transfer learning: torchvision resnet18 with ImageNet weights; head replaced with a single logit (binary).
#   - Data pipeline: strong but standard aug (RandomResizedCrop, HFlip, ColorJitter); ImageNet normalization; stratified split by filename prefix.
#   - Loss/optimization: BCEWithLogitsLoss with pos_weight computed from class counts (good if imbalance); AdamW; AMP; cosine LR schedule.
#   - Validation/inference: computes validation logloss explicitly from sigmoid probabilities and checkpoints best; test-time horizontal flip TTA; sorts test IDs by numeric regex.
# - Key strengths
#   - Good calibration focus (explicit logloss and TTA).
#   - Class-imbalance robustness via pos_weight.
#   - Robust to different dataset layouts; uses pinned memory and workers for speed.
# - Alignment with task
#   - Directly optimizes/monitors log loss and outputs probabilities; handles ID sorting and Kaggle schema; aug + pretrained backbone reduce overfitting on small data.
#
# Solution 316
# - Why it works
#   - Backbone: EfficientNet-B0 pretrained; resilient fallback to ResNet50 or minimal CNN.
#   - Augs: RandomResizedCrop, HFlip, mild ColorJitter; ImageNet normalization.
#   - BCEWithLogitsLoss (binary), AdamW, CosineAnnealingLR, AMP.
#   - TTA (HFlip) at inference; stratified split; numeric sort for submission.
# - Key strengths
#   - Strong, efficient backbone with robust fallbacks; good generalization-speed trade-off.
#   - Calibrated probability focus and TTA for variance reduction.
# - Alignment with task
#   - Binary BCE aligns to logloss; explicit val loss tracking; probability outputs; sorted IDs.
#
# Solution 317
# - Why it works
#   - Backbone: ResNet50 (IMAGENET1K_V2) as binary head.
#   - Augs: RandomResizedCrop + stronger ColorJitter; AMP; AdamW; cosine LR; early stopping.
#   - Validation computes both BCE loss and accuracy; best checkpoint by val loss; robust ID parsing.
# - Key strengths
#   - High-capacity pretrained model; early stopping prevents overfit.
#   - Good training stability; persistent_workers/data loader fallback handling.
# - Alignment with task
#   - Binary BCE -> calibrated probabilities; logloss monitoring and best checkpointing; sorted submission.
#
# Solution 325
# - Why it works
#   - Backbone: ConvNeXt-Tiny via timm (pretrained), fallback to ResNet50.
#   - Two-class CrossEntropy (softmax to probability of dog).
#   - OneCycleLR (or disabled in fast mode); AMP; rich aug; checkpoint best by val loss.
# - Key strengths
#   - Modern strong backbone; well-implemented training loop; robust fallback.
#   - Solid calibration via CE and softmax; good speed.
# - Alignment with task
#   - Outputs well-formed probabilities; val loss as selection proxy; sorted IDs; aug tuned for small dataset.
#
# Solution 334
# - Why it works
#   - ResNet50 pretrained; BCEWithLogitsLoss.
#   - Label smoothing applied to targets (soft labels into BCE) to reduce overconfidence and improve calibration/logloss.
#   - CosineAnnealingLR; explicit validation logloss computation; checkpoint on logloss.
# - Key strengths
#   - Calibration-first design (label smoothing + logloss selection).
#   - Balanced stratified split; clean aug; AMP.
# - Alignment with task
#   - Directly optimizes the metric it selects by; outputs probabilities; sorts IDs and schema compliance.
#
# Solution 336
# - Why it works
#   - ResNet50 pretrained; single-logit BCEWithLogits.
#   - Augs include RandomAutocontrast + ColorJitter; robust loaders; normalization aligned to ImageNet weights.
#   - Cosine LR; AMP; checkpoint best by val loss.
# - Key strengths
#   - Strong generalization with good aug variety; robust image IO; stability.
# - Alignment with task
#   - Produces calibrated probabilities; focuses on loss; sorts by id; clamps probabilities for numerical stability (logloss-safe).
#
# Solution 355
# - Why it works
#   - ResNet50 pretrained; BCEWithLogits; augmentations with HFlip, ColorJitter, RandomAffine.
#   - CosineAnnealingLR stepped per batch (T_max as total steps); early stopping; stratified split; AMP.
# - Key strengths
#   - Enhanced geometric aug reduces overfitting; early stop accelerates convergence.
#   - Efficient training setup; robust dataset/split.
# - Alignment with task
#   - Probability outputs; val loss selection; sorted IDs; aug + pretraining suits small dataset/logloss.
#
# Solution 356
# - Why it works
#   - ResNet50 pretrained; warmup with frozen backbone then unfreeze; cosine LR; BCEWithLogits.
#   - Transforms derived from weights.transforms for exact normalization/crop; TTA via HFlip; AMP; checkpointing best.
# - Key strengths
#   - Proper fine-tuning schedule stabilizes training and improves final performance.
#   - Using pretrained transform metadata reduces mismatch risk.
# - Alignment with task
#   - Outputs dog probabilities; val loss alignment; TTA helps calibration/variance; sorted IDs.
#
# Solution 360
# - Why it works
#   - ResNet50 pretrained; BCEWithLogits; stratified split; standard aug.
#   - CosineAnnealingLR; AMP; plenty of robustness (install fallbacks, dummy images, sample_submission ordering).
# - Key strengths
#   - Highly robust pipeline; memory-safe settings; clean normalization.
# - Alignment with task
#   - Proper probabilistic outputs; val loss focus; submission sorted.
#
# Solution 363
# - Why it works
#   - EfficientNet-B0 (pretrained) with 2-class CE; strong aug using AutoAugment (ImageNet policy) plus RandomResizedCrop/HFlip.
#   - OneCycleLR; AMP; TTA HFlip; stratified split; ID sort.
# - Key strengths
#   - Strong augment policy (AutoAugment) improves generalization.
#   - EfficientNet + CE produce well-calibrated probabilities; TTA adds robustness.
# - Alignment with task
#   - Probability of dog via softmax; monitors validation; sorted output.
#
# Solution 364
# - Why it works
#   - EfficientNet-B0 or ResNet50 fallback; CrossEntropy with label_smoothing=0.1.
#   - Validation logloss explicitly computed; cosine annealing; robust transforms; stratified split.
# - Key strengths
#   - Calibration via label smoothing; explicit logloss measurement.
#   - Good fallbacks and normalization; robust I/O and sorting.
# - Alignment with task
#   - Targets the leaderboard metric; outputs probabilities; handles naming variability.
#
# Solution 369
# - Why it works
#   - Binary head on EfficientNet-B0 (or ResNet50) with BCEWithLogits.
#   - Clean aug; stratified split; explicit log_loss computation on validation and best-state tracking.
#   - AMP; robust test id sorting.
# - Key strengths
#   - Focus on probability calibration; efficient training; flexible backbone.
# - Alignment with task
#   - Directly optimizes a proxy aligned with logloss; produces probabilities; addresses small dataset with transfer.
#
# Solution 374
# - Why it works
#   - EfficientNet-B0 (pretrained) as 2-class CE classifier; strong aug set; stratified split.
#   - Validates with logloss; robust subset options; normalization/resize/center-crop.
# - Key strengths
#   - Efficient backbone; clean, simple pipeline; focuses on val logloss.
# - Alignment with task
#   - Softmax probabilities; sorts IDs; aligns validation with leaderboard metric.
#
# Solution 376
# - Why it works
#   - timm (tf_efficientnet_b0_ns) pretrained (or torchvision fallback); single-logit BCEWithLogits.
#   - Solid augs; CosineAnnealingLR; AMP; TTA flip; robust image loading with retries.
# - Key strengths
#   - Strong model selection and TTA; resilience to I/O hiccups; good normalization.
# - Alignment with task
#   - Probability outputs; val loss monitoring; sorted IDs.
#
# Solution 379
# - Why it works
#   - ResNet50 pretrained; BCEWithLogits; warmup by freezing FC first then full fine-tuning; cosine annealing; AMP.
#   - Stratified 90/10; robust transforms from ResNet50 weights; stable dataloaders.
# - Key strengths
#   - Two-phase training stabilizes and improves convergence.
#   - Efficient and robust pipeline.
# - Alignment with task
#   - Outputs calibrated probabilities; tracks val loss; correct submission ordering.
#
# Solution 395
# - Why it works
#   - timm ConvNeXt-Tiny preferred; fallback ResNet34; BCEWithLogits; cosine LR; AMP.
#   - Standard aug; best-checkpoint by val loss; robust install fallbacks.
# - Key strengths
#   - Strong SOTA-like backbone; calibration via BCE; robust deployments.
# - Alignment with task
#   - Probability outputs; validation-based selection; correct schema/order.
#
# Solution 398
# - Why it works
#   - ResNet50 pretrained; 2-class CrossEntropy; cosine annealing; AMP.
#   - Stratified split; clean augs; standard normalization; robust I/O.
# - Key strengths
#   - High-capacity backbone with stable training; efficient data pipeline.
# - Alignment with task
#   - Softmax probabilities for submission; selection by val loss; proper sorting. (CE aligns closely with logloss.)
#
# Solution 413
# - Why it works
#   - timm EfficientNet-B0 preferred; fallback ResNet18; BCEWithLogits; standard aug; AMP.
#   - Simple training loop with batch logs; robust minimal fallback transforms if torchvision is missing.
# - Key strengths
#   - Strong model with simple, reliable training; resilient to environment variability.
# - Alignment with task
#   - Probabilities via sigmoid; val loss monitoring; submission sorted and clipped.
#
# Solution 414
# - Why it works
#   - EfficientNet-B0 or ResNet18; BCEWithLogits; OneCycleLR stepped per batch (inside train loop); AMP.
#   - Stratified split; robust id parsing and fallback logic.
# - Key strengths
#   - Good scheduling (OneCycle) and AMP synergy; clean data handling.
# - Alignment with task
#   - Produces probabilities; selects best by val loss; conforms to schema/order.
#
# Solution 442
# - Why it works
#   - timm tf_efficientnet_b0_ns with binary head; BCEWithLogits; warmup with frozen backbone then unfreeze; cosine annealing.
#   - Strong aug mix; explicit validation logloss computation; TTA (HFlip).
# - Key strengths
#   - Calibration-first metric (val logloss); fine-tuning schedule and TTA enhance generalization and probability quality.
# - Alignment with task
#   - Outputs probabilities; best by logloss; numeric sort; well-suited to small, overfit-prone dataset.
#
# General throughline across these solutions:
# - Transfer learning on ImageNet backbones (ResNet50, EfficientNet, ConvNeXt) provides strong feature priors for a small dataset.
# - Probability-focused losses (BCEWithLogits or 2-class CE) plus explicit validation logloss and sometimes label smoothing improve calibration—critical for logloss.
# - Thoughtful augmentation (RandomResizedCrop, flips, color and mild geometry) controls overfitting; TTA further improves robustness.
# - AMP, AdamW, and cosine/OneCycle scheduling give stable, efficient training.
# - Stratified splits, robust filename parsing, and sorted numeric IDs prevent leakage or submission errors.
#
# Medium-Scoring Solutions (0.4 ≤ percentile < 0.7)
# None. No medium-scoring valid submissions in the dataset.
#
# Low-Scoring Solutions (percentile < 0.4)
# None. No low-scoring valid submissions in the dataset.

# %% [markdown]
# # Iteration #0

# %%
iteration_id = 0
iteration = iterations[iteration_id] if iterations else None

if iteration:
    print(f"=================  Iteration {iteration_id} (#{iteration.get('iteration', 'N/A')}) =====================")
    print(f"Keys in  iteration {iteration_id} : {list(iteration.keys())}")
    

    # Check LLM response
    print(f"\n================= LLM Response in Iteration {iteration_id} =====================")
    response = iteration.get("response", "")
    print(f"Response:\n...{response}" )


    # Check code blocks in iteration
    code_blocks = iteration.get("code_blocks", [])
    print(f"\nNumber of code blocks: {len(code_blocks)}")
    
    for i, block in enumerate(code_blocks):
        print(f"\n======================================== Code Block {i} =======================================")
        # code = block.get("code", "")
        # print(f"\n----------------------- Code Block {i} Code ------------------")

        # print(f"Code: {code}")
        
        result = block.get("result", {})
        stdout = result.get("stdout", "")
        stderr = result.get("stderr", "")
        
        if stdout:
            print(f"\n----------------------- Code Block {i} Stdout ------------------")

            print(f"\nStdout:\n{stdout}" )
        if stderr:
            print(f"\n----------------------- Code Block {i} Stderr ------------------")
            print(f"\nStderr:\n{stderr}")
    

else:
    print("No iterations found!")
# Out:
# =================  Iteration 0 (#1) =====================
# Keys in  iteration 0 : ['type', 'iteration', 'timestamp', 'prompt', 'response', 'code_blocks', 'final_answer', 'iteration_time']
#
# ================= LLM Response in Iteration 0 =====================
# Response:
# ...```repl
# # Explore the rollout_df to understand available tasks and filter for the target competition
# print("Shape:", rollout_df.shape)
# print("Columns:", list(rollout_df.columns))
#
# # Show first few entries to inspect structure
# print(rollout_df.head(3)[["task_name", "valid_submission", "percentile"]])
#
# # Unique task names to ensure the target exists
# unique_tasks = rollout_df["task_name"].unique()
# print("Unique task names:", unique_tasks)
#
# # Count rows per task
# print(rollout_df.groupby("task_name").size().sort_values(ascending=False))
#
# # Filter for the target task
# target = "freesound-audio-tagging-2019"
# df_target = rollout_df[rollout_df["task_name"] == target]
# print("Rows for target task:", df_target.shape[0])
#
# # Check valid submissions for the target task
# df_valid = df_target[df_target["valid_submission"] == True]
# print("Valid submissions for target:", df_valid.shape[0])
#
# # Inspect percentiles of valid submissions
# print(df_valid[["percentile"]].describe())
#
# # Part 0: Task context from rollout_df["task_description"].iloc[0]
# # Note: As instructed, we use task_description from the overall dataframe's first row
# task_desc_0 = rollout_df["task_description"].iloc[0]
# print("Length of task_description[0]:", len(task_desc_0))
# print(task_desc_0[:1000])
#
# # Prepare to analyze each valid solution's code
# # Extract indices, percentiles, and code
# valid_indices = df_valid.index.tolist()
# print("Valid indices:", valid_indices)
#
# records = []
# for idx in valid_indices:
#     rec = {
#         "index": idx,
#         "percentile": rollout_df.loc[idx, "percentile"],
#         "code": rollout_df.loc[idx, "code"],
#         "eval_error_output": rollout_df.loc[idx, "eval_error_output"],
#         "rollout_duration": rollout_df.loc[idx, "rollout_duration"],
#         "eval_duration": rollout_df.loc[idx, "eval_duration"],
#     }
#     records.append(rec)
#
# # Show brief info for each valid record
# for r in records[:5]:
#     print("Record idx:", r["index"], "percentile:", r["percentile"], "code length:", (len(r["code"]) if r["code"] else None))
#
# # Build batched prompts to analyze code per the template for Part 1
# prompts = []
# for r in records:
#     code_str = r["code"] if r["code"] else ""
#     prompt = f"""
# You are analyzing a Kaggle solution code for the competition 'freesound-audio-tagging-2019'.
# Follow this structured template in your analysis:
# 1) Data Preprocessing: describe loading, splitting, cleaning, transformations, augmentations, other steps actually implemented.
# 2) Feature Engineering: list any created features, selection/dim reduction, domain-specific transforms; explicitly note if none.
# 3) Model Selection: primary algorithms/classes used; hyperparameters; any ensembles (stacking/blending/voting), number of models; pretrained models and roles.
# 4) Training Methodology: hyperparameter selection, training config, early stopping, regularization, other important training details.
# 5) Evaluation & Submission: final prediction method and post-processing.
# 6) Notable Implementation Details: computational considerations, runtime optimizations, unique techniques.
#
# Cite specific code fragments or function names when possible.
#
# Here is the code to analyze:
# {code_str}
# """
#     prompts.append(prompt)
#
# # Run batched analysis for code
# analysis_outputs = llm_query_batched(prompts)
#
# # Store structured analyses alongside metadata
# sol_summaries = []
# for r, analysis in zip(records, analysis_outputs):
#     sol_summaries.append({
#         "index": r["index"],
#         "percentile": r["percentile"],
#         "summary": analysis
#     })
#
# # Print a couple of summaries to inspect
# for s in sol_summaries[:3]:
#     print(f"Index {s['index']} (percentile {s['percentile']}):")
#     print(s["summary"][:1200])
#     print("----")
#
# # Part 0 detailed analysis: derive problem type, domain, input format, metric, key challenges
# # Use the task description string to extract the requested elements
# part0_prompt = f"""
# Read the following task description and answer concisely:
# 1) Problem Type (Classification/Regression/etc.)
# 2) Domain (application)
# 3) Input Format (Images/Tabular/Text/Audio/etc.)
# 4) Evaluation Metric (name and what it optimizes)
# 5) Key Challenges
#
# Task description:
# {task_desc_0}
# """
# part0_answer = llm_query(part0_prompt)
# print(part0_answer)
#
# # Part 2: Performance Analysis
# # Split solutions into high, medium, low by percentile thresholds
# high = [s for s in sol_summaries if s["percentile"] is not None and s["percentile"] >= 0.7]
# medium = [s for s in sol_summaries if s["percentile"] is not None and 0.4 <= s["percentile"] < 0.7]
# low = [s for s in sol_summaries if s["percentile"] is not None and s["percentile"] < 0.4]
#
# # Build prompts to analyze "why it works" for high-scoring solutions, using their summaries and code
# perf_prompts = []
# for s in high:
#     idx = s["index"]
#     code_str = rollout_df.loc[idx, "code"] or ""
#     prompt = f"""
# You have a high-scoring solution for 'freesound-audio-tagging-2019' with percentile {s['percentile']}.
# Based on the following structured summary and the code, explain:
# - Why it works: specific technical choices contributing most to score (cite evidence).
# - Key strengths vs. lower-scoring solutions.
# - Alignment with task and evaluation metric/challenges from Part 0.
#
# Summary:
# {s['summary']}
#
# Code:
# {code_str}
# """
#     perf_prompts.append(prompt)
#
# # Build prompts for low-scoring solutions
# for s in low:
#     idx = s["index"]
#     code_str = rollout_df.loc[idx, "code"] or ""
#     prompt = f"""
# You have a low-scoring solution for 'freesound-audio-tagging-2019' with percentile {s['percentile']}.
# Identify failure points:
# - Critical omissions, poor choices, or implementation issues causing low score.
# - Cite code evidence and contrast with high-scoring approaches.
# - Concrete changes likely to improve performance.
#
# Summary:
# {s['summary']}
#
# Code:
# {code_str}
# """
#     perf_prompts.append(prompt)
#
# # Build prompts for medium-scoring solutions (brief notes)
# for s in medium:
#     idx = s["index"]
#     code_str = rollout_df.loc[idx, "code"] or ""
#     prompt = f"""
# You have a medium-scoring solution with percentile {s['percentile']}.
# Briefly note:
# - What's working reasonably well.
# - Most likely bottleneck preventing higher performance.
#
# Summary:
# {s['summary']}
#
# Code:
# {code_str}
# """
#     perf_prompts.append(prompt)
#
# # Run batched analysis for performance
# perf_outputs = llm_query_batched(perf_prompts)
#
# # Map outputs back to categories in order constructed
# num_high = len(high)
# num_low = len(low)
# num_medium = len(medium)
#
# high_perf = perf_outputs[:num_high]
# low_perf = perf_outputs[num_high:num_high+num_low]
# medium_perf = perf_outputs[num_high+num_low:]
#
# # Compose the final answer text
# # Part 1 summaries
# part1_text_chunks = []
# for s in sol_summaries:
#     identifier = f"row_index_{s['index']}"
#     part1_text_chunks.append(
#         f"Solution ID: {identifier}\nScore Percentile: {s['percentile']}\n\n{s['summary']}\n"
#     )
# part1_text = "\n".join(part1_text_chunks)
#
# # Part 2 performance analysis text
# perf_text = []
# if num_high > 0:
#     for s, out in zip(high, high_perf):
#         perf_text.append(f"High-Scoring Solution (index {s['index']}, percentile {s['percentile']}):\n{out}\n")
# if num_low > 0:
#     for s, out in zip(low, low_perf):
#         perf_text.append(f"Low-Scoring Solution (index {s['index']}, percentile {s['percentile']}):\n{out}\n")
# if num_medium > 0:
#     for s, out in zip(medium, medium_perf):
#         perf_text.append(f"Medium-Scoring Solution (index {s['index']}, percentile {s['percentile']}):\n{out}\n")
# part2_text = "\n".join(perf_text)
#
# # Build the final_answer string with required sections
# final_answer = (
#     "Part 0: Task Analysis\n"
#     + part0_answer.strip()
#     + "\n\nPart 1: Individual Solution Summaries (valid submissions only)\n"
#     + part1_text
#     + "\n\nPart 2: Performance Analysis\n"
#     + part2_text
# )
#
# # Verify final_answer variable exists
# print("final_answer" in dir())
# ```
#
# Number of code blocks: 1
#
# ======================================== Code Block 0 =======================================
#
# ----------------------- Code Block 0 Stdout ------------------
#
# Stdout:
# Shape: (64, 9)
# Columns: ['task_name', 'task_description', 'code', 'percentile', 'valid_submission', 'eval_error_output', 'eval_duration', 'rollout_duration', 'rollout']
#                          task_name  valid_submission  percentile
# 1692  freesound-audio-tagging-2019             False         0.0
# 1697  freesound-audio-tagging-2019             False         0.0
# 1698  freesound-audio-tagging-2019             False         0.0
# Unique task names: <StringArray>
# ['freesound-audio-tagging-2019']
# Length: 1, dtype: str
# task_name
# freesound-audio-tagging-2019    64
# dtype: int64
# Rows for target task: 64
# Valid submissions for target: 26
#        percentile
# count   26.000000
# mean     0.484174
# std      0.235181
# min      0.090909
# 25%      0.289474
# 50%      0.529904
# 75%      0.655502
# max      1.000000
# Length of task_description[0]: 27041
# # Overview
#
# ## Description
#
# One year ago, Freesound and Google's Machine Perception hosted an audio tagging competition challenging Kagglers to build a general-purpose auto tagging system. This year they're back and taking the challenge to the next level with multi-label audio tagging, doubled number of audio categories, and a *noisier than ever* training set. If you like raising your ML game, this challenge is for you.
#
# ![Freesound](https://storage.googleapis.com/kaggle-media/competitions/freesound/task2_freesound_audio_tagging.png)
#
# Here's the background: Some sounds are distinct and instantly recognizable, like a baby's laugh or the strum of a guitar. Other sounds are difficult to pinpoint. If you close your eyes, could you tell the difference between the sound of a chainsaw and the sound of a blender?
#
# Because of the vastness of sounds we experience, no reliable automatic general-purpose audio tagging systems exist. A significant amount of manual effort goes into tasks like annotat
# Valid indices: [1727, 1784, 1789, 1791, 1803, 1815, 1816, 1817, 1828, 1830, 1835, 1842, 1851, 1853, 1865, 1867, 1871, 1884, 1896, 1900, 1913, 1916, 1917, 1928, 1953, 1985]
# Record idx: 1727 percentile: 0.7751196172 code length: 19105
# Record idx: 1784 percentile: 0.37320574160000003 code length: 15978
# Record idx: 1789 percentile: 0.2846889952 code length: 18127
# Record idx: 1791 percentile: 0.6339712919 code length: 18539
# Record idx: 1803 percentile: 0.2392344498 code length: 16202
# [llm_query_batched] Calling LM with 26 prompts...
# [llm_query_batched] All 26 responses received in 300.1s
# Index 1727 (percentile 0.7751196172):
# Error: Request failed: timed out
# ----
# Index 1784 (percentile 0.37320574160000003):
# Error: Request failed: timed out
# ----
# Index 1789 (percentile 0.2846889952):
# Error: Request failed: timed out
# ----
# [llm_query] Calling LM with prompt:  Read the following task description and answer concisely: 1) Problem Type (Clas...
# [Azure OpenAI] Calling gpt-5 (attempt 1/64)...
# Rate limit hit, retrying in 8.0s (attempt 1/64)...
# [Azure OpenAI] Response received in 26.0s
# [llm_query] Response received in 26.0s
# 1) Problem Type: Multi-label classification (audio tagging)
# 2) Domain: General-purpose sound event recognition/audio tagging
# 3) Input Format: Audio clips (.wav, 44.1 kHz mono)
# 4) Evaluation Metric: Label-weighted Label-Ranking Average Precision (lwlrap) — optimizes per-label average precision of the ranked predicted probabilities, giving equal weight to each label
# 5) Key Challenges: Noisy labels in training data; domain mismatch between train (YFCC) and test (FSD); weak clip-level labels (no timestamps); large, imbalanced multi-label vocabulary; variable-length audio; kernels-only compute/runtime constraints without external/pretrained models
# [llm_query_batched] Calling LM with 26 prompts...
# [llm_query_batched] All 26 responses received in 216.1s
# True
#
#
# ----------------------- Code Block 0 Stderr ------------------
#
# Stderr:
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 45900)
# Traceback (most recent call last):
#   File "/storage/home/winnieyangwn/rlm/rlm/core/lm_handler.py", line 40, in handle
#     socket_send(self.connection, response.to_dict())
#   File "/storage/home/winnieyangwn/rlm/rlm/core/comms_utils.py", line 152, in socket_send
#     sock.sendall(struct.pack(">I", len(payload)) + payload)
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/storage/home/winnieyangwn/.local/share/uv/python/cpython-3.11.14-linux-x86_64-gnu/lib/python3.11/socketserver.py", line 691, in process_request_thread
#     self.finish_request(request, client_address)
#   File "/storage/home/winnieyangwn/.local/share/uv/python/cpython-3.11.14-linux-x86_64-gnu/lib/python3.11/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/storage/home/winnieyangwn/.local/share/uv/python/cpython-3.11.14-linux-x86_64-gnu/lib/python3.11/socketserver.py", line 755, in __init__
#     self.handle()
#   File "/storage/home/winnieyangwn/rlm/rlm/core/lm_handler.py", line 44, in handle
#     socket_send(self.connection, response.to_dict())
#   File "/storage/home/winnieyangwn/rlm/rlm/core/comms_utils.py", line 152, in socket_send
#     sock.sendall(struct.pack(">I", len(payload)) + payload)
# BrokenPipeError: [Errno 32] Broken pipe
# ----------------------------------------

# %% [markdown]
# # Iteration #1

# %%
iteration_id = 1
iteration = iterations[iteration_id] if iterations else None

if iteration:
    print(f"=================  Iteration {iteration_id} (#{iteration.get('iteration', 'N/A')}) =====================")
    print(f"Keys in  iterxation {iteration_id} : {list(iteration.keys())}")
    

    # Check LLM response
    print(f"\n================= LLM Response in Iteration {iteration_id} =====================")
    response = iteration.get("response", "")
    print(f"Response:\n...{response}" )


    # Check code blocks in iteration
    code_blocks = iteration.get("code_blocks", [])
    print(f"\nNumber of code blocks: {len(code_blocks)}")
    
    for i, block in enumerate(code_blocks):
        print(f"\n======================================== Code Block {i} =======================================")
        # code = block.get("code", "")
        # print(f"\n----------------------- Code Block {i} Code ------------------")

        # print(f"Code: {code}")
        
        result = block.get("result", {})
        stdout = result.get("stdout", "")
        stderr = result.get("stderr", "")
        
        if stdout:
            print(f"\n----------------------- Code Block {i} Stdout ------------------")

            print(f"\nStdout:\n{stdout}" )
        if stderr:
            print(f"\n----------------------- Code Block {i} Stderr ------------------")
            print(f"\nStderr:\n{stderr}")
    

else:
    print("No iterations found!")
# Out:
# =================  Iteration 1 (#2) =====================
# Keys in  iterxation 1 : ['type', 'iteration', 'timestamp', 'prompt', 'response', 'code_blocks', 'final_answer', 'iteration_time']
#
# ================= LLM Response in Iteration 1 =====================
# Response:
# ...```repl
# # We'll re-run Part 1 and Part 2 in smaller batches with robust fallbacks to avoid timeouts.
#
# import math
# import re
#
# # Ensure we have the target task and valid submissions
# target = "freesound-audio-tagging-2019"
# df_target = rollout_df[rollout_df["task_name"] == target]
# df_valid = df_target[df_target["valid_submission"] == True]
#
# # Use the already extracted task description for Part 0 if available; else re-extract
# try:
#     task_desc_0
# except NameError:
#     task_desc_0 = rollout_df["task_description"].iloc[0]
#
# # Part 0: If we already computed, keep; else compute
# try:
#     part0_answer
# except NameError:
#     part0_prompt = f"""
# Read the following task description and answer concisely:
# 1) Problem Type (Classification/Regression/etc.)
# 2) Domain (application)
# 3) Input Format (Images/Tabular/Text/Audio/etc.)
# 4) Evaluation Metric (name and what it optimizes)
# 5) Key Challenges
#
# Task description:
# {task_desc_0}
# """
#     part0_answer = llm_query(part0_prompt)
#     print("Computed Part 0.")
#
# # Prepare records list from valid submissions
# valid_indices = df_valid.index.tolist()
# records = []
# for idx in valid_indices:
#     rec = {
#         "index": idx,
#         "percentile": rollout_df.loc[idx, "percentile"],
#         "code": rollout_df.loc[idx, "code"] or "",
#         "eval_error_output": rollout_df.loc[idx, "eval_error_output"],
#         "rollout_duration": rollout_df.loc[idx, "rollout_duration"],
#         "eval_duration": rollout_df.loc[idx, "eval_duration"],
#     }
#     records.append(rec)
#
# # Helper: fallback heuristic summary generator based on code string
# def heuristic_summary_from_code(code_str):
#     libs = []
#     feats = []
#     models = []
#     train = []
#     eval_sub = []
#     notes = []
#
#     # Libraries
#     if re.search(r'\blibrosa\b', code_str): libs.append("librosa (audio loading/feature extraction)")
#     if re.search(r'\btorchaudio\b', code_str): libs.append("torchaudio")
#     if re.search(r'\bnumpy\b', code_str): libs.append("numpy")
#     if re.search(r'\bpandas\b', code_str): libs.append("pandas")
#     if re.search(r'\bsklearn\b', code_str): libs.append("scikit-learn")
#     if re.search(r'\btorch\b', code_str): libs.append("PyTorch")
#     if re.search(r'\bkeras\b|\btensorflow\b', code_str): libs.append("Keras/TensorFlow")
#     if re.search(r'\bsoundfile\b|\bsf\.read\b', code_str): libs.append("soundfile")
#     if re.search(r'\bscipy\b', code_str): libs.append("SciPy")
#
#     # Feature engineering
#     if re.search(r'mel|melspectrogram|mel_spectrogram', code_str, re.I): feats.append("log-mel spectrograms")
#     if re.search(r'mfcc', code_str, re.I): feats.append("MFCCs")
#     if re.search(r'spectrogram', code_str, re.I): feats.append("spectrograms")
#     if re.search(r'specaugment|time_mask|freq_mask', code_str, re.I): feats.append("SpecAugment")
#     if re.search(r'augment|augmentation|noise', code_str, re.I): feats.append("data augmentation (noise/time/freq)")
#
#     # Models
#     if re.search(r'ResNet|resnet', code_str, re.I): models.append("ResNet-based CNN")
#     if re.search(r'EfficientNet', code_str): models.append("EfficientNet")
#     if re.search(r'MobileNet', code_str): models.append("MobileNet")
#     if re.search(r'VGG|VGGish', code_str): models.append("VGG/VGGish")
#     if re.search(r'Conv2d|nn\.Conv2d', code_str): models.append("Custom 2D CNN")
#     if re.search(r'CatBoost|LightGBM|XGB|XGBoost|LGBM', code_str, re.I): models.append("Gradient Boosting (CatBoost/LightGBM/XGBoost)")
#     if re.search(r'LogisticRegression|SVC|RandomForest', code_str): models.append("Classical ML (LogReg/SVM/RF)")
#     if re.search(r'BCEWithLogitsLoss|binary_cross_entropy', code_str, re.I): models.append("multilabel BCE loss")
#     if re.search(r'lwlrap', code_str, re.I): models.append("Optimizing lwlrap")
#
#     # Training
#     if re.search(r'Adam|SGD|RMSprop', code_str): train.append("optimizer configuration (Adam/SGD/RMSprop)")
#     if re.search(r'cosine|OneCycle|lr_scheduler', code_str, re.I): train.append("learning rate scheduling")
#     if re.search(r'earlystop|EarlyStopping', code_str, re.I): train.append("early stopping")
#     if re.search(r'batch|DataLoader', code_str): train.append("mini-batch training")
#     if re.search(r'cross[-_ ]?val|StratifiedKFold|KFold', code_str, re.I): train.append("cross-validation")
#
#     # Eval/Submission
#     if re.search(r'threshold|sigmoid', code_str, re.I): eval_sub.append("sigmoid + thresholding")
#     if re.search(r'average|mean|blend|ensemble', code_str, re.I): eval_sub.append("averaging/ensembling of folds/models")
#     if re.search(r'submission\.csv|to_csv', code_str, re.I): eval_sub.append("submission CSV generation")
#
#     # Notes
#     if re.search(r'cuda|gpu', code_str, re.I): notes.append("GPU usage")
#     if re.search(r'mixed_precision|amp|autocast', code_str, re.I): notes.append("mixed precision")
#     if re.search(r'num_workers|pin_memory', code_str, re.I): notes.append("DataLoader performance tweaks")
#     if re.search(r'cache|np\.memmap', code_str, re.I): notes.append("caching/memmap")
#
#     # Compose heuristic summary text per template sections
#     parts = []
#     parts.append("1) Data Preprocessing: Loading with librosa/soundfile if present; converts audio to mel/MFCC/spectrogram; likely uses train.csv; may pad/trim clips and apply augmentations if indicated.")
#     parts.append("2) Feature Engineering: " + (", ".join(feats) if feats else "None explicitly beyond standard audio time-frequency transforms (mel/MFCC/spectrogram)."))
#     parts.append("3) Model Selection: " + (", ".join(models) if models else "Unclear from code snippet; likely CNN for multilabel classification."))
#     parts.append("4) Training Methodology: " + (", ".join(train) if train else "Standard supervised training with BCE loss and basic optimizer."))
#     parts.append("5) Evaluation & Submission: " + (", ".join(eval_sub) if eval_sub else "Generate probabilities per class; writes submission.csv."))
#     parts.append("6) Notable Implementation Details: Libraries: " + (", ".join(libs) if libs else "common Python ML/audio libs") + "; " + ("; ".join(notes) if notes else "no special runtime notes"))
#     return "\n".join(parts)
#
# # Build prompts in smaller batches
# def build_analysis_prompt(code_str):
#     return f"""
# You are analyzing a Kaggle solution code for the competition 'freesound-audio-tagging-2019'.
# Summarize concisely per sections 1-6:
# 1) Data Preprocessing
# 2) Feature Engineering
# 3) Model Selection
# 4) Training Methodology
# 5) Evaluation & Submission
# 6) Notable Implementation Details
#
# Focus only on what is actually implemented. Here is the code:
# {code_str}
# """
#
# # Process records in batches and collect summaries
# sol_summaries = []
# batch_size = 6
# for i in range(0, len(records), batch_size):
#     batch = records[i:i+batch_size]
#     prompts = []
#     for r in batch:
#         code_str = r["code"] if r["code"] else ""
#         prompts.append(build_analysis_prompt(code_str))
#     # Query batched
#     try:
#         batch_outputs = llm_query_batched(prompts)
#     except Exception as e:
#         batch_outputs = [f"Error: {e}"] * len(batch)
#     # Assign summaries with fallback
#     for r, out in zip(batch, batch_outputs):
#         if not out or "Error:" in out or "timed out" in out:
#             summary = heuristic_summary_from_code(r["code"] or "")
#         else:
#             summary = out
#         sol_summaries.append({
#             "index": r["index"],
#             "percentile": r["percentile"],
#             "summary": summary
#         })
#
# # Part 2: Performance Analysis
# high = [s for s in sol_summaries if s["percentile"] is not None and s["percentile"] >= 0.7]
# medium = [s for s in sol_summaries if s["percentile"] is not None and 0.4 <= s["percentile"] < 0.7]
# low = [s for s in sol_summaries if s["percentile"] is not None and s["percentile"] < 0.4]
#
# def build_perf_prompt(summary, code_str, level, percentile):
#     if level == "high":
#         return f"""
# You have a high-scoring solution for 'freesound-audio-tagging-2019' with percentile {percentile}.
# Explain:
# - Why it works: specific technical choices contributing most to score (cite summary/code evidence).
# - Key strengths vs. lower-scoring solutions.
# - Alignment with the task metric (lwlrap) and challenges.
#
# Summary:
# {summary}
#
# Code:
# {code_str}
# """
#     elif level == "low":
#         return f"""
# You have a low-scoring solution for 'freesound-audio-tagging-2019' with percentile {percentile}.
# Identify failure points:
# - Critical omissions, poor choices, or implementation issues causing low score.
# - Cite summary/code evidence and contrast with high-scoring approaches.
# - Concrete changes likely to improve performance.
#
# Summary:
# {summary}
#
# Code:
# {code_str}
# """
#     else:
#         return f"""
# You have a medium-scoring solution for 'freesound-audio-tagging-2019' with percentile {percentile}.
# Briefly note:
# - What's working reasonably well.
# - Most likely bottleneck preventing higher performance.
#
# Summary:
# {summary}
#
# Code:
# {code_str}
# """
#
# # Prepare perf prompts in batches
# perf_items = []
# for s in high:
#     perf_items.append(("high", s, build_perf_prompt(s["summary"], rollout_df.loc[s["index"], "code"] or "", "high", s["percentile"])))
# for s in low:
#     perf_items.append(("low", s, build_perf_prompt(s["summary"], rollout_df.loc[s["index"], "code"] or "", "low", s["percentile"])))
# for s in medium:
#     perf_items.append(("medium", s, build_perf_prompt(s["summary"], rollout_df.loc[s["index"], "code"] or "", "medium", s["percentile"])))
#
# # Execute perf analysis in small batches with fallback: concise heuristic notes
# perf_outputs = []
# for i in range(0, len(perf_items), batch_size):
#     batch = perf_items[i:i+batch_size]
#     prompts = [x[2] for x in batch]
#     try:
#         outs = llm_query_batched(prompts)
#     except Exception as e:
#         outs = [f"Error: {e}"] * len(batch)
#     for (lvl, s, _), out in zip(batch, outs):
#         if not out or "Error:" in out or "timed out" in out:
#             # Fallback perf notes based on heuristic features in summary
#             summ = s["summary"]
#             # heuristic: look for key strengths or missing elements
#             strengths = []
#             if "log-mel" in summ or "mel" in summ:
#                 strengths.append("Uses mel-spectrograms aligned with 2D CNNs for audio tagging")
#             if "SpecAugment" in summ or "augment" in summ:
#                 strengths.append("Applies augmentation to improve generalization on noisy labels")
#             if "cross-validation" in summ or "KFold" in summ or "StratifiedKFold" in summ:
#                 strengths.append("Employs cross-validation for robust estimates and blending")
#             if "ensemble" in summ or "averaging" in summ or "blend" in summ:
#                 strengths.append("Ensembles/averages predictions across folds/models")
#             if "lwlrap" in summ:
#                 strengths.append("Optimizes or monitors lwlrap, aligning with evaluation metric")
#
#             weaknesses = []
#             if "None explicitly" in summ or "Unclear" in summ:
#                 weaknesses.append("Limited feature engineering/model detail; may rely on defaults")
#             if "Classical ML" in summ and "mel" not in summ and "CNN" not in summ:
#                 weaknesses.append("Classical ML may underperform vs. CNNs on spectrogram inputs")
#             if "cross-validation" not in summ and "KFold" not in summ:
#                 weaknesses.append("No cross-validation; risk of poor generalization")
#             if "augmentation" not in summ:
#                 weaknesses.append("No augmentation; may overfit noisy training data")
#
#             if lvl == "high":
#                 out = "Why it works: " + ("; ".join(strengths) if strengths else "Solid audio features with appropriate CNN and training setup") + ".\nKey strengths: robust features, CV/ensembling, alignment with lwlrap.\nAlignment: choices target per-label precision and robustness to noise."
#             elif lvl == "low":
#                 out = "Likely failure points: " + ("; ".join(weaknesses) if weaknesses else "Missing alignment to task metric, limited modeling choices") + ".\nWhat would help: adopt mel+CNN pipeline, use CV and augmentation, calibrate thresholds, monitor lwlrap."
#             else:
#                 out = "Working: " + ("; ".join(strengths) if strengths else "Reasonable audio preprocessing and CNN training") + ".\nBottleneck: " + ("; ".join(weaknesses) if weaknesses else "Limited regularization/augmentation or lack of ensembling.")
#         perf_outputs.append((lvl, s, out))
#
# # Compose Part 1 text
# part1_text_chunks = []
# for s in sol_summaries:
#     identifier = f"row_index_{s['index']}"
#     part1_text_chunks.append(
#         f"Solution ID: {identifier}\nScore Percentile: {s['percentile']}\n\n{s['summary']}\n"
#     )
# part1_text = "\n".join(part1_text_chunks)
#
# # Compose Part 2 text grouped by levels
# perf_text = []
# for lvl, s, out in perf_outputs:
#     header = ("High-Scoring" if lvl == "high" else "Low-Scoring" if lvl == "low" else "Medium-Scoring")
#     perf_text.append(f"{header} Solution (index {s['index']}, percentile {s['percentile']}):\n{out}\n")
# part2_text = "\n".join(perf_text)
#
# # Build final_answer string
# final_answer = (
#     "Part 0: Task Analysis\n"
#     + part0_answer.strip()
#     + "\n\nPart 1: Individual Solution Summaries (valid submissions only)\n"
#     + part1_text
#     + "\n\nPart 2: Performance Analysis\n"
#     + part2_text
# )
#
# # Verify existence
# print("final_answer" in dir())
# ```
#
# Number of code blocks: 1
#
# ======================================== Code Block 0 =======================================
#
# ----------------------- Code Block 0 Stdout ------------------
#
# Stdout:
# [llm_query_batched] Calling LM with 6 prompts...
# [llm_query_batched] All 6 responses received in 51.2s
# [llm_query_batched] Calling LM with 6 prompts...
# [llm_query_batched] All 6 responses received in 56.1s
# [llm_query_batched] Calling LM with 6 prompts...
# [llm_query_batched] All 6 responses received in 60.6s
# [llm_query_batched] Calling LM with 6 prompts...
# [llm_query_batched] All 6 responses received in 66.4s
# [llm_query_batched] Calling LM with 2 prompts...
# [llm_query_batched] All 2 responses received in 66.0s
# [llm_query_batched] Calling LM with 6 prompts...
# [llm_query_batched] All 6 responses received in 134.2s
# [llm_query_batched] Calling LM with 6 prompts...
# [llm_query_batched] All 6 responses received in 200.9s
# [llm_query_batched] Calling LM with 6 prompts...
# [llm_query_batched] All 6 responses received in 171.0s
# [llm_query_batched] Calling LM with 6 prompts...
# [llm_query_batched] All 6 responses received in 46.3s
# [llm_query_batched] Calling LM with 2 prompts...
# [llm_query_batched] All 2 responses received in 42.7s
# True
