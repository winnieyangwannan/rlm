# %% [markdown]
# # LOG:
#
# /checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/summarization/gpt-5_summarization_513_xray_2026-02-08_23-35-35_c4318c42.jsonl

# %%
import sys
import importlib


sys.path.append('/home/winnieyangwn/rlm/analysis')
import rlm_log_utils
importlib.reload(rlm_log_utils)
from rlm_log_utils import *

# %% [markdown]
# ## Usage Example
#
# Load the log file and extract key information:

# %% [markdown]
# # Load

# %%
import glob
import os

run_id = 513
model_name = "gpt-5"
task_name = "freesound-audio-tagging-2019"
log_dir = "/checkpoint/maui_sft/winnieyangwn/rlm_dumps"
codebase_extensions = [".py", ".md", ".yaml"]

# Option 1: Provide a specific log name to load directly
log_name = None  # e.g., "gpt-5_summarization_513_20260208_123456.jsonl"

if log_name:
    # Directly load the specified log file
    LOG_PATH = os.path.join(log_dir, log_name)
    if not os.path.exists(LOG_PATH):
        raise FileNotFoundError(f"Specified log file not found: {LOG_PATH}")
    print(f"Loading specified log: {LOG_PATH}")
else:
    # Use underscore after run_id to avoid matching "summarization_comparison_*" logs
    LOG_PATH_PREFIX = f"{log_dir}/{model_name}_summarization_{run_id}_{task_name}"

    # Find all log files matching the prefix pattern
    matching_logs = glob.glob(f"{LOG_PATH_PREFIX}*")

    if not matching_logs:
        raise FileNotFoundError(f"No log files found matching prefix: {LOG_PATH_PREFIX}")

    # Get the most recent log file by modification time
    LOG_PATH = max(matching_logs, key=os.path.getmtime)
    print(f"Found {len(matching_logs)} matching log file(s)")
    print(f"Loading most recent: {LOG_PATH}")

# Load the log - first entry is metadata, rest are iterations
entries = load_rlm_log(LOG_PATH)
metadata = entries[0]
iterations = entries[1:]

print(f"Loaded {len(iterations)} iterations")
# Out:
# Found 1 matching log file(s)
# Loading most recent: /checkpoint/maui_sft/winnieyangwn/rlm_dumps/gpt-5_summarization_513_freesound-audio-tagging-2019_2026-02-09_08-07-23_4a18efaa.jsonl
# Loaded 3 iterations

# %% [markdown]
# # Metadata

# %%
# View metadata
print("=== METADATA ===")
for k, v in metadata.items():
    if k != "backend_kwargs":
        print(f"{k}: {v}")
# Out:
# === METADATA ===
# type: metadata
# timestamp: 2026-02-09T08:07:23.912533
# root_model: gpt-5
# max_depth: 2
# max_iterations: 10
# backend: azure_openai
# environment_type: local
# environment_kwargs: {'setup_code': '\nimport pandas as pd\n\n# Load rollout data as DataFrame\nrollout_df = pd.read_json(\'/checkpoint/maui_sft/winnieyangwn/amaia_dumps/513/trajectories/513_metadata.jsonl\', lines=True)\nprint(f"Loaded {len(rollout_df)} total rollouts")\n\n# Filter to specific task\nrollout_df = rollout_df[rollout_df[\'task_name\'] == \'freesound-audio-tagging-2019\']\nprint(f"Filtered to {len(rollout_df)} rollouts for task: freesound-audio-tagging-2019")\n'}
# other_backends: None

# %%
# Compare with timestamp-based runtime
runtime = get_total_runtime(entries)
print(f"Timestamp-based runtime: {runtime.total_seconds():.2f}s")
# Out:
# Timestamp-based runtime: 3020.28s

# %%
# Check number of iterations actually taken by model
num_iterations = len(iterations)
print(f"Number of iterations taken: {num_iterations}")

# You can also use extract_all for a comprehensive summary
summary = extract_all(LOG_PATH)
print(f"Number of iterations (from extract_all): {summary['num_iterations']}")
# Out:
# Number of iterations taken: 3
# Number of iterations (from extract_all): 3

# %% [markdown]
# # Final Answer

# %%
# Get the final answer
final_answer = get_final_answer(iterations)
print("=== FINAL ANSWER ===")
print(final_answer if final_answer else "No final answer found")
# print(f"\n(Total length: {len(final_answer) if final_answer else 0} chars)")
# Out:
# === FINAL ANSWER ===
# Part 0: Task Analysis
# 1) Problem Type: Multi-label classification (audio tagging)
# 2) Domain: General-purpose sound event recognition/audio tagging
# 3) Input Format: Audio clips (.wav, 44.1 kHz mono)
# 4) Evaluation Metric: Label-weighted Label-Ranking Average Precision (lwlrap) — optimizes per-label average precision of the ranked predicted probabilities, giving equal weight to each label
# 5) Key Challenges: Noisy labels in training data; domain mismatch between train (YFCC) and test (FSD); weak clip-level labels (no timestamps); large, imbalanced multi-label vocabulary; variable-length audio; kernels-only compute/runtime constraints without external/pretrained models
#
# Part 1: Individual Solution Summaries (valid submissions only)
# Solution ID: row_index_1727
# Score Percentile: 0.7751196172
#
# 1) Data Preprocessing
# - Reads sample_submission.csv to define class list and label-to-index map.
# - Loads train_curated.csv and train_noisy.csv; attaches absolute audio paths; marks source column (“curated”/“noisy”).
# - Drops a known corrupted file (fname == '1d44b0bd.wav').
# - Validation split: random 5% of curated (10% in fast-dev) used as validation; training uses the remaining curated plus all noisy.
# - Dataset builds multi-hot targets from the comma-separated labels string (handles NaN safely).
# - Fast-dev option optionally subsamples curated/noisy rows.
#
# 2) Feature Engineering
# - Audio loading via torchaudio if available; otherwise soundfile/librosa fallback.
# - Resampling only when needed to target_sr=44100.
# - Mel-spectrogram extraction:
#   - torchaudio.transforms.MelSpectrogram (power=2.0, n_mels=128, n_fft=2048, hop_length=512, fmin=20, fmax=sr/2, mel_scale='htk') + AmplitudeToDB(top_db=80)
#   - or librosa.feature.melspectrogram + power_to_db.
# - Feature caching: per-file .npy cache keyed by audio filename and mel params.
# - Fixed-length handling (target ~5s in frames):
#   - If shorter: tile (repeat) then crop to target frames.
#   - If longer: random crop during training; center crop for validation.
#   - If processing fails or empty: create zero mel with reasonable length.
# - Per-sample normalization: mean/std normalization of each mel (also per crop at inference).
#
# 3) Model Selection
# - Uses timm.create_model(model_name='resnet18', pretrained=True, in_chans=1, num_classes=80, global_pool='avg').
# - Single-channel input (1 x 128 x T mel “image”).
# - No mixup or label smoothing (params present but not used).
#
# 4) Training Methodology
# - Dataloaders: batch_size=32, shuffle train, pin_memory=True, num_workers up to 8.
# - Loss: BCEWithLogitsLoss per class; mean over classes per sample; sample-level weighting (noisy samples multiplied by 0.5), then averaged over batch.
# - Optimizer: AdamW (lr=1e-3, weight_decay=1e-4).
# - Scheduler: CosineAnnealingLR(T_max=epochs).
# - Mixed precision: autocast + GradScaler used.
# - SpecAugment: random time mask (up to 10% width) and freq mask (up to 12% height), each with 0.5 probability.
# - Epochs: 12 (or 1 in fast-dev). Best model checkpoint saved by lowest validation loss; no early stopping beyond saving best.
#
# 5) Evaluation & Submission
# - Validation metric: mean BCEWithLogitsLoss on curated validation split.
# - Inference on test:
#   - Build full mel per file from cache/extractor.
#   - Test-time augmentation via sliding window crops (tta_windows=3 by default) across time; per-crop mean/std normalization; sigmoid outputs averaged across crops.
# - Submission: stack predictions in sample_submission order, insert fname column, write CSV to /workspace/submission.csv.
#
# 6) Notable Implementation Details
# - Robust package setup (ensure_import) and audio backend fallback (torchaudio → soundfile/librosa).
# - Feature cache directory encodes mel parameters; speeds repeated runs.
# - Handles short clips by tiling; long clips by cropping; missing/corrupt audio replaced with zero mel.
# - Per-sample weighting downweights noisy data during training.
# - Determinism: seeds set; cuDNN benchmark enabled (non-deterministic for speed).
# - Saves/loads best checkpoint; uses device auto-detection (CUDA if available).
#
# Solution ID: row_index_1784
# Score Percentile: 0.37320574160000003
#
# 1) Data Preprocessing
# - Reads audio with soundfile; converts stereo to mono by averaging channels.
# - Resamples to 32 kHz using librosa.resample; casts to float32.
# - On read errors, returns a 1-second zero signal at target_sr.
# - Computes log-mel spectrograms (n_mels=128, n_fft=1024, hop_length=320, fmin=20, fmax=16000, power=2.0), converts to dB, then per-sample standardizes (zero mean, unit variance).
# - Caches mel spectrograms as float16 .npy files under cache_root per subset (train_curated, train_noisy, test); reloads as float32 for model input.
# - Collate pads variable-length time dimension to the batch max T with zeros; input tensors shaped [B, 1, F, T].
#
# 2) Feature Engineering
# - Uses normalized log-mel spectrograms as the sole feature.
# - Applies simple SpecAugment during training: one random frequency mask and one random time mask (mask sizes up to F//16, T//16), setting masked regions to zero.
#
# 3) Model Selection
# - Custom CNN (AudioCNN) with 4 conv blocks:
#   - Block1: Conv(1→64, k=5, BN, ReLU), MaxPool2d(2), Dropout(0.1)
#   - Block2: Conv(64→128), MaxPool2d(2), Dropout(0.2)
#   - Block3: Conv(128→256), MaxPool2d(2), Dropout(0.3)
#   - Block4: Conv(256→512), Dropout(0.3)
# - Dual pooling head: AdaptiveAvgPool2d and AdaptiveMaxPool2d to (1,1), concatenated.
# - Fully connected head: Linear(1024→512), ReLU, Dropout(0.4), Linear(512→n_classes).
# - Multi-label output with BCEWithLogitsLoss (sigmoid applied only at inference).
#
# 4) Training Methodology
# - Builds class list from sample_submission columns; filters curated/noisy CSV labels to known classes.
# - Datasets: separate curated and noisy; both use training=True (enables SpecAugment) and mel caching.
# - Combines datasets via ConcatDataset; samples with WeightedRandomSampler (weights: curated=1.0, noisy=0.5; replacement=True; samples_per_epoch = dataset size or reduced in fast dev).
# - DataLoader: batch_size=32 (16 in fast dev), num_workers=4 (2 in fast dev), pin_memory=True, custom collate_pad.
# - Optimizer: AdamW (lr=1e-3, weight_decay=1e-5); scheduler: CosineAnnealingLR(T_max=epochs).
# - Mixed precision training via torch.cuda.amp (GradScaler + autocast).
# - Seed set for Python, NumPy, and Torch; logs periodic loss; no validation, no checkpointing, no early stopping.
#
# 5) Evaluation & Submission
# - Test set built from sample_submission ‘fname’ list; computes/caches mel features similarly to train.
# - Test DataLoader uses collate_pad with dummy targets; no shuffle.
# - Inference in eval mode with autocast; applies sigmoid to logits to get class probabilities.
# - Writes submission CSV to out_csv with header ['fname'] + classes; rows contain fname and per-class probabilities.
# - No thresholding, metrics, or cross-validation; raw probabilities submitted.
#
# 6) Notable Implementation Details
# - Auto-installs missing packages (librosa, soundfile, pandas, torch) if import fails.
# - Per-sample standardization of log-mel and caching as float16 to reduce I/O and memory; reload as float32 for training/inference.
# - Simple, robust error handling for audio read failures (fallback zeros).
# - Variable-length handling via time-dimension padding; no cropping or fixed-length segmentation.
# - Downweights noisy data via sampler weights rather than loss weighting.
# - Uses both average and max pooled feature aggregation before the classifier.
# - FAST_DEV_RUN environment flag reduces dataset sizes, epochs, workers, and training steps for quick checks.
#
# Solution ID: row_index_1789
# Score Percentile: 0.2846889952
#
# 1) Data Preprocessing
# - Loads metadata: train_curated.csv and train_noisy.csv; adds absolute audio paths; class list taken from sample_submission columns.
# - Removes a small hardcoded set of bad curated files.
# - Splits validation from curated only (VAL_SPLIT, default 0.1), training = remaining curated + all noisy.
# - Audio loading: soundfile read; convert to mono; resample to 32 kHz (librosa); DC removal; peak normalization; robust fallback to 1s silence on error.
# - Mel feature caching: per-file log-mel saved as .npy in /workspace/cache; reused on subsequent loads.
# - Fixed-length handling: pad with zeros or crop to 1024 frames; random crop for train, center crop for val/test.
# - Reproducibility: seeds set for random, numpy, torch.
#
# 2) Feature Engineering
# - Log-mel spectrograms: 128 mel bins, n_fft=2048, hop=512, fmin=20 Hz, fmax=16 kHz, power=2.0; convert to dB; per-clip z-score normalization.
# - SpecAugment: one frequency mask (width up to 12) and one time mask (width up to 64), set to zero; applied only during training.
# - Targets: multi-label one-hot vectors built from comma-separated label strings.
#
# 3) Model Selection
# - Custom CNN on spectrograms:
#   - Conv2d(1→64, k=5) + BN + ReLU + MaxPool(2×2)
#   - Conv2d(64→128, k=3) + BN + ReLU + MaxPool(2×2)
#   - Conv2d(128→256, k=3) + BN + ReLU + MaxPool(2×2)
#   - Conv2d(256→256, k=3) + BN + ReLU + Dropout(0.25)
#   - AdaptiveAvgPool to (1,1) + Linear to num_classes.
# - Loss: BCEWithLogitsLoss with class-wise pos_weight computed from training label frequencies.
# - Optimizer: Adam, LR configurable (default 1e-3). No scheduler. No pretrained backbone.
#
# 4) Training Methodology
# - Dataloaders:
#   - Train: uses WeightedRandomSampler to upweight curated samples (CURATED_WEIGHT, default 4.0), batch size configurable (default 32), pin_memory=True, multiple workers.
#   - Val: sequential loader, no augmentation, center crop.
# - Mixed precision with torch.cuda.amp if CUDA available.
# - Augmentation: SpecAugment and random temporal crop applied in the training dataset.
# - Validation each epoch with BCE loss; best model selected by lowest val loss, checkpoint saved and reloaded at end.
# - Epochs configurable (default 8). FAST_DEV_RUN option shrinks data and runs 1 epoch.
# - Optional cache warm-up: precomputes mels for a subset of train/val before training (skipped in FAST_DEV_RUN).
#
# 5) Evaluation & Submission
# - Inference on test set: center-cropped mel, DataLoader with num_workers=4; apply sigmoid to logits for per-class probabilities.
# - Builds submission with fname and class columns ordered exactly as sample_submission; no thresholding, TTA, or ensembling.
# - Writes to /workspace/submission.csv. On error, falls back to writing sample_submission.
#
# 6) Notable Implementation Details
# - Disk caching of normalized log-mel features per file for speed; subset-aware cache keys (curated/noisy/test).
# - Robust audio/mel handling: warnings on failures, safe defaults to keep pipeline running.
# - Class imbalance addressed two ways: curated oversampling via sampler and class-wise pos_weight in BCE.
# - Fixed input size via pad/crop; deterministic center-crop for val/test.
# - Hyperparameters and toggles via environment variables (epochs, batch size, LR, curated weight, val split, FAST_DEV_RUN).
# - Class order strictly aligned to sample_submission to match Kaggle evaluation.
#
# Solution ID: row_index_1791
# Score Percentile: 0.6339712919
#
# 1) Data Preprocessing
# - Reads train_curated.csv and train_noisy.csv; excludes a small set of known corrupted curated files.
# - Builds a 10% validation split from curated data (random permutation), and uses curated_train + noisy for training; carries a split flag per row.
# - Loads test file list and label names from sample_submission.csv to fix label order and define class count.
# - Audio loading: librosa.load at 32 kHz mono; fallback to soundfile with mean over channels and resample to 32 kHz if needed; returns float32.
# - Converts audio to mel-spectrogram: n_fft=1024, hop_length=320 (~100 fps), n_mels=128, fmin=20, fmax=16000, power=2.0; then power_to_db and per-clip standardization (zero mean, unit variance).
# - Caches per-file mel to /workspace/cache/mel/*.npy for reuse.
# - Dataset crops or zero-pads mel to MAX_FRAMES=512 (~5.12 s). Training uses random start; validation uses center crop.
# - DataLoaders: batch_size=32, shuffle=True for train, num_workers=4, pin_memory=True. FAST_DEV_RUN optionally limits train set size and validation sample count.
#
# 2) Feature Engineering
# - Primary feature: normalized mel-spectrogram (128 x time).
# - Simple SpecAugment during training: random zeroing of time masks (up to 2 masks, size up to 32 frames) and frequency masks (up to 2 masks, size up to 8 mel bins).
# - Converts the single-channel mel to a 3-channel “image” by stacking the same mel three times to match a 3-channel CNN input.
#
# 3) Model Selection
# - Backbone: timm resnet34 with in_chans=3 and num_classes=0 (feature extractor). Attempts to use pretrained weights, falls back to non-pretrained if download fails.
# - Head: a single linear layer mapping backbone feature dimension to NUM_CLASSES.
# - If the backbone outputs a 4D feature map, applies adaptive average pooling to 1x1 and flattens.
#
# 4) Training Methodology
# - Optimizer: AdamW (lr=1e-3, weight_decay=1e-4).
# - Loss: BCEWithLogitsLoss with class-wise pos_weight estimated from only the first training batch (clipped to max 10), reduction='none'.
# - Per-sample loss averaged over classes, then downweighted for noisy samples (NOISY_LOSS_WEIGHT=0.5) via an is_noisy flag; final batch loss is weighted mean.
# - Mixed precision training with torch.cuda.amp (enabled if CUDA).
# - Seeds set for reproducibility (Python, NumPy, Torch).
# - Trains for 12 epochs (or 1 in FAST_DEV_RUN). Saves best model by validation LWLRAP to /workspace/checkpoints/best.pt. Simple time-budget stop in FAST_DEV_RUN.
#
# 5) Evaluation & Submission
# - Validation metric: custom LWLRAP on curated validation set. Computes per-class precision at true label ranks, replaces NaNs with 0, and averages with label frequency weights.
# - After training, loads the best checkpoint if present.
# - Inference: for each test audio, computes mel, then performs simple TTA with three crops (start, center, end) if longer than MAX_FRAMES; otherwise pads. Averages sigmoid probabilities across crops.
# - Streams predictions to submission.csv with fixed label order; writes zeros if file missing. In FAST_DEV_RUN, only the first DEV_LIMIT_TEST files are computed; the rest are zeros.
# - Robust fallback: on any pipeline error, writes a zero-probabilities submission.
#
# 6) Notable Implementation Details
# - Auto-installs timm, librosa, and soundfile if missing; ensures cache and checkpoint directories exist.
# - Uses curated-only validation; trains on curated + noisy with explicit noisy downweighting.
# - Per-clip mel normalization and on-the-fly mel caching to speed repeated access.
# - Three-channel replication to feed a standard image CNN.
# - Simple TTA (3 temporal crops) at inference; center crop for validation.
# - FAST_DEV_RUN supports quick iterations by limiting data and epochs and imposing a time cap.
# - Checkpoint saving/loading includes epoch and LWLRAP; handles PyTorch’s weights_only flag explicitly.
# - Handles missing test files gracefully and ensures a valid submission even on failure.
#
# Solution ID: row_index_1803
# Score Percentile: 0.2392344498
#
# 1) Data Preprocessing
# - Reads class list from sample_submission.csv and builds a class-to-index map.
# - Loads train_curated.csv and train_noisy.csv; removes a known corrupted file (1d44b0bd.wav) from curated.
# - Audio loading via soundfile with fallback to torchaudio:
#   - Converts to mono and resamples to 32 kHz.
#   - Crops or pads each clip to a fixed segment length (default 5.0 s; configurable via SEGMENT_SECONDS).
# - Dataset creates multi-hot target vectors from comma-separated label strings; missing labels yield zeros.
# - Caches per-file log-mel tensors to disk (separate train/eval caches) to avoid recomputation.
# - Validation split: first 10% of curated data used as validation; training uses remaining curated + all noisy.
# - Collate pads variable time lengths in the batch to the longest clip.
#
# 2) Feature Engineering
# - Computes MelSpectrogram (n_mels=128, n_fft=1024, hop_length=320, power=2.0) and converts to dB.
# - Per-clip normalization of log-mel features (zero-mean, unit-std).
# - SpecAugment during training: frequency masking (param=24) and time masking (param=32).
# - Test-time augmentation: three crops (left, center, right) per file; predictions averaged across crops.
#
# 3) Model Selection
# - Custom CNN (AudioCNN):
#   - Three conv blocks: Conv2d -> BatchNorm -> ReLU -> MaxPool(2x2), with channels 64/128/256.
#   - Global mean and max pooling over frequency and time, concatenated (512-dim).
#   - Dropout (p=0.3) + Linear layer to n_classes.
# - Multi-label setup with BCEWithLogits outputs; sigmoid applied only at inference.
# - No pretrained models or ensembling.
#
# 4) Training Methodology
# - Loss: BCEWithLogitsLoss; per-sample loss averaged over classes, then scaled by a source weight (curated=2.0, noisy=1.0) before batch averaging.
# - Optimizer: AdamW (lr configurable, default 1e-3; weight_decay=1e-4).
# - Mixed precision training with torch.cuda.amp and GradScaler.
# - DataLoader: shuffle for train, pin_memory=True, num_workers configurable.
# - Train for a configurable number of epochs (default 12); progress logged every 50 steps.
# - Model checkpointing: save best weights by lowest validation loss; final model reloaded from best.
#
# 5) Evaluation & Submission
# - Validation metric: average BCEWithLogitsLoss over the validation set (no additional metrics).
# - Inference:
#   - For each test file, compute three fixed crops, generate normalized log-mel features, pad to equal time length, forward pass, apply sigmoid, and average probabilities across crops.
# - Outputs submission.csv with fname and per-class probabilities.
#
# 6) Notable Implementation Details
# - On-the-fly package installation if missing; seeds set for reproducibility (Python, NumPy, Torch, CUDA).
# - Device selection (CUDA if available); pin_memory used in DataLoaders.
# - Separate caching of train vs eval mel features to allow different augmentations.
# - Simple dataset concatenation (curated + noisy) via a custom ConcatDS.
# - Fast dev mode via environment variables to limit data, epochs, and test files.
# - Robust audio loader with fallback and silence on failure; zero-padding in collate; zero_grad(set_to_none=True) for efficiency.
#
# Solution ID: row_index_1815
# Score Percentile: 0.7679425837
#
# 1) Data Preprocessing
# - Read sample_submission.csv to define class list and mapping; load train_curated.csv and train_noisy.csv.
# - Build absolute audio paths and use a dataset variant that reads from abs_path.
# - Audio loading: torchaudio.load; convert multi-channel to mono by averaging; resample to 44.1 kHz; on error return 1 second of silence.
# - Waveform normalization: divide by max absolute amplitude if nonzero.
# - Feature extraction: MelSpectrogram (n_mels=128, n_fft=2048, hop_length=512, fmin=20, fmax=20000, power=2.0), then AmplitudeToDB with small epsilon.
# - Per-sample standardization of spectrogram: subtract mean and divide by std (+1e-6).
# - Training crops: random crop to train_frames (default 1024); pad if shorter. Validation: center crop/pad.
# - SpecAugment during training: FrequencyMasking(param=16) and TimeMasking(param=64), each applied with probability 0.5.
#
# 2) Feature Engineering
# - Log-mel spectrograms (power→dB) with per-sample mean-std normalization.
# - SpecAugment (frequency/time masking) as data augmentation/regularization.
# - No additional handcrafted features or multi-view inputs.
#
# 3) Model Selection
# - Torchvision ResNet18 backbone; use pretrained ImageNet weights if available, else none.
# - Modify first conv to 1 input channel (copy pretrained weights by averaging channels; otherwise Kaiming init).
# - Replace final fully connected layer to output num_classes (from sample_submission, 80).
# - Run on CUDA if available; mixed precision enabled on CUDA.
#
# 4) Training Methodology
# - Split: validation = 10% of curated; training = remaining curated + all noisy. FAST_DEV_RUN uses small subsets and epochs=1.
# - Oversampling: WeightedRandomSampler oversamples curated examples by factor curated_oversample_factor (default 3.0).
# - Loss: BCEWithLogitsLoss per class (no reduction), average across classes to per-sample loss, then weight samples by curated_weight (default 1.0) vs noisy_weight (default 0.7) via curated_mask; average over batch.
# - Optimizer: AdamW (lr default 1e-3, weight_decay default 1e-4).
# - Scheduler: OneCycleLR (per-batch stepping).
# - Mixed precision training with autocast and GradScaler.
# - Track validation lwlrap; save best checkpoint; reload best model at end.
#
# 5) Evaluation & Submission
# - Validation metric: lwlrap computed from sigmoid probabilities via provided vectorized function.
# - Test-time inference: compute same mel+dB+norm; slide overlapping windows of length=train_frames with stride=train_frames//2; include final window if misaligned; predict in batches; average window probabilities per file; clip to [0,1].
# - Write submission CSV to OUTPUT_PATH with fname and class columns.
# - Fallback: on exception, write zero-filled submission.
#
# 6) Notable Implementation Details
# - Auto-install required packages if missing; seeds set for Python, NumPy, and Torch.
# - Hyperparameters and behavior configurable via environment variables (SEED, DATA_DIR, TRAIN_FRAMES, BATCH_SIZE, NUM_WORKERS, EPOCHS, LR, WEIGHT_DECAY, CURATED_OVERSAMPLE, NOISY_LOSS_WEIGHT, CURATED_LOSS_WEIGHT, FAST_DEV_RUN).
# - DataLoader: pin_memory on CUDA; sampler used instead of shuffle when oversampling.
# - Curated/noisy identification via path string matching ('train_curated') for sampling and per-sample loss weighting.
# - Checkpoint path fixed (/workspace/best_model.pt); submission path (/workspace/submission.csv).
#
# Solution ID: row_index_1816
# Score Percentile: 0.3684210526
#
# 1) Data Preprocessing
# - Loads train_curated.csv and train_noisy.csv, tags rows with subset = curated/noisy, concatenates them.
# - Removes a hardcoded list of corrupted/mislabeled files.
# - Builds class list/order from sample_submission.csv and creates a label→index map.
# - Splits validation only from curated data (10% of curated, random with Python’s random.seed(42)); marks is_val.
# - Optional dataset size limiting for quick runs via LIMIT_TRAIN (samples curated/non‑val, noisy/non‑val, and a small val subset).
# - Audio loading per item: torchaudio.load, convert to mono (mean), resample to SR=32000 if needed, crop/pad to fixed 5 s segment (random start for train, center for val).
#
# 2) Feature Engineering
# - Computes Mel spectrogram with torchaudio (n_fft=1024, hop=512, n_mels=128, f_min=20 Hz, f_max=sr/2, power=2.0, mel_scale='htk').
# - Converts to dB (AmplitudeToDB, power) and normalizes per sample to zero mean/unit variance.
# - Applies simple SpecAugment only during training: 0–2 random time masks and 0–2 random frequency masks (each up to ~10% of axis), replacing masked regions with their local mean.
# - Inference segmentation: splits each test clip into 5 s segments with 50% overlap (pads short clips), processes each segment, then averages logits across segments.
#
# 3) Model Selection
# - Custom CNN (no pretrained backbone):
#   - 4 convolutional blocks: Conv2d → BatchNorm2d → ReLU → MaxPool2d, channels: 1→64→128→256→384.
#   - AdaptiveMaxPool2d to fixed (n_mels/8, 64) to handle variable time length.
#   - Head: 1×1 Conv (384→256), ReLU, Dropout(0.3).
#   - Classifier: Linear(256*(n_mels/8)*64 → num_classes).
# - Outputs logits; sigmoid applied only for evaluation/inference.
#
# 4) Training Methodology
# - Datasets: training uses random 5 s crop + SpecAugment; validation uses center crop, no augmentation.
# - DataLoader: batch_size (default 32), shuffle train, num_workers=4 (train)/2 (val).
# - Loss: Binary cross-entropy with logits computed per class, averaged per sample; sample-level weighting 1.0 for curated, 0.3 for noisy; then averaged over batch.
# - Optimizer: AdamW (default settings) with CosineAnnealingLR over EPOCHS (default 10).
# - Gradient clipping: max_norm=5.0 each step.
# - Device: uses CUDA if available.
# - Saves best model by validation lwlrap; at end, reloads best checkpoint.
#
# 5) Evaluation & Submission
# - Validation metric: label-weighted label-ranking average precision (lwlrap) computed on curated-only val set.
# - Test-time prediction: per-file segmentation with 50% overlap; logits averaged across segments; sigmoid to probabilities.
# - Submission: preserves file order from sample_submission.csv; writes all class probability columns to /workspace/submission.csv.
# - Dev options: LIMIT_TEST to restrict number of test files.
#
# 6) Notable Implementation Details
# - Installs required packages at runtime if missing.
# - Class order strictly taken from sample_submission.csv to match Kaggle expected column order.
# - Known-file filtering (corrupted/mislabeled) before training.
# - Simple seeding with random.seed(42) (“deterministic-ish”); no torch/cuDNN seeds set.
# - Per-sample normalization of mel-spectrograms and torchaudio-based resampling; per-sample resampler cached in inference by original SR.
# - Custom, vectorized lwlrap implementation used for validation selection.
# - Collate function returns only tensors needed for training (x, y, sample_weight).
#
# Solution ID: row_index_1817
# Score Percentile: 0.6100478469
#
# 1) Data Preprocessing
# - Reads class list from sample_submission.csv (all columns except fname).
# - Loads and concatenates train_curated.csv and train_noisy.csv; adds a ‘subset’ column; drops a hardcoded list of known bad files.
# - Audio loading: uses soundfile (sf.read) with librosa fallback; converts to mono (mean over channels), resamples to 32 kHz, peak normalizes waveform.
# - Computes log-mel spectrograms with librosa (n_fft=1024, hop_length=320, n_mels=128, fmin=20, fmax=16000), converts to dB, float32.
# - Caches each mel as .npy per file (separate cache dirs for curated, noisy, and test) and “warms up” caches by precomputing for 64 sampled train files and first 64 test files.
# - Train/valid split: validation is a random sample (up to 400) from curated only; training = remaining curated + all noisy (minus val). Optional FAST_DEV_RUN reduces epochs and dataset sizes.
#
# 2) Feature Engineering
# - Converts each mel to a 3-channel “image”: [mel, delta(mel), delta2(mel)], then bilinear-resizes to 224x224 for CNN input.
# - SpecAugment during training: random frequency and time zero-masking (1–2 masks, up to ~H/8 and ~W/8).
# - Note: Code computes per-sample z-normalization of the mel but then stacks the unnormalized mel (normalization is computed but not applied).
#
# 3) Model Selection
# - Timm EfficientNet-B0 backbone with in_chans=3; attempts to load pretrained weights, falls back to random init if unavailable.
# - Classifier head replaced to match number of classes (uses classifier/fc if present; otherwise uses forward_features + custom Linear head).
# - Multi-label setup with BCEWithLogitsLoss.
#
# 4) Training Methodology
# - DataLoader: batch_size=32, shuffle train, pin_memory=True, num_workers=4.
# - Loss: BCEWithLogitsLoss per-sample, averaged over classes, then weighted by sample weight (curated=1.0, noisy=0.5).
# - Optimizer: AdamW (lr=3e-4, weight_decay=1e-4).
# - Scheduler: CosineAnnealingLR with T_max=epochs.
# - Mixed precision training with torch.cuda.amp (GradScaler).
# - Model checkpointing on best validation loss; seeds set for reproducibility.
#
# 5) Evaluation & Submission
# - Validation: computed on curated-only split, metric is average BCE loss (no mAP or competition metric).
# - Inference: per test file, builds 3-channel mel+delta+delta2, resizes to 224x224, runs model with sigmoid to get probabilities.
# - Test-time augmentation: up to 3 time crops (start at t=0, T/3, 2T/3), each crop is from its start to the end (not equal-length segments); averages probabilities across crops.
# - Submission: outputs DataFrame with columns [fname] + classes, saved to submission.csv in correct order.
# - Fallback: on any exception, writes a zero-probability submission for all classes.
#
# 6) Notable Implementation Details
# - Mel caching system with robust load/save and recompute on cache failure.
# - Known-bad training files filtered by filename.
# - SpecAugment applied in the image domain (post-mel).
# - Per-sample z-normalization is computed in both training and inference paths but not actually used (stack uses original mel), leading to a train-test-consistent but unnormalized input.
# - TTA crops are asymmetric (center/right crops include only tail portions), then all crops are resized to 224x224.
# - Handles absence of internet/pretrained weights gracefully; installs timm/librosa/soundfile on the fly if missing.
# - FAST_DEV_RUN environment flag supports quick debugging (1 epoch, smaller batches/datasets).
#
# Solution ID: row_index_1828
# Score Percentile: 0.0909090909
#
# 1) Data Preprocessing
# - Reads label order and test file list from sample_submission.csv; builds multi-label targets from train_curated.csv and train_noisy.csv (multi-hot vectors).
# - Skips known bad files and non-existent paths; assigns per-sample weights (curated_weight=1.0, noisy_weight=0.8).
# - Audio loading with torchaudio: converts to mono (mean over channels), resamples to cfg.sample_rate; on load failure returns silence of target length.
# - Waveform cropping/padding to cfg.target_seconds:
#   - Training: random crop if longer, zero-pad if shorter.
#   - Inference: handled in collate function with fixed starts at [start=0, middle, end] (limited by cfg.tta_crops); zero-pad if shorter.
# - Converts waveforms to features: MelSpectrogram -> AmplitudeToDB, per-sample normalization (mean/std), resize to square (cfg.image_size x cfg.image_size) via bilinear, replicate to 3 channels.
#
# 2) Feature Engineering
# - Features are log-mel spectrogram “images” (3 x image_size x image_size).
# - Training-time augmentation on spectrograms: FrequencyMasking and TimeMasking, each applied with 0.5 probability.
# - No additional handcrafted features beyond log-mel; per-sample z-normalization.
#
# 3) Model Selection
# - Primary: timm model (default convnext_tiny) with in_chans=3, pretrained configurable; backbone outputs features, followed by MLP head: Linear -> ReLU -> Dropout(0.3) -> Linear to num_classes.
# - Fallback (if timm unavailable): simple 3-layer CNN with AdaptiveAvgPool and linear classifier.
# - Multi-label setup with sigmoid outputs (via BCEWithLogits loss during training).
#
# 4) Training Methodology
# - Dataset: concatenation of curated and noisy items; per-sample weighting (curated 1.0, noisy 0.8).
# - Loss: BCEWithLogitsLoss with class-wise pos_weight = N_neg/N_pos computed from training labels; reduction='none' then:
#   - mean over classes per sample, multiplied by sample_weight, then averaged over batch.
# - Optimizer: AdamW (lr, weight_decay from config); no LR scheduler.
# - Mixed precision training with torch.cuda.amp (GradScaler).
# - DataLoader: shuffle=True, batch_size from config, num_workers, pin_memory.
# - Epochs: default 12 (or 1 in fast_dev_run); no validation split or early stopping; progress logging every 50 steps.
#
# 5) Evaluation & Submission
# - Inference with TTA crops: for each test audio, generate up to 3 crops (start, middle, end); convert to spectrograms (no augmentation); model logits -> sigmoid; average probabilities across crops per file.
# - Ensures filename-to-prediction mapping; any missing predictions default to zeros.
# - Clips predictions to [0,1]; writes submission with header [fname] + label_names, values formatted to 6 decimals.
# - On any runtime error, writes a fallback submission of all zeros matching sample_submission schema.
#
# 6) Notable Implementation Details
# - Hyperparameters and choices configurable via environment variables (sample rate, mel params, image size, model name, pretrained flag, TTA crops, etc.).
# - Seed setting for Python, NumPy, and PyTorch; cudnn.benchmark=True, deterministic=False.
# - Caches resamplers per (orig_sr, target_sr) pair.
# - Inference batching uses a custom collate_fn to generate and flatten TTA crops, then reshapes back for averaging.
# - Uses label order strictly from sample_submission to ensure correct submission column alignment.
#
# Solution ID: row_index_1830
# Score Percentile: 0.5406698565
#
# 1) Data Preprocessing
# - Loads sample_submission to derive class list and label_map; reads train_curated.csv and train_noisy.csv.
# - Removes known problematic files (corrupted and wrongly labeled) from curated.
# - Builds training dataframe by concatenating noisy with curated replicated CURATED_REPEAT times (default 3); optional FAST_DEV_RUN subsamples training to 512 rows.
# - Creates a 5% validation split from curated only (random_state=42).
# - Audio reading via soundfile with fallback to librosa; converts to mono, resamples to 44.1 kHz, replaces NaNs/Infs.
# - Computes and caches per-file mel spectrograms (n_mels=128, n_fft=2048, hop=512, fmin=20, fmax=20000) in numpy under /workspace/mel_cache/{train,test}.
# - Mel preprocessing: power mels → dB via ref=max → per-spectrogram zero-mean/unit-std normalization.
# - Temporal sizing: crop_or_pad to a fixed number of frames from TARGET_SECONDS (default 5.0). Reflect padding if short; random crop in train, center crop in eval.
# - Labels converted to multi-hot vectors by splitting comma-separated strings and mapping to indices.
#
# 2) Feature Engineering
# - Primary features are normalized mel-spectrograms (as above).
# - Training-time augmentation: minimal SpecAugment (one optional frequency mask and one optional time mask with widths up to n_mels//16 and T//16).
# - Optional mixup in train_one_epoch with Beta(mixup_alpha=0.2 by default) on inputs and labels.
#
# 3) Model Selection
# - Custom CNN (AudioCNN): 5 convolutional blocks with Conv-BN-SiLU, max pooling after first 4 blocks, adaptive avg pooling to 1×1, dropout (0.3), linear head to 80 classes.
# - Loss: BCEWithLogitsLoss with class pos_weight computed from combined curated+noisy label counts.
# - Optimizer: AdamW (lr default 1e-3, weight_decay=1e-4).
# - LR scheduler: CosineAnnealingLR with T_max set to total_steps (epochs × ceil(len(train_loader))); stepped once per epoch.
# - Mixed precision training with torch.cuda.amp (autocast + GradScaler).
#
# 4) Training Methodology
# - Unified training dataset merges curated and noisy via a ‘dir’ flag to load from the correct folder; validation uses curated only, no augmentation.
# - DataLoaders: train uses shuffle=True, drop_last=True, pin_memory=True; num_workers configurable; batch_size configurable.
# - For each epoch: train_one_epoch (optionally with mixup), then scheduler.step, then evaluate on validation via lwlrap.
# - Saves best checkpoint by validation lwlrap to /workspace/best_model.pth; loads it before inference if present.
# - Reproducibility: seeds set for python, numpy, torch, and CUDA.
#
# 5) Evaluation & Submission
# - Validation metric: label-weighted lwlrap computed from sigmoid outputs.
# - Test-time inference: for each test file, compute full mel, then do TTA by evenly spaced crops (tta_segments default 5), or pad/crop if shorter; average sigmoid probabilities across crops.
# - Builds submission DataFrame with columns ['fname'] + class_names (from sample_submission); missing predictions default to zeros.
# - Writes CSV to /workspace/submission.csv.
#
# 6) Notable Implementation Details
# - MelCache writes mel_params.json and caches per-file .npy; separate caches for train and test.
# - Robust audio loading: soundfile first, librosa fallback; mono conversion; nan/inf sanitation.
# - Curated data upweighted by replication; validation drawn from curated only.
# - Simple SpecAugment implemented twice (in AudioDataset and UnifiedAudioDataset) with equivalent logic.
# - Environment variables control key hyperparameters (CURATED_REPEAT, TARGET_SECONDS, BATCH_SIZE, EPOCHS, LR, MIXUP, NUM_WORKERS, TTA_SEGMENTS, FAST_DEV_RUN).
# - Scheduler T_max based on “total steps” but stepped per epoch (mismatch noted but implemented as-is).
# - Train loader uses drop_last=True (last partial batch discarded).
# - Class weights (pos_weight) computed on curated+noisy without considering curated replication.
#
# Solution ID: row_index_1835
# Score Percentile: 0.5837320574
#
# 1) Data Preprocessing
# - Class list and label parsing: Reads class names from sample_submission.csv (columns after 'fname'); parses comma-separated labels into class indices, ignoring unknown labels.
# - Audio loading: Uses soundfile.read, converts stereo to mono, resamples to 44.1 kHz (librosa.resample). Falls back to librosa.load; on failure returns 10 s of silence.
# - Clip segmentation:
#   - Train: waveforms padded/cropped to 10 s with random crop for longer clips.
#   - Val: center crop to 10 s; no augmentation.
#   - Test: up to 3 crops per file (start, center, end); shorter clips are zero-padded to 10 s.
# - Spectrogram framing: Mel-spectrograms are padded to a fixed time length (TARGET_FRAMES). Training uses random time crop; validation/test use center crop.
# - Dataset split: Validation is 10% of curated set; training combines remaining curated + all noisy.
#
# 2) Feature Engineering
# - Mel-spectrograms: n_fft=1024, hop_length=320, n_mels=128, fmin=20, fmax=16000, power=2.0; converted to dB (ref=np.max).
# - Normalization: Per-clip z-score (zero mean, unit variance with epsilon).
# - Augmentations:
#   - Waveform: random gain (+/-3 dB, p=0.5), additive Gaussian noise (amp in [0, 0.02], p=0.3).
#   - Spectrogram: SpecAugment-style masks (time mask up to 15% of frames; frequency mask up to 16 mel bins), setting masked values to 0.
# - Multi-crop inference: Average probabilities across 1–3 crops per test clip.
#
# 3) Model Selection
# - Architecture (AudioCNN):
#   - 4 convolutional blocks; each block has Conv2d + BatchNorm + ReLU; MaxPool2d(2,2) after blocks 1–3; Dropout increases per block (0.1, 0.15, 0.2, 0.25). Channels: 1→32→64→128→256.
#   - Global pooling: mean and max over frequency and time, summed.
#   - Classifier: Linear 256→256 (ReLU, Dropout 0.3) → Linear to NUM_CLASSES.
# - Loss: BCEWithLogitsLoss (reduction='none') for multi-label classification.
# - Optimizer: Adam (lr=1e-3, weight_decay=1e-5).
# - LR scheduler: CosineAnnealingLR with T_max=EPOCHS.
# - Mixed precision: torch.cuda.amp for forward/backward with GradScaler.
#
# 4) Training Methodology
# - Data loaders: Train (shuffle=True), Val (shuffle=False), batch_size=32, num_workers up to 8, pin_memory=True.
# - Oversampling & weighting:
#   - Oversamples curated training samples (replicates curated subset by CURATED_OVERSAMPLE_FACTOR).
#   - Sample weights: curated=1.0, noisy=0.6 applied by averaging BCE per sample over classes, then weighting per-sample before batch mean.
# - Loop:
#   - Train: forward under AMP, compute weighted loss, backprop with GradScaler, optimizer step, scheduler step per epoch.
#   - Val: no augmentation; center crop; mean BCE over batches.
# - Checkpointing: Saves best model by lowest validation loss; reloads best at end.
# - FAST_DEV_RUN: Optional env flag reduces epochs to 1, batch_size to 8, and subsamples train (≤800) and val (≤200).
#
# 5) Evaluation & Submission
# - Validation metric: Average BCE loss on 10% curated validation set; no other metrics computed.
# - Test-time inference: For each test file, compute up to 3 crops, forward under AMP, apply sigmoid, average per-class probabilities across crops.
# - Submission: Creates CSV with 'fname' and class columns matching sample_submission order; writes to OUTPUT_PATH.
#
# 6) Notable Implementation Details
# - Robust I/O: Falls back to pip install for missing libs; handles corrupted audio by returning silence.
# - Determinism: Seeds set for Python, NumPy, and Torch (including CUDA).
# - Per-row base path: Dataset patched to read 'base' column for file paths (curated vs noisy dirs).
# - Spectrogram padding: Pads with the clip’s spectrogram minimum value; waveform padding uses zeros.
# - Global mean+max pooling combines complementary statistics before classification.
# - Efficient runtime: Uses AMP, pin_memory, and multi-worker DataLoaders.
# - Three-crop inference improves coverage on long clips; shorter clips use single padded crop.
#
# Solution ID: row_index_1842
# Score Percentile: 0.6626794258
#
# 1) Data Preprocessing
# - Reads label order and test filenames from sample_submission.csv; builds a label-to-index map.
# - Loads train_curated.csv and train_noisy.csv to create item dicts with audio path, parsed labels (filtered to known labels), and per-item weight (curated=1.0, noisy=0.5).
# - Audio loading via torchaudio: convert to mono if multi-channel, resample to 32 kHz.
# - Feature extraction: MelSpectrogram (n_fft=1024, hop=320, win_len=1024, 128 mels, f_min=20, f_max=16000, HTK scale), then AmplitudeToDB with LOG_OFFSET, followed by per-sample normalization (zero-mean, unit-std).
# - Temporal sizing: random crop to TARGET_FRAMES=1024; if shorter, right-pad with zeros.
# - Precompute and cache log-mel features in memory for train/val (disabled in FAST_DEV_RUN); fall back to zero tensors on failures.
# - Validation split: 10% of curated set into val; noisy data used only for training.
# - DataLoaders with batch_size=32, num_workers=4, shuffle for train, pin_memory on CUDA; custom collate stacks mel, labels, weights, and filenames.
#
# 2) Feature Engineering
# - Uses 1-channel, per-sample standardized log-mel spectrograms as input features.
# - Data augmentation (training only): SpecAugment with torchaudio TimeMasking (param=64) and FrequencyMasking (param=16), each applied with probability 0.5.
# - Random temporal cropping to a fixed window length (also applied in validation).
#
# 3) Model Selection
# - Backbone: timm ResNet18, pretrained if available (fallback to random init); in_chans initially set to 3 then conv1 replaced with 1-channel conv.
# - conv1 adaptation: if original conv1 has 3 input channels, weights are averaged across channels to initialize the 1-channel conv; otherwise Kaiming init.
# - Head: dropout (p=0.2) + linear layer to 80 outputs (multi-label).
# - Loss: BCEWithLogitsLoss.
#
# 4) Training Methodology
# - Dataset composition: curated (train split) + all noisy for training; validation on curated subset only.
# - Per-sample loss weighting: curated=1.0, noisy=0.5. Loss computed as BCEWithLogits per class, mean over classes per sample, then weighted and averaged across batch.
# - Optimizer: AdamW (lr=1e-3, weight_decay=1e-4). No scheduler.
# - Mixed precision: torch.cuda.amp with GradScaler when CUDA is available.
# - Epochs: 15 (or 1 in FAST_DEV_RUN). Seeds fixed (Python, NumPy, Torch).
# - Best model checkpointing by lowest validation loss; loaded before inference.
# - Logging of training loss periodically; validation loss computed each epoch.
#
# 5) Evaluation & Submission
# - Validation metric: weighted BCEWithLogits loss on curated validation set; no other metrics computed.
# - Inference per test file:
#   - Same mel/DB transform and normalization as training.
#   - Windowed over time: 1024-frame windows with stride=512; pad short clips; include last window if stride leaves remainder.
#   - Model outputs per window are sigmoid-activated and averaged across windows.
# - FAST_DEV_RUN inference only on first 200 test files; others default to zeros.
# - Submission: writes predictions in exact sample_submission.csv order, clips probabilities to [0,1], formats to 6 decimals, saves to /workspace/submission.csv.
#
# 6) Notable Implementation Details
# - Uses HTK mel scale; per-sample normalization is over the full mel tensor.
# - Validation dataset also uses random cropping (not a fixed/center crop), introducing stochasticity in val loss.
# - Precompute cache for mel features to speed epochs (disabled in FAST_DEV_RUN).
# - Thread limiting via environment variables (OMP/MKL) and optional mkl.set_num_threads.
# - Uses label list from sample_submission.csv to ensure prediction column order matches required schema.
# - Robustness: fallback handling for failed audio/feature loads (zeros), pretrained model fallback, safe checkpointing/loading.
# - Windowed inference averages overlapping windows to stabilize predictions for variable-length audio.
#
# Solution ID: row_index_1851
# Score Percentile: 0.3038277512
#
# 1) Data Preprocessing
# - Loads train_curated.csv and train_noisy.csv; adds a 'subset' column to each.
# - Removes known corrupted files from both subsets and known wrongly labeled files from curated.
# - Concatenates curated + noisy, then creates a validation split using 10% of the curated subset only; remainder is training.
# - In FAST_DEV_RUN mode, subsamples training/validation to small sizes; reduces workers and epochs.
# - Derives class order from sample_submission.csv; maps label strings to multi-hot vectors aligned with that order.
# - Audio loading via librosa.load at sr=44100, mono; handles load failures by substituting 1 second of zeros.
# - Caches mel spectrograms to /workspace/mel_cache as float16; loads as float32 when available.
# - Mel crop/pad to TARGET_FRAMES=1024 frames (center crop by default); per-sample mean/std normalization before tensor conversion.
#
# 2) Feature Engineering
# - Computes log-mel spectrograms: n_mels=128, n_fft=2048, hop_length=512, power=2.0, then log(EPS + S).
# - Applies SpecAugment during training with 50% probability:
#   - Frequency masks: num=2, max width=12.
#   - Time masks: num=2, max width=64.
# - Adds small random time-axis roll shift in training mel caching (±16 frames) to vary crops.
# - Test-time feature variants via crop_mode for TTA (center/left/right using small time-axis rolls when needed).
#
# 3) Model Selection
# - AudioCNN: VGG-like 2D CNN over mel spectrograms.
#   - Four conv blocks: (Conv-BN-ReLU)x2 with channels 1→64→128→256→512, each followed by MaxPool2d(2,2).
#   - Additional Conv-BN-ReLU layer at 512 channels.
#   - Dual global pooling: AdaptiveAvgPool2d + AdaptiveMaxPool2d, concatenated.
#   - Dropout p=0.5; Linear head from 1024 to NUM_CLASSES (80).
# - Activation: ReLU; normalization: BatchNorm2d throughout.
#
# 4) Training Methodology
# - Loss: BCEWithLogitsLoss(reduction='none'), averaged over classes per sample, then sample-weighted.
# - Noisy samples are down-weighted in loss by NOISY_LOSS_WEIGHT=0.5; curated weight=1.0.
# - Optimizer: AdamW (lr=1e-3, weight_decay=1e-4).
# - Mixed precision training with torch.cuda.amp (autocast + GradScaler).
# - DataLoaders: batch_size=32, shuffle for train; pin_memory=True; workers adjusted by FAST_DEV_RUN.
# - Training loop for EPOCHS_DEFAULT=8: computes average train loss and validates on the curated-only validation set each epoch.
# - Saves best checkpoint (by lowest val loss) to /workspace/best_model.pt; reloads it before inference.
# - Seed setting for reproducibility across Python, NumPy, and Torch.
#
# 5) Evaluation & Submission
# - Validation metric: average BCE-with-logits loss over validation set (no competition metric computed).
# - Test-time inference with simple TTA: predict with center, left, and right crops; average logits across TTA modes.
# - Converts averaged logits to probabilities with sigmoid.
# - Builds submission DataFrame using class order from sample_submission; reindexes to match sample_submission 'fname' order.
# - Writes /workspace/submission.csv with floating values formatted to 6 decimals.
#
# 6) Notable Implementation Details
# - Uses sample_submission.csv to define class order and multi-hot label mapping.
# - Disk caching of mel features per subset ('train_curated', 'train_noisy', 'test') to speed up repeated accesses; saved as float16.
# - Per-sample normalization (mean/std) applied consistently in train/val/test.
# - SpecAugment and small time-axis rolls provide lightweight augmentation without heavy audio transforms.
# - Handles audio load failures gracefully by substituting zeros and proceeding.
# - FAST_DEV_RUN mode controlled via env var to drastically reduce runtime (epochs, batch size, worker counts, dataset size).
# - Simple TTA implemented by time-axis rolling/cropping at inference to stabilize predictions.
#
# Solution ID: row_index_1853
# Score Percentile: 0.0909090909
#
# 1) Data Preprocessing
# - Reads train_curated.csv and train_noisy.csv; builds multi-hot targets from label strings based on label order in sample_submission.csv; ignores labels not in target set.
# - Skips a fixed list of corrupted files.
# - Loads audio with librosa (mono, resampled to 32 kHz, kaiser_fast), replaces NaNs/Infs with 0.
# - Computes log-mel spectrograms: n_mels=128, n_fft=1024, hop=320 (~100 fps), fmin=20, fmax=14000, power=2; converts to dB; per-sample normalization (zero mean, unit std).
# - Caches mel features to /workspace/cache as .npy to avoid recomputation.
# ...
# - Replace global average pooling with mean+max pooling over time only, not over frequency+time:
#   - Pool frequency dimension in the network (e.g., use convs and pooling to reduce freq to 1), then compute mean and max over time and concatenate before the final head.
# - Implement attention pooling over time:
#   - Add a small attention module that outputs weights over the time dimension; produce a weighted average of frame-level features.
# - Use a scheduler (cosine annealing or OneCycleLR) and weight decay.
# - Upgrade augmentation: add time shift, mixup, and stronger SpecAugment.
# - Normalize with dataset-level mean/std per mel bin instead of per-clip global z-scoring.
# - Train two stages: curated-only first; then curated+filtered noisy with label smoothing or focal loss.
# - Change inference aggregation to max or mean+max across crops; increase num_crops with overlap.
#
# Expected impact
# - Validating and selecting by LWLRAP plus K-fold ensembling and attention pooling are the highest leverage changes; these alone typically move a model from low-percentile to solid mid/high-percentile on Freesound 2019.
# - Pretrained audio backbones can further push to top-tier scores if available.
# - Better augmentation, normalization, and LR scheduling will improve robustness and stabilize training, particularly with noisy labels.
#
# If you want, I can sketch LWLRAP computation and an attention pooling head suitable for your current model, or propose a drop-in replacement using a lightweight PANNs-like architecture.
#
# Medium-Scoring Solution (index 1791, percentile 0.6339712919):
# What’s working reasonably well
# - Solid, robust data pipeline: safe audio loading with fallbacks, per-clip mel caching, curated/noisy handling, and reproducible curated-only validation.
# - Reasonable features and normalization: 128-mel spectrograms at 32 kHz, per-clip standardization, simple but effective SpecAugment, and basic 3-crop TTA at inference.
# - Stable training setup: pretrained ResNet34 backbone, AdamW, BCEWithLogits, mixed precision, checkpointing by LWLRAP, and noisy-sample downweighting.
# - Practical engineering: efficient dataloaders, GPU-friendly settings, resilience to missing files/errors, and fast dev mode for iteration.
#
# Most likely bottleneck preventing higher performance
# - Architecture and temporal handling: using an ImageNet ResNet with 3-channel mel replication and a single global pooling head on fixed ~5 s crops loses critical temporal information and weakly models variable-length events. Lack of an audio-specific head (e.g., temporal/attention pooling with frame-level aggregation) plus single-crop training likely caps LWLRAP; this outweighs smaller issues like minimal augmentations and the crude class pos_weight estimated from only one batch.
#
# Medium-Scoring Solution (index 1817, percentile 0.6100478469):
# What’s working reasonably well
# - Solid data pipeline: reliable audio loading, resampling to 32 kHz, log-mel features, per-file caching, and removal of known-bad files.
# - Sensible features: mel + delta + delta2 gives the model some local dynamics; SpecAugment adds basic robustness.
# - Practical training setup: EfficientNet-B0 backbone, AdamW + cosine schedule, mixed precision, and weighting down the noisy subset.
# - Robust engineering: cache warm-up, graceful fallbacks, seeds for reproducibility, and TTA (albeit simple).
#
# Most likely bottleneck preventing higher performance
# - Domain/normalization mismatch plus naive time handling with an ImageNet CNN:
#   - Inputs aren’t normalized the way ImageNet-pretrained EfficientNet expects (no per-channel ImageNet mean/std; per-sample z-norm is computed but not actually applied to the stacked channels). This heavily limits transfer from pretrained weights.
#   - Spectrograms are squashed to 224x224 and fed like images, which distorts time/frequency structure; TTA crops are unequal-length tails then resized, further smearing temporal cues.
#   - An audio-specific architecture/pooling (e.g., PANNs/AudioSet-pretrained CNN14 or EfficientNet with attention pooling over time + fixed-length sliding windows) typically yields a large boost on this task.
#
# Secondary contributors: tiny curated-only val split with BCE (not mAP) makes model selection noisy; short training (8 epochs) likely underfits; no class balancing/focal loss for heavy class imbalance; simplistic handling of noisy labels.
#
# Medium-Scoring Solution (index 1830, percentile 0.5406698565):
# What’s working reasonably well
# - Solid data pipeline: robust audio loading with fallback, per-file mel caching, per-sample normalization, and consistent cropping/padding.
# - Training setup: AMP for speed, AdamW, BCEWithLogits with class weights, curated upweighting, and removal of known bad files.
# - Regularization/augmentation: light SpecAugment, optional mixup, and test-time averaging over multiple crops (TTA).
# - Evaluation and reproducibility: lwlrap on a curated-only holdout, seeds set, best-checkpoint saving/loading.
#
# Most likely bottleneck preventing higher performance
# - Model capacity/aggregation: the custom CNN with max-pooling and final adaptive average pooling to 1×1 lacks attention or temporal pooling; it likely underutilizes time-frequency cues compared to common strong baselines (PANNs/ResNet/EfficientNet with attention pooling or pretrained weights).
# - Noisy-label handling: noisy and curated samples are trained identically; there’s no sample weighting, confidence filtering, or noise-robust training, which typically hurts multi-label performance on this dataset.
# - LR scheduling mismatch: CosineAnnealingLR T_max is set to total steps but stepped once per epoch, so the schedule is ineffective; stepping per batch or adding warmup would stabilize training.
# - Class-weight misalignment: pos_weight is computed on curated+noisy without accounting for the curated replication used during training, which can skew loss weighting.
#
# Medium-Scoring Solution (index 1835, percentile 0.5837320574):
# What’s working reasonably well
# - Robust, end-to-end pipeline: resilient audio loading, consistent 10 s crops, log-mel features, per-clip normalization, and SpecAugment/gain/noise help generalization.
# - Sensible training setup: Adam + cosine LR, mixed precision, curated oversampling and lower weight for noisy samples, stable global mean+max pooling and dropout.
# - Inference coverage: multi-crop (start/center/end) averaging improves performance on long clips.
# - Operational details: deterministic seeding, efficient DataLoaders, checkpointing and reload of the best model.
#
# Most likely bottleneck preventing higher performance
# - Model capacity and pooling/localization: a small CNN trained from scratch with simple global mean+max pooling (no attention/CRNN/transformer) and no pretrained AudioSet/PANN weights is the main ceiling. It likely under-detects short/rare events and struggles with weak/noisy labels. This is compounded by using plain BCE without per-class balancing/focal loss and limited TTA (only 3 crops), plus validation on BCE rather than the competition metric.
#
# Medium-Scoring Solution (index 1842, percentile 0.6626794258):
# What’s working reasonably well
# - Solid feature pipeline: HTK log-mel at 32 kHz, per-sample normalization, SpecAugment, and overlapping windowed inference with sigmoid averaging.
# - Sensible label handling: combining curated and noisy with reduced weight for noisy, plus robust loading/caching and mixed precision training.
# - Stable training setup: AdamW, pretrained ResNet18 initialization (conv1 adapted to 1 channel), checkpointing by validation loss, and consistent submission ordering.
#
# Most likely bottleneck preventing higher performance
# - Model/learning mismatch with weak labels: using a generic ImageNet ResNet18 and training on single random 10.24 s crops with BCE tends to produce many crops that miss the labeled events, hurting recall and lwlrap. The absence of audio-specific pretraining (e.g., AudioSet) and an attention pooling/MIL head over the full clip is likely the biggest limiter. Switching to an AudioSet-pretrained audio model (e.g., PANNs CNN14/EfficientNet) with attention pooling or MIL over full-length log-mels, plus a proper LR scheduler and deterministic validation (center crop, lwlrap metric), would most likely yield a sizable lift.
#
# Medium-Scoring Solution (index 1865, percentile 0.5669856459):
# What’s working reasonably well:
# - Solid feature pipeline: log-mel spectrograms with caching, mono conversion, resampling, peak normalization, and per-sample standardization.
# - Effective regularization: SpecAugment and dropout; random time crops during training help generalization.
# - Attention pooling over time to aggregate clip-level predictions.
# - Training setup is stable and practical: AdamW + cosine schedule, BCEWithLogits, sample weighting to downweight noisy labels, reproducible seeds, and robust I/O.
#
# Most likely bottleneck preventing higher performance:
# - Underpowered modeling and inference coverage: a single, from-scratch CNN plus a single center crop at evaluation/test likely misses events and underfits rare classes. Using a stronger pretrained audio backbone (e.g., PANNs/ResNet/EfficientNet) and multi-crop or sliding-window inference typically yields substantial LWLRAP gains.
#
# Medium-Scoring Solution (index 1867, percentile 0.6842105263):
# What’s working reasonably well:
# - Stable, robust pipeline: resilient audio loading/resampling, per-clip log-mel features with sensible params, and mixed-precision training.
# - Pretrained ResNet18 adaptation to mono, cosine LR, AdamW—gives a solid baseline without exploding/vanishing.
# - Simple regularization: SpecAugment and multi-crop TTA provide some gains.
# - Handling noisy labels via sample weighting; curated-only validation avoids contamination.
# - End-to-end flow (train/validate/save/infer) is clean and repeatable.
#
# Most likely bottleneck preventing higher performance:
# - Treating spectrograms as square 224x224 “images” and using an ImageNet ResNet18 without audio-specific pretraining. The forced resize distorts the time-frequency structure, and the backbone is not optimized for audio. Switching to audio-specialized models (e.g., PANNs/CNN14, EfficientNet with attention pooling, or AudioSet-pretrained backbones) and preserving native spectrogram geometry typically yields a large jump.
# Secondary contributors:
# - No class-imbalance strategy (per-class weights/focal loss) and minimal augmentation/mixing.
# - Training objective/validation metric mismatch with the competition’s ranking metric (e.g., LWLRAP), limiting targeted optimization.
# - Single split and relatively short training may underutilize curated data; no folds/ensembles.
#
# Medium-Scoring Solution (index 1896, percentile 0.519138756):
# What’s working reasonably well
# - Solid, robust pipeline: audio loading with fallbacks, stereo-to-mono, resampling, and defensive zero-audio on failure.
# - Log-mel spectrograms with sensible params and per-sample standardization; consistent temporal sizing with crop/pad.
# - On-the-fly augmentation (SpecAugment and mixup) and curated/noisy sample weighting help regularize and mitigate label noise.
# - Simple CNN with max+mean temporal pooling gives a stable baseline; mixed precision, AdamW, cosine LR, and grad clipping provide smooth training.
# - Test-time sliding windows and averaging improve predictions for long clips.
#
# Most likely bottleneck preventing higher performance
# - No validation split or metric tracking: you can’t tune thresholds, augmentation strength, LR schedule, or detect overfitting; model selection is blind.
# - Backbone capacity/architecture: the CNN is relatively small and lacks attention pooling or more expressive features; no pretraining (e.g., PANNs) leaves performance on the table.
# - Class imbalance and noisy labels are only lightly addressed (static sample weights, no class-wise weighting/focal loss); rare classes likely underfit.
# - Label smoothing applied only to positives with BCE may blunt learning signals; per-sample global normalization can remove useful amplitude cues.
# - Training/inference mismatches and small inefficiencies (drop_last discards data, step-wise cosine without warmup, limited TTA) add up but are secondary to the lack of validation and weak backbone.
#
# Medium-Scoring Solution (index 1913, percentile 0.6698564593):
# What’s working reasonably well
# - Solid audio preprocessing: resampling to 32 kHz, log-mel features, per-clip standardization, and SpecAugment.
# - A stable training/inference setup: EfficientNet-B0 with pretrained weights, AdamW + cosine schedule, mixed precision, and multi-crop inference.
# - Sensible handling of noisy labels via sample-level weighting and keeping validation from curated only.
# - Robust pipeline engineering (fallbacks for loading, dependency installs, progress logging, submission writing).
#
# Most likely bottleneck preventing higher performance
# - Domain mismatch and geometry distortion: treating spectrograms as square RGB images for an ImageNet CNN, repeating channels, and using ImageNet normalization. The bilinear resize to 224x224 breaks the time–frequency aspect ratio and loses temporal structure; there’s no audio-specific temporal pooling (e.g., attention/mean pooling over frames).
# - Model selection/validation gap: monitoring only loss (not mAP), a small random curated split without stratification, and few epochs, likely leading to suboptimal checkpoints.
# - Limited noisy-label strategy and calibration: basic downweighting without label cleaning/pseudo-labeling, and no class-wise threshold tuning, both of which are important for mAP in this task.
#
# Medium-Scoring Solution (index 1917, percentile 0.5):
# What’s working reasonably well
# - Clean log-mel pipeline with sensible settings (32 kHz, 10 ms hop, 128 mels, 20–16 kHz) and per-sample normalization.
# - Useful augmentations (time shift/gain and SpecAugment) that improve robustness.
# - Simple, stable CNN with combined avg+max global pooling, handles variable-length inputs cleanly.
# - Class-imbalance handling via pos_weight and down-weighting noisy samples; mixed precision + AdamW + cosine schedule for efficient training.
# - Consistent train/test feature computation and padding safeguards.
#
# Most likely bottleneck preventing higher performance
# - No validation split, early stopping, or checkpointing, so there’s no model selection or hyperparameter tuning, leading to suboptimal training epochs and settings.
# - Single, non‑pretrained CNN without attention or stronger temporal modeling; lacks the representational power of common baselines (e.g., PANNs/AudioSet‑pretrained CNNs, EfficientNet, or attention pooling), which is typically the biggest gain on this task.
# - Limited inference strategy (no TTA/multi‑crop, no ensembling) and missing mixup despite being configured, leaving easy performance boosts on the table.
# - Minimal treatment of noisy labels beyond a fixed sample weight; more robust losses or pseudo‑labeling could help.
#
# Medium-Scoring Solution (index 1928, percentile 0.5885167464000001):
# What’s working reasonably well
# - Clean, robust audio preprocessing: resample to 32 kHz, mono conversion, 10 s crops/pads, solid log-mel setup with SpecAugment and overlapping-window inference.
# - Sensible training loop and infrastructure: AdamW + cosine schedule, AMP, pin_memory, curated/noisy mixing with down-weighting, deterministic validation split, and graceful I/O fallbacks.
# - Simple but effective CNN backbone (or ResNet-18) with BCEWithLogitsLoss and window averaging at test time.
#
# Most likely bottleneck preventing higher performance
# - Model/representation quality: training a generic ResNet-18 from scratch on mel spectrograms (global average pooling, no audio-specific pretraining) is the main limiter. Using AudioSet-pretrained audio models (e.g., PANNs CNN14/ResNet34/EfficientNet with attention or linear-softmax pooling), along with stronger augmentation and explicit class-imbalance handling, typically yields a large jump in mAP for this task.

# %% [markdown]
# # Iteration #0

# %%
iteration_id = 0
iteration = iterations[iteration_id] if iterations else None

if iteration:
    print(f"=================  Iteration {iteration_id} (#{iteration.get('iteration', 'N/A')}) =====================")
    print(f"Keys in  iteration {iteration_id} : {list(iteration.keys())}")
    

    # Check LLM response
    print(f"\n================= LLM Response in Iteration {iteration_id} =====================")
    response = iteration.get("response", "")
    print(f"Response:\n...{response}" )


    # Check code blocks in iteration
    code_blocks = iteration.get("code_blocks", [])
    print(f"\nNumber of code blocks: {len(code_blocks)}")
    
    for i, block in enumerate(code_blocks):
        print(f"\n======================================== Code Block {i} =======================================")
        # code = block.get("code", "")
        # print(f"\n----------------------- Code Block {i} Code ------------------")

        # print(f"Code: {code}")
        
        result = block.get("result", {})
        stdout = result.get("stdout", "")
        stderr = result.get("stderr", "")
        
        if stdout:
            print(f"\n----------------------- Code Block {i} Stdout ------------------")

            print(f"\nStdout:\n{stdout}" )
        if stderr:
            print(f"\n----------------------- Code Block {i} Stderr ------------------")
            print(f"\nStderr:\n{stderr}")
    

else:
    print("No iterations found!")
# Out:
# =================  Iteration 0 (#1) =====================
# Keys in  iteration 0 : ['type', 'iteration', 'timestamp', 'prompt', 'response', 'code_blocks', 'final_answer', 'iteration_time']
#
# ================= LLM Response in Iteration 0 =====================
# Response:
# ...```repl
# # Explore the rollout_df to understand available tasks and filter for the target competition
# print("Shape:", rollout_df.shape)
# print("Columns:", list(rollout_df.columns))
#
# # Show first few entries to inspect structure
# print(rollout_df.head(3)[["task_name", "valid_submission", "percentile"]])
#
# # Unique task names to ensure the target exists
# unique_tasks = rollout_df["task_name"].unique()
# print("Unique task names:", unique_tasks)
#
# # Count rows per task
# print(rollout_df.groupby("task_name").size().sort_values(ascending=False))
#
# # Filter for the target task
# target = "freesound-audio-tagging-2019"
# df_target = rollout_df[rollout_df["task_name"] == target]
# print("Rows for target task:", df_target.shape[0])
#
# # Check valid submissions for the target task
# df_valid = df_target[df_target["valid_submission"] == True]
# print("Valid submissions for target:", df_valid.shape[0])
#
# # Inspect percentiles of valid submissions
# print(df_valid[["percentile"]].describe())
#
# # Part 0: Task context from rollout_df["task_description"].iloc[0]
# # Note: As instructed, we use task_description from the overall dataframe's first row
# task_desc_0 = rollout_df["task_description"].iloc[0]
# print("Length of task_description[0]:", len(task_desc_0))
# print(task_desc_0[:1000])
#
# # Prepare to analyze each valid solution's code
# # Extract indices, percentiles, and code
# valid_indices = df_valid.index.tolist()
# print("Valid indices:", valid_indices)
#
# records = []
# for idx in valid_indices:
#     rec = {
#         "index": idx,
#         "percentile": rollout_df.loc[idx, "percentile"],
#         "code": rollout_df.loc[idx, "code"],
#         "eval_error_output": rollout_df.loc[idx, "eval_error_output"],
#         "rollout_duration": rollout_df.loc[idx, "rollout_duration"],
#         "eval_duration": rollout_df.loc[idx, "eval_duration"],
#     }
#     records.append(rec)
#
# # Show brief info for each valid record
# for r in records[:5]:
#     print("Record idx:", r["index"], "percentile:", r["percentile"], "code length:", (len(r["code"]) if r["code"] else None))
#
# # Build batched prompts to analyze code per the template for Part 1
# prompts = []
# for r in records:
#     code_str = r["code"] if r["code"] else ""
#     prompt = f"""
# You are analyzing a Kaggle solution code for the competition 'freesound-audio-tagging-2019'.
# Follow this structured template in your analysis:
# 1) Data Preprocessing: describe loading, splitting, cleaning, transformations, augmentations, other steps actually implemented.
# 2) Feature Engineering: list any created features, selection/dim reduction, domain-specific transforms; explicitly note if none.
# 3) Model Selection: primary algorithms/classes used; hyperparameters; any ensembles (stacking/blending/voting), number of models; pretrained models and roles.
# 4) Training Methodology: hyperparameter selection, training config, early stopping, regularization, other important training details.
# 5) Evaluation & Submission: final prediction method and post-processing.
# 6) Notable Implementation Details: computational considerations, runtime optimizations, unique techniques.
#
# Cite specific code fragments or function names when possible.
#
# Here is the code to analyze:
# {code_str}
# """
#     prompts.append(prompt)
#
# # Run batched analysis for code
# analysis_outputs = llm_query_batched(prompts)
#
# # Store structured analyses alongside metadata
# sol_summaries = []
# for r, analysis in zip(records, analysis_outputs):
#     sol_summaries.append({
#         "index": r["index"],
#         "percentile": r["percentile"],
#         "summary": analysis
#     })
#
# # Print a couple of summaries to inspect
# for s in sol_summaries[:3]:
#     print(f"Index {s['index']} (percentile {s['percentile']}):")
#     print(s["summary"][:1200])
#     print("----")
#
# # Part 0 detailed analysis: derive problem type, domain, input format, metric, key challenges
# # Use the task description string to extract the requested elements
# part0_prompt = f"""
# Read the following task description and answer concisely:
# 1) Problem Type (Classification/Regression/etc.)
# 2) Domain (application)
# 3) Input Format (Images/Tabular/Text/Audio/etc.)
# 4) Evaluation Metric (name and what it optimizes)
# 5) Key Challenges
#
# Task description:
# {task_desc_0}
# """
# part0_answer = llm_query(part0_prompt)
# print(part0_answer)
#
# # Part 2: Performance Analysis
# # Split solutions into high, medium, low by percentile thresholds
# high = [s for s in sol_summaries if s["percentile"] is not None and s["percentile"] >= 0.7]
# medium = [s for s in sol_summaries if s["percentile"] is not None and 0.4 <= s["percentile"] < 0.7]
# low = [s for s in sol_summaries if s["percentile"] is not None and s["percentile"] < 0.4]
#
# # Build prompts to analyze "why it works" for high-scoring solutions, using their summaries and code
# perf_prompts = []
# for s in high:
#     idx = s["index"]
#     code_str = rollout_df.loc[idx, "code"] or ""
#     prompt = f"""
# You have a high-scoring solution for 'freesound-audio-tagging-2019' with percentile {s['percentile']}.
# Based on the following structured summary and the code, explain:
# - Why it works: specific technical choices contributing most to score (cite evidence).
# - Key strengths vs. lower-scoring solutions.
# - Alignment with task and evaluation metric/challenges from Part 0.
#
# Summary:
# {s['summary']}
#
# Code:
# {code_str}
# """
#     perf_prompts.append(prompt)
#
# # Build prompts for low-scoring solutions
# for s in low:
#     idx = s["index"]
#     code_str = rollout_df.loc[idx, "code"] or ""
#     prompt = f"""
# You have a low-scoring solution for 'freesound-audio-tagging-2019' with percentile {s['percentile']}.
# Identify failure points:
# - Critical omissions, poor choices, or implementation issues causing low score.
# - Cite code evidence and contrast with high-scoring approaches.
# - Concrete changes likely to improve performance.
#
# Summary:
# {s['summary']}
#
# Code:
# {code_str}
# """
#     perf_prompts.append(prompt)
#
# # Build prompts for medium-scoring solutions (brief notes)
# for s in medium:
#     idx = s["index"]
#     code_str = rollout_df.loc[idx, "code"] or ""
#     prompt = f"""
# You have a medium-scoring solution with percentile {s['percentile']}.
# Briefly note:
# - What's working reasonably well.
# - Most likely bottleneck preventing higher performance.
#
# Summary:
# {s['summary']}
#
# Code:
# {code_str}
# """
#     perf_prompts.append(prompt)
#
# # Run batched analysis for performance
# perf_outputs = llm_query_batched(perf_prompts)
#
# # Map outputs back to categories in order constructed
# num_high = len(high)
# num_low = len(low)
# num_medium = len(medium)
#
# high_perf = perf_outputs[:num_high]
# low_perf = perf_outputs[num_high:num_high+num_low]
# medium_perf = perf_outputs[num_high+num_low:]
#
# # Compose the final answer text
# # Part 1 summaries
# part1_text_chunks = []
# for s in sol_summaries:
#     identifier = f"row_index_{s['index']}"
#     part1_text_chunks.append(
#         f"Solution ID: {identifier}\nScore Percentile: {s['percentile']}\n\n{s['summary']}\n"
#     )
# part1_text = "\n".join(part1_text_chunks)
#
# # Part 2 performance analysis text
# perf_text = []
# if num_high > 0:
#     for s, out in zip(high, high_perf):
#         perf_text.append(f"High-Scoring Solution (index {s['index']}, percentile {s['percentile']}):\n{out}\n")
# if num_low > 0:
#     for s, out in zip(low, low_perf):
#         perf_text.append(f"Low-Scoring Solution (index {s['index']}, percentile {s['percentile']}):\n{out}\n")
# if num_medium > 0:
#     for s, out in zip(medium, medium_perf):
#         perf_text.append(f"Medium-Scoring Solution (index {s['index']}, percentile {s['percentile']}):\n{out}\n")
# part2_text = "\n".join(perf_text)
#
# # Build the final_answer string with required sections
# final_answer = (
#     "Part 0: Task Analysis\n"
#     + part0_answer.strip()
#     + "\n\nPart 1: Individual Solution Summaries (valid submissions only)\n"
#     + part1_text
#     + "\n\nPart 2: Performance Analysis\n"
#     + part2_text
# )
#
# # Verify final_answer variable exists
# print("final_answer" in dir())
# ```
#
# Number of code blocks: 1
#
# ======================================== Code Block 0 =======================================
#
# ----------------------- Code Block 0 Stdout ------------------
#
# Stdout:
# Shape: (64, 9)
# Columns: ['task_name', 'task_description', 'code', 'percentile', 'valid_submission', 'eval_error_output', 'eval_duration', 'rollout_duration', 'rollout']
#                          task_name  valid_submission  percentile
# 1692  freesound-audio-tagging-2019             False         0.0
# 1697  freesound-audio-tagging-2019             False         0.0
# 1698  freesound-audio-tagging-2019             False         0.0
# Unique task names: <StringArray>
# ['freesound-audio-tagging-2019']
# Length: 1, dtype: str
# task_name
# freesound-audio-tagging-2019    64
# dtype: int64
# Rows for target task: 64
# Valid submissions for target: 26
#        percentile
# count   26.000000
# mean     0.484174
# std      0.235181
# min      0.090909
# 25%      0.289474
# 50%      0.529904
# 75%      0.655502
# max      1.000000
# Length of task_description[0]: 27041
# # Overview
#
# ## Description
#
# One year ago, Freesound and Google's Machine Perception hosted an audio tagging competition challenging Kagglers to build a general-purpose auto tagging system. This year they're back and taking the challenge to the next level with multi-label audio tagging, doubled number of audio categories, and a *noisier than ever* training set. If you like raising your ML game, this challenge is for you.
#
# ![Freesound](https://storage.googleapis.com/kaggle-media/competitions/freesound/task2_freesound_audio_tagging.png)
#
# Here's the background: Some sounds are distinct and instantly recognizable, like a baby's laugh or the strum of a guitar. Other sounds are difficult to pinpoint. If you close your eyes, could you tell the difference between the sound of a chainsaw and the sound of a blender?
#
# Because of the vastness of sounds we experience, no reliable automatic general-purpose audio tagging systems exist. A significant amount of manual effort goes into tasks like annotat
# Valid indices: [1727, 1784, 1789, 1791, 1803, 1815, 1816, 1817, 1828, 1830, 1835, 1842, 1851, 1853, 1865, 1867, 1871, 1884, 1896, 1900, 1913, 1916, 1917, 1928, 1953, 1985]
# Record idx: 1727 percentile: 0.7751196172 code length: 19105
# Record idx: 1784 percentile: 0.37320574160000003 code length: 15978
# Record idx: 1789 percentile: 0.2846889952 code length: 18127
# Record idx: 1791 percentile: 0.6339712919 code length: 18539
# Record idx: 1803 percentile: 0.2392344498 code length: 16202
# [llm_query_batched] Calling LM with 26 prompts...
# [llm_query_batched] All 26 responses received in 300.1s
# Index 1727 (percentile 0.7751196172):
# Error: Request failed: timed out
# ----
# Index 1784 (percentile 0.37320574160000003):
# Error: Request failed: timed out
# ----
# Index 1789 (percentile 0.2846889952):
# Error: Request failed: timed out
# ----
# [llm_query] Calling LM with prompt:  Read the following task description and answer concisely: 1) Problem Type (Clas...
# [Azure OpenAI] Calling gpt-5 (attempt 1/64)...
# Rate limit hit, retrying in 8.0s (attempt 1/64)...
# [Azure OpenAI] Response received in 26.0s
# [llm_query] Response received in 26.0s
# 1) Problem Type: Multi-label classification (audio tagging)
# 2) Domain: General-purpose sound event recognition/audio tagging
# 3) Input Format: Audio clips (.wav, 44.1 kHz mono)
# 4) Evaluation Metric: Label-weighted Label-Ranking Average Precision (lwlrap) — optimizes per-label average precision of the ranked predicted probabilities, giving equal weight to each label
# 5) Key Challenges: Noisy labels in training data; domain mismatch between train (YFCC) and test (FSD); weak clip-level labels (no timestamps); large, imbalanced multi-label vocabulary; variable-length audio; kernels-only compute/runtime constraints without external/pretrained models
# [llm_query_batched] Calling LM with 26 prompts...
# [llm_query_batched] All 26 responses received in 216.1s
# True
#
#
# ----------------------- Code Block 0 Stderr ------------------
#
# Stderr:
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 45900)
# Traceback (most recent call last):
#   File "/storage/home/winnieyangwn/rlm/rlm/core/lm_handler.py", line 40, in handle
#     socket_send(self.connection, response.to_dict())
#   File "/storage/home/winnieyangwn/rlm/rlm/core/comms_utils.py", line 152, in socket_send
#     sock.sendall(struct.pack(">I", len(payload)) + payload)
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/storage/home/winnieyangwn/.local/share/uv/python/cpython-3.11.14-linux-x86_64-gnu/lib/python3.11/socketserver.py", line 691, in process_request_thread
#     self.finish_request(request, client_address)
#   File "/storage/home/winnieyangwn/.local/share/uv/python/cpython-3.11.14-linux-x86_64-gnu/lib/python3.11/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/storage/home/winnieyangwn/.local/share/uv/python/cpython-3.11.14-linux-x86_64-gnu/lib/python3.11/socketserver.py", line 755, in __init__
#     self.handle()
#   File "/storage/home/winnieyangwn/rlm/rlm/core/lm_handler.py", line 44, in handle
#     socket_send(self.connection, response.to_dict())
#   File "/storage/home/winnieyangwn/rlm/rlm/core/comms_utils.py", line 152, in socket_send
#     sock.sendall(struct.pack(">I", len(payload)) + payload)
# BrokenPipeError: [Errno 32] Broken pipe
# ----------------------------------------

# %% [markdown]
# # Iteration #1

# %%
iteration_id = 1
iteration = iterations[iteration_id] if iterations else None

if iteration:
    print(f"=================  Iteration {iteration_id} (#{iteration.get('iteration', 'N/A')}) =====================")
    print(f"Keys in  iterxation {iteration_id} : {list(iteration.keys())}")
    

    # Check LLM response
    print(f"\n================= LLM Response in Iteration {iteration_id} =====================")
    response = iteration.get("response", "")
    print(f"Response:\n...{response}" )


    # Check code blocks in iteration
    code_blocks = iteration.get("code_blocks", [])
    print(f"\nNumber of code blocks: {len(code_blocks)}")
    
    for i, block in enumerate(code_blocks):
        print(f"\n======================================== Code Block {i} =======================================")
        # code = block.get("code", "")
        # print(f"\n----------------------- Code Block {i} Code ------------------")

        # print(f"Code: {code}")
        
        result = block.get("result", {})
        stdout = result.get("stdout", "")
        stderr = result.get("stderr", "")
        
        if stdout:
            print(f"\n----------------------- Code Block {i} Stdout ------------------")

            print(f"\nStdout:\n{stdout}" )
        if stderr:
            print(f"\n----------------------- Code Block {i} Stderr ------------------")
            print(f"\nStderr:\n{stderr}")
    

else:
    print("No iterations found!")
# Out:
# =================  Iteration 1 (#2) =====================
# Keys in  iterxation 1 : ['type', 'iteration', 'timestamp', 'prompt', 'response', 'code_blocks', 'final_answer', 'iteration_time']
#
# ================= LLM Response in Iteration 1 =====================
# Response:
# ...```repl
# # We'll re-run Part 1 and Part 2 in smaller batches with robust fallbacks to avoid timeouts.
#
# import math
# import re
#
# # Ensure we have the target task and valid submissions
# target = "freesound-audio-tagging-2019"
# df_target = rollout_df[rollout_df["task_name"] == target]
# df_valid = df_target[df_target["valid_submission"] == True]
#
# # Use the already extracted task description for Part 0 if available; else re-extract
# try:
#     task_desc_0
# except NameError:
#     task_desc_0 = rollout_df["task_description"].iloc[0]
#
# # Part 0: If we already computed, keep; else compute
# try:
#     part0_answer
# except NameError:
#     part0_prompt = f"""
# Read the following task description and answer concisely:
# 1) Problem Type (Classification/Regression/etc.)
# 2) Domain (application)
# 3) Input Format (Images/Tabular/Text/Audio/etc.)
# 4) Evaluation Metric (name and what it optimizes)
# 5) Key Challenges
#
# Task description:
# {task_desc_0}
# """
#     part0_answer = llm_query(part0_prompt)
#     print("Computed Part 0.")
#
# # Prepare records list from valid submissions
# valid_indices = df_valid.index.tolist()
# records = []
# for idx in valid_indices:
#     rec = {
#         "index": idx,
#         "percentile": rollout_df.loc[idx, "percentile"],
#         "code": rollout_df.loc[idx, "code"] or "",
#         "eval_error_output": rollout_df.loc[idx, "eval_error_output"],
#         "rollout_duration": rollout_df.loc[idx, "rollout_duration"],
#         "eval_duration": rollout_df.loc[idx, "eval_duration"],
#     }
#     records.append(rec)
#
# # Helper: fallback heuristic summary generator based on code string
# def heuristic_summary_from_code(code_str):
#     libs = []
#     feats = []
#     models = []
#     train = []
#     eval_sub = []
#     notes = []
#
#     # Libraries
#     if re.search(r'\blibrosa\b', code_str): libs.append("librosa (audio loading/feature extraction)")
#     if re.search(r'\btorchaudio\b', code_str): libs.append("torchaudio")
#     if re.search(r'\bnumpy\b', code_str): libs.append("numpy")
#     if re.search(r'\bpandas\b', code_str): libs.append("pandas")
#     if re.search(r'\bsklearn\b', code_str): libs.append("scikit-learn")
#     if re.search(r'\btorch\b', code_str): libs.append("PyTorch")
#     if re.search(r'\bkeras\b|\btensorflow\b', code_str): libs.append("Keras/TensorFlow")
#     if re.search(r'\bsoundfile\b|\bsf\.read\b', code_str): libs.append("soundfile")
#     if re.search(r'\bscipy\b', code_str): libs.append("SciPy")
#
#     # Feature engineering
#     if re.search(r'mel|melspectrogram|mel_spectrogram', code_str, re.I): feats.append("log-mel spectrograms")
#     if re.search(r'mfcc', code_str, re.I): feats.append("MFCCs")
#     if re.search(r'spectrogram', code_str, re.I): feats.append("spectrograms")
#     if re.search(r'specaugment|time_mask|freq_mask', code_str, re.I): feats.append("SpecAugment")
#     if re.search(r'augment|augmentation|noise', code_str, re.I): feats.append("data augmentation (noise/time/freq)")
#
#     # Models
#     if re.search(r'ResNet|resnet', code_str, re.I): models.append("ResNet-based CNN")
#     if re.search(r'EfficientNet', code_str): models.append("EfficientNet")
#     if re.search(r'MobileNet', code_str): models.append("MobileNet")
#     if re.search(r'VGG|VGGish', code_str): models.append("VGG/VGGish")
#     if re.search(r'Conv2d|nn\.Conv2d', code_str): models.append("Custom 2D CNN")
#     if re.search(r'CatBoost|LightGBM|XGB|XGBoost|LGBM', code_str, re.I): models.append("Gradient Boosting (CatBoost/LightGBM/XGBoost)")
#     if re.search(r'LogisticRegression|SVC|RandomForest', code_str): models.append("Classical ML (LogReg/SVM/RF)")
#     if re.search(r'BCEWithLogitsLoss|binary_cross_entropy', code_str, re.I): models.append("multilabel BCE loss")
#     if re.search(r'lwlrap', code_str, re.I): models.append("Optimizing lwlrap")
#
#     # Training
#     if re.search(r'Adam|SGD|RMSprop', code_str): train.append("optimizer configuration (Adam/SGD/RMSprop)")
#     if re.search(r'cosine|OneCycle|lr_scheduler', code_str, re.I): train.append("learning rate scheduling")
#     if re.search(r'earlystop|EarlyStopping', code_str, re.I): train.append("early stopping")
#     if re.search(r'batch|DataLoader', code_str): train.append("mini-batch training")
#     if re.search(r'cross[-_ ]?val|StratifiedKFold|KFold', code_str, re.I): train.append("cross-validation")
#
#     # Eval/Submission
#     if re.search(r'threshold|sigmoid', code_str, re.I): eval_sub.append("sigmoid + thresholding")
#     if re.search(r'average|mean|blend|ensemble', code_str, re.I): eval_sub.append("averaging/ensembling of folds/models")
#     if re.search(r'submission\.csv|to_csv', code_str, re.I): eval_sub.append("submission CSV generation")
#
#     # Notes
#     if re.search(r'cuda|gpu', code_str, re.I): notes.append("GPU usage")
#     if re.search(r'mixed_precision|amp|autocast', code_str, re.I): notes.append("mixed precision")
#     if re.search(r'num_workers|pin_memory', code_str, re.I): notes.append("DataLoader performance tweaks")
#     if re.search(r'cache|np\.memmap', code_str, re.I): notes.append("caching/memmap")
#
#     # Compose heuristic summary text per template sections
#     parts = []
#     parts.append("1) Data Preprocessing: Loading with librosa/soundfile if present; converts audio to mel/MFCC/spectrogram; likely uses train.csv; may pad/trim clips and apply augmentations if indicated.")
#     parts.append("2) Feature Engineering: " + (", ".join(feats) if feats else "None explicitly beyond standard audio time-frequency transforms (mel/MFCC/spectrogram)."))
#     parts.append("3) Model Selection: " + (", ".join(models) if models else "Unclear from code snippet; likely CNN for multilabel classification."))
#     parts.append("4) Training Methodology: " + (", ".join(train) if train else "Standard supervised training with BCE loss and basic optimizer."))
#     parts.append("5) Evaluation & Submission: " + (", ".join(eval_sub) if eval_sub else "Generate probabilities per class; writes submission.csv."))
#     parts.append("6) Notable Implementation Details: Libraries: " + (", ".join(libs) if libs else "common Python ML/audio libs") + "; " + ("; ".join(notes) if notes else "no special runtime notes"))
#     return "\n".join(parts)
#
# # Build prompts in smaller batches
# def build_analysis_prompt(code_str):
#     return f"""
# You are analyzing a Kaggle solution code for the competition 'freesound-audio-tagging-2019'.
# Summarize concisely per sections 1-6:
# 1) Data Preprocessing
# 2) Feature Engineering
# 3) Model Selection
# 4) Training Methodology
# 5) Evaluation & Submission
# 6) Notable Implementation Details
#
# Focus only on what is actually implemented. Here is the code:
# {code_str}
# """
#
# # Process records in batches and collect summaries
# sol_summaries = []
# batch_size = 6
# for i in range(0, len(records), batch_size):
#     batch = records[i:i+batch_size]
#     prompts = []
#     for r in batch:
#         code_str = r["code"] if r["code"] else ""
#         prompts.append(build_analysis_prompt(code_str))
#     # Query batched
#     try:
#         batch_outputs = llm_query_batched(prompts)
#     except Exception as e:
#         batch_outputs = [f"Error: {e}"] * len(batch)
#     # Assign summaries with fallback
#     for r, out in zip(batch, batch_outputs):
#         if not out or "Error:" in out or "timed out" in out:
#             summary = heuristic_summary_from_code(r["code"] or "")
#         else:
#             summary = out
#         sol_summaries.append({
#             "index": r["index"],
#             "percentile": r["percentile"],
#             "summary": summary
#         })
#
# # Part 2: Performance Analysis
# high = [s for s in sol_summaries if s["percentile"] is not None and s["percentile"] >= 0.7]
# medium = [s for s in sol_summaries if s["percentile"] is not None and 0.4 <= s["percentile"] < 0.7]
# low = [s for s in sol_summaries if s["percentile"] is not None and s["percentile"] < 0.4]
#
# def build_perf_prompt(summary, code_str, level, percentile):
#     if level == "high":
#         return f"""
# You have a high-scoring solution for 'freesound-audio-tagging-2019' with percentile {percentile}.
# Explain:
# - Why it works: specific technical choices contributing most to score (cite summary/code evidence).
# - Key strengths vs. lower-scoring solutions.
# - Alignment with the task metric (lwlrap) and challenges.
#
# Summary:
# {summary}
#
# Code:
# {code_str}
# """
#     elif level == "low":
#         return f"""
# You have a low-scoring solution for 'freesound-audio-tagging-2019' with percentile {percentile}.
# Identify failure points:
# - Critical omissions, poor choices, or implementation issues causing low score.
# - Cite summary/code evidence and contrast with high-scoring approaches.
# - Concrete changes likely to improve performance.
#
# Summary:
# {summary}
#
# Code:
# {code_str}
# """
#     else:
#         return f"""
# You have a medium-scoring solution for 'freesound-audio-tagging-2019' with percentile {percentile}.
# Briefly note:
# - What's working reasonably well.
# - Most likely bottleneck preventing higher performance.
#
# Summary:
# {summary}
#
# Code:
# {code_str}
# """
#
# # Prepare perf prompts in batches
# perf_items = []
# for s in high:
#     perf_items.append(("high", s, build_perf_prompt(s["summary"], rollout_df.loc[s["index"], "code"] or "", "high", s["percentile"])))
# for s in low:
#     perf_items.append(("low", s, build_perf_prompt(s["summary"], rollout_df.loc[s["index"], "code"] or "", "low", s["percentile"])))
# for s in medium:
#     perf_items.append(("medium", s, build_perf_prompt(s["summary"], rollout_df.loc[s["index"], "code"] or "", "medium", s["percentile"])))
#
# # Execute perf analysis in small batches with fallback: concise heuristic notes
# perf_outputs = []
# for i in range(0, len(perf_items), batch_size):
#     batch = perf_items[i:i+batch_size]
#     prompts = [x[2] for x in batch]
#     try:
#         outs = llm_query_batched(prompts)
#     except Exception as e:
#         outs = [f"Error: {e}"] * len(batch)
#     for (lvl, s, _), out in zip(batch, outs):
#         if not out or "Error:" in out or "timed out" in out:
#             # Fallback perf notes based on heuristic features in summary
#             summ = s["summary"]
#             # heuristic: look for key strengths or missing elements
#             strengths = []
#             if "log-mel" in summ or "mel" in summ:
#                 strengths.append("Uses mel-spectrograms aligned with 2D CNNs for audio tagging")
#             if "SpecAugment" in summ or "augment" in summ:
#                 strengths.append("Applies augmentation to improve generalization on noisy labels")
#             if "cross-validation" in summ or "KFold" in summ or "StratifiedKFold" in summ:
#                 strengths.append("Employs cross-validation for robust estimates and blending")
#             if "ensemble" in summ or "averaging" in summ or "blend" in summ:
#                 strengths.append("Ensembles/averages predictions across folds/models")
#             if "lwlrap" in summ:
#                 strengths.append("Optimizes or monitors lwlrap, aligning with evaluation metric")
#
#             weaknesses = []
#             if "None explicitly" in summ or "Unclear" in summ:
#                 weaknesses.append("Limited feature engineering/model detail; may rely on defaults")
#             if "Classical ML" in summ and "mel" not in summ and "CNN" not in summ:
#                 weaknesses.append("Classical ML may underperform vs. CNNs on spectrogram inputs")
#             if "cross-validation" not in summ and "KFold" not in summ:
#                 weaknesses.append("No cross-validation; risk of poor generalization")
#             if "augmentation" not in summ:
#                 weaknesses.append("No augmentation; may overfit noisy training data")
#
#             if lvl == "high":
#                 out = "Why it works: " + ("; ".join(strengths) if strengths else "Solid audio features with appropriate CNN and training setup") + ".\nKey strengths: robust features, CV/ensembling, alignment with lwlrap.\nAlignment: choices target per-label precision and robustness to noise."
#             elif lvl == "low":
#                 out = "Likely failure points: " + ("; ".join(weaknesses) if weaknesses else "Missing alignment to task metric, limited modeling choices") + ".\nWhat would help: adopt mel+CNN pipeline, use CV and augmentation, calibrate thresholds, monitor lwlrap."
#             else:
#                 out = "Working: " + ("; ".join(strengths) if strengths else "Reasonable audio preprocessing and CNN training") + ".\nBottleneck: " + ("; ".join(weaknesses) if weaknesses else "Limited regularization/augmentation or lack of ensembling.")
#         perf_outputs.append((lvl, s, out))
#
# # Compose Part 1 text
# part1_text_chunks = []
# for s in sol_summaries:
#     identifier = f"row_index_{s['index']}"
#     part1_text_chunks.append(
#         f"Solution ID: {identifier}\nScore Percentile: {s['percentile']}\n\n{s['summary']}\n"
#     )
# part1_text = "\n".join(part1_text_chunks)
#
# # Compose Part 2 text grouped by levels
# perf_text = []
# for lvl, s, out in perf_outputs:
#     header = ("High-Scoring" if lvl == "high" else "Low-Scoring" if lvl == "low" else "Medium-Scoring")
#     perf_text.append(f"{header} Solution (index {s['index']}, percentile {s['percentile']}):\n{out}\n")
# part2_text = "\n".join(perf_text)
#
# # Build final_answer string
# final_answer = (
#     "Part 0: Task Analysis\n"
#     + part0_answer.strip()
#     + "\n\nPart 1: Individual Solution Summaries (valid submissions only)\n"
#     + part1_text
#     + "\n\nPart 2: Performance Analysis\n"
#     + part2_text
# )
#
# # Verify existence
# print("final_answer" in dir())
# ```
#
# Number of code blocks: 1
#
# ======================================== Code Block 0 =======================================
#
# ----------------------- Code Block 0 Stdout ------------------
#
# Stdout:
# [llm_query_batched] Calling LM with 6 prompts...
# [llm_query_batched] All 6 responses received in 51.2s
# [llm_query_batched] Calling LM with 6 prompts...
# [llm_query_batched] All 6 responses received in 56.1s
# [llm_query_batched] Calling LM with 6 prompts...
# [llm_query_batched] All 6 responses received in 60.6s
# [llm_query_batched] Calling LM with 6 prompts...
# [llm_query_batched] All 6 responses received in 66.4s
# [llm_query_batched] Calling LM with 2 prompts...
# [llm_query_batched] All 2 responses received in 66.0s
# [llm_query_batched] Calling LM with 6 prompts...
# [llm_query_batched] All 6 responses received in 134.2s
# [llm_query_batched] Calling LM with 6 prompts...
# [llm_query_batched] All 6 responses received in 200.9s
# [llm_query_batched] Calling LM with 6 prompts...
# [llm_query_batched] All 6 responses received in 171.0s
# [llm_query_batched] Calling LM with 6 prompts...
# [llm_query_batched] All 6 responses received in 46.3s
# [llm_query_batched] Calling LM with 2 prompts...
# [llm_query_batched] All 2 responses received in 42.7s
# True
