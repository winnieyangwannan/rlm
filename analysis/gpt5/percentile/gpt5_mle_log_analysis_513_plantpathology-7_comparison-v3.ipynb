# %% [markdown]
# # LOG:
#
# /checkpoint/maui_sft/winnieyangwn/rlm_dumps/gpt-5_summarization_513_iwildcam-2019-fgvc6_2026-02-09_07-05-37_3bfb9fbc.jsonl

# %%
import sys
import importlib



sys.path.append('/home/winnieyangwn/rlm/analysis')
import rlm_log_utils
importlib.reload(rlm_log_utils)
from rlm_log_utils import *

# %% [markdown]
# ## Usage Example
#
# Load the log file and extract key information:

# %% [markdown]
# # Load

# %%
import glob
import os

run_id = 513
model_name = "gpt-5"
task_name = "plant-pathology-2020-fgvc7"
log_dir = "/checkpoint/maui_sft/winnieyangwn/rlm_dumps/comparison-v3"
codebase_extensions = [".py", ".md", ".yaml"]

# Option 1: Provide a specific log name to load directly
log_name = None  # e.g., "gpt-5_summarization_513_20260208_123456.jsonl"

if log_name:
    # Directly load the specified log file
    LOG_PATH = os.path.join(log_dir, log_name)
    if not os.path.exists(LOG_PATH):
        raise FileNotFoundError(f"Specified log file not found: {LOG_PATH}")
    print(f"Loading specified log: {LOG_PATH}")
else:
    # Use "comparison" prefix for comparison-v3 logs
    LOG_PATH_PREFIX = f"{log_dir}/{model_name}_comparison_{run_id}_{task_name}"

    # Find all log files matching the prefix pattern
    matching_logs = glob.glob(f"{LOG_PATH_PREFIX}*.jsonl")

    if not matching_logs:
        raise FileNotFoundError(f"No log files found matching prefix: {LOG_PATH_PREFIX}")

    # Get the most recent log file by modification time
    LOG_PATH = max(matching_logs, key=os.path.getmtime)
    print(f"Found {len(matching_logs)} matching log file(s)")
    print(f"Loading most recent: {LOG_PATH}")

# Load the log - first entry is metadata, rest are iterations
entries = load_rlm_log(LOG_PATH)
metadata = entries[0]
iterations = entries[1:]

print(f"Loaded {len(iterations)} iterations")
# Out:
# Found 1 matching log file(s)
# Loading most recent: /checkpoint/maui_sft/winnieyangwn/rlm_dumps/comparison-v3/gpt-5_comparison_513_plant-pathology-2020-fgvc7_2026-02-11_07-35-40_d25a70cb.jsonl
# Loaded 5 iterations

# %%
matching_logs[0]
# Out:
# '/checkpoint/maui_sft/winnieyangwn/rlm_dumps/comparison-v3/gpt-5_comparison_513_plant-pathology-2020-fgvc7_2026-02-11_07-35-40_d25a70cb.jsonl'

# %% [markdown]
# # Metadata

# %%
# View metadata
print("=== METADATA ===")
for k, v in metadata.items():
    if k != "backend_kwargs":
        print(f"{k}: {v}")
# Out:
# === METADATA ===
# type: metadata
# timestamp: 2026-02-11T07:35:40.669032
# root_model: gpt-5
# max_depth: 2
# max_iterations: 20
# backend: azure_openai
# environment_type: local
# environment_kwargs: {'setup_code': '\nimport pandas as pd\n\n# Load original rollout data\nrollout_df = pd.read_json(\'/checkpoint/maui_sft/winnieyangwn/amaia_dumps/513/trajectories/513_metadata.jsonl\', lines=True)\nrollout_df = rollout_df[rollout_df[\'task_name\'] == \'plant-pathology-2020-fgvc7\']\nprint(f"Loaded {len(rollout_df)} rollouts")\n\n# Load Round 1 analysis (markdown text)\nwith open(\'/tmp/round1_analysis_513_plant-pathology-2020-fgvc7.txt\') as f:\n    round1_analysis = f.read()\nprint(f"Loaded Round 1 analysis ({len(round1_analysis)} chars)")\n'}
# other_backends: None

# %%
# Compare with timestamp-based runtime
runtime = get_total_runtime(entries)
print(f"Timestamp-based runtime: {runtime.total_seconds():.2f}s")
# Out:
# Timestamp-based runtime: 239.14s

# %%
# Check number of iterations actually taken by model
num_iterations = len(iterations)
print(f"Number of iterations taken: {num_iterations}")

# You can also use extract_all for a comprehensive summary
summary = extract_all(LOG_PATH)
print(f"Number of iterations (from extract_all): {summary['num_iterations']}")
# Out:
# Number of iterations taken: 5
# Number of iterations (from extract_all): 5

# %% [markdown]
# # Final Answer

# %%
# Get the final answer
final_answer = get_final_answer(iterations)
print("=== FINAL ANSWER ===")
print(final_answer if final_answer else "No final answer found")
# print(f"\n(Total length: {len(final_answer) if final_answer else 0} chars)")
# Out:
# === FINAL ANSWER ===
# 1) Contrastive Pattern Analysis (High vs Low)
#
# Data Preprocessing
# - What high-score solutions did (counts out of 24 high):
#   - Stratified splits that preserve class balance (argmax proxy): 21/24
#   - Multi-label-aware stratification (grouping by combined active labels): 1/24 (row_809)
#   - Cross-validation folds (StratifiedKFold) used for training and/or ensembling: 10/24 used KFold; 8/24 averaged predictions across folds for test-time ensembling
#   - Random holdout without stratification: 2/24 (rows 807, 838)
#   - Image augmentations:
#     - RandomResizedCrop in training: 19/24
#     - Vertical flip in training: 19/24
#     - ColorJitter and small rotations are common (≥18/24)
#   - Normalization to ImageNet mean/std: 24/24
#   - Higher input resolution (≥380 px): ≈22/24 (exceptions include row_728 at 224 px)
#
# - What low-score solutions did (counts out of 5 low):
#   - Stratified splits (argmax proxy): 4/5 (row_725 used random holdout)
#   - Cross-validation folds with ensembling: 1/5 (row_755); others used single holdout
#   - Image augmentations:
#     - RandomResizedCrop in training: 5/5
#     - Vertical flip in training: 3/5
#   - Normalization to ImageNet mean/std: 5/5
#   - Input resolution: mixed; one notably low (row_790 default 300 px)
#
# - Concrete difference
#   - High solutions predominantly used stratification and, in many cases, multi-fold CV with out-of-fold ensembling. A small subset even used multi-label-aware stratification (row_809). Low solutions more often relied on single random or simple stratified holdouts and rarely ensembled across folds.
#   - High solutions leaned into richer augmentation diversity (including vertical flips) and higher resolutions, helping capture off-center lesions and fine textures. Low solutions occasionally reduced resolution or omitted vertical flips, increasing the chance of cropping out evidence or missing pose invariances.
#
# - Why these patterns matter
#   - Stratification and CV ensembling stabilize validation feedback and reduce variance, which is crucial for imbalanced classes and multi-label co-occurrence. Higher resolution and robust augmentations preserve small lesions and orientation invariance, directly improving per-class ranking quality (ROC AUC).
#
# - What future solvers should do
#   - Prefer stratified splits; strongly consider MultilabelStratifiedKFold if available.
#   - Use 5-fold CV and average test-time predictions across folds.
#   - Train with ≥380 px inputs; include vertical flips and moderate color/rotation jitter; avoid eval-time center crops that trim edges—use resize + pad or multi-crop TTA.
#
# Feature Engineering
# - What high-score solutions did
#   - No explicit tabular feature engineering: 24/24
#   - Domain-specific “features” were implemented via image augmentations rather than handcrafted features.
#
# - What low-score solutions did
#   - Same: 5/5 reported none beyond image transforms.
#
# - Concrete difference
#   - No material difference; performance hinged on modeling choices, augmentation breadth, and training/evaluation strategy.
#
# - Why these patterns matter
#   - With strong pretrained vision backbones, handcrafted features are rarely beneficial; leveraging augmentation and high-capacity models captures the needed signal.
#
# - What future solvers should do
#   - Focus on augmentation policies that preserve lesions and handle orchard variability; avoid overcomplicating feature engineering unless data offers additional structured metadata.
#
# Model Selection
# - What high-score solutions did
#   - Loss choice:
#     - BCEWithLogitsLoss (multi-label) used: 22/24
#     - CrossEntropyLoss (single-label softmax) used: 2/24 (rows 734, 887)
#   - Backbones (multiple per solution; primary):
#     - EfficientNet-B4 NS: 8/24
#     - EfficientNet-B3 NS: 4/24
#     - ConvNeXt Base: 4/24
#     - EfficientNetV2-S: 2/24
#     - ResNet50 as primary: 3/24
#   - Pretrained weights: 24/24
#
# - What low-score solutions did
#   - Loss choice:
#     - BCEWithLogitsLoss: 4/5
#     - CrossEntropyLoss: 1/5 (row_790)
#   - Backbones:
#     - EfficientNet-B0/B3, ConvNeXt Tiny, ResNet50; mostly pretrained but smaller capacity or training mismatches (e.g., CE loss for multi-label).
#
# - Concrete difference
#   - High performers overwhelmingly used BCEWithLogitsLoss with sigmoid outputs, matching multi-label targets; a small minority used CE successfully under the dataset’s quasi-single-label nature. Low performers included a CE-based pipeline (row_790) that forced exclusivity, misaligning with co-occurrence.
#
# - Why these patterns matter
#   - Independent sigmoid outputs are essential for multi-label ranking and ROC AUC. Larger backbones at appropriate resolutions better capture fine-grained lesions and color/texture patterns.
#
# - What future solvers should do
#   - Default to BCEWithLogitsLoss with sigmoid; consider CE with class weights only if labels are truly mutually exclusive.
#   - Choose a strong pretrained backbone (EfficientNet-B3/B4, ConvNeXt Base) at ≥380 px.
#
# Training Methodology
# - What high-score solutions did
#   - Optimizer/schedule:
#     - AdamW: ~24/24
#     - CosineAnnealingLR: ~23/24 (row_1232 used manual step-down)
#   - Mixed precision (AMP): 24/24
#   - Class imbalance weighting:
#     - pos_weight used in BCE: 16/24
#     - Class weights with CE (inverse frequency): 2/24
#   - Checkpointing/early stopping:
#     - Best by validation mean AUC: 21/24
#     - Best by loss: 3/24
#   - Extras:
#     - Gradient clipping: 3/24 (rows 838, 815, 1231)
#     - Gradient accumulation: 1/24 (row_809)
#
# - What low-score solutions did
#   - AdamW, CosineAnnealingLR, AMP: 5/5
#   - pos_weight: 2/5 (rows 725, 755)
#   - Best by validation AUC: 4/5 (row_779 used loss)
#   - Limited use of gradient clipping/accumulation
#
# - Concrete difference
#   - High solutions more frequently used per-class pos_weight and AUC-driven checkpointing, aligning training signals with the leaderboard metric and addressing imbalance. Low solutions sometimes selected models by loss and underused imbalance-aware losses.
#
# - Why these patterns matter
#   - AUC is threshold-free and rewards ranking quality; optimizing checkpoint selection by AUC ensures the trained model matches the scored metric. pos_weight stabilizes learning for rare labels, improving per-class AUC.
#
# - What future solvers should do
#   - Compute pos_weight per training fold and pass to BCE.
#   - Select checkpoints by mean per-class ROC AUC; guard against degenerate classes (skip AUC when a class has only one label in validation).
#   - Add gradient clipping and, if needed, accumulation for stable training at high resolutions.
#
# Evaluation & Submission
# - What high-score solutions did
#   - Validation metrics:
#     - Compute per-class ROC AUC and report mean: 24/24
#     - Handle degenerate classes gracefully (set NaN/skip): common
#   - Inference:
#     - Test-time augmentation (flip-based TTA): 17/24
#     - Ensembling across folds: 8/24
#   - Submission hygiene:
#     - Align output order with test.csv image_id: common
#     - Clip probabilities to [0,1]: common
#
# - What low-score solutions did
#   - Validation metrics:
#     - Compute ROC AUC per class and mean: 4/5
#     - One pipeline used val loss only: 1/5 (row_779)
#   - Inference:
#     - TTA: 2/5
#     - Fold ensembling: 1/5
#   - Submission hygiene: mostly correct
#
# - Concrete difference
#   - High solutions more often used TTA and fold ensembling, both of which smooth probability estimates and improve ranking stability. One low pipeline optimized loss rather than AUC and lacked TTA/ensembling.
#
# - Why these patterns matter
#   - ROC AUC gains frequently come from stabilizing predictions under pose/lighting variation (TTA) and reducing fold-specific variance (ensembling). Validating on the exact metric avoids mis-selection.
#
# - What future solvers should do
#   - Add TTA (H/V flips, light rotations, multi-crop) and average logits before sigmoid.
#   - Use 5-fold CV and average fold outputs. Always compute per-label AUC and select the best by mean AUC.
#
# Notable Implementation Details
# - What high-score solutions did
#   - Reproducibility (seeds across libraries): common
#   - Efficient DataLoader (pin_memory, num_workers): common
#   - Robust image loading (fallback zero/blank image): several
#   - Albumentations-heavy transforms (ShiftScaleRotate, HueSaturationValue, CoarseDropout): 7/24
#   - RandAugment via timm resolve_data_config: 1/24 (row_816)
#   - WeightedRandomSampler: 1/24 (row_794)
#   - Clamp pos_weight to avoid extremes: 2/24 (e.g., rows 838 [1–50], 919 [1–100])
#
# - What low-score solutions did
#   - Similar runtime practices (seeds, AMP, pin_memory)
#   - WeightedRandomSampler: 1/5 (row_779)
#   - Fewer advanced augmentations beyond basic torchvision transforms
#
# - Concrete difference
#   - High performers sometimes incorporated advanced augmentation libraries (Albumentations), sensible weight clamping, or sampling strategies that directly address orchard image variability and class imbalance.
#
# - Why these patterns matter
#   - Domain-tailored augmentations and safe weighting prevent instability and improve generalization to varied leaf conditions.
#
# - What future solvers should do
#   - Prefer Albumentations with reflect padding and domain-relevant transforms (ShiftScaleRotate, HSV, brightness/contrast, CoarseDropout).
#   - Clamp pos_weight to a reasonable range to avoid exploding gradients.
#   - Consider WeightedRandomSampler in combination with pos_weight if rare labels severely underrepresent batches.
#
#
# 2) Unique High-Performing Approaches (Diversity Preservation)
#
# Note: Top-tier solutions defined as percentile ≥ 0.8.
#
# - Multi-label-aware stratified split by combined label key
#   - Technique: Build a stratification key by concatenating active labels per sample (e.g., “rust+scab”), then stratify train/val by these keys (row_809).
#   - Rarity: 1 top-tier solution.
#   - Why effective: Preserves co-occurrence patterns and rare label combinations in validation, producing more reliable AUC feedback and less overfitting to majority patterns.
#   - When to use: Multi-label datasets where co-occurrence matters and class combinations are imbalanced.
#
# - CrossEntropyLoss with class weighting in a high-scoring pipeline
#   - Technique: Treat labels as single-class indices; use weighted CrossEntropy (inverse-frequency class weights) (rows 734, 887).
#   - Rarity: 2 top-tier solutions.
#   - Why effective: Works when the dataset is effectively single-label per image (mutually exclusive one-hot), and “multiple_diseases” behaves as its own class. Class weights counter bias towards “healthy”.
#   - When to use: If labels are truly exclusive or you confirm minimal co-occurrence; otherwise prefer BCE.
#
# - RandAugment via timm resolve_data_config and auto_augment
#   - Technique: Use timm’s create_transform with auto_augment='rand-m9-mstd0.5' to diversify training augmentations (row_816).
#   - Rarity: 1 top-tier solution.
#   - Why effective: Automated augmentation recipes cover color/geometric variations systematically, improving robustness to orchard lighting and pose shifts.
#   - When to use: When you want strong augmentation without hand-tuning policies; especially effective for EfficientNet-family models.
#
# - Gradient accumulation for large images/batches
#   - Technique: Divide loss, backward each batch, and step optimizer every N steps (ACCUM_STEPS) (row_809).
#   - Rarity: 1 top-tier solution.
#   - Why effective: Enables higher resolution or more complex models on limited GPUs, stabilizing optimization and permitting better feature granularity.
#   - When to use: Under memory constraints with ≥384–512 px inputs or larger backbones.
#
# - WeightedRandomSampler alongside pos_weight BCE
#   - Technique: Use WeightedRandomSampler to balance per-batch class representation combined with pos_weight in BCE (row_794).
#   - Rarity: 1 top-tier solution.
#   - Why effective: Ensures rare class positives appear regularly in training batches while pos_weight balances gradients; helps minority classes’ ROC AUC.
#   - When to use: Severe class imbalance where rare labels barely appear per epoch.
#
# - Clamp pos_weight to a safe range
#   - Technique: Limit pos_weight to [1, 50] or [1, 100] (rows 838, 919).
#   - Rarity: 2 top-tier solutions.
#   - Why effective: Prevents extreme gradients/instability when positive counts are very low; stabilizes training.
#   - When to use: Highly imbalanced datasets; apply clamp after computing neg/pos ratios.
#
# - Very high-resolution input (512 px)
#   - Technique: Train at 512 px (rows 706, 1180).
#   - Rarity: 2 top-tier solutions.
#   - Why effective: Preserves small lesion detail and vein textures; boosts separability and ranking under ROC AUC.
#   - When to use: If GPU memory allows; combine with AMP, gradient clipping/accumulation.
#
# - ConvNeXt Base with IN22k fine-tuned weights
#   - Technique: Use convnext_base.fb_in22k_ft_in1k via timm with pretrained=True (row_754).
#   - Rarity: 1 top-tier solution.
#   - Why effective: Strong, modern backbone with broader pretraining improves texture recognition and robustness to distribution shift.
#   - When to use: When EfficientNet performance plateaus; try ConvNeXt Base with ≥384 px inputs.
#
# - Four-variant flip TTA (original, horizontal, vertical, both flips)
#   - Technique: Average predictions over 4 deterministic flip variants (rows 807, 838).
#   - Rarity: 2 top-tier solutions.
#   - Why effective: Maximizes orientation invariance at inference; stabilizes probability rankings for leaves captured at arbitrary orientations.
#   - When to use: Low-cost TTA in test; combine with fold ensembling for additive gains.
#
#
# Actionable summary for future solvers
# - Use BCEWithLogitsLoss + sigmoid and compute pos_weight per training fold; clamp pos_weight if extreme.
# - Train ≥380 px (preferably 448–512 px if resources permit) on strong backbones (EffNet-B3/B4, ConvNeXt Base), with ImageNet normalization.
# - Stratify splits; consider multilabel-aware stratification for co-occurrence. Prefer 5-fold CV and average predictions across folds.
# - Validate and checkpoint by mean per-class ROC AUC; add TTA (H/V flips, multi-crop) and ensemble across folds.
# - Adopt robust augmentation (ShiftScaleRotate, HSV/HueSaturationValue, RandomBrightnessContrast, CoarseDropout) via Albumentations or RandAugment; include vertical flips.
# - Stabilize training with AMP, AdamW + cosine schedule, gradient clipping, and accumulation if needed.
# - Ensure submission integrity: match test.csv order, use unclipped sigmoid probabilities (clip only to [0,1]) and avoid thresholding.

# %%
archive_file(archive_dir = "/checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/comparison/",
             file_path=matching_logs[0])
# Out:
# Skipped (already exists): /checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/comparison/gpt-5_comparison_513_plant-pathology-2020-fgvc7_2026-02-11_07-35-40_d25a70cb.jsonl
# Archived: /checkpoint/maui_sft/winnieyangwn/rlm_dumps/comparison-v3/gpt-5_comparison_513_plant-pathology-2020-fgvc7_2026-02-11_07-35-40_d25a70cb.md -> /checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/comparison/gpt-5_comparison_513_plant-pathology-2020-fgvc7_2026-02-11_07-35-40_d25a70cb.md
# ['/checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/comparison/gpt-5_comparison_513_plant-pathology-2020-fgvc7_2026-02-11_07-35-40_d25a70cb.md']
