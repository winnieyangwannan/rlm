# %% [markdown]
# # LOG:
#
# /checkpoint/maui_sft/winnieyangwn/rlm_dumps/gpt-5_summarization_513_iwildcam-2019-fgvc6_2026-02-09_07-05-37_3bfb9fbc.jsonl

# %%
import sys
import importlib



sys.path.append('/home/winnieyangwn/rlm/analysis')
import rlm_log_utils
importlib.reload(rlm_log_utils)
from rlm_log_utils import *

# %% [markdown]
# ## Usage Example
#
# Load the log file and extract key information:

# %% [markdown]
# # Load

# %%
import glob
import os

run_id = 513
model_name = "gpt-5"
task_name = "plant-pathology-2020-fgvc7"
log_dir = "/checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/summarization"
codebase_extensions = [".py", ".md", ".yaml"]

# Option 1: Provide a specific log name to load directly
log_name = None  # e.g., "gpt-5_summarization_513_20260208_123456.jsonl"

if log_name:
    # Directly load the specified log file
    LOG_PATH = os.path.join(log_dir, log_name)
    if not os.path.exists(LOG_PATH):
        raise FileNotFoundError(f"Specified log file not found: {LOG_PATH}")
    print(f"Loading specified log: {LOG_PATH}")
else:
    # Use underscore after run_id to avoid matching "summarization_comparison_*" logs
    LOG_PATH_PREFIX = f"{log_dir}/{model_name}_summarization_{run_id}_{task_name}"

    # Find all log files matching the prefix pattern
    matching_logs = glob.glob(f"{LOG_PATH_PREFIX}*")

    if not matching_logs:
        raise FileNotFoundError(f"No log files found matching prefix: {LOG_PATH_PREFIX}")

    # Get the most recent log file by modification time
    LOG_PATH = max(matching_logs, key=os.path.getmtime)
    print(f"Found {len(matching_logs)} matching log file(s)")
    print(f"Loading most recent: {LOG_PATH}")

# Load the log - first entry is metadata, rest are iterations
entries = load_rlm_log(LOG_PATH)
metadata = entries[0]
iterations = entries[1:]

print(f"Loaded {len(iterations)} iterations")
# Out:
# Found 1 matching log file(s)
# Loading most recent: /checkpoint/maui_sft/winnieyangwn/rlm_dumps/summarization/gpt-5_summarization_513_plant-pathology-2020-fgvc7_2026-02-11_03-49-42_4be09052.jsonl
# Loaded 3 iterations

# %% [markdown]
# # Metadata

# %%
# View metadata
print("=== METADATA ===")
for k, v in metadata.items():
    if k != "backend_kwargs":
        print(f"{k}: {v}")
# Out:
# === METADATA ===
# type: metadata
# timestamp: 2026-02-11T03:49:42.358827
# root_model: gpt-5
# max_depth: 2
# max_iterations: 10
# backend: azure_openai
# environment_type: local
# environment_kwargs: {'setup_code': '\nimport pandas as pd\n\n# Load rollout data as DataFrame\nrollout_df = pd.read_json(\'/checkpoint/maui_sft/winnieyangwn/amaia_dumps/513/trajectories/513_metadata.jsonl\', lines=True)\nprint(f"Loaded {len(rollout_df)} total rollouts")\n\n# Filter to specific task\nrollout_df = rollout_df[rollout_df[\'task_name\'] == \'plant-pathology-2020-fgvc7\']\nprint(f"Filtered to {len(rollout_df)} rollouts for task: plant-pathology-2020-fgvc7")\n'}
# other_backends: None

# %%
# Compare with timestamp-based runtime
runtime = get_total_runtime(entries)
print(f"Timestamp-based runtime: {runtime.total_seconds():.2f}s")
# Out:
# Timestamp-based runtime: 1547.71s

# %%
# Check number of iterations actually taken by model
num_iterations = len(iterations)
print(f"Number of iterations taken: {num_iterations}")

# You can also use extract_all for a comprehensive summary
summary = extract_all(LOG_PATH)
print(f"Number of iterations (from extract_all): {summary['num_iterations']}")
# Out:
# Number of iterations taken: 3
# Number of iterations (from extract_all): 3

# %% [markdown]
# # Final Answer

# %%
# Get the final answer
final_answer = get_final_answer(iterations)
print("=== FINAL ANSWER ===")
print(final_answer if final_answer else "No final answer found")
# print(f"\n(Total length: {len(final_answer) if final_answer else 0} chars)")
# Out:
# === FINAL ANSWER ===
# ## Part 0: Task Analysis
# - Problem Type: Multi-label image classification
# - Domain: Agriculture (Plant pathology / crop health)
# - Input Format: Images (JPEG photos of apple leaves)
# - Evaluation Metric: Mean column-wise ROC AUC; averages per-label ROC AUC to reward good probability ranking for each target class
# - Key Challenges:
#   - Multiple diseases can co-occur on a single leaf (multi-label)
#   - Rare classes and novel/atypical symptoms (class imbalance, distribution shift)
#   - High variability due to leaf age, genetic variation, lighting within trees
#   - Depth/pose factors: angle, light, shade affecting appearance
#   - Need to leverage expert knowledge for identification and annotation quality
#
# ## Part 1: Individual Solution Summaries
# Solution ID: row_706
# Score Percentile: 1.0
#
# 1) Data Preprocessing
# - Data loading:
#   - Reads CSVs with pandas: "train.csv", "test.csv", and "sample_submission.csv" from DATA_DIR ("/root/data").
#     - train_df = pd.read_csv(train_csv_path)
#     - test_df = pd.read_csv(test_csv_path)
#   - Extracts IDs and labels:
#     - image_ids_train = train_df['image_id'].tolist()
#     - y = train_df[TARGET_COLUMNS].values.astype(np.float32) with TARGET_COLUMNS = ["healthy", "multiple_diseases", "rust", "scab"]
#     - image_ids_test = test_df['image_id'].tolist()
#   - Robust fallback: if CSV read fails, writes out the original sample submission to SUBMISSION_PATH ("/workspace/submission.csv").
#
# - Splitting:
#   - "stratified_split(image_ids, labels, val_frac)" converts multi-hot labels to a single class via argmax and performs a per-class split:
#     - class_idx = labels.argmax(axis=1)
#     - Shuffles with seeded RNG: rng = np.random.RandomState(SEED)
#     - For each class, selects n_val = max(1, int(round(n_c * val_frac))) for validation; rest for training.
#     - Controlled by CFG["val_frac"] (default 0.1; env override "VAL_FRAC").
#
# - Transformations and augmentation:
#   - "get_transforms(img_size)" returns train and eval transforms:
#     - Train: transforms.RandomResizedCrop(img_size, scale=(0.8, 1.0), ratio=(0.75, 1.3333)), transforms.RandomHorizontalFlip(), transforms.RandomVerticalFlip(), transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.05), transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]).
#     - Eval: transforms.Resize(img_size + 32), transforms.CenterCrop(img_size), transforms.ToTensor(), transforms.Normalize(mean/std as above).
#   - Image normalization matches ImageNet stats to align with pretrained backbones.
#
# - Dataset and loaders:
#   - "PlantDataset" loads images from IMAGES_DIR = "/root/data/images" and converts to RGB; on error, uses a blank image of size CFG["img_size"].
#     - __getitem__: returns (img, label, image_id) for train/val and (img, image_id) for test.
#   - DataLoaders:
#     - train_loader = DataLoader(train_ds, batch_size=CFG["batch_size"], shuffle=True, num_workers=CFG["num_workers"], pin_memory=True)
#     - val_loader/test_loader use shuffle=False; pin_memory=True.
#
# - Other preprocessing:
#   - "compute_pos_weight(labels)" computes class-wise pos_weight = (N - P) / P for nn.BCEWithLogitsLoss, with safeguards:
#     - pos = labels.sum(axis=0); pos = np.clip(pos, 1.0, None); eps = 1e-6.
#
# 2) Feature Engineering
# - None beyond image transforms. No additional tabular features, no dimensionality reduction, no handcrafted features. Domain-specific transformations are image augmentations ("RandomResizedCrop", flips, "ColorJitter").
#
# 3) Model Selection
# - Primary model:
#   - "build_model(num_classes=4)":
#     - If timm is available (via "ensure_timm()" that attempts pip install if missing), uses timm.create_model(model_name, pretrained=True, num_classes=num_classes) with model_name from env "MODEL" (default "convnext_base").
#     - Fallback: torchvision "resnet50" with "ResNet50_Weights.IMAGENET1K_V2"; replaces final fully connected layer:
#       - in_feat = m.fc.in_features
#       - m.fc = nn.Linear(in_feat, num_classes)
# - Pretrained usage:
#   - timm: pretrained=True
#   - torchvision: ImageNet pretrained weights ("IMAGENET1K_V2").
# - Loss:
#   - nn.BCEWithLogitsLoss(pos_weight=pos_weight). Even though the dataset has a single active label per row (noted in "stratified_split"), it treats it as multi-label and outputs 4 logits with sigmoid.
# - No ensembles, stacking, blending, or voting. Single model end-to-end.
#
# 4) Training Methodology
# - Training loop:
#   - "train_one_epoch(model, optimizer, scaler, loss_fn, dataloader, device)" uses mixed precision:
#     - with torch.cuda.amp.autocast(enabled=True): logits = model(imgs); loss = loss_fn(logits, labels)
#     - GradScaler: scaler.scale(loss).backward(); scaler.step(optimizer); scaler.update()
#   - optimizer.zero_grad(set_to_none=True) for performance.
# - Validation:
#   - "validate(model, dataloader, device)" computes per-sample loss:
#     - F.binary_cross_entropy_with_logits(logits, labels, reduction='none').mean(dim=1)
#   - Metrics:
#     - Per-class ROC-AUC via sklearn.metrics.roc_auc_score if available; otherwise mean_auc = nan.
# - Hyperparameters and config:
#   - CFG defaults; overridable by environment:
#     - "img_size": 512 ("IMG_SIZE")
#     - "batch_size": 32 ("BATCH_SIZE")
#     - "epochs": 6 ("EPOCHS")
#     - "lr": 1e-4 ("LR")
#     - "weight_decay": 1e-4 ("WD")
#     - "num_workers": 4 ("WORKERS")
#   - Optimizer: torch.optim.AdamW(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"])
#   - LR schedule: torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=CFG["epochs"], eta_min=1e-6)
#   - Best model selection:
#     - Tracks best by validation AUC if available, else by negative validation loss:
#       - score = val_auc if not math.isnan(val_auc) else -val_loss
#       - Saves best_state = {k: v.cpu() for k, v in model.state_dict().items()} and reloads after training.
# - Regularization:
#   - Weight decay via AdamW. No explicit dropout changes, no gradient clipping, no early stopping beyond best checkpoint tracking.
#
# 5) Evaluation & Submission
# - Inference:
#   - "infer(model, dataloader, device, image_ids)":
#     - Computes probs = torch.sigmoid(logits)
#     - Ensures output order matches test_df['image_id'] by building a dict id_to_probs and then ordering: ordered_probs = np.array([id_to_probs[i] for i in image_ids], dtype=np.float32)
# - Post-processing:
#   - Clipping probabilities to [0, 1]: sub_df[TARGET_COLUMNS] = sub_df[TARGET_COLUMNS].clip(0.0, 1.0)
# - Submission creation:
#   - sub_df = pd.DataFrame(test_probs, columns=TARGET_COLUMNS); sub_df.insert(0, 'image_id', image_ids_test)
#   - Writes to SUBMISSION_PATH ("/workspace/submission.csv"); on failure, falls back to writing "sample_submission.csv".
#
# 6) Notable Implementation Details
# - GPU/TPU and AMP:
#   - Device selection: device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#   - Mixed precision: torch.cuda.amp.autocast(enabled=True) and torch.cuda.amp.GradScaler(enabled=True)
#   - Data transfer optimizations: .to(device, non_blocking=True) and DataLoader(pin_memory=True).
# - Runtime optimizations:
#   - optimizer.zero_grad(set_to_none=True)
#   - CosineAnnealingLR for smooth LR decay over epochs.
# - Reproducibility:
#   - Seeds set from env "SEED" (default 42): random.seed(SEED), np.random.seed(SEED), torch.manual_seed(SEED), torch.cuda.manual_seed_all(SEED)
#   - "set_deterministic()" sets torch.backends.cudnn.deterministic = True and benchmark = False.
#   - "stratified_split" uses np.random.RandomState(SEED) for reproducible shuffling.
# - Robustness and fallbacks:
#   - "ensure_timm()" tries to pip install timm if missing; falls back to torchvision "resnet50" if installation fails.
#   - Image loading errors handled by substituting a blank image and logging: print("[ERROR] Failed to load image ... Using blank image.")
#   - If ROC-AUC computation fails, logs warning and continues.
#   - If submission write fails, attempts fallback with "sample_submission.csv".
# - CV strategy:
#   - Single stratified hold-out split based on class indices (argmax). No K-fold CV.
# - Data leakage prevention:
#   - Train/val split is done before dataset creation and is stratified by label. Validation is separate and no test data is used in training.
#   - Inference explicitly reorders predictions to match "test.csv" ID order to avoid mismatched rows.
# - Configuration via environment:
#   - Model choice via "MODEL" (default "convnext_base").
#   - Core training params via "IMG_SIZE", "BATCH_SIZE", "EPOCHS", "LR", "WD", "WORKERS", "VAL_FRAC".
#
#
# Solution ID: row_725
# Score Percentile: 0.3975720789
#
# 1) Data Preprocessing
# - Data loading:
#   - Reads training and test metadata via "pd.read_csv(TRAIN_CSV)" and "pd.read_csv(TEST_CSV)".
#   - Validates schema with "assert set(CLASSES).issubset(set(train_df.columns))" and presence of "image_id".
#   - Image directory assumed at "IMAGES_DIR = os.path.join(DATA_DIR, 'images')"; images are opened using "Image.open(img_path).convert('RGB')" with "img_path = os.path.join(self.images_dir, f'{image_id}.jpg')".
# - Train/validation split:
#   - Random holdout split (no stratification): indices shuffled with "np.random.shuffle(idx)".
#   - "val_ratio" is 0.1 (or 0.2 if FAST_DEV_RUN), computed size "val_size = int(len(train_df) * val_ratio)".
#   - "df_tr" and "df_va" created by slicing "train_df" based on shuffled indices; "test_df" kept intact.
# - Transformations and augmentation (in "PlantDataset"):
#   - Augmented training transforms when "augment=True":
#     - "T.Resize(int(img_size * 1.2))"
#     - "T.RandomResizedCrop(img_size, scale=(0.7, 1.0))"
#     - "T.RandomHorizontalFlip()", "T.RandomVerticalFlip()", "T.RandomRotation(20)"
#     - "T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1)"
#     - "T.ToTensor()", "T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])"
#   - Validation/test transforms when "augment=False":
#     - "T.Resize(img_size)", "T.CenterCrop(img_size)"
#     - "T.ToTensor()", "T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])"
# - Label handling:
#   - For labeled datasets, "y = torch.tensor(row[CLASSES].values.astype(np.float32))" returns 4-class one-hot targets.
# - DataLoaders:
#   - "DataLoader(..., batch_size=32, shuffle=True, num_workers=4, pin_memory=True)" for train; shuffle=False for val/test.
#   - FAST_DEV_RUN switches: "batch_size = 8", "num_workers = 2", "img_size = 256", "val_ratio = 0.2".
# - Class imbalance weighting:
#   - "compute_pos_weight(train_df)" computes "pos_weight = (N - p) / p" per class (guarded against zero) and is used in loss.
#
# 2) Feature Engineering
# - None beyond image transformations. No explicit feature creation or dimensionality reduction. The pipeline relies on learned features from pretrained CNN backbones.
#
# 3) Model Selection
# - Primary model:
#   - Attempts to use timm EfficientNet: "timm.create_model('efficientnet_b0', pretrained=True, num_classes=num_classes)".
#   - Fallback to torchvision ResNet-50: "torchvision.models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V2)" with classifier head replaced: "model.fc = nn.Linear(in_features, num_classes)".
# - Output and loss:
#   - Multi-label setup with "nn.BCEWithLogitsLoss(pos_weight=pos_weight)"; logits later passed through sigmoid for probabilities.
# - Ensembles:
#   - None. Single model trained; no stacking/blending/voting.
# - Pretrained usage:
#   - EfficientNet-B0 and ResNet-50 both use ImageNet pretraining ("pretrained=True" or "weights=...IMAGENET1K_V2").
#
# 4) Training Methodology
# - Hyperparameter search:
#   - None. Fixed hyperparameters.
# - Training config:
#   - Optimizer: "torch.optim.AdamW(model.parameters(), lr=2e-4, weight_decay=1e-4)".
#   - Scheduler: "torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=max(1, epochs))" stepped once per epoch.
#   - Epochs: "epochs = 10" (or "1" if FAST_DEV_RUN).
#   - Batch size: 32 (or 8 if FAST_DEV_RUN).
#   - Loss: "nn.BCEWithLogitsLoss(pos_weight=pos_weight)" using "pos_weight" from entire "train_df".
#   - Mixed precision: "torch.cuda.amp.autocast(enabled=True)" and "torch.cuda.amp.GradScaler(enabled=True)".
#   - Device transfer optimization: ".to(device, non_blocking=True)" and "pin_memory=True" in DataLoaders.
#   - Gradient handling: "optimizer.zero_grad(set_to_none=True)" then scaled backward and "scaler.step(optimizer); scaler.update()".
# - Early stopping/regularization:
#   - No explicit early stopping; tracks and saves best validation AUC to "/workspace/best_model.pt".
#   - Regularization via "weight_decay=1e-4" on AdamW.
# - Reproducibility:
#   - Seeds set via "random.seed(SEED)", "np.random.seed(SEED)", "torch.manual_seed(SEED)", "torch.cuda.manual_seed_all(SEED)". No cudnn deterministic flags.
#
# 5) Evaluation & Submission
# - Validation metrics:
#   - "evaluate(...)" computes class-wise ROC AUC using "sklearn.metrics.roc_auc_score" on "torch.sigmoid(logits)" predictions and reports "Mean column-wise AUC".
# - Test prediction:
#   - Inference loop: "logits = model(x)"; probabilities via "torch.sigmoid(logits).cpu().numpy()".
#   - No test-time augmentation or ensembling; no thresholding—raw probabilities submitted.
# - Submission file creation:
#   - Writes to "SUBMISSION_PATH = '/workspace/submission.csv'".
#   - Header: "['image_id'] + CLASSES".
#   - Rows: "[img_id] + [float(p) for p in prob]" for each test image.
# - Fallback:
#   - If pipeline crashes, writes a valid submission with uniform probabilities "0.25" for each of the 4 classes per image_id.
#
# 6) Notable Implementation Details
# - Hardware:
#   - Uses CUDA if available: "device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')"; otherwise CPU.
# - Runtime optimizations:
#   - Mixed precision training/inference ("autocast", "GradScaler").
#   - "pin_memory=True" and "non_blocking=True" for faster host-to-device transfers.
#   - Periodic training logs: "[TRAIN] Batch {batch_idx+1}/{len(loader)} loss=..." every 50 batches.
# - Model management:
#   - Auto-install timm if missing (via "subprocess.check_call([... 'pip', 'install', '--quiet', 'timm'])"), with fallback to torchvision.
#   - Checkpointing best model with keys "model_state_dict", "epoch", "auc".
# - Cross-validation/Leakage:
#   - Single random holdout split; no K-fold CV; no stratification.
#   - "pos_weight" computed from full "train_df", not just training fold—does not leak target values from validation in a way that affects predictions, since weights are class-level and no test data is used.
# - Data specifics:
#   - "CLASSES = ['healthy', 'multiple_diseases', 'rust', 'scab']".
#   - Image filenames expected as "{image_id}.jpg", comment notes "Train_#.jpg or Test_#.jpg" IDs.
# - FAST_DEV_RUN toggle:
#   - Controlled by "FAST_DEV_RUN = os.environ.get('FAST_DEV_RUN', '0') == '1'".
#   - Adjusts image size (256), batch size (8), num_workers (2), val_ratio (0.2), and epochs (1) for quick verification.
#
#
# Solution ID: row_728
# Score Percentile: 1.0
#
# 1) Data Preprocessing
# - Data loading:
#   - Reads training CSV from TRAIN_CSV and test CSV from TEST_CSV using pandas.read_csv.
#   - Image directory set via IMG_DIR and images loaded from "{image_id}.jpg".
# - Splitting:
#   - Function split_train_valid(df, valid_frac=0.15) approximates multi-label stratification by creating "primary_label" = argmax over ["healthy", "multiple_diseases", "rust", "scab"], shuffling with random_state=SEED, and splitting each primary_label group into train/valid by fraction.
# - Cleaning:
#   - Asserts required columns exist: ["image_id", "healthy", "multiple_diseases", "rust", "scab"].
# - Transformations:
#   - get_transforms(img_size=224) returns:
#     - Train transforms: T.RandomResizedCrop(224, scale=(0.7, 1.0), ratio=(0.75, 1.333)), T.RandomHorizontalFlip(), T.RandomVerticalFlip(), T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.05), T.ToTensor(), T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]).
#     - Validation transforms: T.Resize(int(224 * 1.15)), T.CenterCrop(224), T.ToTensor(), T.Normalize(…ImageNet mean/std…).
#   - Inference transforms in predict_test use the same resizing/centercrop/normalize pipeline as validation.
# - Augmentation:
#   - Train-time augmentations: random resized crop, horizontal and vertical flips, color jitter.
# - Dataset class:
#   - PlantDataset(df, image_dir, transforms, is_train) returns (img, label) for training (label vector of 4 floats) or (img, image_id) for test, with has_labels auto-detection.
#
# 2) Feature Engineering
# - None beyond image augmentations and standard normalization. No handcrafted features or dimensionality reduction.
#
# 3) Model Selection
# - Primary algorithm:
#   - Class ResNet50MultiLabel(pretrained=True, out_dim=4) wraps torchvision.models.resnet50 with weights=torchvision.models.ResNet50_Weights.IMAGENET1K_V2 when pretrained=True.
#   - Replaces backbone.fc with nn.Linear(in_features, out_dim=4) for multi-label outputs.
# - Loss:
#   - nn.BCEWithLogitsLoss(pos_weight=compute_pos_weight(train_df)) for multi-label classification with class imbalance handling.
# - Hyperparameters:
#   - Image size: 224.
#   - Learning rate: 3e-4.
#   - Weight decay: 1e-4 (AdamW).
#   - Batch size: 32 (train), 64 (test).
#   - Epochs: 12 (or 1 in DEV_RUN).
# - Pretrained model usage:
#   - Loads ImageNet1K_V2 weights for ResNet50 and fine-tunes all layers (no freezing).
#
# 4) Training Methodology
# - Training function:
#   - train_one_model(train_df, valid_df, device, epochs=12, batch_size=32, lr=3e-4, img_size=224).
# - Optimizer and scheduler:
#   - optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-4).
#   - optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs).
# - Loss weighting:
#   - compute_pos_weight(train_df) calculates pos_weight per class as neg/pos; returns 1.0 if a class has zero positives.
# - Mixed precision:
#   - torch.cuda.amp.GradScaler and autocast enabled when device.type == 'cuda'.
# - DataLoader:
#   - Train: DataLoader(train_ds, batch_size=32, shuffle=True, num_workers=4, pin_memory=True).
#   - Valid: DataLoader(valid_ds, batch_size=32, shuffle=False, num_workers=4, pin_memory=True).
# - Training loop:
#   - For each batch: optimizer.zero_grad(set_to_none=True), forward, BCEWithLogitsLoss, scaler.scale(loss).backward(), scaler.step(optimizer), scaler.update().
#   - Validation every epoch computing val_loss; scheduler.step() after validation.
#   - Logging lr via scheduler.get_last_lr()[0].
# - Early stopping/regularization:
#   - No explicit early stopping, but best checkpoint is saved when val_loss improves:
#     - torch.save(best_state, CHECKPOINT_PATH).
#     - best_state captured with CPU tensors and reloaded at end.
#   - Regularization via weight_decay=1e-4 and data augmentation.
# - DEV mode:
#   - DEV_RUN environment variable shortens run: samples up to 200 training rows, epochs=1, and breaks after epoch >= 1.
#
# 5) Evaluation & Submission
# - Prediction:
#   - predict_test(model, device, img_size=224) performs batched inference over test set with TTA:
#     - Computes logits for original images and horizontally flipped images (images_flipped = torch.flip(images, dims=[3])) and averages: logits = (logits1 + logits2) / 2.0.
#     - Converts to probabilities with torch.sigmoid(logits).
# - Post-processing:
#   - No thresholding; outputs raw probabilities for ["healthy", "multiple_diseases", "rust", "scab"].
# - Submission creation:
#   - Constructs DataFrame with "image_id" followed by the four class columns.
#   - Writes to SUBMISSION_PATH via DataFrame.to_csv(index=False).
#   - Ensures correct column order: ["image_id", "healthy", "multiple_diseases", "rust", "scab"].
#
# 6) Notable Implementation Details
# - Hardware/GPU:
#   - Selects device via torch.device('cuda' if torch.cuda.is_available() else 'cpu').
#   - Uses pin_memory=True and non_blocking=True for .to(device) to speed host-to-device transfers.
#   - torch.backends.cudnn.benchmark = True for performance on CUDA (note: may reduce determinism).
# - Reproducibility:
#   - Seeds set: random.seed(SEED), np.random.seed(SEED), torch.manual_seed(SEED), torch.cuda.manual_seed_all(SEED).
#   - DataFrame shuffling uses random_state=SEED; splitting deterministic within groups.
# - Class imbalance handling:
#   - pos_weight computed from training split only, avoiding leakage.
# - CV strategy:
#   - Single train/valid split via split_train_valid with primary_label stratification; no K-fold CV.
# - Checkpointing:
#   - Saves best state dict to CHECKPOINT_PATH on validation loss improvement; reloads best_state before returning model.
# - TTA:
#   - Simple test-time augmentation with horizontal flip averaging.
# - Runtime optimizations:
#   - Mixed precision (autocast/GradScaler), num_workers=4, pin_memory, cudnn.benchmark enabled.
# - Error handling and logging:
#   - log(msg) prints timestamps; main wrapped in try/except to log and re-raise exceptions.
#
#
# Solution ID: row_734
# Score Percentile: 1.0
#
# 1) Data Preprocessing
# - Data loading:
#   - Function read_csvs(data_dir) reads train.csv and test.csv from DATA_DIR (default "/root/data"), returning df_train, df_test. It logs paths and shapes.
#   - TARGET_COLS = ["healthy", "multiple_diseases", "rust", "scab"]; NUM_CLASSES = 4.
# - Train/val split:
#   - stratified_split(df, label_cols, val_frac=0.15) uses sklearn.model_selection.StratifiedShuffleSplit with random_state=SEED to split once into df_tr and df_val.
#   - Labels for stratification are derived via argmax over one-hot columns: y = labels.argmax(axis=1).
# - Dataset class:
#   - LeafDataset(df, images_dir, transform=None, is_train=True, label_cols=TARGET_COLS)
#     - __getitem__: loads image at os.path.join(images_dir, f"{image_id}.jpg"), converts to RGB via PIL, applies transform if provided.
#     - Label handling: for training, converts multi-column one-hot target to a class index via int(np.argmax(labels)). For test, returns (image_tensor, image_id).
# - Transformations/augmentation:
#   - get_transforms(img_size=380) returns (train_tf, eval_tf):
#     - train_tf = T.Compose([
#         T.RandomResizedCrop(img_size, scale=(0.7, 1.0)),
#         T.RandomHorizontalFlip(),
#         T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.05),
#         T.RandomRotation(20),
#         T.ToTensor(),
#         T.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD),
#       ])
#     - eval_tf = T.Compose([
#         T.Resize(int(img_size * 1.14)),
#         T.CenterCrop(img_size),
#         T.ToTensor(),
#         T.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD),
#       ])
#   - IMAGENET_MEAN = [0.485, 0.456, 0.406], IMAGENET_STD = [0.229, 0.224, 0.225].
# - DataLoaders:
#   - Train DataLoader: DataLoader(ds_tr, batch_size=batch_size, shuffle=True, num_workers=min(8, os.cpu_count()), pin_memory=True)
#   - Val DataLoader: shuffle=False, same num_workers/pin_memory.
# - Fast dev mode:
#   - If FAST_DEV_RUN=1, subsets data via df_train.sample(n=min(200, len(df_train))) and df_test.sample(n=min(50, len(df_test))), sets epochs=1, batch_size=8, img_size=256, val_frac=0.2.
#
# 2) Feature Engineering
# - There is no explicit feature engineering beyond image augmentations and label conversion to indices.
# - No dimensionality reduction, feature selection, or domain-specific handcrafted features are implemented.
#
# 3) Model Selection
# - Primary model:
#   - build_model(num_classes=NUM_CLASSES, model_name='tf_efficientnet_b4_ns')
#     - Uses timm.create_model(model_name, pretrained=True, num_classes=num_classes).
#     - Default model_name comes from env var MODEL_NAME or defaults to "tf_efficientnet_b4_ns".
#     - Pretrained weights are enabled.
# - Ensembles:
#   - No multi-model ensembles are trained. At inference, a simple test-time augmentation (horizontal flip) is used to average predictions.
# - timm dependency:
#   - If timm import fails, installs timm==0.9.12 via pip and re-imports.
#
# 4) Training Methodology
# - Loss:
#   - Class-weighted CrossEntropyLoss: nn.CrossEntropyLoss(weight=class_weights).
#   - class_weights computed by compute_class_weights(df_tr, TARGET_COLS):
#     - counts = df[label_cols].sum(axis=0).values.astype(np.float32)
#     - weights = counts.max() / np.clip(counts, 1.0, None)
#     - torch.tensor(weights, dtype=torch.float32)
# - Optimizer:
#   - torch.optim.AdamW(model.parameters(), lr=lr) with lr from env var LR (default 3e-4). No explicit weight_decay argument (defaults to 0).
# - LR scheduler:
#   - torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=max(epochs,1)); scheduler.step() called once per epoch.
# - Mixed precision:
#   - Uses torch.cuda.amp:
#     - GradScaler(enabled=(device.type == 'cuda'))
#     - with torch.cuda.amp.autocast(enabled=True) around forward + loss.
# - Training loop:
#   - train_one_epoch(model, loader, optimizer, scaler, device, loss_fn):
#     - optimizer.zero_grad(set_to_none=True)
#     - outputs = model(images)
#     - loss backward via scaler.scale(loss).backward(); scaler.step(optimizer); scaler.update()
#     - Tracks running_loss and accuracy via preds = outputs.argmax(dim=1).
#   - Epoch-level validation:
#     - validate(model, loader, device):
#       - Computes softmax probabilities and accuracy.
#       - ROC AUC: Constructs one-hot labels for all_targets and computes class-wise roc_auc_score, then mean across classes. If computation fails, mean_auc = NaN.
# - Hyperparameters:
#   - epochs from env EPOCHS (default 15).
#   - batch_size from env BATCH_SIZE (default 24).
#   - img_size from env IMG_SIZE (default 380).
#   - val_frac from env VAL_FRAC (default 0.15).
# - Checkpointing:
#   - Saves checkpoint when val_auc improves:
#     - save_checkpoint(model, best_ckpt) where best_ckpt = "/workspace/artifacts/best_{model_name}_img{img_size}.pth".
#   - If no checkpoint saved (e.g., AUC NaN), saves last state before inference.
#
# 5) Evaluation & Submission
# - Validation metrics:
#   - validate returns (val_acc, val_auc). val_auc is mean per-class ROC AUC on validation split. Accuracy also computed via argmax prediction vs class index.
# - Inference:
#   - infer(model, df_test, images_dir, transform, device, tta=True, batch_size=32):
#     - DataLoader over LeafDataset with is_train=False, eval_tf transform, shuffle=False, pin_memory=True.
#     - Computes probs = softmax(outputs, dim=1). If tta=True:
#       - Performs horizontal flip TTA: flipped = torch.flip(images, dims=[3]) (width dimension).
#       - Runs model on flipped batch, averages probs: probs = (probs + probs2) / 2.0.
#     - Returns image_ids and concatenated probs array.
# - Submission creation:
#   - write_submission(image_ids, probs, out_path=SUBMISSION_PATH):
#     - Constructs DataFrame with columns TARGET_COLS, inserts 'image_id' at index 0, and writes CSV to "/workspace/submission.csv".
# - Error handling fallback:
#   - If pipeline fails, writes uniform predictions: probs = np.full((len(image_ids), NUM_CLASSES), 0.25, dtype=np.float32).
#   - If even that fails, writes a header-only CSV to signal failure.
#
# 6) Notable Implementation Details
# - Hardware and performance:
#   - Device selection: device = torch.device('cuda' if torch.cuda.is_available() else 'cpu').
#   - Uses mixed precision (AMP) and non_blocking=True when transferring tensors to GPU.
#   - DataLoader optimizations: pin_memory=True, num_workers=min(8, os.cpu_count()).
#   - optimizer.zero_grad(set_to_none=True) for minor performance gains.
# - Reproducibility:
#   - Seeds set: SEED = 42; random.seed(SEED), np.random.seed(SEED), torch.manual_seed(SEED), torch.cuda.manual_seed_all(SEED).
#   - Stratified split uses random_state=SEED.
#   - Note: No torch.backends.cudnn.deterministic/benchmark settings; DataLoader workers are not given a worker_init_fn, so complete determinism is not guaranteed.
# - CV strategy:
#   - Single train/validation split via StratifiedShuffleSplit (n_splits=1). No k-fold cross-validation.
# - Label handling:
#   - Training uses class indices derived from one-hot labels via argmax.
#   - Validation ROC AUC converts back to one-hot to compute per-class AUC against predicted probabilities; accuracy uses argmax class predictions.
# - Pretrained models:
#   - timm.create_model with pretrained=True, default "tf_efficientnet_b4_ns".
#   - Eval transform aligns with EfficientNet’s typical input size (img_size default 380); Resize(int(img_size * 1.14)) then CenterCrop(img_size).
# - Test-time augmentation (TTA):
#   - Simple horizontal flip on normalized tensor inputs within infer; averages probabilities over original and flipped versions.
# - Artifacts and paths:
#   - DATA_DIR = "/root/data"; IMAGES_DIR = "/root/data/images".
#   - SUBMISSION_PATH = "/workspace/submission.csv".
#   - ARTIFACTS_DIR = "/workspace/artifacts" (created if missing).
# - Unused helper:
#   - transform_batch(batch_imgs_tensor, transform) is defined to re-apply transforms element-wise on a batch but is not used anywhere in the pipeline.
#
#
# Solution ID: row_748
# Score Percentile: 0.5789074355
#
# 1) Data Preprocessing
# - Data loading:
#   - Reads CSVs: pd.read_csv("/root/data/train.csv") and pd.read_csv("/root/data/test.csv").
#   - Images are expected at "/root/data/images/<image_id>.jpg".
#   - Validates labels with assert set(CLASS_NAMES).issubset(df_train.columns).
# - Splitting:
#   - Creates stratification labels via argmax of one-hot: df_train["strat"] = df_train[CLASS_NAMES].values.argmax(axis=1).
#   - Uses StratifiedKFold(n_splits=5, shuffle=True, random_state=42) and takes the first split for validation: train_idx, val_idx = next(skf.split(df_train, df_train["strat"])) to form df_tr and df_val.
# - Dataset class:
#   - LeafDataset(df, img_dir, transform=None, is_train=True) returns (img, target) for training/validation and (img, image_id) for test. Targets are float32 tensors of the four class probabilities: torch.tensor(row[CLASS_NAMES].values.astype(np.float32)).
# - Transformations and augmentation via build_transforms(img_size=380, is_train=True):
#   - Training: T.RandomResizedCrop(img_size, scale=(0.7, 1.0)), T.RandomHorizontalFlip(), T.RandomVerticalFlip(), T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.05), T.ToTensor(), T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]).
#   - Validation/Test: T.Resize(int(img_size * 1.15)), T.CenterCrop(img_size), T.ToTensor(), Normalize with ImageNet stats.
# - DataLoader setup:
#   - DataLoader(train_ds, batch_size=32, shuffle=True, num_workers=min(8, os.cpu_count() or 4), pin_memory=True).
#   - Validation/test loaders use shuffle=False.
# - Dev shortcut:
#   - FAST_DEV_RUN environment var toggles subsampling and smaller config:
#     - df_tr.sample(n=min(256, len(df_tr)), random_state=42), df_val.sample(n=min(128, len(df_val)), random_state=42), df_test = df_test.head(16).
#     - img_size = 256, batch_size = 16, epochs = 1.
#
# 2) Feature Engineering
# - None beyond image preprocessing/augmentation. No new features, no dimensionality reduction, no domain-specific transforms outside of standard vision augmentations.
#
# 3) Model Selection
# - Primary model class: PlantModel(model_name="efficientnet_b3", num_classes=4).
#   - Wraps a timm model: timm.create_model(model_name, pretrained=True, num_classes=num_classes).
#   - Model choices controlled via env MODEL_NAME; comments suggest "efficientnet_b3", "tf_efficientnet_b4_ns", "convnext_tiny".
# - Output/labels:
#   - Multi-label formulation with 4 outputs and BCEWithLogitsLoss; predictions use torch.sigmoid on logits.
# - Ensembles:
#   - None. Single model trained and selected via best validation AUC.
# - Pretrained usage:
#   - pretrained=True is set in timm.create_model for transfer learning.
#
# 4) Training Methodology
# - Seeding and device:
#   - set_seed(42) sets seeds across random, numpy, torch, torch.cuda; sets torch.backends.cudnn.benchmark = True.
#   - get_device() selects CUDA if available, else CPU.
# - Loss/optimizer/scheduler:
#   - loss_fn = nn.BCEWithLogitsLoss().
#   - optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-4).
#   - scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs).
# - Mixed precision:
#   - Uses torch.cuda.amp.autocast(enabled=(device.type == 'cuda')) and torch.cuda.amp.GradScaler(enabled=(device.type == 'cuda')).
# - Training loop:
#   - train_one_epoch(model, loader, optimizer, scaler, device, loss_fn) uses optimizer.zero_grad(set_to_none=True), scales loss, backward, step, update scaler; aggregates loss.
#   - validate(model, loader, device) computes probabilities with torch.sigmoid and AUC via compute_mean_auc.
#   - Epochs default: epochs = 12 (or 1 in FAST_DEV_RUN).
#   - Batch size default: batch_size = 32.
#   - Image size default: img_size = 380.
#   - Checkpointing: saves best by validation AUC: torch.save({"model": model.state_dict(), "model_name": model_name, "img_size": img_size}, "/workspace/best.pth").
#   - Early stopping: none in normal mode; in FAST_DEV_RUN it breaks after 1 epoch.
# - Learning rate schedule logging:
#   - Prints current lr via optimizer.param_groups[0]['lr'] each epoch and steps scheduler after validation.
#
# 5) Evaluation & Submission
# - Validation metric:
#   - compute_mean_auc(y_true, y_pred) computes per-class roc_auc_score; ignores NaNs for columns with a single class in the fold; returns mean of valid AUCs.
#   - validate returns (val_auc, y_pred, y_true) for the validation set.
# - Test prediction:
#   - Inference loop collects probs = torch.sigmoid(logits).cpu().numpy() and image_ids.
# - Post-processing:
#   - Builds submission DataFrame: sub = pd.DataFrame(y_pred, columns=CLASS_NAMES); sub.insert(0, "image_id", ids).
#   - Ensures row order aligns with test.csv via order_df = pd.read_csv(test_csv)[["image_id"]] and sub = order_df.merge(sub, on="image_id", how="left").
#   - Fills any missing class predictions (e.g., due to FAST_DEV_RUN subset) with 0.25: sub[c] = sub[c].fillna(0.25).astype(float).
# - Thresholding:
#   - None. Submits raw sigmoid probabilities for all 4 classes as required by competition.
# - Submission file:
#   - Writes to "/workspace/submission.csv" and prints sub.head().
#
# 6) Notable Implementation Details
# - Package setup:
#   - Auto-installs missing packages "timm" and "sklearn" at runtime using pip if import fails.
# - GPU utilization and performance:
#   - Uses CUDA automatically if available; pin_memory=True in DataLoaders; up to 8 workers.
#   - Mixed precision training (autocast + GradScaler) to speed up and reduce memory.
#   - optimizer.zero_grad(set_to_none=True) for slight performance/memory gains.
#   - torch.backends.cudnn.benchmark = True for potentially faster convolutions (non-deterministic).
# - Reproducibility:
#   - Seeds are set via set_seed(42), but cudnn.benchmark=True may compromise strict determinism.
# - Cross-validation strategy:
#   - StratifiedKFold with 5 splits; only the first fold is used as a simple validation split (no full CV/averaging).
#   - Stratification labels derived by argmax from one-hot label columns: df_train["strat"].
# - Checkpoint robustness:
#   - Saves "model_name" and "img_size" in checkpoint; on load, if model_name differs from current env, it reinitializes PlantModel with the checkpoint’s model_name before loading state_dict.
# - Data leakage prevention:
#   - Validation is strictly within train.csv via StratifiedKFold; test.csv is only used for inference and to enforce submission order.
#   - Ensures submission includes all required class columns and order matching test.csv.
# - Label handling choice:
#   - Treats the problem as multi-label using BCEWithLogitsLoss and sigmoid; competition labels are mutually exclusive, but this formulation still yields valid per-class probabilities and AUC validation.
# - Dev mode:
#   - FAST_DEV_RUN environment variable provides a quick smoke test by subsetting data, reducing image size, batch size, and epochs, and filling missing test rows with 0.25 to meet submission schema.
#
#
# Solution ID: row_753
# Score Percentile: 0.9946889226000001
#
# 1) Data Preprocessing
# - Data loading:
#   - Reads CSVs with pandas: train_df = pd.read_csv(train_csv_path), test_df = pd.read_csv(test_csv_path), with assertions for schema.
#   - TARGET_COLUMNS = ['healthy','multiple_diseases','rust','scab'] used to verify train.csv and as label columns.
#   - Image paths constructed in PlantDataset.__getitem__: img_path = self.images_dir / f"{img_id}.jpg".
# - Train/val split:
#   - Derives a single label for stratification via derive_single_label(row), mapping to {healthy:0, rust:1, scab:2, multiple_diseases:3}. This avoids collapsing "multiple_diseases" with others during stratification.
#   - StratifiedKFold(n_splits=5, shuffle=True, random_state=42) used; only the first split is taken. Fallback to a random 80/20 split if sklearn not available.
# - Class weights:
#   - compute_pos_weight(df) calculates per-class pos_weight for BCEWithLogitsLoss: pos_weight = (neg + 1e-6) / (pos + 1e-6), using train_split labels.
# - Dataset and loaders:
#   - Custom Dataset class PlantDataset(df, images_dir, transforms, is_train=True). Returns (image tensor, label tensor of shape (4,), image_id). For is_train=False, labels are zeros.
#   - DataLoaders:
#     - train_loader = DataLoader(train_ds, batch_size=32, shuffle=True, num_workers=8, pin_memory=True) (adjusted to 16/2 if FAST_DEV_RUN).
#     - val_loader = DataLoader(val_ds, batch_size=32, shuffle=False, num_workers=8, pin_memory=True).
# - Transformations and augmentation:
#   - IMG_SIZE = 384 (256 if FAST_DEV_RUN).
#   - train_tfms = transforms.Compose([
#     transforms.RandomResizedCrop(IMG_SIZE, scale=(0.8, 1.0)),
#     transforms.RandomHorizontalFlip(),
#     transforms.RandomVerticalFlip(),
#     transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.05),
#     transforms.RandomRotation(20),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225]),
#   ])
#   - val_tfms = transforms.Compose([
#     transforms.Resize(IMG_SIZE + 32),
#     transforms.CenterCrop(IMG_SIZE),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225]),
#   ])
# - Fast dev run:
#   - Controlled by env FAST_DEV_RUN; shrinks train/val samples to 256/128 respectively and adjusts IMG_SIZE, batch size, num_workers, epochs, scheduler T_max, and disables TTA.
#
# 2) Feature Engineering
# - None applied to tabular features; this is pure image modeling.
# - The only derived feature is strat_label for splitting (not used in modeling).
#
# 3) Model Selection
# - Primary model:
#   - If timm available: timm.create_model('tf_efficientnet_b4_ns', pretrained=True, num_classes=NUM_CLASSES), where NUM_CLASSES = 4.
#   - Fallback to torchvision resnet50:
#     - model = resnet50(weights=None) initially, replacing model.fc with nn.Linear(in_features, NUM_CLASSES).
#     - Further attempt to load pretrained weights: ResNet50_Weights.DEFAULT. Wrap with custom head ResnetHead(base_model, num_classes) where base.fc = nn.Identity() and new self.fc = nn.Linear(in_features, num_classes).
#   - Final fallback: TinyCNN with three Conv2d blocks, MaxPool2d, AdaptiveAvgPool2d(1), and a Linear classifier.
# - No ensembles (no stacking/blending/voting).
# - Pretrained usage:
#   - EfficientNet B4 NS via timm with pretrained=True.
#   - Torchvision ResNet50 pretrained weights via ResNet50_Weights.DEFAULT if timm not available.
#
# 4) Training Methodology
# - Training loop:
#   - EPOCHS = 12 (2 if FAST_DEV_RUN).
#   - train_one_epoch(model, loader, optimizer, criterion, epoch, scaler) uses mixed precision if CUDA: torch.cuda.amp.autocast and GradScaler.
#   - validate(model, loader, criterion) computes loss and macro ROC AUC via sklearn.metrics.roc_auc_score(average='macro'); applies sigmoid to logits.
# - Loss:
#   - criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight.to(DEVICE)) for multi-label classification with class imbalance handling.
# - Optimizer:
#   - optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4).
# - LR scheduler:
#   - scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10) (T_max=2 if FAST_DEV_RUN).
# - Batch size and workers:
#   - batch_size = 32 (16 if FAST_DEV_RUN), num_workers = 8 (2 if FAST_DEV_RUN).
# - Early stopping/regularization:
#   - No explicit early stopping; best model checkpointing by val_auc in the loop:
#     - torch.save({'model': model.state_dict(), 'epoch': epoch, 'val_auc': val_auc, 'cfg': {...}}, MODEL_SAVE_PATH) when val_auc improves.
#   - Regularization via weight_decay=1e-4 and data augmentation.
#
# 5) Evaluation & Submission
# - Evaluation:
#   - validate returns avg_loss and macro AUC. best_auc tracked and used for checkpointing.
# - Inference:
#   - infer(model, df, tfms, batch_size=64, num_workers=8, tta=False). For test-time augmentation (if not FAST_DEV_RUN):
#     - aug_imgs = [images, torch.flip(images, dims=[3]), torch.flip(images, dims=[2])], average sigmoid probabilities over these three variants.
#   - Outputs probabilities via torch.sigmoid on logits.
# - Post-processing:
#   - No thresholding; multi-label probabilities used directly.
#   - Clipping to [0,1] for each target column: sub_df[col] = sub_df[col].clip(0, 1).
# - Submission creation:
#   - Builds DataFrame: sub_df = pd.DataFrame(probs, columns=TARGET_COLUMNS); inserts 'image_id' column first.
#   - Ensures column order matches sample_submission.csv if available: sub_df = sub_df[sample_cols].
#   - Writes submission CSV to SUBMISSION_PATH with index=False.
#
# 6) Notable Implementation Details
# - GPU/TPU:
#   - DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'; mixed precision enabled via scaler = torch.cuda.amp.GradScaler(enabled=(DEVICE=='cuda')).
# - Runtime optimizations:
#   - pin_memory=True in DataLoaders; num_workers up to 8; cudnn.benchmark=True (in set_seed) for speed; mixed precision training; TTA during inference.
# - Reproducibility:
#   - set_seed(42) sets seeds for Python, NumPy, Torch; torch.backends.cudnn.deterministic = False and benchmark = True favors speed over strict determinism.
# - CV strategy:
#   - StratifiedKFold with 5 splits, but only first split used; not a full CV ensemble.
# - Data leakage prevention:
#   - Proper train/val split and no use of test data during training; val_loader has shuffle=False; target labels only used for train/val; PlantDataset returns zeros for y in test mode (is_train=False), avoiding accidental label usage.
# - Model management:
#   - Attempts to import or install timm at runtime; falls back gracefully to torchvision/tiny CNN.
#   - Saves best checkpoint to MODEL_SAVE_PATH; reloads best before inference.
#   - Training history logged to LOG_PATH as JSON.
# - Fast development:
#   - FAST_DEV_RUN environment flag reduces dataset sizes, image sizes, epochs, and disables TTA for quick iteration.
#
#
# Solution ID: row_754
# Score Percentile: 0.9984825493
#
# 1) Data Preprocessing
# - Data loading
#   - Reads CSVs via pandas in "main": "train_df = pd.read_csv(train_csv)" and "test_df = pd.read_csv(test_csv)" where "train_csv = os.path.join(DATA_DIR, 'train.csv')" and "test_csv = os.path.join(DATA_DIR, 'test.csv')".
#   - Verifies image directory "IMAGES_DIR = os.path.join(DATA_DIR, 'images')" exists and checks two sample image files: "assert os.path.exists(os.path.join(IMAGES_DIR, sample_train_id + '.jpg'))" and same for test.
# - Dataset class
#   - "PlantPathologyDataset": constructs with "(df, images_dir, mode, transform)". It sets "self.has_labels" only if the four label columns exist and "mode != 'test'".
#   - "__getitem__": loads PIL image with "Image.open(img_path).convert('RGB')", applies "transform" if provided, and returns:
#     - For train/val: "(img, target, image_id)" where "target" is "torch.from_numpy(self.labels[idx])".
#     - For test: "(img, image_id)".
# - Splitting
#   - "stratified_split(train_df, val_frac=0.1)": derives single label per sample via "labels.argmax(axis=1)", buckets indices by class into a dict, does "random.shuffle(idxs)", and holds out "n_val = max(1, int(n * val_frac))" per class for validation. Returns "train_df_split" and "val_df_split".
# - Transformations and augmentation
#   - "build_transforms(img_size, mode)":
#     - Train transforms: "T.Resize(int(img_size*1.05))", "T.RandomResizedCrop(img_size, scale=(0.7, 1.0), ratio=(0.75, 1.33))", "T.RandomHorizontalFlip(p=0.5)", "T.RandomVerticalFlip(p=0.1)", "T.RandomRotation(degrees=20)", "T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.02)", "T.ToTensor()", "T.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225])".
#     - Val/Test transforms: "T.Resize(int(img_size*1.05))", "T.CenterCrop(img_size)", "T.ToTensor()", "T.Normalize(...)".
#
# 2) Feature Engineering
# - None beyond image augmentations and normalization. No additional features, selection, or dimensionality reduction are implemented.
#
# 3) Model Selection
# - Model wrapper
#   - "ModelWrapper(model_name=None, num_classes=4, img_size=384)":
#     - If timm is available: "timm.create_model(name, pretrained=True, num_classes=num_classes)" with default "model_name" set to "convnext_base.fb_in22k_ft_in1k" and "img_size = 384".
#     - Else fallback: torchvision "models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V2)", replacing the final FC: "self.backbone.fc = nn.Linear(in_feats, num_classes)" and "img_size = 224".
#   - "forward(self, x)" returns raw logits from "self.backbone(x)". Note: "self.sigmoid = nn.Sigmoid()" is defined but not used in forward.
# - Pretrained models
#   - Uses pretrained weights ("pretrained=True") for timm models; uses pretrained ResNet50 weights ("IMAGENET1K_V2") in fallback.
# - Ensembles
#   - No ensembling (stacking/blending/voting). Single model training and inference.
#
# 4) Training Methodology
# - Function "train_and_validate(train_df, val_df, device, timer, epochs=12, batch_size=24, lr=5e-4, model_name=None, img_size=384)"
#   - Datasets and loaders:
#     - Train dataset: "PlantPathologyDataset(train_df, IMAGES_DIR, mode='train', transform=tf_train)".
#     - Val dataset: "PlantPathologyDataset(val_df, IMAGES_DIR, mode='val', transform=tf_val)".
#     - DataLoaders: "shuffle=True" for train, "shuffle=False" for val, "num_workers = min(8, os.cpu_count() or 4)", "pin_memory=True", "drop_last=False".
#   - Loss: "nn.BCEWithLogitsLoss()" for multi-label outputs.
#   - Optimizer: "torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)".
#   - LR schedule: "torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)" stepped once per epoch.
#   - AMP: "torch.cuda.amp.autocast(enabled=(device.type == 'cuda'))" and "torch.cuda.amp.GradScaler(enabled=(device.type == 'cuda'))".
#   - Epoch loop:
#     - Training: zero grads via "optimizer.zero_grad(set_to_none=True)", compute "loss = criterion(logits, targets)", scale/backward/step with GradScaler.
#     - Validation: no grad, compute "loss", and probabilities via "probs = torch.sigmoid(logits)"; accumulate "all_probs" and "all_targets".
#   - Metric: AUC computed by "multi_label_auc(y_true, y_prob)" which wraps "sklearn.metrics.roc_auc_score" per class and averages valid scores.
#   - Checkpointing: saves best by AUC to "best_path = os.path.join(CACHE_DIR, 'best_model.pth')" with "torch.save({'model_state': model.state_dict(), 'auc': best_auc, 'epoch': epoch, 'img_size': model.img_size}, best_path)".
#   - Fast dev run: if "FAST_DEV_RUN" env flag set, breaks after first epoch.
#   - After training: loads best checkpoint if exists via "model.load_state_dict(ckpt['model_state'])".
# - Training config in "main"
#   - If timm: "model_name = 'convnext_base.fb_in22k_ft_in1k'", "img_size = 384", "batch_size = 24".
#   - Else: torchvision fallback: "img_size = 224", "batch_size = 32".
#   - "epochs = 12" (or "1" if FAST_DEV_RUN), "lr = 5e-4".
#
# 5) Evaluation & Submission
# - Prediction method
#   - "infer(model, test_df, device, tta=False)": val/test transform pipeline, DataLoader "batch_size=32", applies model, gets "logits = model(imgs)", probabilities via "probs = torch.sigmoid(logits)".
#   - Note: "tta" parameter exists but is not used; no test-time augmentation implemented.
# - Post-processing
#   - No thresholding; outputs raw probabilities for each of the four labels.
# - Label handling
#   - Ensures DataFrame columns: creates "sub_df = pd.DataFrame(y_prob, columns=['healthy', 'multiple_diseases', 'rust', 'scab'])" and inserts "image_id".
#   - Final order enforced: "sub_df = sub_df[['image_id', 'healthy', 'multiple_diseases', 'rust', 'scab']]".
# - Submission file creation
#   - Writes CSV to "SUBMISSION_PATH = '/workspace/submission.csv'" with "sub_df.to_csv(SUBMISSION_PATH, index=False)" and logs shape.
#
# 6) Notable Implementation Details
# - GPU and AMP
#   - Device selection: "device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')".
# ...
#
# Solution ID: row_1180 (percentile: 0.9992412747)
# Here’s why this pipeline performs well on multi-label apple leaf disease classification, what sets it apart, and how its design aligns with the metric and domain challenges.
#
# 1) Why it works: code-backed technical choices that drive performance
# - Pretrained, high-capacity backbone tailored to image tasks
#   - Uses a strong timm backbone: tf_efficientnet_b4_ns with pretrained=True, num_classes=4 (“LeafModel” via timm.create_model). This gives robust mid-scale capacity and transfer learning from ImageNet, which is critical for subtle texture/spot patterns on leaves.
#   - Correct normalization for pretrained weights: IMAGENET_MEAN/STD in both train and valid transforms.
#   - Large input size (CFG['img_size'] = 512) preserves fine-grained lesion details (rust pustules, scab lesions), improving separability.
# - Proper multi-label formulation
#   - BCEWithLogitsLoss for independent class probabilities: torch.nn.BCEWithLogitsLoss(...). This matches the multi-label nature (co-occurrence possible) and avoids softmax mutual exclusivity errors.
#   - Sigmoid at inference: torch.sigmoid(logits) ensures well-calibrated per-class probabilities for ROC AUC ranking.
# - Imbalance-aware training
#   - Per-class pos_weight from training fold only: compute_pos_weight(df) returns N_negative / max(N_positive, 1.0), then BCEWithLogitsLoss(pos_weight=...). This counteracts rare classes and improves recall/precision balance, directly improving ROC curves for underrepresented diseases.
# - Strong augmentation against domain variability
#   - Albumentations pipeline in get_train_transforms(size): Resize(512), HorizontalFlip, ShiftScaleRotate, RandomBrightnessContrast, Normalize. These directly target leaf pose (angle), scale/rotation, and lighting variability within trees/shade, helping robustness to real-world noise and atypical looks.
# - Cross-validation + ensembling
#   - StratifiedKFold with shuffle, random_state=42, folds=CFG['folds'], splitting by onehot_to_class(train_df) ensures similar label distribution across folds, reducing variance of estimates.
#   - Best-per-fold checkpointing with early stopping (patience=3) saves the most ROC-AUC-aligned model per fold.
#   - At inference, averages predictions across folds and also uses TTA horizontal flip: preds = torch.stack(fold_preds, dim=0).mean(dim=0). This reduces variance and improves ranking stability across classes.
# - Training stability and efficiency
#   - AdamW with weight_decay=1e-4 and CosineAnnealingLR over CFG['epochs'] improves convergence and generalization.
#   - AMP (GradScaler + autocast) enables larger effective batch size and stable training on GPU.
#   - Consistent seeding and sensible DataLoader settings (pin_memory=True, num_workers=4) provide performance and a baseline of reproducibility.
#
# 2) Key strengths vs lower-scoring approaches
# - Uses BCEWithLogitsLoss + sigmoid for multi-label; many weaker baselines mistakenly use softmax/CrossEntropy, hurting co-occurrence modeling and per-class probability quality.
# - Class imbalance handled via pos_weight computed per class on the training fold, rather than ignoring imbalance or using a single global weight. This typically boosts ROC AUC for rare classes.
# - Strong data-centric augmentation that matches field variability: geometric and photometric transformations via Albumentations, instead of minimal/no augmentation.
# - Pretrained EfficientNet-B4 (tf_efficientnet_b4_ns) at 512 resolution, providing better feature granularity than smaller/backbone-from-scratch models.
# - Cross-validation with fold ensembling and TTA horizontal flip; weaker setups often rely on a single split and single model without TTA, leading to higher variance and worse ranking metrics.
# - Metric-aligned model selection: validates with mean column-wise ROC AUC and early stops on that score; weaker baselines often optimize for loss or accuracy, which misaligns with leaderboard evaluation.
# - Implementation robustness:
#   - Correct normalization (IMAGENET_MEAN/STD) with pretrained weights.
#   - AMP for throughput and stability.
#   - Ensures submission order matches test.csv; avoids accidental shuffling mismatches.
#
# 3) Alignment with the task metric and challenges
# - Metric match
#   - Validation directly computes mean column-wise ROC AUC (roc_auc_score with per-label averaging), the same metric used for evaluation. Best checkpoints are chosen by this metric, ensuring training focuses on probability ranking quality per class.
#   - Sigmoid probabilities and no forced normalization across classes align perfectly with multi-label ROC AUC, which evaluates each class independently.
# - Domain challenges
#   - Multi-label co-occurrence: Independent BCE loss and sigmoid outputs let the model assign high probabilities to multiple classes on a single leaf.
#   - Class imbalance and rare/atypical symptoms: pos_weight combats skew toward common labels, helping ROC curves for rare diseases.
#   - Variability in leaf age/genotype/lighting: HorizontalFlip, ShiftScaleRotate, RandomBrightnessContrast augmentations target pose and illumination changes; EfficientNet’s capacity + 512 resolution captures subtle lesions across ages/genotypes.
#   - Depth/pose/light/shade: Augmentations plus TTA horizontal flip and fold averaging reduce sensitivity to viewpoint and lighting variations.
#   - Expert-knowledge leverage via pretrained features: ImageNet-pretrained EfficientNet offers strong low- and mid-level visual features (edges, textures) beneficial for lesion pattern recognition without needing massive domain-specific data.
#
# In short, the pipeline is strong because it uses the right problem formulation (multi-label BCE + sigmoid), addresses imbalance, leverages a capable pretrained backbone at adequate resolution, augments aggressively for real-world variability, and aligns training/selection with the ROC AUC metric—then further stabilizes results via cross-validation ensembling and TTA.
#
# Solution ID: row_1231 (percentile: 0.9738239757)
# Here is why this solution achieved a high score and how its design aligns with the task and metric.
#
# 1) Why it works: key technical choices that drove performance
# - Strong pretrained backbone
#   - Uses timm.create_model("tf_efficientnet_b4_ns", pretrained=True, num_classes=4), a high-capacity, well-regularized ImageNet-pretrained model.
#   - ImageNet normalization (mean/std) is applied in transforms, ensuring the backbone’s pretrained features transfer effectively.
#   - Larger input size (image_size=448) preserves fine-grained leaf textures needed for disease cues.
#
# - Correct objective for multi-label with imbalance
#   - Trains with nn.BCEWithLogitsLoss(pos_weight=pos_weight), not softmax cross-entropy, so classes are independent and multiple labels can be active simultaneously.
#   - pos_weight derived from the full training set counteracts rare classes, improving probability ranking for underrepresented diseases.
#
# - Robust augmentation tailored to field variability
#   - Albumentations pipeline includes HorizontalFlip, VerticalFlip, ShiftScaleRotate, HueSaturationValue, RandomBrightnessContrast, and CoarseDropout.
#   - These directly address lighting changes within trees, angles/pose, occlusions, and heterogeneous leaf appearances noted in the challenges.
#
# - Generalization via cross-validation and ensembling
#   - StratifiedKFold across 5 folds trains multiple models and then averages their probabilities, reducing variance and improving ROC ranking robustness, especially under distribution shifts.
#   - Best checkpoints per fold are selected by validation mean_columnwise_auc, aligning model selection with the competition metric.
#
# - Metric-aware training and inference
#   - Evaluates with mean_columnwise_auc on sigmoid probabilities per class, exactly matching the competition’s per-label ROC AUC aggregation.
#   - Submits raw probabilities (no thresholds), which is optimal for AUC-based evaluation.
#
# - Inference boosts with TTA
#   - Test-time augmentation averages predictions from original, horizontal flip, and vertical flip, increasing stability of rankings across pose/orientation variation.
#
# - Stable, efficient optimization
#   - AdamW with weight decay, CosineAnnealingLR over epochs, mixed precision (autocast + GradScaler), and gradient clipping (=1.0) collectively enable smooth convergence without overfitting or instability.
#
# Code-backed evidence: build_model uses tf_efficientnet_b4_ns with pretrained=True; loss is BCEWithLogitsLoss(pos_weight=…); transforms include Flip/ShiftScaleRotate/HSV/BrightnessContrast/CoarseDropout; cross-validation via StratifiedKFold; evaluation via mean_columnwise_auc; TTA via flipped variants; optimizer AdamW + CosineAnnealingLR; mixed precision and gradient clipping in train_one_epoch.
#
# 2) Key strengths versus lower-scoring approaches
# - Objective and outputs match multi-label and AUC metric: BCE + sigmoid probabilities outperform softmax/CE setups that force single-label assumptions.
# - Class imbalance handled via pos_weight; many weaker baselines ignore this, hurting rare class ranking.
# - Strong backbone and larger input size: EfficientNet-B4 pretrained with appropriate normalization outperforms smaller or unpretrained models.
# - Rich augmentation specifically combats field variability; weaker pipelines often rely on minimal augmentations, reducing robustness to lighting/pose/occlusion.
# - Cross-validation with fold ensembling reduces variance and improves generalization; single-split training typically scores lower.
# - TTA provides consistent gains in probability ranking; many baselines skip it.
# - Metric-driven checkpointing (best AUC) ensures the selected model is optimal for the exact evaluation criterion.
#
# 3) Alignment with task metric and identified challenges
# - Metric alignment: Training and validation compute mean_columnwise_auc and submit per-class probabilities, directly optimizing for and evaluating the same ROC AUC measure used for scoring.
# - Multi-label co-occurrence: BCEWithLogitsLoss and sigmoid outputs allow multiple diseases to be predicted independently.
# - Class imbalance and rare/novel symptoms: pos_weight strengthens learning signals for rare classes, improving per-class ROC AUC.
# - High variability (leaf age, genetics, lighting) and depth/pose effects: Augmentations (HueSaturationValue, BrightnessContrast, flips, rotations, scale/shift) and TTA explicitly handle illumination, color shifts, orientation, and composition changes.
# - Distribution shift/annotation noise: Fold ensembling and robust augmentation increase resilience to shifts and inconsistencies, improving ranking stability across classes.
# - Expert knowledge leverage: The augmentation choices mirror practical field conditions (shade, occlusion, variable angles), embedding domain-informed variability into training.
#
# Overall, the combination of a strong pretrained model, multi-label-aware loss with imbalance handling, domain-relevant augmentation, cross-validation ensembling, TTA, and metric-aligned evaluation explains the high ROC AUC performance.
#
# Solution ID: row_1232 (percentile: 0.8687405159)
# 1) Why it works (code-backed reasons)
# - Correct multi-label formulation and loss: The model uses nn.BCEWithLogitsLoss with sigmoid outputs, not softmax, which is essential when multiple diseases can co-occur. Class imbalance is directly handled via pos_weight computed from train_df (labels_matrix.sum, neg_counts/pos_counts), improving signal for rare labels.
# - Strong pretrained backbone at appropriate resolution: timm.create_model("tf_efficientnet_b3_ns", pretrained=True, num_classes=N_CLASSES) with IMG_SIZE=380 leverages Noisy Student EfficientNet-B3’s texture/color sensitivity that works well on leaf disease patterns.
# - Augmentation tailored to orchard variability: Albumentations pipeline includes flips, RandomRotate90, ShiftScaleRotate, ColorJitter, and RandomBrightnessContrast with reflect padding (cv2.BORDER_REFLECT_101). These choices explicitly target angle, pose, and lighting variation within trees while preserving botanical structures, improving generalization under the stated challenges.
# - Metric-aligned model selection: The epoch_runner computes per-label roc_auc_score (average=None) and uses the mean across labels as the validation score, then saves the “best” checkpoint per fold by this val_auc. This tightly aligns training/selection with the competition’s mean column-wise ROC AUC.
# - Variance reduction via ensembling and TTA: 5-fold KFold(shuffle=True, random_state=SEED) training plus flip-based TTA (original + HorizontalFlip, optionally VerticalFlip) averages predictions across folds and views, stabilizing probabilities under pose/depth changes noted in the challenge.
# - Solid training mechanics: AdamW(lr=2e-4, weight_decay=1e-5) with a simple step-down schedule, mixed precision (torch.cuda.amp) on GPU, pin_memory DataLoaders, and reproducible seeds collectively enable efficient, stable training at reasonably large batch sizes and image resolution.
#
# 2) Key strengths versus lower-scoring approaches
# - Problem-appropriate outputs: Using BCEWithLogitsLoss with sigmoid and per-label probabilities avoids a common mistake of treating the task as single-label softmax classification.
# - Explicit imbalance handling: pos_weight from the full training label distribution boosts learning for rare classes that are often neglected in simpler baselines.
# - Robust generalization: Comprehensive, domain-relevant augmentations plus TTA directly counter pose/lighting variability; many weaker solutions either under-augment or use generic transforms that don’t address orchard conditions.
# - Cross-validation and checkpointing by AUC: 5-fold CV and selecting best checkpoints by the exact evaluation metric reduce overfitting to any single split and ensure metric-focused model selection, outperforming single-split or accuracy-based early stopping.
# - High-capacity pretrained vision model: EfficientNet-B3 Noisy Student is a strong choice for fine-grained plant textures; weaker baselines often use smaller/backbones or non-pretrained models, limiting feature quality.
# - Engineering for reliability: Robust image I/O (cv2 with PIL fallback), reflect padding to avoid edge artifacts, IMAGENET normalization, and reproducibility via seeds help avoid subtle data/processing issues that can degrade AUC.
#
# 3) Alignment with the task metric and identified challenges
# - Metric alignment: Training and model selection optimize mean column-wise ROC AUC by computing per-class ROC AUC in validation and averaging; predictions are continuous probabilities from sigmoid, exactly what ROC AUC rewards (ranking quality rather than thresholded accuracy).
# - Multi-label co-occurrence: Sigmoid outputs with BCEWithLogitsLoss correctly allow simultaneous activation of multiple diseases on one leaf.
# - Class imbalance and rare/novel cases: pos_weight increases loss contributions for underrepresented labels, improving ranking for rare classes and mitigating skew in AUC.
# - Variability in leaf appearance: Augmentations (flips, rotations, shifts, brightness/contrast/color jitter) mimic real orchard conditions (angle, light, shade), while reflect padding prevents artificial borders—both key to handling distribution shift and pose/depth factors.
# - Pose/light sensitivity at inference: Flip-based TTA averages predictions over different views, reducing sensitivity to orientation and shadows, which directly benefits ROC ranking stability.
# - Expert-knowledge echoes: The augmentation choices reflect practical plant pathology imaging scenarios (intra-tree lighting variation, leaf orientations, camera angles), improving the model’s ability to identify atypical symptoms without overfitting to canonical views.
#
# Collectively, these choices produce calibrated, robust per-label probability estimates and train with the same metric used for evaluation, which is why the approach scores well.

# %%
archive_file(archive_dir = "/checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/summarization/",
             file_path="/checkpoint/maui_sft/winnieyangwn/rlm_dumps/summarization/gpt-5_summarization_513_plant-pathology-2020-fgvc7_2026-02-11_03-49-42_4be09052.jsonl")
# Out:
# Archived: /checkpoint/maui_sft/winnieyangwn/rlm_dumps/summarization/gpt-5_summarization_513_plant-pathology-2020-fgvc7_2026-02-11_03-49-42_4be09052.jsonl -> /checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/summarization/gpt-5_summarization_513_plant-pathology-2020-fgvc7_2026-02-11_03-49-42_4be09052.jsonl
# '/checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/summarization/gpt-5_summarization_513_plant-pathology-2020-fgvc7_2026-02-11_03-49-42_4be09052.jsonl'
