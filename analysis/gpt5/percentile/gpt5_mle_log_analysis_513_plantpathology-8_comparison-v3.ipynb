# %% [markdown]
# # LOG:
#
# /checkpoint/maui_sft/winnieyangwn/rlm_dumps/gpt-5_summarization_513_iwildcam-2019-fgvc6_2026-02-09_07-05-37_3bfb9fbc.jsonl

# %%
import sys
import importlib


sys.path.append('/home/winnieyangwn/rlm/analysis')
import rlm_log_utils
importlib.reload(rlm_log_utils)
from rlm_log_utils import *

# %% [markdown]
# ## Usage Example
#
# Load the log file and extract key information:

# %% [markdown]
# # Load

# %%
import glob
import os

run_id = 513
model_name = "gpt-5"
task_name = "plant-pathology-2021-fgvc8"
log_dir = "/checkpoint/maui_sft/winnieyangwn/rlm_dumps/comparison-v3"
codebase_extensions = [".py", ".md", ".yaml"]

# Option 1: Provide a specific log name to load directly
log_name = None  # e.g., "gpt-5_summarization_513_20260208_123456.jsonl"

if log_name:
    # Directly load the specified log file
    LOG_PATH = os.path.join(log_dir, log_name)
    if not os.path.exists(LOG_PATH):
        raise FileNotFoundError(f"Specified log file not found: {LOG_PATH}")
    print(f"Loading specified log: {LOG_PATH}")
else:
    # Use underscore after run_id to avoid matching "summarization_comparison_*" logs
    LOG_PATH_PREFIX = f"{log_dir}/{model_name}_comparison_{run_id}_{task_name}"

    # Find all log files matching the prefix pattern (only .jsonl files)
    matching_logs = glob.glob(f"{LOG_PATH_PREFIX}*.jsonl")

    if not matching_logs:
        raise FileNotFoundError(f"No log files found matching prefix: {LOG_PATH_PREFIX}")

    # Get the most recent log file by modification time
    LOG_PATH = max(matching_logs, key=os.path.getmtime)
    print(f"Found {len(matching_logs)} matching log file(s)")
    print(f"Loading most recent: {LOG_PATH}")

# Load the log - first entry is metadata, rest are iterations
entries = load_rlm_log(LOG_PATH)
metadata = entries[0]
iterations = entries[1:]

print(f"Loaded {len(iterations)} iterations")
# Out:
# Found 1 matching log file(s)
# Loading most recent: /checkpoint/maui_sft/winnieyangwn/rlm_dumps/comparison-v3/gpt-5_comparison_513_plant-pathology-2021-fgvc8_2026-02-11_07-39-40_99b7fe99.jsonl
# Loaded 3 iterations

# %% [markdown]
# # Metadata

# %%
# View metadata
print("=== METADATA ===")
for k, v in metadata.items():
    if k != "backend_kwargs":
        print(f"{k}: {v}")
# Out:
# === METADATA ===
# type: metadata
# timestamp: 2026-02-11T05:39:29.239548
# root_model: gpt-5
# max_depth: 2
# max_iterations: 10
# backend: azure_openai
# environment_type: local
# environment_kwargs: {'setup_code': '\nimport pandas as pd\n\n# Load rollout data as DataFrame\nrollout_df = pd.read_json(\'/checkpoint/maui_sft/winnieyangwn/amaia_dumps/513/trajectories/513_metadata.jsonl\', lines=True)\nprint(f"Loaded {len(rollout_df)} total rollouts")\n\n# Filter to specific task\nrollout_df = rollout_df[rollout_df[\'task_name\'] == \'plant-pathology-2021-fgvc8\']\nprint(f"Filtered to {len(rollout_df)} rollouts for task: plant-pathology-2021-fgvc8")\n'}
# other_backends: None

# %%
# Compare with timestamp-based runtime
runtime = get_total_runtime(entries)
print(f"Timestamp-based runtime: {runtime.total_seconds():.2f}s")
# Out:
# Timestamp-based runtime: 511.08s

# %%
# Check number of iterations actually taken by model
num_iterations = len(iterations)
print(f"Number of iterations taken: {num_iterations}")

# You can also use extract_all for a comprehensive summary
summary = extract_all(LOG_PATH)
print(f"Number of iterations (from extract_all): {summary['num_iterations']}")
# Out:
# Number of iterations taken: 3
# Number of iterations (from extract_all): 3

# %% [markdown]
# # Final Answer

# %%
# Get the final answer
final_answer = get_final_answer(iterations)
print("=== FINAL ANSWER ===")
print(final_answer if final_answer else "No final answer found")
# print(f"\n(Total length: {len(final_answer) if final_answer else 0} chars)")
# Out:
# === FINAL ANSWER ===
# Contrastive Pattern Analysis (High vs Low Performance)
# Thresholds:
# - High Score: percentile >= 0.6
# - Low Score: percentile < 0.6
#
# Contrastive Pattern Analysis for multi-label apple leaf disease detection
#
# Data preprocessing
# - High-score solutions did
#   - Common: Parse space-separated labels into multi-hot targets; ImageNet normalization; robust PIL RGB loading.
#   - Many: Multilabel stratified splits (MultilabelStratifiedKFold) to form train/val (IDs 3138, 3182, 3316, 3364, 3473, 3655); otherwise seeded random 90/10 hold-out.
#   - Common: Strong train-time augmentation (RandomResizedCrop, horizontal/vertical flips, rotation ~20°, ColorJitter); val/test use Resize+CenterCrop and Normalize.
#   - Common: Compute per-class pos_weight for BCEWithLogitsLoss, often clipped (e.g., [1, 5–10]) to prevent extremes.
#   - Many: Input size around 384px; some higher (448) or backbone-specific (e.g., 380 for EfficientNet).
#   - Few: Albumentations with CoarseDropout or timm’s AutoAugment/Random Erasing (IDs 3985, 3156, 3505).
#   - Few: Robust fallbacks for unreadable images (.png fallbacks, dummy black images).
# - Low-score solutions did
#   - Common: Random 90/10 split without multilabel stratification.
#   - Common: Similar basic augmentations and normalization; one uses timm’s RandAugment (3056).
#   - Common: Per-class pos_weight; one adds WeightedRandomSampler (3056).
#   - Some: Black-image fallback on load errors (2934).
# - Concrete difference
#   - High-scorers often preserve label distribution with multilabel stratification and cap pos_weight; low-scorers use non-stratified splits and, in one case, combine pos_weight with WeightedRandomSampler.
# - Why these patterns matter
#   - Stratified splits yield validation sets representative of co-occurring labels, stabilizing threshold tuning and macro F1 estimates. Over-balancing (pos_weight + sampling) can distort prevalence and harm probability calibration.
# - What future solvers should do
#   - Prefer MultilabelStratifiedKFold; compute pos_weight on the training split with sensible clipping; avoid double-balancing (do not combine heavy sampling with pos_weight); use strong yet sane augmentations; stick to ~384px and ImageNet normalization; include robust image-load fallbacks.
#
# Feature engineering
# - High-score solutions did
#   - Common: None beyond multi-hot encoding and image transforms.
# - Low-score solutions did
#   - Common: None.
# - Concrete difference
#   - No meaningful differences.
# - Why these patterns matter
#   - End-to-end CNNs learn features; handcrafting isn’t necessary for this task as per observed winners.
# - What future solvers should do
#   - Focus efforts on data quality, augmentation, and calibration rather than engineered features.
#
# Model selection
# - High-score solutions did
#   - Common: Use timm pretrained backbones (ConvNeXt Base/Tiny/Small; EfficientNet B3/B4/V2_S), often with in21k/in22k weights; set num_classes properly.
#   - Few: Add dropout in head or model drop_rate; gradient clipping present in some.
#   - Many: Train at higher resolution (≈384–448); occasional TTA at inference.
# - Low-score solutions did
#   - Common: timm ConvNeXt (Base or Tiny) pretrained; standard heads; no ensembling; typical resolutions.
# - Concrete difference
#   - Many high-scorers leverage stronger pretraining (in21k/22k) or higher-capacity backbones and occasionally regularization in the head; low-scorers stick to standard ImageNet-1k pretraining or smaller backbones.
# - Why these patterns matter
#   - Fine-grained leaf textures benefit from higher-capacity models and richer pretraining; these typically yield better representations at larger input sizes.
# - What future solvers should do
#   - Choose robust backbones (ConvNeXt Base, EfficientNet-B4/V2_S_in21k) at ~384–448px; consider mild regularization (dropout or gradient clipping).
#
# Training methodology
# - High-score solutions did
#   - Common: AdamW, CosineAnnealingLR; mixed precision (AMP).
#   - Common: Per-class threshold tuning over a broad grid (often 0.05–0.95) optimizing per-class F1; ensure at least one label per image.
#   - Many: Class imbalance via pos_weight; some add label smoothing or warmup/cosine decay; some use gradient clipping.
#   - Many: Save best checkpoint by validation macro F1 and reload for inference.
#   - Few: Test-time augmentation (horizontal flip; sometimes vertical flip) averaged at inference.
# - Low-score solutions did
#   - Common: AMP, AdamW, CosineAnnealingLR.
#   - Common: Threshold tuning, but sometimes narrower grids (e.g., 0.2–0.6) or validate with fixed 0.4; one uses WeightedRandomSampler with pos_weight.
#   - Rare: No TTA in practice (3056 mentions but not implemented; 2934 no TTA).
# - Concrete difference
#   - High-scorers consistently align training/selection with macro F1 and perform thorough per-class threshold sweeps; many add simple TTA. Low-scorers use narrower threshold ranges, fixed validation thresholds, and sampling that can harm calibration.
# - Why these patterns matter
#   - Macro F1 hinges on proper thresholds per class; broad per-class sweeps adapt to rare classes that need low thresholds. TTA provides small but reliable gains. Weighted sampling can skew predicted probabilities, undermining threshold selection.
# - What future solvers should do
#   - Tune per-class thresholds across a wide range (≈0.05–0.95); always enforce at least one label; add simple TTA (horizontal flip); reload the best checkpoint; consider warmup and gradient clipping; avoid WeightedRandomSampler when using pos_weight.
#
# Evaluation & Submission
# - High-score solutions did
#   - Common: Use macro F1 for validation; save tuned thresholds; apply them at test; enforce at least one predicted label.
#   - Many: TTA at inference (flip averaging); sort outputs; store thresholds in checkpoint.
#   - Few: Handle classes with zero validation positives by defaulting thresholds sensibly.
# - Low-score solutions did
#   - Common: Macro F1; per-class thresholds; ensure at least one label.
#   - Rare: TTA; threshold search sometimes limited or based on unique probabilities only.
# - Concrete difference
#   - High-scorers standardize a broad per-class threshold search, TTA, and checkpointed thresholds; low-scorers skip TTA and sometimes constrain threshold ranges or validation thresholds.
# - Why these patterns matter
#   - Proper calibration directly lifts macro F1; TTA reduces variance; storing thresholds ensures consistent inference.
# - What future solvers should do
#   - Systematically grid-search per-class thresholds; implement lightweight TTA; persist thresholds with the model; align all evaluation with macro F1.
#
# Notable Implementation Details
# - High-score solutions did
#   - Common: Seeds for reproducibility; pin_memory, non_blocking transfers; multi-worker loaders; AMP.
#   - Many: Auto-install dependencies; robust image handling (fallbacks, extension checks); environment-driven configuration.
#   - Few: Label smoothing; Random Erasing/AutoAugment; stratified split tooling; fallback “healthy” submission on error.
# - Low-score solutions did
#   - Common: Similar runtime optimizations; dependency auto-install; black-image fallback.
#   - Few: WeightedRandomSampler; narrower threshold search ranges.
# - Concrete difference
#   - More frequent use of multilabel stratification tooling, threshold persistence, and TTA in high-scorers; low-scorers introduce sampling that can conflict with pos_weight.
# - Why these patterns matter
#   - Reliability and calibration improvements accumulate into better final F1; avoiding conflicting imbalance techniques maintains stable learning.
# - What future solvers should do
#   - Integrate iterative-stratification; persist thresholds; add simple TTA; keep pipelines robust with fallbacks; avoid conflicting balancing strategies.
#
# Summary of actionable priorities
# - Use MultilabelStratifiedKFold for splits.
# - Train strong pretrained backbones at ~384–448px; consider in21k/in22k weights.
# - Handle imbalance with clipped pos_weight; avoid WeightedRandomSampler alongside pos_weight.
# - Align with macro F1: perform broad per-class threshold tuning; enforce at least one label; reload best checkpoint.
# - Add simple TTA (horizontal flip) at inference.
# - Maintain reproducibility and robust data loading; use strong yet practical augmentations.
#
# Unique High-Performing Approaches (Top-tier ≥ 0.8)
# Below are rare yet effective techniques observed among the top-tier solutions, with evidence, rationale, cautions, and quick tips to reproduce.
#
# - BCE label smoothing toward 0.5 for multi-label targets
#   - Evidence: row_3135 (BCEWithLogitsLossSmooth; targets := targets*(1−smooth) + 0.5*smooth)
#   - Why it likely helped: Multi-label BCE can be overconfident and noisy; slight smoothing improves calibration and makes threshold tuning more reliable, often boosting macro F1.
#   - Caution: Excessive smoothing can suppress positive signal and hurt recall; keep smoothing small (e.g., 0.02–0.10).
#   - How to reproduce: Wrap BCEWithLogitsLoss and pre-process targets with a smoothing factor (e.g., smooth=0.05) toward 0.5 before loss computation.
#
# - Backbone-aligned preprocessing and strong augmentation (timm resolve_data_config + RandAugment + Random Erasing)
#   - Evidence: row_3505 (timm resolve_data_config/create_transform; RandAugment rand-m9-mstd0.5-inc1; Random Erasing re_prob=0.25)
#   - Why it likely helped: Matching preprocessing to the backbone’s expected statistics maximizes transfer learning. RandAugment and Random Erasing add robust regularization, reducing overfitting, especially on limited data.
#   - Caution: Too-strong erasing or aggressive policies can remove subtle disease cues; validate augmentation strength on a held-out set.
#   - How to reproduce: Use timm.resolve_data_config(model) + timm.create_transform(config); enable RandAugment (rand-m9-mstd0.5-inc1) and Random Erasing (re_prob≈0.25, pixel mode).
#
# - Albumentations pipeline with CoarseDropout and ShiftScaleRotate (reflect border)
#   - Evidence: row_3985 (Albumentations: CoarseDropout, ShiftScaleRotate with border reflect, color ops, V/H flips)
#   - Why it likely helped: Albumentations enables complex, efficient transforms. CoarseDropout simulates occlusions and leaf damage; ShiftScaleRotate with reflect avoids edge artifacts, improving invariance and generalization.
#   - Caution: Overusing CoarseDropout can hide target patterns; set moderate p (≈0.2–0.3) and check validation.
#   - How to reproduce: Albumentations chain: Resize → HFlip/VFlip → ShiftScaleRotate(border_mode=REFLECT) → OneOf(ColorJitter/RandomBrightnessContrast) → CoarseDropout → Normalize → ToTensorV2.
#
# - Per-batch cosine LR scheduling (T_max = total steps)
#   - Evidence: row_3279 (CosineAnnealingLR stepped every batch; T_max set to total training steps)
#   - Why it likely helped: Smoother, fine-grained LR decay can improve convergence and final performance versus per-epoch stepping.
#   - Caution: Ensure T_max equals total steps; stepping per batch with T_max=epochs will collapse LR too quickly.
#   - How to reproduce: Set T_max = num_epochs * len(train_loader); call scheduler.step() each batch.
#
# - Warmup + cosine decay schedule
#   - Evidence: row_3182 (manual warmup then cosine), row_3655 (LambdaLR with one-epoch warmup), row_3364 (~10% warmup factor)
#   - Why it likely helped: Warmup stabilizes early training with large pretrained backbones and AdamW, preventing divergence and improving final F1.
#   - Caution: Too-long warmup can slow learning; typical warmup 5–10% of epochs or one epoch suffices.
#   - How to reproduce: Use LambdaLR: linear ramp-up for the first epoch(s) then cosine decay; or manual warmup logic before switching to cosine.
#
# - Pretraining on larger datasets (ImageNet-21k/22k)
#   - Evidence: row_3135 (‘convnext_base.fb_in22k’), row_3473 (‘convnext_base.fb_in22k’), row_3182 (‘tf_efficientnetv2_s_in21k’ with drop_rate=0.2)
#   - Why it likely helped: Wider pretraining corpora (21k/22k) yield richer representations for fine-grained plant disease patterns, improving transfer.
#   - Caution: Heavier models and stronger pretraining can overfit if data is tiny; watch validation and adjust regularization/augmentation.
#   - How to reproduce: Choose timm models with in21k/in22k weights (e.g., convnext_base.fb_in22k, tf_efficientnetv2_s_in21k) and set pretrained=True.
#
# - TTA with vertical flips (beyond horizontal)
#   - Evidence: row_3120 (TTA averaging: identity + horizontal + vertical flips)
#   - Why it likely helped: Leaf images are orientation-agnostic; vertical flips add invariance and reduce prediction variance, boosting recall and macro F1.
#   - Caution: Adds latency; ensure labels are flip-invariant (safe for plant leaves but not for text).
#   - How to reproduce: At inference, run original + hflip + vflip, average sigmoid probabilities, then apply tuned thresholds.
#
# - Dynamic batch size reduction on CUDA OOM
#   - Evidence: row_3655 (auto-reduces batch size until allocation succeeds)
#   - Why it likely helped: Prevents training crashes and enables higher resolutions/models, indirectly improving accuracy by preserving the chosen setup.
#   - Caution: Changing batch size mid-training affects LR and batch norm; consider scaling LR with batch size and avoiding BN-sensitive changes mid-epoch.
#   - How to reproduce: Wrap forward/backward in try/except for CUDA OOM; on OOM, halve batch size, recreate DataLoader, optionally scale LR accordingly.
#
# - Threshold search augmented with class probability quantiles
#   - Evidence: row_3567 (combines grid thresholds with class-wise probability quantiles)
#   - Why it likely helped: For imbalanced classes, optimal decision points often align with distribution quantiles; adding quantile candidates improves threshold calibration and macro F1.
#   - Caution: For very rare classes, quantiles are unstable; guard with minimum-positive checks and fallbacks.
#   - How to reproduce: After validation, collect per-class probabilities; add quantiles (e.g., 0.7, 0.8, 0.9) to the threshold candidate set and pick the F1-optimal threshold per class.
#
# - Gradient accumulation to emulate larger batch sizes
#   - Evidence: row_3567 (grad_accum_steps > 1)
#   - Why it likely helped: Smoother gradients and effective larger batch can stabilize optimization and improve generalization when memory is tight.
#   - Caution: Adjust LR for effective batch size; ensure proper scaler/optimizer stepping only on accumulation boundary.
#   - How to reproduce: Accumulate loss.backward() for N steps; call optimizer.step() and zero_grad() every N steps; scale LR with N if needed.
#
# - Regularizing the classification head with Dropout
#   - Evidence: row_3473 (nn.Sequential(Dropout(0.2), Linear))
#   - Why it likely helped: Simple head-level dropout reduces overfitting on multi-label heads, improving calibration and thresholded F1.
#   - Caution: Too high dropout can hamper learning; start at 0.1–0.3 and tune.
#   - How to reproduce: Replace timm head with a small nn.Sequential including Dropout before the final Linear(num_features → num_classes).

# %%
archive_file(archive_dir = "/checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/comparison/",
             file_path=matching_logs[0])
# Out:
# Skipped (already exists): /checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/comparison/gpt-5_comparison_513_plant-pathology-2021-fgvc8_2026-02-11_07-39-40_99b7fe99.jsonl
# Archived: /checkpoint/maui_sft/winnieyangwn/rlm_dumps/comparison-v3/gpt-5_comparison_513_plant-pathology-2021-fgvc8_2026-02-11_07-39-40_99b7fe99.md -> /checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/comparison/gpt-5_comparison_513_plant-pathology-2021-fgvc8_2026-02-11_07-39-40_99b7fe99.md
# ['/checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/comparison/gpt-5_comparison_513_plant-pathology-2021-fgvc8_2026-02-11_07-39-40_99b7fe99.md']
