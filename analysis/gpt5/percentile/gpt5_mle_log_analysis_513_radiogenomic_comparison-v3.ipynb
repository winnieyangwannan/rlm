# %% [markdown]
# # LOG:
#
# /checkpoint/maui_sft/winnieyangwn/rlm_dumps/gpt-5_summarization_513_iwildcam-2019-fgvc6_2026-02-09_07-05-37_3bfb9fbc.jsonl

# %%
import sys
import importlib


sys.path.append('/home/winnieyangwn/rlm/analysis')
import rlm_log_utils
importlib.reload(rlm_log_utils)
from rlm_log_utils import *

# %% [markdown]
# ## Usage Example
#
# Load the log file and extract key information:

# %% [markdown]
# # Load

# %%
import glob
import os

run_id = 513
model_name = "gpt-5"
task_name = "rsna-miccai-brain-tumor-radiogenomic-classification"
log_dir = "/checkpoint/maui_sft/winnieyangwn/rlm_dumps/comparison-v3"
codebase_extensions = [".py", ".md", ".yaml"]

# Option 1: Provide a specific log name to load directly
log_name = None  # e.g., "gpt-5_summarization_513_20260208_123456.jsonl"

if log_name:
    # Directly load the specified log file
    LOG_PATH = os.path.join(log_dir, log_name)
    if not os.path.exists(LOG_PATH):
        raise FileNotFoundError(f"Specified log file not found: {LOG_PATH}")
    print(f"Loading specified log: {LOG_PATH}")
else:
    # Use underscore after run_id to avoid matching "summarization_comparison_*" logs
    LOG_PATH_PREFIX = f"{log_dir}/{model_name}_comparison_{run_id}_{task_name}"

    # Find all log files matching the prefix pattern
    matching_logs = glob.glob(f"{LOG_PATH_PREFIX}*")

    if not matching_logs:
        raise FileNotFoundError(f"No log files found matching prefix: {LOG_PATH_PREFIX}")

    # Get the most recent log file by modification time
    LOG_PATH = max(matching_logs, key=os.path.getmtime)
    print(f"Found {len(matching_logs)} matching log file(s)")
    print(f"Loading most recent: {LOG_PATH}")

# Load the log - first entry is metadata, rest are iterations
entries = load_rlm_log(LOG_PATH)
metadata = entries[0]
iterations = entries[1:]

print(f"Loaded {len(iterations)} iterations")
# Out:
# Found 2 matching log file(s)
# Loading most recent: /checkpoint/maui_sft/winnieyangwn/rlm_dumps/comparison-v3/gpt-5_comparison_513_rsna-miccai-brain-tumor-radiogenomic-classification_2026-02-11_07-49-31_c3613114.jsonl
# Loaded 5 iterations

# %% [markdown]
# # Metadata

# %%
# View metadata
print("=== METADATA ===")
for k, v in metadata.items():
    if k != "backend_kwargs":
        print(f"{k}: {v}")
# Out:
# === METADATA ===
# type: metadata
# timestamp: 2026-02-11T07:49:31.294205
# root_model: gpt-5
# max_depth: 2
# max_iterations: 20
# backend: azure_openai
# environment_type: local
# environment_kwargs: {'setup_code': '\nimport pandas as pd\n\n# Load original rollout data\nrollout_df = pd.read_json(\'/checkpoint/maui_sft/winnieyangwn/amaia_dumps/513/trajectories/513_metadata.jsonl\', lines=True)\nrollout_df = rollout_df[rollout_df[\'task_name\'] == \'rsna-miccai-brain-tumor-radiogenomic-classification\']\nprint(f"Loaded {len(rollout_df)} rollouts")\n\n# Load Round 1 analysis (markdown text)\nwith open(\'/tmp/round1_analysis_513_rsna-miccai-brain-tumor-radiogenomic-classification.txt\') as f:\n    round1_analysis = f.read()\nprint(f"Loaded Round 1 analysis ({len(round1_analysis)} chars)")\n'}
# other_backends: None

# %%
# Compare with timestamp-based runtime
runtime = get_total_runtime(entries)
print(f"Timestamp-based runtime: {runtime.total_seconds():.2f}s")
# Out:
# Timestamp-based runtime: 516.27s

# %%
# Check number of iterations actually taken by model
num_iterations = len(iterations)
print(f"Number of iterations taken: {num_iterations}")

# You can also use extract_all for a comprehensive summary
summary = extract_all(LOG_PATH)
print(f"Number of iterations (from extract_all): {summary['num_iterations']}")
# Out:
# Number of iterations taken: 5
# Number of iterations (from extract_all): 5

# %% [markdown]
# # Final Answer

# %%
# Get the final answer
final_answer = get_final_answer(iterations)
print("=== FINAL ANSWER ===")
print(final_answer if final_answer else "No final answer found")
# print(f"\n(Total length: {len(final_answer) if final_answer else 0} chars)")
# Out:
# === FINAL ANSWER ===
# Contrastive Pattern Analysis (High-score vs Low-score)
#
# Definitions used here:
# - High-score solutions (>= 0.6): IDs [5, 6, 11, 15, 16, 18, 19, 21, 22, 24, 26, 27, 28] (13 total)
# - Low-score solutions (< 0.6): IDs [0, 1, 2, 3, 4, 7, 8, 9, 10, 12, 13, 14, 17, 20, 23, 25, 29] (17 total)
#
# 1) Data preprocessing
# - What high-score solutions did (with counts)
#   - Excluded known bad cases (00109, 00123, 00709): 13/13 (all: 5,6,11,15,16,18,19,21,22,24,26,27,28).
#   - Applied DICOM rescale slope/intercept correction: 13/13 (5,6,11,15,16,18,19,21,22,24,26,27,28).
#   - Robust slice ordering by metadata (ImagePositionPatient/SliceLocation/InstanceNumber) with fallbacks: 12/13 (all except 5; 6,11,15,16,18,19,21,22,24,26,27,28).
#   - Robust intensity normalization (percentile clipping then scaling, often 1–99%): 13/13 (all).
#   - Handled missing modalities explicitly (zero-fill or alternate naming, e.g., T1Gd when T1wCE missing): 12/13 (5,6,15,16,18,19,21,22,24,26,27,28; 11 drops cases when modality missing).
#   - Captured 3D context via either multi-slice selection, projection, or 3D volumes:
#     - Projection-based 2D per modality (MIP/mean/max): 6/13 (5,16,21,22,24,28).
#     - Multi-slice 2D (bags or K slices): 4/13 (6,11,18,26).
#     - 3D volumes: 1/13 (19).
#     - Single representative slice: 1/13 (15).
#   - Precomputed/cached preprocessed data for speed (PNG/NPY/NPZ): 11/13 (5,6,11,15,18,19,21,22,24,26,28).
#
# - What low-score solutions did (with counts)
#   - Excluded known bad cases: 17/17 (all).
#   - Applied DICOM rescale slope/intercept correction: 15/17 (most; notable omissions/unclear: 20 not explicit; 29’s pixel read omitted slope/intercept).
#   - Slice sorting by metadata: 14/17 (most; some used only InstanceNumber or filename fallback).
#   - Robust intensity normalization (percentile/z-score): 16/17 (most; 4 focused on tabular intensities rather than training-time image normalization).
#   - Missing modalities zero-filled or ad hoc substitution: 15/17 (most).
#   - 3D context capture:
#     - Projection-based 2D: 3/17 (3 central MIP, 7 percentile projection, 29 mean projection).
#     - Multi-slice 2D training with mean aggregation: common but often naive (10,13,14,20,23,9), without MIL-style learning.
#     - 3D CNN: 1/17 (2, custom 3D; from scratch).
#     - Single/very few slices (≤3) per case: 5/17 (0 central slice, 12 middle slice, 17 one slice per modality, 8 three slices, 9 mean of 3).
#
# - Concrete difference (what explains the gap)
#   - High-score solutions almost never rely on a single or very few slices (1/13 vs 5/17 low) and more often summarize or sample 3D context robustly (projection 6/13; multi-slice MIL 4/13; 3D CNN 1/13).
#   - High-score solutions more consistently implement strong DICOM handling (sorting with fallbacks, slope/intercept) and modality fallback (e.g., T1Gd for T1wCE), reducing data noise and missingness issues.
#   - High-score solutions more often precompute caches to ensure consistent, reproducible preprocessing, avoiding repeated I/O variations.
#
# - Why these patterns matter
#   - MGMT methylation signal is weak and spatially localized; losing 3D context (e.g., single-slice) often misses tumor or dilutes signal with background.
#   - Robust DICOM handling prevents slice misordering and intensity miscalibration, which can severely degrade model learning.
#   - Consistent modality handling avoids teaching the model spurious “missingness” shortcuts.
#
# - What future solvers should do
#   - Use robust 3D-to-2D projections (MIP/mean) or multi-slice sampling (MIL-style bags), or 3D CNNs if resources allow.
#   - Always apply slope/intercept, robust metadata-based slice sorting (with fallbacks), and per-volume percentile normalization.
#   - Handle missing T1wCE with T1Gd fallback (and explicit zeros otherwise), and cache all preprocessed data to stabilize the pipeline.
#
# 2) Feature engineering
# - What high-score solutions did (with counts)
#   - Multi-modal fusion by channel stacking:
#     - All four modalities: 10/13 (5,6,11,19,21,22,24,26,27-features,28).
#     - Three modalities (FLAIR/T1wCE/T2w): 3/13 (15,16,18).
#   - 3D summarization choices:
#     - Projection stacks (MIP/mean/max): 6/13 (5,16,21,22,24,28).
#     - MIL-style bags of slices or K-slice selection: 4/13 (6,11,18,26).
#     - 3D volume input: 1/13 (19).
#   - Special designs:
#     - 12-channel feature maps (mean/std/max per modality): 1/13 (5).
#     - 2x2 montage of sequence MIPs: 1/13 (21).
#     - Tabular engineered features (intensity/entropy/edges) with gradient boosting: 1/13 (27).
#
# - What low-score solutions did (with counts)
#   - Multi-modal stacking common but often limited to 3 channels or ad hoc (e.g., 1-channel training in ID 1): 6/17 used ≤3-channel inputs (1,3,10,12,13,29).
#   - Projection-based summarization: 3/17 (3,7,29).
#   - Many treated slices independently with average aggregation, without MIL or attention mechanisms: 8+/17 (10,13,14,20,23,9,26-low not in this group, 17).
#   - Handcrafted/tabular features: 2/17 (4,25).
#
# - Concrete difference
#   - High-score solutions favor robust 3D summarization (projection or MIL), whereas low-score solutions more often rely on single/very few slices or naive per-slice averaging with case labels replicated across slices.
#   - High-score solutions include unique designs (12-channel stats; montage; tabular boosting) that extract richer global information or mitigate weak supervision noise.
#
# - Why these patterns matter
#   - Projection or MIL approaches reduce label noise from non-informative slices and encode volumetric context without the full cost of 3D CNNs.
#   - Diversity in feature representations (e.g., tabular radiomics-like features, montages) can improve robustness to domain shift and complement CNNs.
#
# - What future solvers should do
#   - Prefer projection-based stacks (max/mean, possibly combining statistics per modality) or MIL aggregators over single-slice inputs.
#   - Consider design diversity: montage layouts (sequencing spatially), per-modality summary statistics, or a tabular fallback model to hedge against domain shift.
#
# 3) Model selection
# - What high-score solutions did (with counts)
#   - Used pretrained image backbones (ResNet/EfficientNet) adapted to MRI channels: 11/13 (5,6,11,15,16,18,21,22,24,26,28; exceptions: 19 custom 3D from scratch; 27 tabular).
#   - Architectures:
#     - ResNet-18 family: 6/13 (6,11,16,18,24; plus 26 fallback).
#     - EfficientNet-B0: 4/13 (5,15,26,28).
#     - ResNet-50: 1/13 (21).
#     - Custom 3D ResNet-like: 1/13 (19).
#     - Gradient boosting on engineered features: 1/13 (27).
#   - Cross-validation ensemble: 3/13 (15 3-fold; 21 5-fold; 27 5-fold).
#   - Test-time augmentation (TTA): 1/13 (21 used H-flip TTA).
#
# - What low-score solutions did (with counts)
#   - Pretrained backbones used but with weaker pipelines or inconsistent setup: 11/17 used pretrained CNNs; 6/17 trained from scratch or used non-pretrained backbones (e.g., 2 custom 3D scratch; 8 custom CNN scratch; 13/17 pretrained=False; 17 pretrained=False).
#   - Cross-validation ensembling limited: 2/17 (2 3-fold CV ensemble; 4 5-fold CV averaging).
#   - TTA absent: 0/17.
#
# - Concrete difference
#   - High-score solutions more consistently leverage pretrained CNNs correctly adapted to 3–4 input channels and sometimes add CV ensembles; low-score ones more often train from scratch or misalign training/inference distributions (e.g., ID 1’s 1-channel training vs multi-modality averaging at test).
#
# - Why these patterns matter
#   - Strong pretrained features stabilize training for limited medical datasets; CV ensembles reduce variance and improve generalization to heterogeneous scanners/protocols.
#
# - What future solvers should do
#   - Use pretrained backbones with proper input-conv adaptation to 3–4 channels; add lightweight CV ensembling where runtime allows; reserve 3D CNNs for when compute and implementation robustness are assured.
#
# 4) Training methodology
# - What high-score solutions did (with counts)
#   - Optimizer: AdamW nearly universal; LR ~1e-3 to 2e-4.
#   - Mixed-precision (AMP): 10/13 (5,6,11,15,16,18,19,21,24,26,28; 27 N/A; 22 not stated).
#   - Class imbalance handling (pos_weight or weighted sampling): 5/13 (16 sampler; 21 pos_weight; 22 sampler; 19 pos_weight; 28 pos_weight).
#   - Case-level metric alignment: many validated on case-level AUC when using case images or aggregated slices (5,15,16,18,21,24,28), though some saved by loss or slice-level AUC (6,11,26,19,22).
#
# - What low-score solutions did (with counts)
#   - Mixed-precision: 7/17 (1,2,8,10,13,17,20).
#   - Class imbalance handling: ~8/17 (1 pos_weight; 2 pos_weight; 3 pos_weight; 12 weighted BCE; 17 pos_weight; 20 pos_weight; 23 pos_weight; 25 LightGBM’s internal; others none).
#   - Misaligned validation: frequent use of slice-level AUC or loss for selection while test uses case-level aggregation (10,13,14,20,23,29), and even broken AUC computation (29).
#
# - Concrete difference
#   - High-score solutions more often adopt AMP, keep training stable, and evaluate at the case level; low-score group more often optimizes/monitors slice-level surrogates or has implementation pitfalls (broken metrics).
#
# - Why these patterns matter
#   - AMP improves throughput and batch sizes under constraints; selecting checkpoints by case-level AUC better matches the leaderboard metric; broken or misaligned validation can misguide model selection.
#
# - What future solvers should do
#   - Turn on AMP by default on GPU; compute validation at case level (aggregate slice predictions first); if using slice-level training, consider MIL-style training and checkpoint on case-level AUC.
#
# 5) Evaluation & submission
# - What high-score solutions did (with counts)
#   - Case-level aggregation consistent across val/test (mean of slice probabilities or logits): 7/13 (6 mean-of-logits then sigmoid; 11 mean of probs; 18 mean of probs; 21 montage per case; 24/28 single projected image; 26 mean of probs).
#   - CV ensembling at inference: 3/13 (15,21,27).
#   - Minimal but solid TTA: 1/13 (21 used H-flip).
#
# - What low-score solutions did (with counts)
#   - Slice-level validation with case-level inference (mismatch): 5+/17 (10,13,14,20,23).
#   - No ensembling or TTA: 17/17.
#
# - Concrete difference
#   - High-score solutions ensure validation metrics reflect final inference aggregation and sometimes ensemble folds; low-score ones often select models by slice-level signals that don’t translate to case-level AUC.
#
# - Why these patterns matter
#   - AUC is computed per subject; validating/ensembling at that level reduces variance and improves leaderboard stability.
#
# - What future solvers should do
#   - Always aggregate to case level before computing AUC (during both training and validation) and consider light ensembling/TTA if budget allows.
#
# 6) Notable implementation details
# - What high-score solutions did (with counts)
#   - Robust DICOM quirks handling: MONOCHROME1 inversion and VOI LUT when present: 3/13 (16,21,22).
#   - Alternate naming resolution (T1Gd as T1wCE): 3–4/13 (15,16,18,28).
#   - Efficient caching (NPY/PNG) for reproducibility/speed: 11/13.
#   - Diverse but effective designs preserved:
#     - MIL bag-of-slices (6).
#     - Projection stats per modality (12-channel) (5).
#     - 2x2 montage layout (21).
#     - Tabular engineered features + HGB (27).
#     - 3D CNN end-to-end (19).
#
# - What low-score solutions did (with counts)
#   - Some pipelines lacked these medical-specific protections (e.g., slope/intercept sometimes omitted, MONOCHROME1/VOI LUT rarely used).
#   - Diversity existed but often with pitfalls: training from scratch (2,8,17); broken metrics (29); mismatched train/test distributions (1).
#
# - Concrete difference
#   - High-score solutions accounted for modality quirks and preserved diverse, robust approaches; low-score ones more often suffered from avoidable implementation issues.
#
# - Why these patterns matter
#   - Medical DICOM quirks directly affect pixel intensities; missing these steps yields unstable inputs. Methodological diversity (MIL, projections, tabular) reduces overfitting to a single assumption about the data.
#
# - What future solvers should do
#   - Implement MONOCHROME1 inversion and VOI LUT when present; resolve alternate sequence names; preserve a diverse approach portfolio (projection/MIL/tabular) to hedge against domain shift.
#
#
# Unique High-Performing Approaches (Top-tier only: IDs [6, 15, 18, 19, 24, 27, 28])
#
# Focus: techniques rare across high-score solutions but present in top-tier, likely effective.
#
# - Multiple-Instance Learning (bag of slices with per-slice logits averaged)
#   - Count: 1/7 (ID 6)
#   - Why effective: Reduces weak-label noise by letting the model learn from multiple informative slices while keeping runtime lower than full 3D; preserves 3D context without explicit segmentation.
#   - Used by: 6
#
# - End-to-end 3D multi-modal CNN
#   - Count: 1/7 (ID 19)
#   - Why effective: Captures true volumetric context and inter-slice dependencies natively; with robust normalization and simple 3D augmentations it excels despite being trained from scratch.
#   - Used by: 19
#
# - Stratified CV ensembling for robustness
#   - Count: 2/7 (IDs 15, 27)
#   - Why effective: Reduces variance on heterogeneous, site-diverse MRI cohorts; averaging over folds stabilizes predictions and mitigates split sensitivity.
#   - Used by: 15 (3-fold EfficientNet), 27 (5-fold HGB)
#
# - Tabular radiomics-like features + HistGradientBoostingClassifier
#   - Count: 1/7 (ID 27)
#   - Why effective: Robust to domain shift, low compute footprint, and less sensitive to pixel-level artifacts; complements CNN approaches and can perform strongly on limited budgets.
#   - Used by: 27
#
# - Projection restricted to central slices (e.g., central 64) before 2D mean projection
#   - Count: 1/7 (ID 28)
#   - Why effective: Avoids extremes (padding/artefacts) and focuses on anatomically relevant region; improves projection consistency across variable-length stacks.
#   - Used by: 28
#
# - Representative-slice selection by intensity sum + cross-modality relative index alignment
#   - Count: 1/7 (ID 15)
#   - Why effective: Focuses on informative slices likely to contain tumor and maintains anatomical alignment across modalities; strong signal-to-noise trade-off with minimal compute.
#   - Used by: 15
#
# - Alternate contrast sequence name mapping (T1Gd as fallback for T1wCE)
#   - Count: 3/7 (IDs 15, 18, 28)
#   - Why effective: Reduces missingness impact and site-specific naming variance, preserving the most diagnostic modality for many cases.
#   - Used by: 15, 18, 28
#
# Actionable takeaways to preserve diversity:
# - Don’t converge exclusively on a single 2D design; keep MIL bags or a 3D variant in the ensemble when possible.
# - Consider a projection variant that restricts to central slices to reduce noise from extremes.
# - Preserve a simple tabular model (entropy/edges/intensities) as a complementary path—especially useful under runtime constraints or for ensembling.
# - When using single-slice strategies, ensure smart slice selection and cross-modality alignment.
# - Always map alternate sequence names (e.g., T1Gd) to avoid losing the most informative contrast.
#
#
# Summary recommendations
# - Preprocessing: Always apply slope/intercept, robust DICOM sorting, percentile normalization; handle missing sequences with explicit fallbacks (T1Gd for T1wCE) and cache outputs.
# - Features: Prefer 3D-aware summarization—projection stacks (possibly multi-statistics) or MIL bags; avoid single slices unless using smart selection and alignment.
# - Models: Use pretrained ResNet/EfficientNet backbones adapted to 3–4 channels; where possible, add CV ensembling; consider a 3D model or tabular HGB as a complementary option.
# - Training: Use AMP; address class imbalance (pos_weight or sampling); select checkpoints by case-level AUC (aggregate slices first).
# - Inference: Aggregate per-slice predictions to case level consistently across validation and test; consider lightweight TTA and fold averaging.

# %%
archive_file(archive_dir = "/checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/comparison/",
             file_path=matching_logs[0])
# Out:
# Skipped (already exists): /checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/comparison/gpt-5_comparison_513_rsna-miccai-brain-tumor-radiogenomic-classification_2026-02-11_07-49-31_c3613114.jsonl
# Archived: /checkpoint/maui_sft/winnieyangwn/rlm_dumps/comparison-v3/gpt-5_comparison_513_rsna-miccai-brain-tumor-radiogenomic-classification_2026-02-11_07-49-31_c3613114.md -> /checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/comparison/gpt-5_comparison_513_rsna-miccai-brain-tumor-radiogenomic-classification_2026-02-11_07-49-31_c3613114.md
# ['/checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/comparison/gpt-5_comparison_513_rsna-miccai-brain-tumor-radiogenomic-classification_2026-02-11_07-49-31_c3613114.md']
