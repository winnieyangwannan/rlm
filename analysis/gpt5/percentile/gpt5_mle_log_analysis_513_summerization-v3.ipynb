# %% [markdown]
# # LOG:/checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/summerization/gpt-5_summarization_513_2026-02-08_23-35-35_c4318c42.jsonl

# %%
import sys
import importlib


sys.path.append('/home/winnieyangwn/rlm/analysis')
import rlm_log_utils
importlib.reload(rlm_log_utils)
from rlm_log_utils import *

# %% [markdown]
# ## Usage Example
#
# Load the log file and extract key information:

# %% [markdown]
# # Load

# %%
import glob
import os

run_id = 513
model_name = "gpt-5"
job_name = "summarization"
log_dir = "/checkpoint/maui_sft/winnieyangwn/rlm_dumps"
codebase_extensions = [".py", ".md", ".yaml"]

# Option 1: Provide a specific log name to load directly
log_name = None  # e.g., "gpt-5_summarization_513_20260208_123456.jsonl"

if log_name:
    # Directly load the specified log file
    LOG_PATH = os.path.join(log_dir, log_name)
    if not os.path.exists(LOG_PATH):
        raise FileNotFoundError(f"Specified log file not found: {LOG_PATH}")
    print(f"Loading specified log: {LOG_PATH}")
else:
    # Use underscore after run_id to avoid matching "summarization_comparison_*" logs
    LOG_PATH_PREFIX = f"{log_dir}/{model_name}_{job_name}_{run_id}_"

    # Find all log files matching the prefix pattern
    matching_logs = glob.glob(f"{LOG_PATH_PREFIX}*")

    if not matching_logs:
        raise FileNotFoundError(f"No log files found matching prefix: {LOG_PATH_PREFIX}")

    # Get the most recent log file by modification time
    LOG_PATH = max(matching_logs, key=os.path.getmtime)
    print(f"Found {len(matching_logs)} matching log file(s)")
    print(f"Loading most recent: {LOG_PATH}")

# Load the log - first entry is metadata, rest are iterations
entries = load_rlm_log(LOG_PATH)
metadata = entries[0]
iterations = entries[1:]

print(f"Loaded {len(iterations)} iterations")
# Out:
# Found 7 matching log file(s)
# Loading most recent: /checkpoint/maui_sft/winnieyangwn/rlm_dumps/gpt-5_summarization_513_2026-02-08_23-35-35_c4318c42.jsonl
# Loaded 2 iterations

# %% [markdown]
# # Metadata

# %%
# View metadata
print("=== METADATA ===")
for k, v in metadata.items():
    if k != "backend_kwargs":
        print(f"{k}: {v}")
# Out:
# === METADATA ===
# type: metadata
# timestamp: 2026-02-08T23:35:35.455807
# root_model: gpt-5
# max_depth: 2
# max_iterations: 10
# backend: azure_openai
# environment_type: local
# environment_kwargs: {'setup_code': '\nimport pandas as pd\n\n# Load rollout data as DataFrame\nrollout_df = pd.read_json(\'/checkpoint/maui_sft/winnieyangwn/amaia_dumps/513/trajectories/513_metadata.jsonl\', lines=True)\nprint(f"Loaded {len(rollout_df)} total rollouts")\n\n# Filter to specific task\nrollout_df = rollout_df[rollout_df[\'task_name\'] == \'vinbigdata-chest-xray-abnormalities-detection\']\nprint(f"Filtered to {len(rollout_df)} rollouts for task: vinbigdata-chest-xray-abnormalities-detection")\n'}
# other_backends: None

# %%
# Compare with timestamp-based runtime
runtime = get_total_runtime(entries)
print(f"Timestamp-based runtime: {runtime.total_seconds():.2f}s")
# Out:
# Timestamp-based runtime: 271.49s

# %%
# Check number of iterations actually taken by model
num_iterations = len(iterations)
print(f"Number of iterations taken: {num_iterations}")

# You can also use extract_all for a comprehensive summary
summary = extract_all(LOG_PATH)
print(f"Number of iterations (from extract_all): {summary['num_iterations']}")
# Out:
# Number of iterations taken: 2
# Number of iterations (from extract_all): 2

# %% [markdown]
# # Final Answer

# %%
# Get the final answer
final_answer = get_final_answer(iterations)
print("=== FINAL ANSWER ===")
print(final_answer if final_answer else "No final answer found")
# print(f"\n(Total length: {len(final_answer) if final_answer else 0} chars)")
# Out:
# === FINAL ANSWER ===
# ## Part 0: Task Analysis
#
# Part 0
#
# 1) Problem Type:
# - Object detection with multi-class classification (localize and classify multiple thoracic abnormalities per image, including a “No finding” class)
#
# 2) Domain:
# - Healthcare / Medical Imaging (Radiology, chest X-rays)
#
# 3) Input Format:
# - Images (DICOM chest radiographs; postero-anterior CXR scans)
#
# 4) Evaluation Metric:
# - PASCAL VOC 2010 mean Average Precision (mAP) at IoU > 0.4; higher mAP is better
#
# 5) Key Challenges:
# - Localizing and classifying multiple abnormalities per image (multi-instance, multi-class)
# - Ground truth from multiple radiologists (inter-reader variability and potential label noise)
# - Medical imaging subtleties in chest X-rays (findings can be small, overlapping, or visually subtle)
# - Handling DICOM specifics and preprocessing (windowing, pixel spacing, intensity/contrast)
# - Class imbalance across 14 findings and a “No finding” class
# - Special handling of the “No finding” case requiring a one-pixel bounding box prediction
#
# ## Part 1: Individual Solution Summaries
#
# **Solution ID:** row_index_4322
# **Score Percentile:** 0.1074509804
#
# 1. Data Preprocessing:
# - Data loading and splitting approaches:
#   - Loads train.csv from /root/data/train.csv using pandas.
#   - Groups annotations by image_id and shuffles image_ids with a fixed seed (random.seed(SEED)).
#   - Limits the number of training images:
#     - If FAST_DEV_RUN=1: uses the first DEV_TRAIN_IMAGES (default 400) image_ids.
#     - Else: caps to MAX_TRAIN_IMAGES (default 2000) if > 0.
#   - Splits into train/val by a simple fraction VAL_SPLIT (default 0.1):
#     - After conversion, takes the first max(1, int(len(train_imgs) * VAL_SPLIT)) images as validation, the rest as training. No stratification.
# - Cleaning strategies:
#   - Skips annotations with NaN in any of x_min, y_min, x_max, y_max.
#   - Excludes class_id == 14 (“No finding”) from training labels.
#   - For DICOM conversion:
#     - Applies RescaleSlope and RescaleIntercept if present.
#     - Handles PhotometricInterpretation MONOCHROME1 by inverting intensities.
#     - Clips pixel values to the 0.5 and 99.5 percentiles to reduce outliers.
#     - Normalizes to [0, 255] and converts to uint8.
#   - For bounding boxes:
#     - Clamps xmin, ymin, xmax, ymax to image dimensions.
#     - Ensures width/height are at least 1 pixel before normalizing.
# - Transformations applied:
#   - DICOM to JPEG conversion:
#     - Reads with pydicom (force=True), decodes pixel_array, rescales, inverts if needed, percentile clipping, normalization to 8-bit.
#     - Stacks grayscale into 3 channels.
#     - Saves as JPEG with quality=90, optimize=True.
#   - Label conversion to YOLO format:
#     - Writes class x_center y_center width height normalized to [0,1].
# - Data augmentation techniques (if any):
#   - None specified in the code.
# - Other preprocessing steps:
#   - Parallel conversion of training images and label writing using multiprocessing with up to MAX_WORKERS processes.
#   - Writes empty label files for images without annotations or failed conversions to avoid loader crashes.
#   - Builds Ultralytics dataset YAML pointing to train/val image lists (train.txt and val.txt) and class names (excluding “No finding”).
#   - Converts test DICOMs to JPEG in parallel before inference.
#
# 2. Feature Engineering:
# - New features and their derivation: None.
# - Feature selection or dimensionality reduction: None.
# - Domain-specific transformations: None beyond DICOM intensity rescale/inversion and bbox clamping described above.
# - If none, explicitly say none: None.
#
# 3. Model Selection:
# - Primary algorithm(s) and exact classes/functions used:
#   - Ultralytics YOLO v8 detector via ultralytics.YOLO.
# - Hyperparameters used:
#   - Training (first attempt):
#     - epochs = EPOCHS (default 30; 1 if FAST_DEV_RUN=1)
#     - imgsz = IMG_SIZE (default 1024; 512 if FAST_DEV_RUN=1)
#     - batch = BATCH (default 8; 4 if FAST_DEV_RUN=1)
#     - device = 0 (GPU)
#     - workers = min(8, MAX_WORKERS)
#     - patience = 10
#     - optimizer = 'auto'
#     - lr0 = 0.01
#     - cache = 'disk'
#   - Training (retry on failure):
#     - epochs = max(1, EPOCHS//2)
#     - imgsz = max(640, IMG_SIZE//2)
#     - batch = max(2, BATCH//2)
#     - device = 0
#     - workers = min(4, MAX_WORKERS)
#     - patience = 5
#     - optimizer = 'auto'
#     - lr0 = 0.01
#     - cache = 'disk'
#   - Inference:
#     - conf = CONF_THRES (default 0.1)
#     - imgsz = IMG_SIZE
#     - device = 0
#     - batch = max(8, BATCH)
# - Ensemble architecture (stacking/blending/voting), number of models:
#   - None.
# - Pretrained models (which ones, how used):
#   - Model initialization tries in order:
#     - YOLO('yolov8{size}.yaml') where size from MODEL_SIZE env (default 'n'); this initializes from architecture (no weights).
#     - Fallback: YOLO('yolov8n.yaml').
#     - Last resort: YOLO('yolov8n.pt') to load pretrained weights.
#   - After training, loads the best.pt or last.pt from the training run directory for inference if available.
#
# 4. Training Methodology:
# - Hyperparameter selection (grid/random/manual):
#   - Manual configuration via hardcoded defaults and environment variables; no automated search.
# - Training config details:
#   - Uses Ultralytics YOLO .train with the parameters listed above.
#   - Early stopping via patience parameter (10 on first attempt, 5 on retry).
#   - Dataloader workers limited by min(8, MAX_WORKERS) or min(4, MAX_WORKERS) on retry.
#   - Uses cache='disk' to cache dataset.
#   - Trains on GPU device 0 if available.
#   - Project and run naming: project='vinbig_models', name='vinbig_yolo' (or 'vinbig_models_retry'/'vinbig_yolo_retry' on retry).
#
# 5. Evaluation & Submission:
# - Final prediction method and any averaging:
#   - Runs model.predict on the list of converted test JPEGs with specified conf threshold, image size, batch size, and GPU device.
#   - No ensembling or averaging.
# - Post-processing of predictions:
#   - For each predicted box:
#     - Extracts class id (int), confidence (float), and xyxy box.
#     - Rounds coordinates to integers, enforces xmin,ymin >= 0.
#     - Enforces xmax >= xmin+1 and ymax >= ymin+1 to ensure at least 1-pixel width/height.
#   - If an image yields no predictions, assigns "14 1.0 0 0 1 1" (No finding with a 1x1 box).
# - Submission file format creation specifics:
#   - Creates a DataFrame with columns:
#     - image_id: test image id (stem of filename)
#     - PredictionString: space-separated sequence of "cls conf xmin ymin xmax ymax" for all boxes per image.
#   - Writes CSV to /workspace/submission.csv without index.
#   - Fallback: On fatal error in main, writes a dummy submission with "14 1 0 0 1 1" for every test image.
#
# 6. Notable Implementation Details:
# - Computational considerations (GPU usage, mixed precision, runtime optimization):
#   - Uses GPU device=0 for training and inference.
#   - Employs multiprocessing for DICOM-to-JPEG conversion for both train and test to speed up preprocessing.
#   - Uses Ultralytics cache='disk' to speed data loading.
#   - Limits MAX_TRAIN_IMAGES (default 2000) to reduce conversion/training time.
#   - Retry logic reduces batch size and image size if the first training attempt fails (e.g., due to OOM).
#   - Disables Weights & Biases (WANDB) logging via environment variables to avoid interruptions.
#   - Isolates Python dependencies in /workspace/pydeps and installs with --no-deps to avoid conflicts.
# - Unique approaches or techniques:
#   - Handles compressed DICOMs by attempting to import/install pylibjpeg backends.
#   - DICOM preprocessing includes percentile clipping (0.5–99.5), RescaleSlope/Intercept, and MONOCHROME1 inversion.
#   - Ensures labels exist for every image (empty files for images without boxes) to prevent dataset loader crashes.
#   - Builds the Ultralytics dataset YAML using explicit train/val text file lists.
# - Other significant aspects:
#   - Random seed set for Python and NumPy (SEED) before shuffling to ensure reproducible splits.
#   - Selection of best training weights: prefers best.pt, falls back to last.pt, and falls back to the retry run directory if the first run’s weights are absent.
#   - Test-time conversion reuses existing JPEGs if already present.
#
#
# **Solution ID:** row_index_4346
# **Score Percentile:** 0.9584313725
#
# 1. Data Preprocessing:
# - Data loading and splitting approaches:
#   - Reads annotations from train.csv via csv.DictReader into a list of dicts.
#   - Lists DICOM files in train and test directories; extracts image_ids by stripping the .dicom extension.
#   - Splits training into train/val by shuffling train_ids and taking the first 5% as validation (val_ratio=0.05), remainder as training.
#   - DEV_FAST mode (environment variable DEV_FAST='1') restricts training IDs to first 200 and validation IDs to first 50.
#
# - Cleaning strategies:
#   - While building targets, skips rows with class_id == 14 (No finding).
#   - Skips rows with missing or empty bounding box fields (x_min, x_max, y_min, y_max).
#   - Converts class_id to label by adding 1 (background=0 is reserved); ignores labels < 1.
#   - Ensures every image_id in the dataset has an entry in targets, even if empty.
#   - After loading per-sample, clips boxes to image bounds.
#   - Removes invalid boxes where x1 <= x0 or y1 <= y0.
#
# - Transformations applied:
#   - DICOM reading with pydicom, using:
#     - RescaleSlope and RescaleIntercept (if present) applied to pixel_array.
#     - Windowing: uses WindowCenter and WindowWidth if valid, otherwise uses [0.5, 99.5] percentiles.
#     - Clipping to window range and normalization to [0, 1].
#   - Converts single-channel image to 3 channels by stacking the same array three times; returns a PyTorch tensor [3, H, W] float.
#   - Resizes images to a maximum size of 1024 on the longer side while maintaining aspect ratio (bilinear interpolation). Returns scale factors sx and sy (new_w/w, new_h/h). Corresponding ground-truth boxes are scaled accordingly.
#
# - Data augmentation techniques (if any):
#   - Random horizontal flip with 0.5 probability during training, with corresponding box coordinate updates.
#
# - Other preprocessing steps:
#   - Caching support: optional caching of processed images to .npz files (img tensor, original size, scale factors) if cache_dir is provided. In main(), cache_dir is not used.
#   - Collate function returns lists of images, targets, and image_ids for detection models.
#
# 2. Feature Engineering:
# - New features and their derivation:
#   - None beyond basic image and bounding box preparation.
# - Feature selection or dimensionality reduction:
#   - None.
# - Domain-specific transformations:
#   - DICOM-specific rescale (slope/intercept) and windowing as described above.
# - If none, explicitly say none:
#   - No additional feature engineering beyond the above.
#
# 3. Model Selection:
# - Primary algorithm(s) and exact classes/functions used:
#   - torchvision.models.detection.fasterrcnn_resnet50_fpn(weights="DEFAULT").
#   - Head replaced with torchvision.models.detection.faster_rcnn.FastRCNNPredictor.
#
# - Hyperparameters used:
#   - Number of classes passed to FastRCNNPredictor: 15 (14 disease classes + background).
#   - Optimizer: torch.optim.SGD with lr=5e-3, momentum=0.9, weight_decay=1e-4.
#   - Batch size: 2.
#   - No learning rate scheduler.
#
# - Ensemble architecture (stacking/blending/voting), number of models:
#   - None.
#
# - Pretrained models (which ones, how used):
#   - Faster R-CNN ResNet-50 FPN with weights="DEFAULT" (pretrained backbone/head from torchvision). The final classifier head is replaced to match the dataset classes.
#
# 4. Training Methodology:
# - Hyperparameter selection (grid/random/manual):
#   - Manual fixed values; no search.
#
# - Training config details:
#   - Epochs: environment variable NUM_EPOCHS (default 2); if DEV_FAST, 1 epoch.
#   - Loss: model’s built-in detection loss (sum of all components from the returned loss_dict).
#   - Optimizer: SGD as above; no scheduler.
#   - Mixed precision: torch.cuda.amp.autocast(enabled=True) and torch.cuda.amp.GradScaler(enabled=True).
#   - Regularization: weight_decay=1e-4 via SGD; no other explicit regularization.
#   - Early stopping: none.
#   - DataLoader: num_workers = min(8, os.cpu_count()), pin_memory=True, shuffle=True for train, shuffle=False for val.
#   - Seeding: random, numpy, torch, and torch.cuda (manual_seed_all) set with seed=42.
#   - DEV_FAST early break inside training loop after >50 iterations.
#
# 5. Evaluation & Submission:
# - Final prediction method and any averaging:
#   - For validation: runs model in eval mode, counts detections with scores > score_thresh (default 0.05); reports simple stats (number of images and number of detections). No averaging across models or TTA.
#   - For test: per-image inference with resizing to max_size=1024; runs model and filters detections by score_thresh=0.05.
#
# - Post-processing of predictions:
#   - Predicted boxes are scaled back to original image size by dividing by sx, sy and clipped to original bounds.
#   - Scores and labels are taken as returned by the model; label is converted back to 0..13 by subtracting 1.
#   - Boxes rounded to integers.
#   - If no detections pass the threshold, inserts a default prediction: "14 1.0 0 0 1 1".
#
# - Submission file format creation specifics:
#   - Creates a CSV with headers: image_id, PredictionString.
#   - PredictionString is a space-separated sequence of: class score x_min y_min x_max y_max for each detection above threshold.
#   - Output path: /workspace/submission.csv.
#   - DEV_FAST early break after >50 test images.
#
# 6. Notable Implementation Details:
# - Computational considerations (GPU usage, mixed precision, runtime optimization):
#   - Uses CUDA if available; else CPU.
#   - Mixed precision training with autocast and GradScaler.
#   - pin_memory=True for DataLoader.
#   - DEV_FAST mode to limit dataset sizes and break early in loops for quicker runs.
#
# - Unique approaches or techniques:
#   - On-the-fly pydicom installation if missing via pip.
#   - DICOM preprocessing includes windowing with fallback to [0.5, 99.5] percentile-based clipping if DICOM windowing metadata is unavailable or invalid.
#   - Optional image caching to .npz (not utilized in main).
#
# - Other significant aspects:
#   - Targets include additional metadata: image_id (index), orig_size, and scale_xy stored in the target dict.
#   - Imports torchvision.ops.box_convert but does not use it.
#   - An initial attempt to replace the predictor head with a Sequential is present but immediately overridden by FastRCNNPredictor; only FastRCNNPredictor is actually used.
#
#
# **Solution ID:** row_index_4350
# **Score Percentile:** 0.19058823530000002
#
# 1. Data Preprocessing:
# - Data loading and splitting approaches:
#   - Reads training annotations from TRAIN_CSV (/root/data/train.csv) using pandas into a list of row dicts.
#   - Constructs a custom Dataset (VinBigDataset) by grouping rows by image_id, collecting bounding boxes and labels.
#   - Image files are expected at TRAIN_DIR/<image_id>.dicom (/root/data/train).
#   - For test, iterates all .dicom files in TEST_DIR (/root/data/test), sorted by filename.
#   - No explicit train/validation split; all available training images with at least one box are used for training.
#   - Optional dataset size limit when FAST_DEV_RUN=1 via TRAIN_LIMIT environment variable.
#
# - Cleaning strategies:
#   - Skips rows without a valid bounding box (any of x_min, y_min, x_max, y_max is None).
#   - Keeps only class_id values in 0..13 (VALID_CLASS_IDS); 14 (No finding) is not used for training.
#   - Skips images whose .dicom file is missing.
#   - Skips images that end up with zero bounding boxes (only positive samples kept).
#
# - Transformations applied:
#   - DICOM reading via pydicom with apply_voi_lut if available.
#   - For MONOCHROME1 images, pixel values are inverted.
#   - Min-max normalization per image to [0, 255], then cast to uint8.
#   - Single-channel image is stacked to 3 channels (RGB-like).
#   - Optional resizing to enforce a maximum side length (MAX_SIZE env var, default 1024); bounding boxes are scaled accordingly.
#   - Converted to torch tensor with channel-first order and normalized to [0, 1] by dividing by 255.
#
# - Data augmentation techniques (if any):
#   - Random horizontal flip with probability 0.5; bounding boxes are adjusted accordingly.
#
# - Other preprocessing steps:
#   - Seeding: random, numpy, torch, and torch.cuda seeds set from SEED env var (default 42).
#   - Custom collate_fn returns lists of images and targets to match torchvision detection API.
#
#
# 2. Feature Engineering:
# - New features and their derivation:
#   - None.
#
# - Feature selection or dimensionality reduction:
#   - None.
#
# - Domain-specific transformations:
#   - DICOM VOI LUT application when present.
#   - MONOCHROME1 inversion.
#   - Per-image min-max rescaling to 8-bit and 3-channel stacking.
#
# - If none, explicitly say none:
#   - See above; no additional engineered features.
#
#
# 3. Model Selection:
# - Primary algorithm(s) and exact classes/functions used:
#   - torchvision.models.detection.fasterrcnn_resnet50_fpn (Faster R-CNN with ResNet-50 FPN backbone).
#   - Head replaced with torchvision.models.detection.faster_rcnn.FastRCNNPredictor.
#
# - Hyperparameters used:
#   - Number of classes for the predictor: 15 (14 findings + background).
#   - Optimizer: torch.optim.AdamW with lr=0.0005 (default, configurable via LR env), weight_decay=1e-4.
#   - Learning rate scheduler: torch.optim.lr_scheduler.MultiStepLR with milestones at int(epochs*0.6) and int(epochs*0.85), gamma=0.1.
#   - Gradient clipping: max_norm=5.0.
#   - Batch size: default 2 (configurable via BATCH_SIZE env).
#   - DataLoader num_workers: default min(8, os.cpu_count()) (configurable via NUM_WORKERS env).
#   - Inference score threshold: 0.15 (configurable via function parameter).
#   - Max detections per image at inference: 50.
#
# - Ensemble architecture (stacking/blending/voting), number of models:
#   - None.
#
# - Pretrained models (which ones, how used):
#   - Attempts to load pretrained weights "DEFAULT" for fasterrcnn_resnet50_fpn. Falls back to random initialization if loading fails.
#   - Only the box predictor head is replaced to match the number of classes.
#
#
# 4. Training Methodology:
# - Hyperparameter selection (grid/random/manual):
#   - Manual via code defaults and environment variables; no search procedure.
#
# - Training config details:
#   - Epochs: default 3 (configurable via EPOCHS env).
#   - DataLoader: shuffle=True, custom collate_fn.
#   - Loss: uses the internal Faster R-CNN losses via model(images, targets) returning a loss dict; summed for backpropagation.
#   - Optimizer: AdamW (lr and weight decay as above).
#   - LR scheduling: MultiStepLR stepped once per epoch.
#   - Regularization: weight decay (1e-4) and gradient clipping (5.0).
#   - Early stopping: none.
#   - Checkpointing: after each epoch, saves {'epoch': epoch+1, 'model_state': model.state_dict()} to CHECKPOINT_PATH (/workspace/model_frcnn_vinbig.pth).
#   - Device: uses CUDA if available; otherwise CPU.
#   - No validation loop; training loss and per-batch loss printed via tqdm where available.
#
#
# 5. Evaluation & Submission:
# - Final prediction method and any averaging:
#   - Single-model inference on each test image.
#   - Per-image predictions filtered by confidence score >= 0.15, then optionally limited to top 50 by score.
#   - No model ensembling, no test-time augmentation, no averaging.
#
# - Post-processing of predictions:
#   - Labels from model (1..14) are mapped to Kaggle class_id (0..13) by subtracting 1.
#   - Bounding boxes are rounded to ints, clamped to image bounds, and enforced to have minimum size of 1 pixel in width and height (x2 >= x1+1, y2 >= y1+1).
#   - If no detection remains after thresholding, outputs a default "No finding" entry: class "14", confidence "1.0", box "0 0 1 1".
#
# - Submission file format creation specifics:
#   - Writes CSV to SUB_PATH (/workspace/submission.csv) with header ["image_id", "PredictionString"].
#   - PredictionString is a space-separated sequence: for each detection, "class_id score x_min y_min x_max y_max". Multiple detections are concatenated.
#   - Test images processed in sorted filename order. One row per image_id.
#
#
# 6. Notable Implementation Details:
# - Computational considerations (GPU usage, mixed precision, runtime optimization):
#   - Uses GPU if available; sets CUDA seeds.
#   - No mixed precision, no AMP.
#   - Optional resizing to a maximum side length (MAX_SIZE, default 1024) to control memory usage.
#   - tqdm progress bars if available.
#   - DataLoader workers configurable; no pin_memory or persistent_workers specified.
#
# - Unique approaches or techniques:
#   - On-the-fly dependency installation for pydicom, tqdm, and torchvision if missing.
#   - DICOM-specific preprocessing: VOI LUT application and MONOCHROME1 inversion.
#   - Dataset excludes images without bounding boxes (no explicit handling of negative samples in training), and labels are shifted by +1 for torchvision’s background convention.
#
# - Other significant aspects:
#   - Random horizontal flip augmentation with corresponding box updates.
#   - Checkpoint saved after each epoch to a fixed path.
#   - Environment variables control seed, batch size, epochs, learning rate, num_workers, max input size, and optional dataset limiting for fast development.
#
#
# **Solution ID:** row_index_4355
# **Score Percentile:** 0.9537254902000001
#
# 1. Data Preprocessing:
# - Data loading and splitting approaches:
#   - Training IDs are taken from train.csv (unique image_id) and filtered to those whose corresponding DICOM file exists at train/<image_id>.dicom.
#   - Test IDs are read from sample_submission.csv (column image_id).
#   - No validation split is implemented; the full available training set (after optional limits) is used for training.
#   - Optional dataset size controls via environment variables:
#     - FAST_DEV_RUN=1 randomly shuffles and limits training to 200 images and sets epochs to 1.
#     - LIMIT_TRAIN=N truncates training image IDs to the first N.
# - Cleaning strategies:
#   - From train.csv, only rows with class_id parsable to int and class_id != 14 are kept.
#   - Rows must have x_min, y_min, x_max, y_max parsable to float.
#   - Bounding boxes with invalid geometry (x_max <= x_min or y_max <= y_min) are discarded.
#   - Only annotations for image_ids present in the provided image_ids list are used.
# - Transformations applied:
#   - DICOM reading:
#     - Reads via pydicom.dcmread.
#     - Applies VOI LUT if available (apply_voi_lut), with try/except fallback.
#     - Converts to float32.
#     - If PhotometricInterpretation == MONOCHROME1, inverts image (max - arr).
#     - Normalizes each image to [0, 1] by min-max scaling.
#     - Converts single-channel to 3-channel by stacking the same channel three times.
#   - Spatial resizing:
#     - For training and testing, images are resized to preserve aspect ratio so that the long side equals RESIZE_LONG (default 1024). Implemented via cv2.resize with INTER_LINEAR.
#     - For training, bounding boxes are scaled to match the resized image coordinates.
#   - Tensor conversion:
#     - Images are converted from HxWxC float32 in [0,1] to PyTorch tensors shaped CxHxW.
# - Data augmentation techniques:
#   - Random horizontal flip with 0.5 probability during training; bounding boxes are adjusted accordingly (x coordinates mirrored).
# - Other preprocessing steps:
#   - Targets include:
#     - boxes: Nx4 tensor (float32) in [x1, y1, x2, y2] format.
#     - labels: N tensor (int64), with class indices mapped from 0..13 in CSV to 1..14 to comply with torchvision (background=0).
#     - image_id: tensor([idx]).
#     - area: per-box area computed as (x2 - x1) * (y2 - y1).
#     - iscrowd: zeros of length N (int64).
#   - Custom collate_fn returns lists of images, targets, and image_ids for detection models.
#
# 2. Feature Engineering:
# - New features and their derivation: None.
# - Feature selection or dimensionality reduction: None.
# - Domain-specific transformations: Only DICOM-specific reading (VOI LUT application, MONOCHROME1 inversion) and normalization; no additional domain-driven feature engineering.
# - If none, explicitly say none: None.
#
# 3. Model Selection:
# - Primary algorithm(s) and exact classes/functions used:
#   - torchvision.models.detection Faster R-CNN with ResNet-50 FPN backbone.
#   - Function: get_model uses:
#     - Prefer fasterrcnn_resnet50_fpn_v2(weights="DEFAULT"); fallback to pretrained=True if necessary.
#     - If v2 unavailable, fallback to fasterrcnn_resnet50_fpn (v1) with weights="DEFAULT" or pretrained=True.
#   - Head replacement: torchvision.models.detection.faster_rcnn.FastRCNNPredictor to set num_classes.
# - Hyperparameters used (model-related):
#   - num_classes = 15 (14 findings + background).
#   - Other model internals (anchors, NMS thresholds, etc.) remain at torchvision defaults.
# - Ensemble architecture:
#   - None. Single model only.
# - Pretrained models:
#   - Uses torchvision “DEFAULT” weights (or pretrained=True) for the chosen Faster R-CNN variant; then replaces the classifier head for 15 classes.
#
# 4. Training Methodology:
# - Hyperparameter selection:
#   - All training hyperparameters are set manually or via environment variables; no grid/random search.
# - Training config details:
#   - Optimizer: torch.optim.SGD with:
#     - Learning rate: LR env (default 0.005).
#     - Momentum: 0.9.
#     - Weight decay: 1e-4.
#   - LR scheduler: torch.optim.lr_scheduler.StepLR:
#     - step_size: LR_STEP env (default 1 epoch).
#     - gamma: LR_GAMMA env (default 0.9).
#   - Epochs: EPOCHS env (default 2); overridden to 1 if FAST_DEV_RUN=1.
#   - Batch size: BATCH_SIZE env (default 2).
#   - DataLoader: shuffle=True, num_workers = NUM_WORKERS env (default 8), custom collate_fn.
#   - Loss: sum of Faster R-CNN loss components returned by the model (as provided by torchvision).
#   - Regularization: weight decay 1e-4; no additional regularization is used.
#   - Mixed precision: optional via USE_AMP env (default enabled if CUDA present). Uses torch.cuda.amp.autocast and torch.cuda.amp.GradScaler.
#   - Early stopping: None.
#   - Logging: average loss printed every 20 steps; LR logged at epoch end.
#   - Device: CUDA if available, otherwise CPU.
#   - Checkpointing: saves model.state_dict to /workspace/fasterrcnn_vinbig.pth after training (best-effort with try/except).
#
# 5. Evaluation & Submission:
# - Final prediction method and any averaging:
#   - Inference on the test set with model.eval() and torch.no_grad().
#   - Test images are resized the same way (long side = RESIZE_LONG), and the scale factor is recorded.
#   - Model outputs are adjusted by dividing predicted boxes by the recorded scale to map back to original image coordinates.
#   - No ensembling or test-time augmentation; single forward pass per image with batch_size=1.
# - Post-processing of predictions:
#   - Filtering by confidence: only detections with score >= SCORE_THRESH env (default 0.2) are kept.
#   - Label remapping: model labels 1..14 are mapped back to 0..13 for submission.
#   - Coordinates: rounded to integers; clamped to ensure non-degenerate boxes:
#     - x1 >= 0, y1 >= 0.
#     - x2 >= x1 + 1, y2 >= y1 + 1.
#   - If no detections pass the threshold (or no output), outputs the required “No finding” line: "14 1 0 0 1 1".
# - Submission file format creation specifics:
#   - Output CSV at /workspace/submission.csv with header ["image_id", "PredictionString"].
#   - The PredictionString is a space-separated sequence of per-detection six-tuples: class_id score x_min y_min x_max y_max, with score formatted to 4 decimals.
#   - Ensures all test_ids from sample_submission.csv are present; any missing predictions are filled with "14 1 0 0 1 1".
#
# 6. Notable Implementation Details:
# - Computational considerations:
#   - GPU support with automatic selection; mixed precision training on CUDA when enabled.
#   - DataLoader parallelism controlled via NUM_WORKERS (default 8).
#   - optimizer.zero_grad(set_to_none=True) for potential performance gains.
#   - Image resizing to a fixed long side (default 1024) to standardize input sizes and reduce memory usage.
# - Unique approaches or techniques:
#   - DICOM-specific preprocessing: VOI LUT application and handling of MONOCHROME1 inversion.
#   - Label offset handling for torchvision detection models (training labels = CSV class_id + 1; background = 0).
# - Other significant aspects:
#   - Development mode (FAST_DEV_RUN) to quickly iterate with a reduced dataset and 1 epoch.
#   - Score threshold, resize size, LR/scheduler parameters, batch size, and other behaviors are configurable via environment variables.
#   - No validation set or metric computation is included; the pipeline proceeds directly from training to test inference and submission generation.
#
#
# **Solution ID:** row_index_4369
# **Score Percentile:** 0.9835294118000001
#
# 1. Data Preprocessing:
# - Data loading and splitting approaches:
#   - Reads train.csv from data_dir (/root/data/train.csv).
#   - Collects DICOM image_ids by listing files ending with .dicom in the train directory and stripping the suffix.
#   - Intersects collected image_ids with those present in train.csv to ensure only valid images are used.
#   - No explicit validation split; all selected training images are used for training.
#   - For testing, collects all .dicom files from the test directory.
#   - Optional subset controls:
#     - FAST_DEV=1 limits training to a small shuffled subset (max of 1% or at least 8 images), sets epochs=1 and max_steps=50.
#     - SUBSET_FRAC<1.0 randomly shuffles and takes that fraction (at least 100 images).
# - Cleaning strategies:
#   - Skips rows with class_name == "No finding" for training annotations (no boxes for that class).
#   - Skips rows where any of x_min, y_min, x_max, y_max are NaN.
#   - Skips rows with invalid boxes where x_max <= x_min or y_max <= y_min.
#   - Clips bounding boxes to image boundaries (0..width for x, 0..height for y).
# - Transformations applied:
#   - DICOM reading via pydicom.dcmread.
#   - Applies VOI LUT if available (apply_voi_lut).
#   - Inverts pixel values if PhotometricInterpretation == "MONOCHROME1".
#   - Min-max normalization per image to [0, 1].
#   - Converts single-channel image to 3-channel by stacking the same channel (HWC -> 3 channels).
#   - Converts to torch float tensor with channel-first layout (CHW).
# - Data augmentation techniques:
#   - None implemented.
# - Other preprocessing steps:
#   - Shifts class labels by +1 to reserve 0 for background: cls_id = int(row['class_id']) + 1.
#   - Stores per-sample metadata: image_id (index) and orig_size (height, width), though these are not used during training.
#
# 2. Feature Engineering:
# - New features and their derivation: None.
# - Feature selection or dimensionality reduction: None.
# - Domain-specific transformations:
#   - DICOM-specific VOI LUT application.
#   - Handling MONOCHROME1 inversion.
#   - Min-max normalization of medical images.
# - If none, explicitly say none: Not applicable (above transformations are present).
#
# 3. Model Selection:
# - Primary algorithm(s) and exact classes/functions used:
#   - Object detector: torchvision.models.detection.faster_rcnn.fasterrcnn_resnet50_fpn_v2.
#   - Replaced classifier head with torchvision.models.detection.faster_rcnn.FastRCNNPredictor.
# - Hyperparameters used:
#   - num_classes = 15 (includes background=0 and 14 competition classes; “No finding” handled specially).
#   - Optimizer: torch.optim.SGD with lr = 0.005 (configurable via LR env), momentum = 0.9, weight_decay = 0.0005.
#   - Batch size: default 2 (configurable via BATCH_SIZE env).
#   - num_workers: default min(8, CPU count) (configurable via NUM_WORKERS env).
#   - Inference score threshold: 0.15 (configurable via SCORE_THRESH env).
#   - Max detections per image during inference: 50.
# - Ensemble architecture:
#   - None.
# - Pretrained models:
#   - Attempts to load pretrained weights ("DEFAULT") for fasterrcnn_resnet50_fpn_v2.
#   - Falls back to random initialization (weights=None) if pretrained download fails.
#
# 4. Training Methodology:
# - Hyperparameter selection:
#   - Manual via environment variables (LR, BATCH_SIZE, NUM_WORKERS, EPOCHS, FAST_DEV, SUBSET_FRAC).
# - Training config details:
#   - Epochs: default 2 (configurable via EPOCHS). If FAST_DEV=1, epochs=1 and max_steps=50.
#   - Loss: sum of losses returned by the detection model (from torchvision; classification, bbox regression, etc.).
#   - Optimizer: SGD as above.
#   - Learning rate schedule: warmup during first epoch using torch.optim.lr_scheduler.LinearLR with start_factor=1/1000 for total_iters=min(1000, len(data_loader)-1).
#   - Mixed precision: uses torch.cuda.amp.autocast and torch.cuda.amp.GradScaler when running on CUDA.
#   - Regularization: weight_decay=0.0005 via SGD; no other explicit regularization.
#   - Early stopping: None.
#   - Logging: average training loss printed every 20 steps and at epoch end.
#   - Data loading: DataLoader with shuffle=True, collate_fn to handle variable targets, pin_memory=True.
#
# 5. Evaluation & Submission:
# - Final prediction method and any averaging:
#   - Model in eval mode; no ensembling or averaging.
#   - For each image, retrieves boxes, scores, labels from model output.
#   - Filters detections by score >= score_thresh.
#   - Keeps top max_det_per_img detections by highest scores.
#   - Converts model labels l to competition labels by comp_label = l - 1.
#   - Rounds and clips bounding boxes to non-negative integers, ensuring at least 1 pixel size (x2 >= x1+1, y2 >= y1+1).
# - Post-processing of predictions:
#   - If no detections remain after filtering, outputs a default “No finding” prediction: "14 1.0 0 0 1 1".
# - Submission file format creation specifics:
#   - Builds a DataFrame with columns:
#     - image_id: all test image IDs (from test directory listing).
#     - PredictionString: space-separated triplets per detection [class score x_min y_min x_max y_max] or the default “No finding” string.
#   - Writes CSV to /workspace/submission.csv with index=False.
#
# 6. Notable Implementation Details:
# - Computational considerations:
#   - Installs missing packages (pydicom, torchvision) at runtime if not present.
#   - Sets random seeds for Python, NumPy, and PyTorch (SEED env or default 1337).
#   - Uses CUDA if available; enables torch.backends.cudnn.benchmark = True.
#   - Mixed precision training enabled on GPU via AMP; optimizer uses set_to_none=True for zero_grad.
#   - DataLoader uses pin_memory=True and multi-workers (up to 8).
# - Unique approaches or techniques:
#   - DICOM preprocessing with VOI LUT application and MONOCHROME1 handling.
#   - Label shifting strategy to accommodate background class; excludes “No finding” rows from training boxes but retains label space to include it at inference via fallback.
#   - Warmup LR scheduler limited to first epoch only.
# - Other significant aspects:
#   - Collate function composes lists of images/targets for detection model compatibility.
#   - During training, only passes "boxes" and "labels" to the model (removes helper fields).
#   - Test dataset defined inline; returns minimal target metadata.
#   - Robustness: if pretrained weights cannot be downloaded, the code continues with uninitialized weights.
#
#
# **Solution ID:** row_index_4374
# **Score Percentile:** 0.2274509804
#
# 1. Data Preprocessing:
# - Data loading and splitting approaches:
#   - Loads annotations from TRAIN_CSV using pandas.read_csv.
#   - Constructs a training dataset (VinBigDataset) by grouping rows by image_id only for entries with valid bounding boxes and class_id != 14 ("No finding").
#   - No explicit train/validation split; trains on all images that have at least one valid bounding box. An optional limit is applied when FAST_DEV_RUN=1 to downsample to 32 images.
#   - Test image IDs are collected by listing files ending with .dicom in TEST_IMG_DIR.
# - Cleaning strategies:
#   - Skips rows where class_name == "No finding" or class_id == 14.
#   - Skips rows with any missing bounding box coordinates (x_min, y_min, x_max, y_max).
# - Transformations applied:
#   - DICOM reading:
#     - Uses pydicom to read the DICOM file and extracts pixel_array.
#     - Attempts to apply VOI LUT (apply_voi_lut); falls back to raw pixel data on failure.
#     - Inverts image if PhotometricInterpretation is MONOCHROME1.
#     - Converts to float32, normalizes to [0, 255], then casts to uint8.
#     - Converts to RGB 3-channel PIL Image.
#   - Image-to-tensor conversion:
#     - Converts PIL image to numpy array, then to torch tensor of shape [C,H,W], dtype float, scaled to [0,1] by dividing by 255.
#   - Resizing:
#     - If the larger image side exceeds 1024, resizes the image to keep aspect ratio with max side 1024 using bilinear resampling.
#     - Scales bounding boxes accordingly.
# - Data augmentation techniques:
#   - Optional horizontal flip with 50% probability when augment=True (used for training).
#   - Bounding boxes are adjusted for horizontal flip (x coordinates mirrored).
# - Other preprocessing steps:
#   - Optional caching of DICOMs to PNG for speed (used when FAST_DEV_RUN=1) with caching directories for train and test.
#   - During dataset creation, labels are kept as original 0..13 disease IDs; at return time they are mapped to 1..14 for the detector (0 reserved for background).
#
# 2. Feature Engineering:
# - New features and their derivation:
#   - None.
# - Feature selection or dimensionality reduction:
#   - None.
# - Domain-specific transformations:
#   - DICOM-specific processing: VOI LUT application and MONOCHROME1 inversion.
# - If none, explicitly say none:
#   - No additional feature engineering beyond the above.
#
# 3. Model Selection:
# - Primary algorithm(s) and exact classes/functions used:
#   - Object detection model: torchvision.models.detection.fasterrcnn_resnet50_fpn.
#   - Classifier head replaced with FastRCNNPredictor for the desired number of classes.
# - Hyperparameters used:
#   - Number of classes set to 15 (14 disease classes + background).
#   - Score threshold during inference: 0.35.
# - Ensemble architecture:
#   - None (single model).
# - Pretrained models:
#   - Uses pretrained weights ("DEFAULT" if available; falls back to pretrained=True) for Faster R-CNN ResNet50 FPN.
#
# 4. Training Methodology:
# - Hyperparameter selection:
#   - Manual/static configuration in code (no search).
# - Training config details:
#   - Epochs: 3 (or 1 when FAST_DEV_RUN=1).
#   - Batch size: 4 if CUDA is available, else 2.
#   - Optimizer: torch.optim.AdamW with specified lr; other parameters left at defaults.
#     - Learning rate: 3e-4 (or 5e-4 when FAST_DEV_RUN=1).
#   - LR scheduler: StepLR with step_size = max(1, epochs // 2) and gamma = 0.1.
#   - Loss: sum of Faster R-CNN loss components returned by the model (computed internally by torchvision).
#   - Mixed precision: torch.cuda.amp autocast and GradScaler enabled when using CUDA.
#   - Regularization: No explicit regularization besides what AdamW defaults provide (no custom weight decay set in code).
#   - Early stopping: None.
#
# 5. Evaluation & Submission:
# - Final prediction method and any averaging:
#   - Single pass inference over the test set with the trained model.
#   - Filters predictions by score >= 0.35.
#   - Maps model labels from 1..14 back to class_id 0..13.
# - Post-processing of predictions:
#   - Coordinates are cast to integers.
#   - If no predictions remain after thresholding, outputs a default "No finding" entry: "14 1 0 0 1 1".
# - Submission file format creation specifics:
#   - CSV with headers ["image_id", "PredictionString"].
#   - PredictionString is a space-separated sequence for each detection: class_id score x_min y_min x_max y_max.
#   - Ensures all test IDs are present; if a test image has no model output in the results dict, writes the default "No finding" string.
#   - Baseline fallback: if no training samples with bounding boxes are found (empty dataset), writes a submission with "14 1 0 0 1 1" for all test images.
#
# 6. Notable Implementation Details:
# - Computational considerations:
#   - Uses GPU if available (torch.cuda.is_available()).
#   - Mixed precision training/inference on CUDA to accelerate and reduce memory usage.
#   - Optional DICOM-to-PNG caching for faster subsequent loads (enabled in FAST_DEV_RUN).
#   - Image resizing to a max side of 1024 to control memory/compute.
#   - DataLoader uses num_workers=2 and a custom collate_fn compatible with detection models.
# - Unique approaches or techniques:
#   - Simple baseline submission generation when no training data with boxes is available.
#   - Skips "No finding" class during training and relies on a default "No finding" output in inference when no boxes pass the threshold.
# - Other significant aspects:
#   - Package installation helper to ensure required dependencies are present at runtime.
#   - Saves model state_dict to a checkpoint file after training.
#
#
# **Solution ID:** row_index_4407
# **Score Percentile:** 0.1074509804
#
# 1. Data Preprocessing:
# - Data loading and splitting approaches:
#   - Train annotations loaded from /root/data/train.csv using pandas.read_csv.
#   - Train image IDs collected by listing files ending with .dicom in /root/data/train; IDs are filenames without extension.
#   - Train/validation split: random shuffle of train IDs, then 95% used for training and 5% for validation; the validation split is created but not used later.
#   - Test image IDs collected by listing files ending with .dicom in /root/data/test and sorting them.
#   - Debug mode (env DEBUG=1) reduces train IDs to first 400 and test IDs to first 50; also limits training to 1 epoch and max 50 steps.
# - Cleaning strategies:
#   - In VinBigTrainDataset, rows with class_id == 14 (“No finding”) are skipped (no boxes created).
#   - Malformed annotation rows (non-numeric bbox fields) are skipped.
#   - Invalid boxes where x_max <= x_min or y_max <= y_min are skipped.
#   - For images with no valid boxes, boxes and labels are set to empty arrays of shape (0,4) and (0,), respectively.
#   - DICOM reading handles MONOCHROME1 by inverting pixel values and applies VOI LUT when available.
#   - If a test DICOM read fails, a 1024x1024 blank uint8 image is used and a warning is logged.
# - Transformations applied:
#   - DICOM images converted to float32, normalized to [0,1], then scaled to [0,255] and cast to uint8.
#   - Resizing: images are resized to ensure max(H, W) <= MAX_SIDE (default 1024 via env var), preserving aspect ratio. Returns resize scale factor.
#     - Primary resize uses PIL Image.resize with bilinear interpolation.
#     - Fallback (if PIL import fails) uses array slicing to new_h and new_w (top-left crop-like behavior).
#   - Conversion to tensors: uint8 HxW or HxWx1 images are replicated to 3 channels, normalized to [0,1], and transposed to CHW float tensors.
#   - Bounding boxes scaled by the same factor as image resizing.
# - Data augmentation techniques:
#   - None present.
# - Other preprocessing steps:
#   - pydicom is ensured; if not installed, it is installed at runtime.
#   - Train dataset target includes 'image_id' as the dataset index (torch.tensor([idx])).
#
# 2. Feature Engineering:
# - New features and their derivation:
#   - None.
# - Feature selection or dimensionality reduction:
#   - None.
# - Domain-specific transformations:
#   - DICOM VOI LUT application.
#   - MONOCHROME1 inversion.
#   - Replication of grayscale to 3 channels for model compatibility.
# - If none, explicitly say none:
#   - Apart from the domain-specific DICOM handling listed above, none.
#
# 3. Model Selection:
# - Primary algorithm(s) and exact classes/functions used:
#   - Object detection using torchvision.models.detection.fasterrcnn_resnet50_fpn_v2 with default pretrained weights.
#   - Classification head replaced with torchvision.models.detection.faster_rcnn.FastRCNNPredictor.
# - Hyperparameters used:
#   - Number of classes passed to FastRCNNPredictor: 15 (background + 14 detectable classes).
#   - Optimizer: torch.optim.SGD with lr=0.005, momentum=0.9, weight_decay=0.0005.
#   - Learning rate scheduler: torch.optim.lr_scheduler.StepLR with step_size=3, gamma=0.1, created only in epoch 0 and stepped every training iteration within that epoch.
# - Ensemble architecture:
#   - None.
# - Pretrained models:
#   - FasterRCNN_ResNet50_FPN_V2_Weights.DEFAULT used to initialize the backbone/model.
#
# 4. Training Methodology:
# - Hyperparameter selection:
#   - Manual settings; no hyperparameter search implemented.
# - Training config details:
#   - Epochs: 2 (or 1 in DEBUG mode).
#   - Batch size: 2.
#   - DataLoader num_workers: 4.
#   - Loss: sum of losses returned by the detection model (as provided by torchvision’s Faster R-CNN).
#   - Optimizer: SGD (lr=0.005, momentum=0.9, weight_decay=0.0005).
#   - LR scheduler: StepLR applied only during epoch 0 and stepped each batch (not per epoch).
#   - Regularization: weight decay via optimizer; no other explicit regularization.
#   - Early stopping: none.
#   - Gradient clipping: none.
#   - Mixed precision: none.
#   - Checkpointing: model.state_dict() and epochs saved to /workspace/fasterrcnn_vinbig.pth after training.
#
# 5. Evaluation & Submission:
# - Final prediction method and any averaging:
#   - Inference on test set using the trained model.
#   - Predictions filtered by confidence score >= 0.25.
#   - Non-maximum suppression applied once across all boxes irrespective of class labels using torchvision.ops.nms with IoU threshold 0.5.
#   - Maximum of 60 detections per image after NMS.
#   - Boxes rescaled back to original image coordinates by dividing by the resize scale.
# - Post-processing of predictions:
#   - Model labels (1..14) mapped back to competition class_id by subtracting 1 (resulting 0..13).
#   - Bounding boxes converted to integers for submission.
#   - If no predictions for an image, outputs the required “No finding” fallback: "14 1 0 0 1 1".
# - Submission file format creation specifics:
#   - CSV with headers: image_id, PredictionString.
#   - PredictionString is a space-separated sequence of class_id score xmin ymin xmax ymax repeated for all detections, scores formatted to 4 decimals.
#   - Ensures all test image IDs have an entry (adds empty list if missing) before writing.
#   - Output path: /workspace/submission.csv.
#
# 6. Notable Implementation Details:
# - Computational considerations:
#   - Uses CUDA if available; otherwise CPU.
#   - DataLoader uses num_workers=4.
#   - No distributed training or mixed precision.
# - Unique approaches or techniques:
#   - NMS is applied globally across all classes rather than per-class.
#   - Grayscale DICOM images are replicated to 3 channels to fit the pretrained model’s expected input.
#   - Dynamic installation of pydicom if missing.
# - Other significant aspects:
#   - Environment variables:
#     - MAX_SIDE controls maximum image side length during resizing (default 1024).
#     - DEBUG toggles reduced dataset size, fewer epochs, and max training steps.
#   - Validation split is created but not used further.
#   - The target 'image_id' stored in the training target is the dataset index, not the actual image identifier.
#   - PIL-based resize uses bilinear interpolation; fallback path slices arrays to target size if PIL is unavailable.
#
#
# **Solution ID:** row_index_4413
# **Score Percentile:** 1.0
#
# 1. Data Preprocessing:
# - Data loading and splitting approaches:
#   - Reads annotations from TRAIN_CSV (/root/data/train.csv) via read_train_csv, returning a dict mapping image_id to a list of bounding boxes (class_id, xmin, ymin, xmax, ymax). Rows with class_id 14 (“No finding”) are recorded as an empty list of boxes for that image.
#   - Gathers training image_ids by listing all .dicom files in TRAIN_DIR (/root/data/train) and stripping the extension. This list is shuffled and split into train/val:
#     - Default val_ratio = 0.05.
#     - If FAST_DEV=1, the list is truncated to at most 200 images and val_ratio = 0.10.
#     - Validation IDs are the first val_count items; train IDs are the remainder.
#   - Gathers test image_ids by listing .dicom files in TEST_DIR (/root/data/test). If FAST_DEV=1, test_ids are truncated to the first 100.
# - Cleaning strategies:
#   - Skips annotation rows with:
#     - class_id == 14 (no bounding boxes).
#     - Non-numeric or NaN coordinates.
#     - Non-positive area boxes (xmax <= xmin or ymax <= ymin).
# - Transformations applied:
#   - DICOM to image:
#     - Reads DICOM with pydicom.
#     - Applies VOI LUT if available.
#     - Applies RescaleSlope and RescaleIntercept if present.
#     - If PhotometricInterpretation == MONOCHROME1, inverts intensities.
#     - Normalizes to 0–255 uint8.
#   - Image resizing/padding:
# ...
#   - YOLOv8s and 1024 imgsz support multi-instance detection and small findings; mAP@0.4 favors higher recall achievable with low conf threshold (0.05).
#   - Domain-specific intensity correction reduces variability; label space excludes “No finding” in training and handles it in submission per rules.
#
# Solution 4704 (Percentile 1.0)
# - Why it works
#   - Complete DICOM pipeline: VOI LUT, rescale slope/intercept, MONOCHROME1 inversion to 8-bit; aspect-preserving resize to 1024; stores per-image metadata (sx, sy) for precise inverse scaling. Evidence: “apply_voi_lut… RescaleSlope/Intercept… Inversion… Resizing… Recording per-image metadata JSON containing ... scaling factors sx, sy.”
#   - Efficient YOLOv8 finetuning with pretrained weights (default yolov8n.pt), reasonably long training (default 20 epochs). Evidence: “Ultralytics YOLOv8… default 'yolov8n.pt'… EPOCHS default 20.”
#   - Clean label generation and clipping; enforced submission fallback. Evidence: “Skips class_id == 14… Clips scaled bounding boxes… outputs '14 1 0 0 1 1' if no detections.”
# - Key strengths
#   - Accurate geometry conversion via stored per-image metadata.
#   - Lightweight yet effective model choice (YOLOv8n) allowing high input resolution.
#   - Robust, idempotent preprocessing (skips recomputation when JPG/JSON exist).
# - Alignment with task
#   - High resolution (1024) useful for small lesions; YOLO detects multiple instances efficiently—good for mAP@0.4.
#   - Domain-specific preprocessing reduces intensity variation; proper fallback and class handling align with competition constraints.
#
# Solution 4781 (Percentile 0.9616)
# - Why it works
#   - Strong DICOM processing and contrast enhancement: VOI LUT, MONOCHROME1 inversion, normalization to 0–255, optional CLAHE to improve detectability of subtle findings. Evidence: “apply_voi_lut… MONOCHROME1 inversion… CLAHE (clipLimit=2.0…).”
#   - Clean target geometry and normalization for both YOLO and Faster R-CNN paths: clamps boxes, enforces minimum sizes, proper label mapping and shifts. Evidence: “Clamps… enforces x2 >= x1+1… YOLO normalized labels… labels 0–13 and background 0 for FRCNN with shift.”
#   - High input size option (1024) and correct target handling in PyTorch detection API (collate_fn, target dicts). Evidence: “Image tensors… CHW float32… collate function… detection model compatibility.”
# - Key strengths
#   - Comprehensive and robust preprocessing that addresses medical imaging nuances.
#   - Correct inverse scaling and clipping at submission time to ensure valid boxes.
#   - Safety fallbacks (dummy images for conversion failures) to avoid breaking inference.
# - Alignment with task
#   - Proper geometric and intensity normalization improves consistency across radiographs, aiding mAP@0.4.
#   - Multi-instance detection-friendly architectures (Faster R-CNN, optional YOLO) and high-res images suit small, overlapping abnormalities.
#   - Proper “No finding” fallback and label space compliance match evaluation and submission requirements.
#
# General alignment themes across these top solutions
# - DICOM-specific intensity handling (VOI LUT, slope/intercept, MONOCHROME1 inversion) is consistently present and directly addresses the medical imaging domain challenge of variable contrast and acquisition.
# - High-resolution inputs (max side ~1024) and FPN or YOLO backbones improve sensitivity to small findings, benefiting mAP@0.4.
# - Clean label handling: excluding “No finding” from training, label shift for background in PyTorch, clipping boxes, and removing invalid geometry reduces noise and training instability.
# - Accurate geometry transforms and inverse scaling ensure submitted boxes align with original DICOM coordinates, crucial for IoU-based mAP.
# - Sensible thresholds, NMS defaults, and limiting max detections help manage precision/recall for the relatively lenient IoU threshold (0.4), aligning with the competition’s mAP metric.
#
# ### Medium-Scoring Solutions (0.4 ≤ percentile < 0.7)
#
# Could you share the specific solution summaries? In the meantime, here are common patterns seen in medium-scoring submissions for this task.
#
# What’s working reasonably well
# - Correct DICOM ingestion with basic windowing/normalization and aspect-preserving resizing
# - Use of standard detectors (e.g., Faster R-CNN/RetinaNet/YOLO) with FPN and reasonable anchor settings
# - Basic class-imbalance handling (focal loss, weighted sampling) and standard augmentations
# - Alignment with evaluation (IoU > 0.4) and sensible NMS/thresholding per class
# - Cross-validation or holdout strategy that avoids leakage and yields stable mAP
#
# Most likely bottlenecks preventing higher performance
# - Insufficient resolution and anchor tuning for tiny, subtle thoracic findings; small-object recall is low
# - NMS/configuration not well adapted to multi-instance per class, causing missed duplicates or cross-class suppression
# - Weak handling of label noise/inter-reader variability (training on noisy boxes without robust loss or uncertainty modeling)
# - “No finding” class mishandled (missing one‑pixel box logic or poor confidence calibration), hurting precision/recall
# - Residual class imbalance leads to undertrained rare findings; limited hard-negative mining or targeted sampling
# - Limited domain-specific preprocessing (e.g., lung field masking, rib suppression, pixel spacing use) and radiography-specific augmentations, reducing generalization to subtle/overlapping findings
#
# ### Low-Scoring Solutions (percentile < 0.4)
#
# Solution 4322 (YOLOv8, Percentile 0.107)
# - Likely failure points:
#   - Training may start from architecture-only YAML (random init) instead of pretrained weights, leading to severe underperformance on a medical detection task.
#   - Hard cap of MAX_TRAIN_IMAGES=2000 drastically underuses the dataset and harms generalization.
#   - No explicit data augmentation listed; relying only on whatever YOLO defaults provide is insufficient for small, subtle findings in CXRs.
#   - Naive train/val split (first VAL_SPLIT fraction after conversion) risks distribution bias; no stratification or cross-validation.
#   - Very low inference threshold (conf=0.1) likely yields many false positives and lower mAP@0.4.
#   - JPEG conversion (quality=90) plus 8-bit normalization may destroy subtle grayscale information important for small findings.
# - Evidence:
#   - “Model initialization tries YOLO('yolov8{size}.yaml')… last resort: YOLO('yolov8n.pt')” shows a real risk of training from scratch.
#   - “Limits MAX_TRAIN_IMAGES (default 2000)” and “VAL_SPLIT default 0.1… takes the first … as validation” confirm underuse and naive splitting.
#   - “Data augmentation techniques: None specified” and reliance on external preprocessing.
#   - “predict… conf = 0.1” and “saves as JPEG quality=90” indicate aggressive FP risk and potential information loss.
# - What would help:
#   - Force pretrained weights with nc=14 (e.g., yolov8m.pt) and disable the YAML-only init path; error out if fine-tuned weights aren’t produced.
#   - Train on the full dataset with 5-fold cross-validation; track mAP@0.4 and select best checkpoints.
#   - Add stronger augmentation (scale/translation, mixup/mosaic, HSV gain off for medical, random brightness/contrast) and multi-scale training.
#   - Use a more realistic inference threshold (per-class tuned, typically 0.25–0.35) based on validation PR curves.
#   - Consider PNG over JPEG or lossless formats for preprocessing; preserve more grayscale detail.
#   - Ensemble several folds with Weighted Boxes Fusion; calibrate thresholds per class.
#
# Solution 4350 (Faster R-CNN pretrained, Percentile 0.191)
# - Likely failure points:
#   - Excludes negative samples (images with zero boxes) from training, encouraging the model to always predict boxes and increasing false positives.
#   - No validation split or metric logging; thresholds and training length cannot be tuned to maximize mAP@0.4.
#   - Only 3 training epochs is too short for detection fine-tuning on medical images.
#   - Minimal augmentation (only horizontal flip) for a task with small, subtle targets.
#   - Low score threshold (0.15) further increases false positives.
# - Evidence:
#   - “Skips images that end up with zero bounding boxes (only positive samples kept).”
#   - “No explicit train/validation split; … used for training” and “Epochs: default 3.”
#   - “Random horizontal flip with probability 0.5” is the only listed augmentation.
#   - “Inference score threshold: 0.15.”
# - What would help:
#   - Include negative images in training to teach the model when to abstain.
#   - Add a proper validation split or k-fold CV; compute mAP@0.4 and tune per-class thresholds.
#   - Train longer (15–30+ epochs) with a sensible LR schedule (warmup + cosine or MultiStep) and monitor validation.
#   - Strengthen augmentation (scale/translation jitter, random resize, brightness/contrast) and multi-scale training.
#   - Use test-time augmentation and ensemble multiple folds; apply WBF per class.
#
# Solution 4374 (Faster R-CNN pretrained, Percentile 0.227)
# - Likely failure points:
#   - Trains only on images with boxes; misses negative samples, inflating false positives.
#   - No validation loop or mAP metric; thresholds (0.35) are arbitrary and uncalibrated.
#   - Very short training (3 epochs; 1 in FAST_DEV_RUN) for fine-tuning on medical data.
#   - Limited augmentation (only horizontal flip); insufficient for subtle findings.
# - Evidence:
#   - “Trains on all images that have at least one valid bounding box.”
#   - “No explicit train/validation split; … inference score threshold: 0.35.”
#   - “Epochs: 3 (or 1 when FAST_DEV_RUN=1), augmentation: Optional horizontal flip.”
# - What would help:
#   - Include negative samples and class-balanced sampling.
#   - Add validation/CV and compute mAP@0.4; tune thresholds per class to trade precision/recall.
#   - Train more epochs with better LR scheduling; consider freezing then unfreezing backbone.
#   - Expand augmentation and use multi-scale training; ensemble folds with WBF.
#
# Solution 4407 (Faster R-CNN v2 pretrained, Percentile 0.107)
# - Likely failure points:
#   - Applies NMS globally across all classes; this suppresses true positives of different classes and severely hurts recall/mAP.
#   - LR scheduler stepped only during epoch 0 per-iteration; misapplied scheduling can destabilize or under-train the model.
#   - Very short training (2 epochs); no validation or metrics.
#   - No augmentation; fallback “resize” path crops the image top-left if PIL fails, corrupting data and bboxes.
# - Evidence:
#   - “NMS applied once across all boxes irrespective of class labels.”
#   - “LR scheduler… created only in epoch 0 and stepped every training iteration within that epoch.”
#   - “Epochs: 2… Data augmentation techniques: None present.”
#   - “Fallback (if PIL import fails) uses array slicing… top-left crop-like behavior.”
# - What would help:
#   - Use per-class NMS (or rely on model’s built-in class-aware NMS).
#   - Fix LR scheduling: step per epoch; adopt warmup + cosine/Multistep; train 10–20+ epochs.
#   - Add validation/CV with mAP@0.4; tune thresholds; increase augmentation.
#   - Remove crop-based fallback; ensure proper resizing and bbox scaling always.
#
# Solution 4571 (YOLOv8, Percentile 0.0016)
# - Likely failure points:
#   - If trained weights aren’t found, inference falls back to the original COCO ‘yolov8n.pt’, causing class-id mismatch (80 COCO classes vs 14 Kaggle classes) and nonsensical submissions.
#   - Extremely low inference threshold (0.05) floods predictions with false positives, crushing precision/mAP.
#   - Short training (15 epochs) with no explicit validation or metric tracking.
#   - No augmentation beyond YOLO defaults; potential underfitting on subtle medical findings.
# - Evidence:
#   - “Fallback… if unavailable, uses the original model_name for inference.”
#   - “predict… conf_thres=0.05” and no val/CV or mAP logging indicated.
# - What would help:
#   - Ensure fine-tuned weights exist; error out if not found; always use a checkpoint trained with nc=14.
#   - Raise conf threshold (per-class tuned from validation PR, typically 0.25–0.35).
#   - Train longer (50–100 epochs) with proper validation; consider larger models (yolov8m/l) and multi-scale training.
#   - Use k-fold CV and WBF; add stronger augmentation tailored to CXR.
#
# Solution 4607 (Faster R-CNN pretrained, Percentile 0.107)
# - Likely failure points:
#   - Aggressive AdamW lr=1e-3 for detection fine-tuning can underperform or destabilize; common practice uses lower LR or SGD.
#   - No augmentation; only PNG caching—insufficient for medical detection.
#   - Only 4 epochs; no proper validation metric (val loss computed in train mode under no_grad is not informative; no mAP).
#   - Threshold fixed at 0.25 without calibration.
# - Evidence:
#   - “Optimizer: AdamW with lr=1e-3… Epochs: 4… No augmentation.”
#   - “Validation… model in train mode… sums losses… No metrics.”
#   - “BOX_SCORE_THRESH=0.25.”
# - What would help:
#   - Switch to SGD with momentum or reduce AdamW LR (e.g., 3e-4–5e-4) and add a warmup + cosine/Multistep schedule.
#   - Train longer with proper validation/CV and compute mAP@0.4; tune thresholds per class.
#   - Add augmentation (scale jitter, random resize) and multi-scale training; include negative samples.
#   - Consider test-time augmentation and ensembling folds with WBF.
#
# Solution 4634 (Faster R-CNN from scratch, Percentile 0.0031)
# - Likely failure points:
#   - Trains from scratch (weights=None) on a limited medical dataset—very unlikely to converge to strong performance in 8 epochs.
#   - Excludes negative images from training; increases false positives.
#   - Does not map predictions back to original DICOM coordinate system; submissions use resized PNG coordinates, yielding incorrect boxes and near-zero mAP.
#   - Very low inference threshold (0.05) further harms precision.
#   - No validation loop or mAP; thresholds and training length are not tuned.
# - Evidence:
#   - “torchvision… weights=None… Epochs: 8.”
#   - “Filters train set to only images with at least one label.”
#   - “Predictions are produced in the resized PNG coordinate system (no conversion back to original DICOM dimensions).”
#   - “confidence threshold: 0.05.”
# - What would help:
#   - Use pretrained Faster R-CNN weights (DEFAULT) and fine-tune; include negative samples.
#   - Correctly rescale predictions back to original DICOM size before submission and clamp to bounds.
#   - Add validation/CV with mAP@0.4; raise thresholds and tune per class.
#   - Train longer with stronger augmentation and multi-scale; consider ensembling and WBF.
#
# Solution 4729 (Faster R-CNN from scratch, Percentile 0.173)
# - Likely failure points:
#   - Instantiates Faster R-CNN with weights=None; training from scratch for 2–3 epochs is far too weak for medical detection.
#   - No explicit validation; cannot tune threshold or select checkpoints by mAP.
#   - Training only on PNG-available images may exclude usable data and introduce bias; DEV_RUN sampling further reduces coverage.
#   - Minimal augmentation (only horizontal flip) and small batch size; likely underfitting.
# - Evidence:
#   - “weights=None… Epochs default 3; default 2 if DEV_RUN=1.”
#   - “No explicit validation split; the entire available set is used for training.”
#   - “DEV_RUN=1… randomly samples up to 200 images.”
#   - “Random horizontal flip… no additional normalization beyond [0,1].”
# - What would help:
#   - Use pretrained weights (DEFAULT) and train longer with proper LR schedule.
#   - Introduce a validation split or k-fold CV; compute mAP@0.4 and tune thresholds per class.
#   - Train on the full dataset; avoid reducing coverage unless for quick local tests.
#   - Strengthen augmentation and consider multi-scale training; ensemble folds with WBF and apply TTA.
#
# General contrasts with high-scoring approaches:
# - High-scoring solutions typically use pretrained detectors, multi-fold cross-validation with mAP@0.4 tracking, strong augmentation and multi-scale training, include negative samples, calibrate per-class thresholds from validation, and ensemble models (e.g., WBF). Many also add TTA and careful DICOM handling without losing grayscale detail.

# %% [markdown]
# # Iteration #0

# %%
iteration_id = 0
iteration = iterations[iteration_id] if iterations else None

if iteration:
    print(f"=================  Iteration {iteration_id} (#{iteration.get('iteration', 'N/A')}) =====================")
    print(f"Keys in  iteration {iteration_id} : {list(iteration.keys())}")
    

    # Check LLM response
    print(f"\n================= LLM Response in Iteration {iteration_id} =====================")
    response = iteration.get("response", "")
    print(f"Response:\n...{response}" )


    # Check code blocks in iteration
    code_blocks = iteration.get("code_blocks", [])
    print(f"\nNumber of code blocks: {len(code_blocks)}")
    
    for i, block in enumerate(code_blocks):
        print(f"\n======================================== Code Block {i} =======================================")
        # code = block.get("code", "")
        # print(f"\n----------------------- Code Block {i} Code ------------------")

        # print(f"Code: {code}")
        
        result = block.get("result", {})
        stdout = result.get("stdout", "")
        stderr = result.get("stderr", "")
        
        if stdout:
            print(f"\n----------------------- Code Block {i} Stdout ------------------")

            print(f"\nStdout:\n{stdout}" )
        if stderr:
            print(f"\n----------------------- Code Block {i} Stderr ------------------")
            print(f"\nStderr:\n{stderr}")
    

else:
    print("No iterations found!")
# Out:
# =================  Iteration 0 (#1) =====================
# Keys in  iteration 0 : ['type', 'iteration', 'timestamp', 'prompt', 'response', 'code_blocks', 'final_answer', 'iteration_time']
#
# ================= LLM Response in Iteration 0 =====================
# Response:
# ...```repl
# # Inspect the dataframe structure and first few rows
# print(rollout_df.shape)
# print(rollout_df.columns.tolist())
# print(rollout_df.head(3)[["task_name", "valid_submission", "percentile"]])
#
# # Find how many rows correspond to the specified task
# task = "vinbigdata-chest-xray-abnormalities-detection"
# df_task = rollout_df[rollout_df["task_name"] == task]
# print("Rows for task:", df_task.shape[0])
#
# # Show a quick summary of validity and percentiles for this task
# print(df_task[["valid_submission", "percentile"]].describe(include="all"))
# print(df_task[["valid_submission", "percentile"]].value_counts())
#
# # Filter valid submissions
# valid_df = df_task[df_task["valid_submission"] == True]
# print("Valid submissions:", valid_df.shape[0])
#
# # Peek at their indices and percentiles
# print(valid_df[["percentile"]].head(10))
#
# # Extract the task description from iloc[0] per instructions (global first row, not necessarily same task)
# task_desc = rollout_df["task_description"].iloc[0]
# ```
#
# ```repl
# # Use sub-LLM to analyze Part 0 based on the task description at iloc[0]
# part0 = llm_query(f"""
# You are given a Kaggle competition task description in markdown below.
# Extract the following for Part 0:
# 1) Problem Type (Classification/Regression/Object Detection/etc.)
# 2) Domain (Healthcare/Finance/etc.)
# 3) Input Format (Images/Tabular/Text/etc.)
# 4) Evaluation Metric (what metric, what it optimizes)
# 5) Key Challenges (what makes the task difficult)
#
# Task description:
# {task_desc}
# """)
# print(part0)
# ```
#
# ```repl
# # For each valid solution for the vinbigdata task, analyze the code using sub-LLM.
# # Prepare prompts in batch to summarize according to the template fields.
# prompts = []
# rows = []
# for idx, row in valid_df.iterrows():
#     code = row["code"]
#     percentile = row["percentile"]
#     # If code is None for a valid submission, handle explicitly
#     if code is None:
#         summary_prompt = f"""
# The solution's code is None (empty). Based on this, produce a concise analysis noting that no code was provided.
# Still fill the template fields with 'No implementation' or 'Not applicable' as appropriate.
# """
#     else:
#         summary_prompt = f"""
# Analyze the provided Python solution code for the Kaggle competition 'vinbigdata-chest-xray-abnormalities-detection'.
# Document strictly what is implemented in the code. Use the following template sections and be concrete:
#
# 1. Data Preprocessing:
# - Data loading and splitting approaches
# - Cleaning strategies
# - Transformations applied
# - Data augmentation techniques (if any)
# - Other preprocessing steps
#
# 2. Feature Engineering:
# - New features and their derivation
# - Feature selection or dimensionality reduction
# - Domain-specific transformations
# - If none, explicitly say none
#
# 3. Model Selection:
# - Primary algorithm(s) and exact classes/functions used
# - Hyperparameters used (learning rate, depth, n_estimators, etc.)
# - Ensemble architecture (stacking/blending/voting), number of models
# - Pretrained models (which ones, how used)
#
# 4. Training Methodology:
# - Hyperparameter selection (grid/random/manual)
# - Training config details (epochs, batch size, loss, optimizer, regularization, early stopping)
#
# 5. Evaluation & Submission:
# - Final prediction method and any averaging
# - Post-processing of predictions
# - Submission file format creation specifics
#
# 6. Notable Implementation Details:
# - Computational considerations (GPU usage, mixed precision, runtime optimization)
# - Unique approaches or techniques
# - Other significant aspects
#
# Only describe what is present in the code. Do not invent steps not in code.
#
# Code:
# {code}
# """
#     prompts.append(summary_prompt)
#     rows.append((idx, percentile))
#
# summaries = llm_query_batched(prompts)
# print(f"Generated {len(summaries)} solution summaries.")
# ```
#
# ```repl
# # Build performance analysis (Part 2) by classifying solutions into high/medium/low by percentile,
# # and asking sub-LLM to reason about why they worked or not using the summaries.
# high = []
# medium = []
# low = []
# for (idx, percentile), summary in zip(rows, summaries):
#     if percentile is None:
#         # Treat None as low-score in analysis context; but keep explicit mention
#         low.append((idx, percentile, summary))
#     elif percentile >= 0.7:
#         high.append((idx, percentile, summary))
#     elif percentile < 0.4:
#         low.append((idx, percentile, summary))
#     else:
#         medium.append((idx, percentile, summary))
#
# def build_perf_prompt(category_name, items):
#     text = f"Category: {category_name}\n"
#     for idx, perc, summ in items:
#         text += f"\nSolution index {idx}, Percentile: {perc}\nSummary:\n{summ}\n"
#     return text
#
# # Ask sub-LLM to produce performance analysis per category
# high_prompt = f"""
# Given the following high-scoring solution summaries (percentile >= 0.7), produce for each:
# - Why it works: specific technical choices that likely contributed most (cite evidence from summary/code details)
# - Key strengths
# - Alignment with task: how choices align with evaluation metric and challenges identified in Part 0
#
# {build_perf_prompt("High-Scoring", high)}
# Part 0 reference:
# {part0}
# """
# medium_prompt = f"""
# Given the following medium-scoring solution summaries (0.4 <= percentile < 0.7), briefly note:
# - What's working reasonably well
# - The most likely bottleneck preventing higher performance
#
# {build_perf_prompt("Medium-Scoring", medium)}
# Part 0 reference:
# {part0}
# """
# low_prompt = f"""
# Given the following low-scoring solution summaries (percentile < 0.4 or missing),
# for each:
# - Likely failure points: critical omissions, poor choices for this task, or implementation issues
# - Evidence: cite specific summary/code evidence or contrast with high-scoring approaches
# - What would help: concrete changes likely to improve the score
#
# {build_perf_prompt("Low-Scoring", low)}
# Part 0 reference:
# {part0}
# """
#
# perf_analyses = llm_query_batched([high_prompt, medium_prompt, low_prompt])
# print("Performance analyses generated.")
# ```
#
# ```repl
# # Assemble the final answer string with Part 0, Part 1 solution summaries, and Part 2 performance analysis.
# lines = []
# lines.append("## Part 0: Task Analysis\n")
# lines.append(part0.strip() if isinstance(part0, str) else str(part0))
#
# lines.append("\n## Part 1: Individual Solution Summaries\n")
# # Ensure deterministic ordering by index
# for (idx, percentile), summary in zip(rows, summaries):
#     sol_id = f"row_index_{idx}"
#     lines.append(f"**Solution ID:** {sol_id}\n**Score Percentile:** {percentile}\n")
#     lines.append(summary.strip() if isinstance(summary, str) else str(summary))
#     lines.append("\n")
#
# lines.append("## Part 2: Performance Analysis\n")
# lines.append("### High-Scoring Solutions (percentile ≥ 0.7)\n")
# lines.append(perf_analyses[0].strip())
# lines.append("\n### Medium-Scoring Solutions (0.4 ≤ percentile < 0.7)\n")
# lines.append(perf_analyses[1].strip())
# lines.append("\n### Low-Scoring Solutions (percentile < 0.4)\n")
# lines.append(perf_analyses[2].strip())
#
# final_answer = "\n".join(lines)
#
# # Verify existence of final_answer variable
# print("final_answer" in dir())
# ```
#
# Number of code blocks: 5
#
# ======================================== Code Block 0 =======================================
#
# ----------------------- Code Block 0 Stdout ------------------
#
# Stdout:
# (64, 9)
# ['task_name', 'task_description', 'code', 'percentile', 'valid_submission', 'eval_error_output', 'eval_duration', 'rollout_duration', 'rollout']
#                                           task_name  valid_submission  percentile
# 4251  vinbigdata-chest-xray-abnormalities-detection             False         0.0
# 4264  vinbigdata-chest-xray-abnormalities-detection             False         0.0
# 4269  vinbigdata-chest-xray-abnormalities-detection             False         0.0
# Rows for task: 64
#        valid_submission  percentile
# count                64   64.000000
# unique                2         NaN
# top               False         NaN
# freq                 46         NaN
# mean                NaN    0.167770
# std                 NaN    0.356262
# min                 NaN    0.000000
# 25%                 NaN    0.000000
# 50%                 NaN    0.000000
# 75%                 NaN    0.029216
# max                 NaN    1.000000
# valid_submission  percentile
# False             0.000000      46
# True              1.000000       5
#                   0.107451       3
#                   0.961569       2
#                   0.958431       1
#                   0.190588       1
#                   0.953725       1
#                   0.983529       1
#                   0.227451       1
#                   0.001569       1
#                   0.003137       1
#                   0.173333       1
# Name: count, dtype: int64
# Valid submissions: 18
#       percentile
# 4322    0.107451
# 4346    0.958431
# 4350    0.190588
# 4355    0.953725
# 4369    0.983529
# 4374    0.227451
# 4407    0.107451
# 4413    1.000000
# 4571    0.001569
# 4583    1.000000
#
#
# ======================================== Code Block 1 =======================================
#
# ----------------------- Code Block 1 Stdout ------------------
#
# Stdout:
# [Azure OpenAI] Calling gpt-5 (attempt 1/64)...
# [Azure OpenAI] Response received in 15.9s
# Part 0
#
# 1) Problem Type:
# - Object detection with multi-class classification (localize and classify multiple thoracic abnormalities per image, including a “No finding” class)
#
# 2) Domain:
# - Healthcare / Medical Imaging (Radiology, chest X-rays)
#
# 3) Input Format:
# - Images (DICOM chest radiographs; postero-anterior CXR scans)
#
# 4) Evaluation Metric:
# - PASCAL VOC 2010 mean Average Precision (mAP) at IoU > 0.4; higher mAP is better
#
# 5) Key Challenges:
# - Localizing and classifying multiple abnormalities per image (multi-instance, multi-class)
# - Ground truth from multiple radiologists (inter-reader variability and potential label noise)
# - Medical imaging subtleties in chest X-rays (findings can be small, overlapping, or visually subtle)
# - Handling DICOM specifics and preprocessing (windowing, pixel spacing, intensity/contrast)
# - Class imbalance across 14 findings and a “No finding” class
# - Special handling of the “No finding” case requiring a one-pixel bounding box prediction
#
#
# ======================================== Code Block 2 =======================================
#
# ----------------------- Code Block 2 Stdout ------------------
#
# Stdout:
# Generated 18 solution summaries.
#
#
# ======================================== Code Block 3 =======================================
#
# ----------------------- Code Block 3 Stdout ------------------
#
# Stdout:
# Performance analyses generated.
#
#
# ======================================== Code Block 4 =======================================
#
# ----------------------- Code Block 4 Stdout ------------------
#
# Stdout:
# True

# %% [markdown]
# ## Iteration 0 Summary
#
# The model performs a **3-part analysis** of Kaggle competition solutions for "vinbigdata-chest-xray-abnormalities-detection".
#
# ### Code Block 1: Data Exploration
# - Inspects `rollout_df` structure (shape, columns)
# - Filters to the specific task and valid submissions only
# - Extracts task description from `iloc[0]`
#
# ### Code Block 2: Part 0 - Task Analysis
# - Uses `llm_query()` (single sub-LLM call) to analyze the task description
# - Extracts: Problem Type, Domain, Input Format, Evaluation Metric, Key Challenges
#
# ### Code Block 3: Part 1 - Solution Summaries
# - Uses `llm_query_batched()` for **parallel** sub-LLM calls (one per valid solution)
# - Each prompt asks the sub-LLM to analyze solution code using a structured template:
#   - Data Preprocessing
#   - Feature Engineering
#   - Model Selection
#   - Training Methodology
#   - Evaluation & Submission
#   - Notable Implementation Details
#
# ### Code Block 4: Part 2 - Performance Analysis
# - Classifies solutions by percentile score:
#   - **High** (≥ 0.7): Why they worked
#   - **Medium** (0.4–0.7): What's limiting them
#   - **Low** (< 0.4): Failure points and fixes
# - Uses `llm_query_batched()` to analyze all three categories in parallel
#
# ### Code Block 5: Assemble Final Answer
# - Combines Part 0, Part 1, and Part 2 into a structured markdown document
# - Stores result in `final_answer` variable
# - Verifies variable exists with `print("final_answer" in dir())`
#
# ### Key RLM Features Used
#
# | Feature | Usage |
# |---------|-------|
# | `llm_query()` | Single sub-LLM call for task analysis |
# | `llm_query_batched()` | Parallel sub-LLM calls for efficiency |
# | `FINAL_VAR()` | Returns the final answer (called in next iteration) |

# %% [markdown]
# # Iteration #1

# %%
iteration_id = 1
iteration = iterations[iteration_id] if iterations else None

if iteration:
    print(f"=================  Iteration {iteration_id} (#{iteration.get('iteration', 'N/A')}) =====================")
    print(f"Keys in  iterxation {iteration_id} : {list(iteration.keys())}")
    

    # Check LLM response
    print(f"\n================= LLM Response in Iteration {iteration_id} =====================")
    response = iteration.get("response", "")
    print(f"Response:\n...{response}" )


    # Check code blocks in iteration
    code_blocks = iteration.get("code_blocks", [])
    print(f"\nNumber of code blocks: {len(code_blocks)}")
    
    for i, block in enumerate(code_blocks):
        print(f"\n======================================== Code Block {i} =======================================")
        # code = block.get("code", "")
        # print(f"\n----------------------- Code Block {i} Code ------------------")

        # print(f"Code: {code}")
        
        result = block.get("result", {})
        stdout = result.get("stdout", "")
        stderr = result.get("stderr", "")
        
        if stdout:
            print(f"\n----------------------- Code Block {i} Stdout ------------------")

            print(f"\nStdout:\n{stdout}" )
        if stderr:
            print(f"\n----------------------- Code Block {i} Stderr ------------------")
            print(f"\nStderr:\n{stderr}")
    

else:
    print("No iterations found!")
# Out:
# =================  Iteration 1 (#2) =====================
# Keys in  iterxation 1 : ['type', 'iteration', 'timestamp', 'prompt', 'response', 'code_blocks', 'final_answer', 'iteration_time']
#
# ================= LLM Response in Iteration 1 =====================
# Response:
# ...FINAL_VAR(final_answer)
#
# Number of code blocks: 0
