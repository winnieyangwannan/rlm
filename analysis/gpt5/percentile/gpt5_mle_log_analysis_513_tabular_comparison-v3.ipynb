# %% [markdown]
# # LOG:
#
# /checkpoint/maui_sft/winnieyangwn/rlm_dumps/gpt-5_summarization_513_iwildcam-2019-fgvc6_2026-02-09_07-05-37_3bfb9fbc.jsonl

# %%
import sys
import importlib


sys.path.append('/home/winnieyangwn/rlm/analysis')
import rlm_log_utils
importlib.reload(rlm_log_utils)
from rlm_log_utils import *

# %% [markdown]
# ## Usage Example
#
# Load the log file and extract key information:

# %% [markdown]
# # Load

# %%
import glob
import os

run_id = 513
model_name = "gpt-5"
task_name = "tabular-playground-series-dec-2021"
log_dir = "/checkpoint/maui_sft/winnieyangwn/rlm_dumps/comparison-v3"
codebase_extensions = [".py", ".md", ".yaml"]

# Option 1: Provide a specific log name to load directly
log_name = None  # e.g. "gpt-5_summarization_513_iwildcam-2019-fgvc6_2026-02-09_07-05-37_3bfb9fbc.jsonl"
if log_name:
    # Directly load the specified log file
    LOG_PATH = os.path.join(log_dir, log_name)
    if not os.path.exists(LOG_PATH):
        raise FileNotFoundError(f"Specified log file not found: {LOG_PATH}")
    print(f"Loading specified log: {LOG_PATH}")
else:
    # Use underscore after run_id to avoid matching "summarization_comparison_*" logs
    LOG_PATH_PREFIX = f"{log_dir}/{model_name}_comparison_{run_id}_{task_name}"

    # Find all log files matching the prefix pattern (only .jsonl files)
    matching_logs = glob.glob(f"{LOG_PATH_PREFIX}*.jsonl")

    if not matching_logs:
        raise FileNotFoundError(f"No log files found matching prefix: {LOG_PATH_PREFIX}")

    # Get the most recent log file by modification time
    LOG_PATH = max(matching_logs, key=os.path.getmtime)
    print(f"Found {len(matching_logs)} matching log file(s)")
    print(f"Loading most recent: {LOG_PATH}")

# Load the log - first entry is metadata, rest are iterations
entries = load_rlm_log(LOG_PATH)
metadata = entries[0]
iterations = entries[1:]

print(f"Loaded {len(iterations)} iterations")
# Out:
# Found 1 matching log file(s)
# Loading most recent: /checkpoint/maui_sft/winnieyangwn/rlm_dumps/comparison-v3/gpt-5_comparison_513_tabular-playground-series-dec-2021_2026-02-11_07-58-08_5718beec.jsonl
# Loaded 2 iterations

# %% [markdown]
# # Metadata

# %%
# View metadata
print("=== METADATA ===")
for k, v in metadata.items():
    if k != "backend_kwargs":
        print(f"{k}: {v}")
# Out:
# === METADATA ===
# type: metadata
# timestamp: 2026-02-11T07:58:08.384670
# root_model: gpt-5
# max_depth: 2
# max_iterations: 20
# backend: azure_openai
# environment_type: local
# environment_kwargs: {'setup_code': '\nimport pandas as pd\n\n# Load original rollout data\nrollout_df = pd.read_json(\'/checkpoint/maui_sft/winnieyangwn/amaia_dumps/513/trajectories/513_metadata.jsonl\', lines=True)\nrollout_df = rollout_df[rollout_df[\'task_name\'] == \'tabular-playground-series-dec-2021\']\nprint(f"Loaded {len(rollout_df)} rollouts")\n\n# Load Round 1 analysis (markdown text)\nwith open(\'/tmp/round1_analysis_513_tabular-playground-series-dec-2021.txt\') as f:\n    round1_analysis = f.read()\nprint(f"Loaded Round 1 analysis ({len(round1_analysis)} chars)")\n'}
# other_backends: None

# %%
# Compare with timestamp-based runtime
runtime = get_total_runtime(entries)
print(f"Timestamp-based runtime: {runtime.total_seconds():.2f}s")
# Out:
# Timestamp-based runtime: 432.10s

# %%
# Check number of iterations actually taken by model
num_iterations = len(iterations)
print(f"Number of iterations taken: {num_iterations}")

# You can also use extract_all for a comprehensive summary
summary = extract_all(LOG_PATH)
print(f"Number of iterations (from extract_all): {summary['num_iterations']}")
# Out:
# Number of iterations taken: 2
# Number of iterations (from extract_all): 2

# %% [markdown]
# # Final Answer

# %%
# Get the final answer
final_answer = get_final_answer(iterations)
print("=== FINAL ANSWER ===")
print(final_answer if final_answer else "No final answer found")
# print(f"\n(Total length: {len(final_answer) if final_answer else 0} chars)")
# Out:
# === FINAL ANSWER ===
# Below is an evidence-based synthesis of the Round 1 document with explicit counts and concrete contrasts.
#
# 1) Contrastive Pattern Analysis (High vs Low)
#
# Group sizes
# - High group (percentile ≥ 0.6): 26/27 solutions (all except row17)
# - Low group (percentile < 0.6): 1/27 solution (row17)
#
# A. Data Preprocessing
# - What high-score solutions did (with counts among 26 high solutions):
#   - Type optimization and float32 features: 24/26 cast features to float32 and downcast integers (often int32/int16/int8) to reduce memory and speed up training.
#   - Stratified splits/folds: 26/26 attempted stratification (either train_test_split with stratify or StratifiedKFold; many had safe fallbacks).
#   - Train/test column alignment checks: ~10/26 explicitly verified engineered feature consistency and column order between train and test (e.g., reindex, feature_names in DMatrix).
#   - Robust NaN/inf handling: ~10/26 explicitly replaced inf with NaN and/or filled NaNs or relied on model’s NaN handling.
#   - Label remapping to contiguous 0-based indices: 26/26 for boosted trees (and proper inverse mapping at the end).
#   - Optional fast-dev sampling (for iteration speed, not used in final submissions): many implemented this without harming the final pipeline.
#
# - What low-score solution did (row17):
#   - dtype conversions are minimal (engineered features cast but no systematic downcasting); no explicit inf/NaN handling.
#   - Stratified single holdout split (90/10) only; no cross-validation.
#   - Label encoding to 0..K-1 is present; train/test concatenation for FE used (also seen in some highs).
#
# - Concrete difference:
#   - Highs more consistently enforce dtype optimization and explicit column alignment; around 8/26 of highs use K-fold CV (vs. single holdout in the low). Highs also more often sanitize inf/NaN.
#   - Low used class-weighted DMatrix (inverse frequency), which no high performer used.
#
# - Why these patterns matter:
#   - Dtype optimization and float32 reduce memory pressure and stabilize training on large CTGAN-generated data.
#   - Stratification ensures class balance in validation/folds, stabilizing early stopping and selection of best_iteration.
#   - Column alignment prevents silent train/test schema drift after FE.
#   - Class weights on modestly imbalanced, synthetic cover data can distort boundaries and degrade accuracy.
#
# - Actionable recommendations:
#   - Always downcast/tabular dtypes and use float32 features; verify train/test column alignment after FE.
#   - Use stratified splits and prefer K-fold CV (3–5 folds) for final submissions; if single holdout, ensure robustness.
#   - Avoid class weights unless severe imbalance is demonstrated via OOF metrics; if needed, test milder weights (e.g., sqrt inverse frequency).
#   - Add basic inf/NaN guards (replace inf with NaN, let XGBoost/LightGBM handle NaNs or fill sensibly).
#
# B. Feature Engineering
# - What high-score solutions did:
#   - Hydrology Euclidean distance: 20/26 added sqrt(Horizontal_Distance_To_Hydrology^2 + Vertical_Distance_To_Hydrology^2).
#   - Hillshade mean: 21/26 added mean of Hillshade_9am/Noon/3pm; many also added range/min/max/diffs.
#   - Elevation ± Vertical_Distance_To_Hydrology (VDH): 18/26 added Elevation−VDH and/or Elevation+VDH.
#   - Distance sums/diffs (road/fire/hydro): ≈24/26 created sums/differences/abs-diffs among the three horizontal distance features; several computed combined/total distances.
#   - Aspect trigonometric transforms (sin/cos): 12/26 used Aspect_sin/Aspect_cos; a few projected slope onto aspect (Slope*cos/sin(Aspect)).
#   - Ratios with safe division: 4/26 used ratios (e.g., Hydrology/Road, Road/Fire) with safe denominators.
#   - Wilderness/Soil indices (argmax over one-hots): 4/26 computed Soil_Index/Wilderness_Index while retaining one-hots.
#   - One-hot sums (Soil/Wilderness): 3–4/26 added sums of one-hot groups.
#
# - What low-score solution did (row17):
#   - Limited FE vs. top patterns: Aspect_sin/cos, Hydrology Euclid, product H×V, vertical distance sign, Road_Fire sum/diff, Hillshade mean/range.
#   - Missing several high-signal transforms heavily used by highs: Elevation ± VDH (18/26 highs), broader distance sums/diffs (≈24/26), hillshade min/max/deltas, slope–aspect interactions (2–3/26), ratios with safe division (4/26), and wilderness/soil indices (4/26).
#
# - Concrete difference:
#   - Highs systematically exploit terrain physics and geometry (Elevation-VDH, distance combinations, hillshade aggregates) and cyclic encoding of Aspect. The low score lacked many of these, shrinking feature signal.
#
# - Why these patterns matter:
#   - These transforms reflect domain structure (terrain, illumination, distances) known to separate cover types; boosted trees capitalize on such engineered splits.
#   - Cyclic encoding (sin/cos) prevents discontinuities at 0/360. Distance combos capture accessibility and hydrological context.
#
# - Actionable recommendations:
#   - Implement a standard FE pack: Hydrology Euclid, Hillshade mean/range/diffs, Elevation ± VDH, multi-way distance sums/diffs/abs-diffs, Aspect sin/cos; consider slope–aspect projections and safe ratios.
#   - Optionally add Wilderness/Soil indices (argmax) while keeping one-hots.
#   - Use safe division guards and, for skewed distances, consider log1p on selected distances.
#
# C. Model Selection
# - What high-score solutions did:
#   - XGBoost as primary: 19/26 (objective=multi:softprob), typically with gpu_hist and early stopping.
#   - LightGBM as primary: 7/26 (objective=multiclass), CPU with early stopping; sometimes k-fold CV averaging.
#   - CatBoost/RandomForest: present only as fallbacks in a small subset (e.g., row21, row22), not dominant.
#
# - What low-score solution did (row17):
#   - XGBoost single booster with gpu_hist; reasonable core params (depth=8, eta=0.08, subsample/colsample=0.8).
#
# - Concrete difference:
#   - Algorithm choice was not the problem (low used the same family as most highs). The gap stems from FE scope, CV/ensembling, metric alignment, and weighting choices.
#
# - Why these patterns matter:
#   - Gradient boosting trees are well-suited for this tabular, multi-class problem; the differences come from how they’re trained/tuned and with what features.
#
# - Actionable recommendations:
#   - Prefer XGBoost or LightGBM. If using XGBoost, enable gpu_hist when available. Keep parameters in proven ranges (max_depth 8–10, eta 0.05–0.1, subsample/colsample≈0.8, min_child_weight≥1, lambda 1–2).
#
# D. Training Methodology
# - What high-score solutions did:
#   - Early stopping on a stratified validation set: 26/26.
#   - K-fold CV with probability averaging: 8/26 (XGB: 4/26; LGB: 4/26).
#   - Evaluation metric alignment: ~12/26 tracked merror (accuracy) or both merror and mlogloss; others used mlogloss but still argmaxed probabilities.
#   - Two-stage refit (early-stop to find best rounds, then retrain on full data): 2/26 (rows 6 and 14).
#   - GPU utilization for XGBoost: 19/19 XGB highs attempted GPU with fallback.
#
# - What low-score solution did (row17):
#   - Single 90/10 holdout early stopping; eval_metric='mlogloss' only.
#   - Applied inverse-frequency sample weights to the training DMatrix.
#
# - Concrete difference:
#   - Highs either use CV ensembles (8/26) or single holdout with strong FE; several align early stopping to accuracy (merror). No high used class weighting on this data.
#
# - Why these patterns matter:
#   - CV reduces variance and overfitting risk on synthetic, large data, improving leaderboard robustness.
#   - Early stopping on accuracy (or tracking it alongside logloss) aligns training progress with the leaderboard metric.
#   - Unnecessary class weighting can skew decision boundaries when imbalance is modest.
#
# - Actionable recommendations:
#   - For final submissions, use 3–5 fold StratifiedKFold and average probabilities. If time-limited, perform a solid single holdout but validate with OOF where possible.
#   - Track merror during early stopping (or both merror and mlogloss).
#   - Avoid class weights; if experimenting, verify OOF impact.
#
# E. Evaluation & Submission
# - What high-score solutions did:
#   - Prediction = argmax over multi:softprob (XGB) or multiclass probabilities (LGB): 26/26.
#   - Correct label remapping back to original classes: 26/26.
#   - Some ensured sorting by Id and column order; submission line-count checks: ~8/26.
#   - Many used best_iteration/iteration_range or best_ntree_limit for inference: ≈20/26.
#
# - What low-score solution did (row17):
#   - Same argmax and remapping pattern; used best_iteration/ntree_limit correctly.
#
# - Concrete difference:
#   - None significant; submission mechanics were consistent.
#
# - Why these patterns matter:
#   - Ensures alignment with the competition’s accuracy metric and submission format.
#
# - Actionable recommendations:
#   - Always use best_iteration/ntree_limit (or iteration_range) for test-time predictions and verify submission row counts and Id sorting.
#
# F. Notable Details
# - What high-score solutions did:
#   - GPU/CPU fallback and environment-controlled dev modes: ≈26/26 used robustness guards and logging.
#   - Some unique FE details: wilderness/soil argmax indices (4/26), slope–aspect projections (2–3/26), safe ratios (4/26), log1p on distances (1/26).
#   - Train+test concatenation for consistent FE in a minority: 2/26.
#
# - What low-score solution did (row17):
#   - Used sample weights; concatenated train/test for FE (which is fine).
#   - No special safeguards for inf/NaN beyond default.
#
# - Concrete difference:
#   - Sample weights stand out as the outlier choice vs. the high group.
#
# - Why these patterns matter:
#   - Rare but beneficial FE ideas add diversity and incremental gains; miscalibrated weighting can reduce accuracy.
#
# - Actionable recommendations:
#   - Prefer robust FE ideas over weighting; include sanity checks (NaN/inf), and exploit GPU when available.
#
#
# 2) Unique High-Performing Approaches (Diversity Preservation)
#
# Below are rare but effective techniques among the high group (counts are within the 26 high solutions).
#
# - Two-stage refit on full data after early stopping (2/26: rows 6, 14)
#   - Why effective: Early stopping finds an optimal number of rounds with a validation set; retraining on all data at that iteration exploits the full dataset while controlling overfitting.
#   - How to implement:
#     - Train with early stopping to get best_iteration.
#     - Refit a fresh model on the entire training set with num_boost_round=best_iteration (or best_ntree_limit) and no validation set; predict using that refit model.
#
# - Wilderness/Soil indices from one-hot argmax while retaining one-hots (4/26: rows 3, 12, 13, 19)
#   - Why effective: Adds compact categorical summaries (indices) that can create different tree splits than 40/4 one-hot columns alone; sometimes reduces sparsity effects and reveals category interactions.
#   - How to implement:
#     - Wilderness_Index = argmax across Wilderness_Area1..4 (0..3 or 1..4), Soil_Index = argmax across Soil_Type1..40; cast to small ints.
#     - Keep original one-hots and add these two integer features.
#
# - Slope–Aspect projections (2–3/26: rows 7, 20; row18 used Aspect*Slope and ratios)
#   - Why effective: Encodes directional exposure by projecting slope onto the aspect direction, which is physically meaningful for illumination and moisture; trees exploit these directional gradients.
#   - How to implement:
#     - Aspect_rad = deg2rad(Aspect); Aspect_cos = cos(Aspect_rad); Aspect_sin = sin(Aspect_rad).
#     - Add Slope*cos(Aspect_rad) and Slope*sin(Aspect_rad). Optionally include simple Slope*Aspect and Aspect/Slope (safe denom) if sin/cos feels too heavy.
#
# - Safe ratio features for distances (4/26: rows 8, 9, 22, 23)
#   - Why effective: Ratios capture relative proximity (e.g., Road/Fire, Hydro/Road), which can separate classes; safe division (add small constants, handle zeros) prevents numerical issues that hurt tree split quality.
#   - How to implement:
#     - Define safe_ratio(a, b, add=1.0): return np.where(b == 0, 0.0, a / (b + add)), then replace non-finite values with 0.0.
#     - Engineer Road_to_Fire_Ratio, Hydro_to_Road_Ratio, Hydro_Horiz_Ratio, etc.
#
# - log1p transforms for skewed distances (1/26: row 18)
#   - Why effective: Distance features can be heavy-tailed; log1p reduces skew and helps trees form more balanced splits.
#   - How to implement:
#     - For selected horizontal distances, add log1p versions (e.g., df['log1p_Horizontal_Distance_To_Roadways'] = np.log1p(df['Horizontal_Distance_To_Roadways'])).
#
# - K-fold CV probability averaging with XGBoost (4/26: rows 5, 13, 18, 19) and LightGBM (4/26: rows 21, 22, 25, 26)
#   - Why effective: Reduces variance and overfitting to a single validation split, especially important for large synthetic data where patterns may be unstable.
#   - How to implement:
#     - StratifiedKFold(n_splits=3–5, shuffle=True, random_state=SEED), train a model per fold with early stopping, predict probabilities on test per fold, and average probabilities across folds before argmax.
#
# - Aspect wrap-around transform (1/26 explicitly: row 6)
#   - Why effective: Converts Aspect to a continuous representation handling the 0/360 discontinuity (e.g., transform >180 to negative angles), improving split continuity.
#   - How to implement:
#     - Aspect_wrapped = Aspect if Aspect ≤ 180 else Aspect − 360; optionally still add sin/cos.
#
# - Manual per-class stratified split (1/26: row 24)
#   - Why effective: Guarantees class balance in validation, even if standard stratify fails for edge cases; helpful under FAST_DEV or skewed subsets.
#   - How to implement:
#     - Group by class, shuffle indices within each class (with a fixed RNG), and sample a fixed fraction per class for validation.
#
#
# Practical takeaways for future solvers
# - Minimal baseline: XGBoost or LightGBM with early stopping, stratified 90/10 split, and a standard FE pack (Hydrology Euclid, Hillshade mean/range/diffs, Elevation ± VDH, distance sums/diffs/abs-diffs, Aspect sin/cos). Cast features to float32, labels to 0-based, and use GPU for XGBoost if available.
# - Stronger submission: 3–5 fold StratifiedKFold probability averaging; track merror (accuracy) alongside mlogloss for early stopping; use best_iteration in inference. Avoid class weights unless OOF shows clear benefit.
# - Easy, high-impact extras: Add Wilderness/Soil indices (keep one-hots), slope–aspect projections, safe ratios; consider log1p on select distances.
# - Optional refinement: Two-stage refit on full data with best_iteration from early stopping.
#
# Cross-check counts summary:
# - Total solutions: 27
# - High (>=0.6): 26
# - Low (<0.6): 1
#
# - Data preprocessing (High — top 5)
#   - 0-based label encoding/mapping for target: 26
#   - Stratified splitting for validation/CV (attempted with fallback): 26
#   - Use of XGBoost DMatrix for data: 19
#   - Memory-optimized dtypes (downcasting ints/bools): 18
#   - Train/test feature alignment and column-order checks: 8
#
# - Data preprocessing (Low — top 5)
#   - Stratified 90/10 hold-out split: 1
#   - Concatenate train+test for unified feature engineering: 1
#   - 0-based label encoding: 1
#   - DEV-mode stratified downsampling: 1
#   - DMatrix with sample weights: 1
#
# - Feature engineering (High — top 5)
#   - Hydrology Euclidean distance (sqrt(HH^2 + VH^2)): 23
#   - Hillshade mean (9am/Noon/3pm): 21
#   - Elevation − Vertical_Distance_To_Hydrology: 20
#   - Road–Fire distance sum: 18
#   - Hillshade range/differences (non-mean stats): 17
#
# - Feature engineering (Low — top 5)
#   - Hydrology Euclidean distance: 1
#   - Aspect sine/cosine: 1
#   - Road–Fire sum and difference: 1
#   - Hillshade mean and range: 1
#   - Vertical_Distance_Neg flag and Hydrology H×V interaction: 1
#
# - Model selection (High — top 5)
#   - XGBoost (objective=multi:softprob): 19
#   - LightGBM (objective=multiclass): 7
#   - XGBoost with GPU histogram (gpu_hist/device=cuda): 19
#   - eval_metric includes mlogloss: 12
#   - eval_metric includes merror: 7
#
# - Model selection (Low — top 5)
#   - XGBoost (multi:softprob): 1
#   - tree_method gpu_hist (fallback to hist): 1
#   - eval_metric='mlogloss': 1
#   - max_depth=8, eta=0.08: 1
#   - subsample=0.8, colsample_bytree=0.8: 1
#
# - Training methodology (High — top 5)
#   - Early stopping on validation: 26
#   - Use best_iteration/ntree_limit/iteration_range for prediction: 23
#   - K-fold CV with probability averaging: 8
#   - Single stratified hold-out (~90/10): 14
#   - Refit on full data with best rounds: 2
#
# - Training methodology (Low — top 5)
#   - Single hold-out with early stopping (50): 1
#   - Class-weighted training (inverse-frequency weights): 1
#   - GPU/CPU retry fallback: 1
#   - Verbose eval logging (every ~200): 1
#   - Fixed seed and nthread (2021, 12): 1
#
# - Evaluation & submission (High — top 5)
#   - Argmax over predicted class probabilities: 26
#   - Restore original labels (inverse mapping or +1): 26
#   - Average fold probabilities before argmax (for CV): 8
#   - Sort submission by Id: 9
#   - Write submission to /workspace/submission.csv with ['Id','Cover_Type']: 26
#
# - Evaluation & submission (Low — top 5)
#   - Argmax over soft probabilities: 1
#   - Map indices back to original labels: 1
#   - Write CSV with ['Id','Cover_Type']: 1
#   - Ensure output directory exists: 1
#   - Fallback dummy submission on failure: 1
#
# - Notable details (High — top 5)
#   - GPU detection and fallback to CPU: 19
#   - FAST_DEV/DEV_RUN modes (row/round limits): 21
#   - Memory/dtype optimization (downcasting): 18
#   - Auto-install missing packages at runtime: 17
#   - Explicit train/test feature alignment safeguards: 10
#
# - Notable details (Low — top 5)
#   - GPU availability probe and retry: 1
#   - Concatenate train+test for FE: 1
#   - DEV-mode sampling for speed: 1
#   - Runtime and validation accuracy logging: 1
#   - Inverse-frequency weighting despite modest imbalance: 1

# %%
archive_file(archive_dir = "/checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/comparison/",
             file_path=matching_logs[0])
# Out:
# Skipped (already exists): /checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/comparison/gpt-5_comparison_513_tabular-playground-series-dec-2021_2026-02-11_07-58-08_5718beec.jsonl
# Archived: /checkpoint/maui_sft/winnieyangwn/rlm_dumps/comparison-v3/gpt-5_comparison_513_tabular-playground-series-dec-2021_2026-02-11_07-58-08_5718beec.md -> /checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/comparison/gpt-5_comparison_513_tabular-playground-series-dec-2021_2026-02-11_07-58-08_5718beec.md
# ['/checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/comparison/gpt-5_comparison_513_tabular-playground-series-dec-2021_2026-02-11_07-58-08_5718beec.md']
