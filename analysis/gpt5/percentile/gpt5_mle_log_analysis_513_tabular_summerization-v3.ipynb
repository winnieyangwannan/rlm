# %% [markdown]
# # LOG:
#
# /checkpoint/maui_sft/winnieyangwn/rlm_dumps/gpt-5_summarization_513_iwildcam-2019-fgvc6_2026-02-09_07-05-37_3bfb9fbc.jsonl

# %%
import sys
import importlib


sys.path.append('/home/winnieyangwn/rlm/analysis')
import rlm_log_utils
importlib.reload(rlm_log_utils)
from rlm_log_utils import *

# %% [markdown]
# ## Usage Example
#
# Load the log file and extract key information:

# %% [markdown]
# # Load

# %%
import glob
import os

run_id = 513
model_name = "gpt-5"
task_name = "tabular-playground-series-dec-2021"
log_dir = "/checkpoint/maui_sft/winnieyangwn/rlm_dumps/summarization"
codebase_extensions = [".py", ".md", ".yaml"]

# Option 1: Provide a specific log name to load directly
log_name = None  # e.g. "gpt-5_summarization_513_iwildcam-2019-fgvc6_2026-02-09_07-05-37_3bfb9fbc.jsonl"
if log_name:
    # Directly load the specified log file
    LOG_PATH = os.path.join(log_dir, log_name)
    if not os.path.exists(LOG_PATH):
        raise FileNotFoundError(f"Specified log file not found: {LOG_PATH}")
    print(f"Loading specified log: {LOG_PATH}")
else:
    # Use underscore after run_id to avoid matching "summarization_comparison_*" logs
    LOG_PATH_PREFIX = f"{log_dir}/{model_name}_summarization_{run_id}_{task_name}"

    # Find all log files matching the prefix pattern
    matching_logs = glob.glob(f"{LOG_PATH_PREFIX}*")

    if not matching_logs:
        raise FileNotFoundError(f"No log files found matching prefix: {LOG_PATH_PREFIX}")

    # Get the most recent log file by modification time
    LOG_PATH = max(matching_logs, key=os.path.getmtime)
    print(f"Found {len(matching_logs)} matching log file(s)")
    print(f"Loading most recent: {LOG_PATH}")

# Load the log - first entry is metadata, rest are iterations
entries = load_rlm_log(LOG_PATH)
metadata = entries[0]
iterations = entries[1:]

print(f"Loaded {len(iterations)} iterations")
# Out:
# Found 1 matching log file(s)
# Loading most recent: /checkpoint/maui_sft/winnieyangwn/rlm_dumps/summarization/gpt-5_summarization_513_tabular-playground-series-dec-2021_2026-02-11_06-47-42_133f65a1.jsonl
# Loaded 3 iterations

# %% [markdown]
# # Metadata

# %%
# View metadata
print("=== METADATA ===")
for k, v in metadata.items():
    if k != "backend_kwargs":
        print(f"{k}: {v}")
# Out:
# === METADATA ===
# type: metadata
# timestamp: 2026-02-11T06:47:42.925202
# root_model: gpt-5
# max_depth: 2
# max_iterations: 10
# backend: azure_openai
# environment_type: local
# environment_kwargs: {'setup_code': '\nimport pandas as pd\n\n# Load rollout data as DataFrame\nrollout_df = pd.read_json(\'/checkpoint/maui_sft/winnieyangwn/amaia_dumps/513/trajectories/513_metadata.jsonl\', lines=True)\nprint(f"Loaded {len(rollout_df)} total rollouts")\n\n# Filter to specific task\nrollout_df = rollout_df[rollout_df[\'task_name\'] == \'tabular-playground-series-dec-2021\']\nprint(f"Filtered to {len(rollout_df)} rollouts for task: tabular-playground-series-dec-2021")\n'}
# other_backends: None

# %%
# Compare with timestamp-based runtime
runtime = get_total_runtime(entries)
print(f"Timestamp-based runtime: {runtime.total_seconds():.2f}s")
# Out:
# Timestamp-based runtime: 313.71s

# %%
# Check number of iterations actually taken by model
num_iterations = len(iterations)
print(f"Number of iterations taken: {num_iterations}")

# You can also use extract_all for a comprehensive summary
summary = extract_all(LOG_PATH)
print(f"Number of iterations (from extract_all): {summary['num_iterations']}")
# Out:
# Number of iterations taken: 3
# Number of iterations (from extract_all): 3

# %% [markdown]
# # Final Answer

# %%
# Get the final answer
final_answer = get_final_answer(iterations)
print("=== FINAL ANSWER ===")
print(final_answer if final_answer else "No final answer found")
# print(f"\n(Total length: {len(final_answer) if final_answer else 0} chars)")
# Out:
# === FINAL ANSWER ===
# Part 0: Task Analysis
# - Problem Type: Multi-class classification (predict discrete Cover_Type classes)
# - Domain: Forest cover type prediction (forestry/land cover), based on the original Kaggle Forest Cover Type dataset
# - Input Format: Tabular CSV data (train.csv with features + target Cover_Type; test.csv with features and Id; sample_submission.csv format)
# - Evaluation Metric: Multi-class classification accuracy — proportion of test rows correctly classified
# - Key Challenges:
#   - Data are synthetically generated by CTGAN and may not preserve the original feature–target relationships
#   - Dataset is much larger than the original, implying computational and scalability considerations
#   - Multi-class target requires modeling multiple categories and robust generalization
#   - Ensuring correct submission format (one predicted class per Id with proper header)
#
# Part 1: Individual Solution Summaries
# Solution ID: tabular-playground-series-dec-2021__row0
# Score Percentile: 1.0
#
# Solution ID: tabular-playground-series-dec-2021__row0
# Score Percentile: 1.0
#
# 1) Data Preprocessing
# - Data loading and splitting approaches:
#   - Load train.csv and test.csv via pandas.read_csv. Optionally limit train rows if FAST_DEV=1 (DEV_NROWS default 300000).
#   - Split train into train/valid using sklearn.model_selection.train_test_split with stratify=y, test_size=VALID_SIZE (default 0.1), random_state=SEED. Fallback to non-stratified split if stratification fails.
# - Cleaning strategies (missing values, outliers, filtering):
#   - None. Basic assertions that train has Cover_Type and both sets have Id. Comment mentions NaNs but no fillna used.
# - Transformations (scaling, encoding, type conversions):
#   - Feature columns cast to float32.
#   - Labels y cast to int32 and shifted to zero-based (y = y - 1) for XGBoost.
#   - Feature list excludes ['Id', 'Cover_Type'].
# - Data augmentation (if any):
#   - None.
# - Other preprocessing steps:
#   - Build xgb.DMatrix for train/valid/test with nthread=NTHREAD.
#   - FAST_DEV mode reduces num_boost_round and early_stopping_rounds.
#
# 2) Feature Engineering
# - New features created:
#   - Hydrology_Euclidean_Distance = sqrt(Horizontal_Distance_To_Hydrology^2 + Vertical_Distance_To_Hydrology^2)
#   - HF1 = Horizontal_Distance_To_Hydrology + Horizontal_Distance_To_Fire_Points
#   - HR1 = Horizontal_Distance_To_Hydrology + Horizontal_Distance_To_Roadways
#   - FR1 = Horizontal_Distance_To_Fire_Points + Horizontal_Distance_To_Roadways
#   - Mean_Hillshade = (Hillshade_9am + Hillshade_Noon + Hillshade_3pm) / 3
# - Feature selection / dimensionality reduction:
#   - None (uses all original features plus engineered ones, excluding Id and Cover_Type).
# - Domain-specific transforms:
#   - Distance combinations and mean of hillshade measures relevant to the dataset.
# - Notes if none:
#   - N/A.
#
# 3) Model Selection
# - Algorithm(s) used (exact class/function names):
#   - xgboost.DMatrix
#   - xgboost.train (XGBoost multiclass classifier, objective='multi:softprob')
# - Key hyperparameters (list from code):
#   - objective='multi:softprob'
#   - num_class (computed from labels)
#   - eval_metric='mlogloss'
#   - max_depth=8
#   - eta=0.08
#   - subsample=0.8
#   - colsample_bytree=0.8
#   - min_child_weight=3
#   - lambda=2.0
#   - tree_method=('gpu_hist' if GPU detected else 'hist')
#   - predictor=('gpu_predictor' if GPU detected else 'auto')
#   - seed=SEED
#   - num_boost_round=1500 (override in FAST_DEV)
#   - early_stopping_rounds=60 (override in FAST_DEV)
# - Ensemble architecture (stacking/blending/voting) and number of models:
#   - None (single XGBoost model).
# - Pretrained models (if any):
#   - None.
#
# 4) Training Methodology
# - Hyperparameter selection method:
#   - Fixed values; no search/tuning. Some parameters configurable via environment variables.
# - Training configuration details (splits, folds, early stopping, regularization):
#   - Train/valid split via train_test_split (stratified if possible).
#   - Early stopping with early_stopping_rounds on validation set.
#   - Regularization via min_child_weight=3 and lambda=2.0.
#   - Eval sets: [('train'), ('valid')] with verbose_eval=50.
# - Other training details:
#   - best_iteration extracted (if available) and used for prediction via iteration_range.
#   - nthread set on DMatrix.
#   - Seed set for reproducibility.
#
# 5) Evaluation & Submission
# - Final prediction method (mean/median/weighted/etc.):
#   - Predict class probabilities; take argmax per row.
# - Post-processing of predictions (rounding/clipping/logit/inverse, etc.):
#   - Convert back to 1-based class labels (add 1).
# - How submission CSV is written:
#   - pandas.DataFrame with columns ['Id', 'Cover_Type']; written to OUT_PATH ('/workspace/submission.csv') with index=False.
#   - Prints head; verifies line count equals test rows + header.
#
# 6) Notable Implementation Details
# - Computational considerations (GPU/CPU, runtime):
#   - Detects GPU via nvidia-smi; uses 'gpu_hist' and 'gpu_predictor' if available, otherwise 'hist' on CPU.
#   - Uses NTHREAD for DMatrix threading; FAST_DEV mode to limit rows and training rounds; prints total runtime.
#   - Installs required packages at runtime if missing.
# - Unique approaches or techniques:
#   - Robust handling of best_iteration across XGBoost versions using getattr and iteration_range prediction.
#   - Submission line count verification for sanity.
# - Other significant aspects:
#   - Environment-configurable SEED, VALID_SIZE, NUM_BOOST_ROUND, EARLY_STOPPING_ROUNDS, NTHREAD, FAST_DEV.
#   - Asserts presence of required columns before processing.
#
# Solution ID: tabular-playground-series-dec-2021__row1
# Score Percentile: 1.0
#
# Solution ID: tabular-playground-series-dec-2021__row1
# Score Percentile: 1.0
#
# 1) Data Preprocessing
# - Data loading and splitting approaches:
#   - Reads header from /root/data/train.csv to build dtype map.
#   - Loads train.csv and test.csv with pandas.read_csv using dtype_map.
#   - Splits train into train/validation via sklearn.model_selection.train_test_split(test_size=0.1, random_state=SEED, stratify=y_zero). Optional DEV_RUN downsampling (keep ~5% of rows) with stratify fallback.
# - Cleaning strategies (missing values, outliers, filtering):
#   - None
# - Transformations (scaling, encoding, type conversions):
#   - Dtype mapping: Wilderness_Area* and Soil_Type* as uint8; other features as int32; Id and Cover_Type as int32.
#   - Engineered features cast to float32.
#   - Features converted to float32 before XGBoost (X_train/X_valid/X_test).
#   - Labels converted to zero-based (y_zero = y-1 if min_label != 0) and int32 for XGBoost.
# - Data augmentation (if any):
#   - None
# - Other preprocessing steps:
#   - Constructs feature_cols excluding Id and Cover_Type.
#   - Logs memory usage; ensures /workspace exists.
#   - Creates xgboost.DMatrix for train/valid/test.
#
# 2) Feature Engineering
# - New features created:
#   - Hillshade_Mean, Hillshade_Diff_9_3, Hillshade_Diff_Noon_9
#   - Hydrology_Distance_Euclid, Elevation_minus_VertHydro, Elevation_minus_HydroEuclid
#   - Road_Fire_Diff, Road_Fire_Sum
#   - Aspect_Slope_Prod
# - Feature selection / dimensionality reduction:
#   - None
# - Domain-specific transforms:
#   - Euclidean distance from hydrology; differences/sums between road and fire distances; hillshade differences; aspect-slope product.
# - Notes if none:
#   - N/A
#
# 3) Model Selection
# - Algorithm(s) used (exact class/function names):
#   - xgboost.train
#   - xgboost.DMatrix
# - Key hyperparameters (list from code):
#   - objective='multi:softprob'
#   - num_class (derived from y.nunique())
#   - eval_metric='merror'
#   - tree_method ('gpu_hist' if GPU probe succeeds else 'hist')
#   - max_depth=10
#   - eta=0.05
#   - subsample=0.8
#   - colsample_bytree=0.8
#   - lambda=1.0
#   - alpha=0.0
#   - min_child_weight=1
#   - max_bin=256
#   - verbosity=1
#   - num_boost_round=3000 (50 if DEV_RUN)
#   - early_stopping_rounds=50 (10 if DEV_RUN)
# - Ensemble architecture (stacking/blending/voting) and number of models:
#   - None (single XGBoost model)
# - Pretrained models (if any):
#   - None
#
# 4) Training Methodology
# - Hyperparameter selection method:
#   - None (fixed parameters; GPU availability probed by a tiny train run)
# - Training configuration details (splits, folds, early stopping, regularization):
#   - Train/valid split: 90%/10%, stratified (fallback to non-stratified on error), random_state=SEED.
#   - Early stopping on validation with rounds=50 (10 in DEV_RUN).
#   - Regularization: lambda=1.0, alpha=0.0, min_child_weight=1.
#   - Sampling: subsample=0.8, colsample_bytree=0.8.
#   - evals=[(dtrain,'train'), (dvalid,'valid')], verbose_eval=50.
# - Other training details:
#   - Validation accuracy computed via sklearn.metrics.accuracy_score.
#   - Predictions limited to best_iteration using iteration_range.
#
# 5) Evaluation & Submission
# - Final prediction method (mean/median/weighted/etc.):
#   - Argmax over class probabilities from multi:softprob.
# - Post-processing of predictions (rounding/clipping/logit/inverse, etc.):
#   - Convert predicted labels back to 1-based (ytest_pred + 1) if training labels were shifted.
# - How submission CSV is written:
#   - pandas.DataFrame with columns Id (int32) and Cover_Type (int32), written to /workspace/submission.csv with index=False.
#
# 6) Notable Implementation Details
# - Computational considerations (GPU/CPU, runtime):
#   - Attempts GPU via tree_method='gpu_hist'; falls back to 'hist' if probe fails.
#   - Dtype optimization (uint8/int32) and float32 conversion to reduce memory; logs memory usage.
#   - Garbage collection after writing submission.
# - Unique approaches or techniques:
#   - Header-only read to build precise dtype map before full CSV load.
#   - GPU availability probe using a tiny xgb.train run.
#   - Domain-informed engineered features for terrain/hydrology/road/fire relationships.
#   - DEV_RUN mode for quick iteration (downsampling and fewer rounds).
# - Other significant aspects:
#   - Dynamic installation of pandas, numpy, xgboost, scikit-learn if missing.
#   - Timestamped logging, reproducible SEED, and workspace setup.
#
# Solution ID: tabular-playground-series-dec-2021__row2
# Score Percentile: 1.0
#
# Solution ID: tabular-playground-series-dec-2021__row2
# Score Percentile: 1.0
#
# 1) Data Preprocessing
# - Data loading and splitting approaches:
#   - Read train.csv and test.csv from /root/data using pandas.
#   - If FAST_DEV_RUN=1: stratified subset of train using sklearn.model_selection.train_test_split (size min(50000, len(train)), stratify on Cover_Type); fallback to random sample if stratification fails. Test sampled randomly to min(20000, len(test)).
#   - Otherwise, use full datasets.
# - Cleaning strategies (missing values, outliers, filtering): Not shown.
# - Transformations (scaling, encoding, type conversions):
#   - Cast all feature columns to float32.
#   - Target Cover_Type converted to int32 and offset to 0-based classes (subtract min_class).
# - Data augmentation (if any): None.
# - Other preprocessing steps:
#   - Feature columns selected as all columns excluding Cover_Type and Id.
#   - Compute num_classes and min_class from target.
#   - Extract X as numpy array of features, y0 as 0-based labels, X_test as test features, ids from test Id (or generated range if Id missing).
#
# 2) Feature Engineering
# - New features created:
#   - Hillshade_Mean = (Hillshade_9am + Hillshade_Noon + Hillshade_3pm) / 3.0
#   - Hillshade_Diff_9to3 = Hillshade_9am - Hillshade_3pm
#   - Hydrology_Euclidean_Dist = sqrt(Horizontal_Distance_To_Hydrology^2 + Vertical_Distance_To_Hydrology^2)
#   - Vertical_Distance_To_Hydrology_Abs = abs(Vertical_Distance_To_Hydrology)
#   - Sum_Road_Fire_Distance = Horizontal_Distance_To_Roadways + Horizontal_Distance_To_Fire_Points
#   - Diff_Road_Fire_Distance = Horizontal_Distance_To_Roadways - Horizontal_Distance_To_Fire_Points
# - Feature selection / dimensionality reduction: None (use all features except Cover_Type and Id).
# - Domain-specific transforms: Yes (hillshade and hydrology-related distance features, combined distances).
# - Notes if none: N/A.
#
# 3) Model Selection
# - Algorithm(s) used (exact class/function names):
#   - xgboost.train with DMatrix (objective: multi:softprob).
# - Key hyperparameters (list from code):
#   - objective='multi:softprob'
#   - num_class=num_classes
#   - eval_metric=['mlogloss', 'merror']
#   - tree_method='gpu_hist' (preferred) or 'hist' (fallback)
#   - max_depth=8
#   - learning_rate=0.06
#   - subsample=0.8
#   - colsample_bytree=0.8
#   - lambda=1.0
#   - alpha=0.0
#   - max_bin=256
#   - verbosity=1
#   - seed=SEED
#   - nthread=NTHREAD
#   - num_boost_round=1000 (50 if FAST_DEV_RUN)
#   - early_stopping_rounds=100 (10 if FAST_DEV_RUN)
#   - verbose_eval=50
# - Ensemble architecture (stacking/blending/voting) and number of models: None (single XGBoost model).
# - Pretrained models (if any): None.
#
# 4) Training Methodology
# - Hyperparameter selection method: None (fixed values).
# - Training configuration details (splits, folds, early stopping, regularization):
#   - Train/valid split: StratifiedShuffleSplit with test_size=0.1; fallback to ShuffleSplit if stratified fails.
#   - Early stopping with early_stopping_rounds (100 or 10 depending on FAST_DEV_RUN).
#   - Regularization: lambda=1.0, alpha=0.0.
#   - GPU probe and automatic fallback to CPU; seed set.
# - Other training details:
#   - Uses xgboost.DMatrix for train/valid.
#   - Evaluates with metrics mlogloss and merror.
#
# 5) Evaluation & Submission
# - Final prediction method (mean/median/weighted/etc.):
#   - Predict class probabilities on test; take argmax to get class index; add back min_class to restore original labels.
# - Post-processing of predictions (rounding/clipping/logit/inverse, etc.):
#   - Cast predictions to int32; apply label offset. No other post-processing.
# - How submission CSV is written:
#   - Create DataFrame with columns ['Id', 'Cover_Type'] and write to /workspace/submission.csv with index=False (ensure parent directory exists).
#
# 6) Notable Implementation Details
# - Computational considerations (GPU/CPU, runtime):
#   - Attempts to use XGBoost GPU ('gpu_hist') via a probe; falls back to CPU ('hist') if unavailable.
#   - nthread set from environment or CPU count; FAST_DEV_RUN reduces data size and boosting rounds.
#   - Logs pipeline duration; uses gc.collect for memory management.
# - Unique approaches or techniques:
#   - Runtime package installation via ensure_pkg for xgboost and scikit-learn.
#   - Stratified subset sampling in fast dev mode; dynamic handling of label offsets (min_class not assumed to be 1).
# - Other significant aspects:
#   - Robust logging with timestamps.
#   - Id handling: uses test 'Id' column if present, else sequential indices.
#
# Solution ID: tabular-playground-series-dec-2021__row3
# Score Percentile: 1.0
#
# Solution ID: tabular-playground-series-dec-2021__row3
# Score Percentile: 1.0
#
# 1) Data Preprocessing
# - Data loading and splitting approaches:
#   - Load train/test via pandas.read_csv from /root/data/train.csv and /root/data/test.csv.
#   - Create a single train/validation split using sklearn.model_selection.train_test_split with test_size=0.05 (or 0.1 if FAST_DEV), random_state=42, stratify=y_adj if safe.
# - Cleaning strategies (missing values, outliers, filtering):
#   - Convert base numeric columns to numeric using pd.to_numeric(errors='coerce'). No explicit imputation, outlier handling, or row filtering beyond optional FAST_DEV subsampling.
# - Transformations (scaling, encoding, type conversions):
#   - Features cast to np.float32 for memory efficiency.
#   - Labels mapped from 1..7 to 0..6 (y_adj = y - 1).
#   - Categorical one-hot indices created via argmax: Wilderness_Idx (0..3) and Soil_Idx (0..39), cast to int16.
#   - Id and final Cover_Type cast to int when writing submission.
# - Data augmentation (if any):
#   - None.
# - Other preprocessing steps:
#   - Verify test contains all engineered feature columns and same order; raise error if missing.
#   - FAST_DEV option: subsample to first min(len(X), 200000) rows (no stratify).
#   - Build feature_cols as all columns except ['Id', 'Cover_Type'].
#   - Create workspace directory for submission path.
#
# 2) Feature Engineering
# - New features created:
#   - Hydrology_Euclid_Dist = sqrt(Horizontal_Distance_To_Hydrology^2 + Vertical_Distance_To_Hydrology^2)
#   - Hydrology_Dist_Sum = Horizontal_Distance_To_Hydrology + Vertical_Distance_To_Hydrology
#   - Hydrology_Dist_Diff = Horizontal_Distance_To_Hydrology - Vertical_Distance_To_Hydrology
#   - Hillshade_Mean, Hillshade_Max, Hillshade_Min, Hillshade_Delta (from Hillshade_9am/Noon/3pm)
#   - Road_Fire_Dist_Sum = Horizontal_Distance_To_Roadways + Horizontal_Distance_To_Fire_Points
#   - Road_Fire_Dist_Diff = Horizontal_Distance_To_Roadways - Horizontal_Distance_To_Fire_Points
#   - Elev_Minus_VertHyd = Elevation - Vertical_Distance_To_Hydrology
#   - Elev_Plus_VertHyd = Elevation + Vertical_Distance_To_Hydrology
#   - Wilderness_Idx (argmax across Wilderness_Area1..4)
#   - Soil_Idx (argmax across Soil_Type1..40)
# - Feature selection / dimensionality reduction:
#   - None (use all columns except Id and Cover_Type).
# - Domain-specific transforms:
#   - Distance-based combinations and hillshade statistics relevant to terrain/cover type prediction.
# - Notes if none:
#   - N/A
#
# 3) Model Selection
# - Algorithm(s) used (exact class/function names):
#   - xgboost.DMatrix
#   - xgboost.train (native API) with objective='multi:softprob'
#   - Note: sklearn’s XGBClassifier is imported but not used.
# - Key hyperparameters (list from code):
#   - max_depth=9
#   - eta=0.05 (0.1 if FAST_DEV)
#   - subsample=0.8
#   - colsample_bytree=0.8
#   - lambda=1.0
#   - alpha=0.0
#   - objective='multi:softprob'
#   - num_class=7
#   - verbosity=1
#   - nthread=12
#   - tree_method='gpu_hist' (fallback to 'hist' on CPU)
#   - predictor='gpu_predictor' (fallback to 'cpu_predictor')
#   - num_boost_round=4000 (300 if FAST_DEV)
#   - early_stopping_rounds=100 (20 if FAST_DEV)
# - Ensemble architecture (stacking/blending/voting) and number of models:
#   - None; single XGBoost model.
# - Pretrained models (if any):
#   - None.
#
# 4) Training Methodology
# - Hyperparameter selection method:
#   - Fixed values; no search/tuning beyond early stopping.
# - Training configuration details (splits, folds, early stopping, regularization):
#   - Single hold-out validation split (5% or 10% if FAST_DEV).
#   - Conditional stratification based on class counts and split proportions.
#   - Early stopping on validation with specified rounds.
#   - Regularization via lambda (L2), alpha (L1=0), subsample, and colsample_bytree.
#   - GPU training attempted; falls back to CPU if GPU fails.
# - Other training details:
#   - Features cast to float32.
#   - Use best_ntree_limit from early stopping for test-time prediction if available.
#   - Log best_iteration and best_ntree_limit.
#
# 5) Evaluation & Submission
# - Final prediction method (mean/median/weighted/etc.):
#   - Predict class probabilities (softprob) and take argmax; convert to 1-based labels by adding 1.
# - Post-processing of predictions (rounding/clipping/logit/inverse, etc.):
#   - Use ntree_limit=best_ntree_limit if available; predictions cast to int for submission. No other post-processing.
# - How submission CSV is written:
#   - pandas.DataFrame with columns ['Id', 'Cover_Type']; to_csv at /workspace/submission.csv with index=False.
#
# 6) Notable Implementation Details
# - Computational considerations (GPU/CPU, runtime):
#   - Attempts GPU training with 'gpu_hist' and 'gpu_predictor'; falls back to CPU 'hist' and 'cpu_predictor' on failure.
#   - nthread=12 for CPU/GPU thread usage.
#   - Cast to float32 to reduce memory usage.
#   - FAST_DEV mode reduces rows and boosting rounds for quicker runs.
# - Unique approaches or techniques:
#   - Dynamic safety check before using stratified split.
#   - Deriving categorical indices from one-hot features via argmax (Wilderness_Idx, Soil_Idx).
#   - Ensuring engineered features exist in test, enforcing column alignment.
#   - Auto-install missing packages via pip within the script.
# - Other significant aspects:
#   - Logs informative messages and total elapsed time.
#   - Uses native xgboost.DMatrix/xgb.train rather than sklearn wrapper.
#
# Solution ID: tabular-playground-series-dec-2021__row4
# Score Percentile: 1.0
#
# Solution ID: tabular-playground-series-dec-2021__row4
# Score Percentile: 1.0
#
# 1) Data Preprocessing
# - Data loading and splitting approaches:
#   - Reads train/test CSVs via pandas.read_csv with dtype inference (dtypes=None).
#   - Optional fast-dev stratified sampling of train by Cover_Type to sample_n rows (controlled by env FAST_DEV, FAST_DEV_SAMPLE).
#   - Preserves test Ids.
#   - Aligns test features to the training feature columns after feature engineering.
# - Cleaning strategies (missing values, outliers, filtering):
#   - None shown.
# - Transformations (scaling, encoding, type conversions):
#   - Drops Id and Cover_Type from features.
#   - Casts feature matrices (X, X_test) to float32.
#   - Maps labels to 0..num_class-1 indices (if labels start at 1, uses y-1; otherwise ranks unique labels).
# - Data augmentation (if any):
#   - None.
# - Other preprocessing steps:
#   - Computes num_class = len(np.unique(y)).
#   - Uses gc.collect() to free memory between steps.
#
# 2) Feature Engineering
# - New features created:
#   - EVDH = Elevation - Vertical_Distance_To_Hydrology
#   - E_plus_VDH = Elevation + Vertical_Distance_To_Hydrology
#   - HF_sum = Horizontal_Distance_To_Fire_Points + Horizontal_Distance_To_Roadways
#   - HF_diff = Horizontal_Distance_To_Fire_Points - Horizontal_Distance_To_Roadways
#   - HF_abs_diff = abs(Horizontal_Distance_To_Fire_Points - Horizontal_Distance_To_Roadways)
#   - Hydrology_Road_Sum = Horizontal_Distance_To_Hydrology + Horizontal_Distance_To_Roadways
#   - Hydrology_Road_Diff = Horizontal_Distance_To_Hydrology - Horizontal_Distance_To_Roadways
#   - Hydrology_Fire_Sum = Horizontal_Distance_To_Hydrology + Horizontal_Distance_To_Fire_Points
#   - Hydrology_Fire_Diff = Horizontal_Distance_To_Hydrology - Horizontal_Distance_To_Fire_Points
#   - Hillshade_mean = mean(Hillshade_9am, Hillshade_Noon, Hillshade_3pm)
#   - Hillshade_range = max(...) - min(...) across Hillshade_9am, Hillshade_Noon, Hillshade_3pm
#   - Aspect_sin = sin(Aspect in radians)
#   - Aspect_cos = cos(Aspect in radians)
#   - Slope_times_HDH = Slope * Horizontal_Distance_To_Hydrology
# - Feature selection / dimensionality reduction:
#   - None (features = all columns except Id and Cover_Type).
# - Domain-specific transforms:
#   - Circular encoding for Aspect (sine/cosine).
#   - Distance sums/differences and hillshade statistics.
#   - Interaction Slope * Horizontal_Distance_To_Hydrology.
# - Notes if none:
#   - N/A.
#
# 3) Model Selection
# - Algorithm(s) used (exact class/function names):
#   - xgboost.train with xgboost.DMatrix.
# - Key hyperparameters (list from code):
#   - objective='multi:softprob'
#   - num_class (computed)
#   - eval_metric=['mlogloss', 'merror']
#   - eta=0.05
#   - max_depth=8
#   - min_child_weight=1
#   - subsample=0.8
#   - colsample_bytree=0.8
#   - lambda=1.0
#   - alpha=0.0
#   - verbosity=1
#   - seed=42
#   - nthread=12
#   - tree_method='gpu_hist' (attempt) or 'hist' (fallback)
#   - predictor='gpu_predictor' (attempt) or 'cpu_predictor' (fallback)
#   - num_boost_round=2000 (100 if fast_dev)
#   - early_stopping_rounds=100 (20 if fast_dev)
# - Ensemble architecture (stacking/blending/voting) and number of models:
#   - None (single XGBoost model).
# - Pretrained models (if any):
#   - None.
#
# 4) Training Methodology
# - Hyperparameter selection method:
#   - None (fixed parameters; optional overrides via params_overrides).
# - Training configuration details (splits, folds, early stopping, regularization):
#   - train_test_split with test_size=0.1, random_state=42, stratify=y_idx (falls back to random split on error).
#   - Early stopping based on validation set.
#   - Regularization via lambda and alpha (as set above).
#   - evals=[(dtrain,'train'),(dval,'valid')], verbose_eval=50.
# - Other training details:
#   - Labels mapped to 0-based indices for XGBoost.
#   - Uses DMatrix with feature_names.
#   - Attempts GPU acceleration; falls back to CPU if not available.
#
# 5) Evaluation & Submission
# - Final prediction method (mean/median/weighted/etc.):
#   - Predicts class probabilities (softprob) and takes argmax per row to get class index.
# - Post-processing of predictions (rounding/clipping/logit/inverse, etc.):
#   - Maps predicted indices back to class labels by pred_idx + 1.
# - How submission CSV is written:
#   - Creates DataFrame with columns 'Id' (int) and 'Cover_Type' (int).
#   - Writes to /workspace/submission.csv with index=False; ensures directory exists.
#
# 6) Notable Implementation Details
# - Computational considerations (GPU/CPU, runtime):
#   - Attempts to use GPU (tree_method='gpu_hist', predictor='gpu_predictor'); falls back to CPU ('hist', 'cpu_predictor').
#   - nthread=12.
#   - Logs timing; reports total runtime in minutes.
#   - Frees memory with gc.collect().
# - Unique approaches or techniques:
#   - Fast-dev mode with stratified sampling by Cover_Type.
#   - Circular encoding for Aspect.
#   - Robust prediction handling using iteration_range or ntree_limit depending on xgboost version.
#   - Ensures test features align with train feature set and uses feature_names in DMatrix.
# - Other significant aspects:
#   - Consistent feature engineering applied to both train and test.
#   - Seeds set for reproducibility (seed=42).
#
# Solution ID: tabular-playground-series-dec-2021__row5
# Score Percentile: 1.0
#
# Solution ID: tabular-playground-series-dec-2021__row5
# Score Percentile: 1.0
#
# 1) Data Preprocessing
# - Data loading and splitting approaches:
#   - Reads train.csv and test.csv from DATA_DIR using pandas.read_csv.
#   - Uses StratifiedKFold for cross-validation splits (train/val) within training.
#   - Optional subsampling for fast dev runs: sample up to 200,000 rows from train if FAST_DEV_RUN=1.
# - Cleaning strategies (missing values, outliers, filtering):
#   - Converts features to numeric with pd.to_numeric(errors='coerce'), then fills NaNs with 0.
#   - No explicit outlier handling or filtering.
# - Transformations (scaling, encoding, type conversions):
#   - Downcasts boolean-like columns (values subset of {0,1}) to np.uint8 (both train and test).
#   - Ensures numeric types for all features.
#   - Aligns train and test feature columns (X, X_test) with join='left', fill_value=0.
#   - Maps target labels to indices 0..num_classes-1 for XGBoost.
# - Data augmentation (if any):
#   - None.
# - Other preprocessing steps:
#   - Sets random seeds (numpy and random) to 42.
#   - Creates directories for models and submission.
#   - Ensures xgboost is installed (auto-installs if missing).
#
# 2) Feature Engineering
# - New features created:
#   - Aspect_sin, Aspect_cos (from Aspect converted to radians).
#   - Hydrology_Euclid = sqrt(Horizontal_Distance_To_Hydrology^2 + Vertical_Distance_To_Hydrology^2).
#   - Hydrology_signed = Vertical_Distance_To_Hydrology.
#   - Hillshade_mean, Hillshade_range, Hillshade_9_3_diff (from Hillshade_9am, Hillshade_Noon, Hillshade_3pm).
#   - Pairwise distance interactions (plus and minus):
#     - Horizontal_Distance_To_Roadways_plus_Horizontal_Distance_To_Fire_Points and minus variant.
#     - Horizontal_Distance_To_Roadways_plus_Horizontal_Distance_To_Hydrology and minus variant.
#     - Horizontal_Distance_To_Fire_Points_plus_Horizontal_Distance_To_Hydrology and minus variant.
#   - Slope_by_Elevation = Slope * Elevation.
# - Feature selection / dimensionality reduction:
#   - None.
# - Domain-specific transforms:
#   - Trigonometric transforms of aspect; hydrology distance; hillshade statistics; distance interactions; slope-elevation interaction.
# - Notes if none:
#   - N/A.
#
# 3) Model Selection
# - Algorithm(s) used (exact class/function names):
#   - xgboost.train (producing xgb.Booster models).
# - Key hyperparameters (list from code):
#   - objective='multi:softprob'
#   - num_class=derived from labels
#   - learning_rate=0.05
#   - max_depth=8
#   - min_child_weight=1
#   - subsample=0.8
#   - colsample_bytree=0.8
#   - reg_lambda=1.0
#   - reg_alpha=0.0
#   - tree_method='gpu_hist' (fallback to 'hist' on failure)
#   - max_bin=512
#   - verbosity=1
#   - eval_metric='merror'
#   - seed=42
# - Ensemble architecture (stacking/blending/voting) and number of models:
#   - Cross-validation ensemble: average of probability outputs from n_splits models (n_splits=3 by default; 2 in FAST_DEV_RUN).
# - Pretrained models (if any):
#   - None.
#
# 4) Training Methodology
# - Hyperparameter selection method:
#   - Fixed hyperparameters; no search or tuning shown.
# - Training configuration details (splits, folds, early stopping, regularization):
#   - StratifiedKFold(n_splits=3, shuffle=True, random_state=42) [2 in FAST_DEV_RUN].
#   - num_boost_round=3000 (300 in FAST_DEV_RUN).
#   - early_stopping_rounds=100 (30 in FAST_DEV_RUN).
#   - Regularization via reg_lambda and reg_alpha in params.
#   - Watchlist includes ('train', 'val); verbose_eval set to max(1, num_boost_round // 20).
#   - Uses bst.best_iteration for prediction range.
#   - Saves each fold model to MODEL_DIR as xgb_fold{fold}.json.
#   - Evaluates validation accuracy via accuracy_score on argmax of probabilities.
# - Other training details:
#   - Attempts GPU ('gpu_hist'); if training fails, logs and retries with CPU ('hist').
#   - Uses xgb.DMatrix for data.
#
# 5) Evaluation & Submission
# - Final prediction method (mean/median/weighted/etc.):
#   - Averages predicted class probabilities across CV models; takes argmax for final class per row.
# - Post-processing of predictions (rounding/clipping/logit/inverse, etc.):
#   - Maps predicted indices back to original classes:
#     - If classes are exactly 1..K, uses index+1.
#     - Else uses a dictionary mapping index->class from training labels.
#   - Casts Cover_Type to int.
# - How submission CSV is written:
#   - Constructs DataFrame with columns ['Id', 'Cover_Type'] (Id from test_df).
#   - Writes to SUBMISSION_PATH with index=False.
#
# 6) Notable Implementation Details
# - Computational considerations (GPU/CPU, runtime):
#   - Tries GPU training via tree_method='gpu_hist'; automatic fallback to CPU 'hist' on exception.
#   - Optional FAST_DEV_RUN to reduce data size, folds, and boosting rounds for quicker runs.
#   - Downcasts boolean-like features to uint8 to reduce memory usage.
# - Unique approaches or techniques:
#   - Aligns train and test feature columns after feature engineering to ensure consistency.
#   - Explicit label-index mapping to handle non-1..K class labels.
# - Other significant aspects:
#   - Ensures xgboost is installed programmatically.
#   - Logs timestamps and fold-level metrics; saves fold models as JSON.
#
# Solution ID: tabular-playground-series-dec-2021__row6
# Score Percentile: 1.0
#
# Solution ID: tabular-playground-series-dec-2021__row6
# Score Percentile: 1.0
#
# 1) Data Preprocessing
# - Data loading and splitting approaches:
#   - Loads train.csv and test.csv from /root/data using pandas.read_csv(low_memory=False).
#   - Splits training data into train/valid via sklearn.model_selection.train_test_split with test_size=0.1, random_state=42, stratified if minimum class count ≥ 2, otherwise unstratified.
#   - Optional debug mode (FAST_DEV_RUN env): samples a subset per class from train (groupby Cover_Type, sample max(1000, 5%) with random_state=42).
# - Cleaning strategies (missing values, outliers, filtering):
#   - Replaces +/-inf with NaN.
#   - Converts boolean columns to int8.
#   - Converts object columns to numeric (pd.to_numeric with errors='coerce').
#   - Casts feature matrices to float32. No explicit missing-value imputation or outlier handling beyond this.
# - Transformations (scaling, encoding, type conversions):
#   - Type conversions as above; no scaling.
#   - No new categorical encoding performed; assumes existing one-hot columns, later used for sums.
# - Data augmentation (if any):
#   - None.
# - Other preprocessing steps:
#   - Applies identical feature engineering to train and test.
#   - Defines feature columns as all columns except 'Id' and 'Cover_Type'.
#   - Aligns test columns to match feature_cols via reindex(columns=['Id'] + feature_cols).
#   - Extracts labels y as int and test_ids as int.
#
# 2) Feature Engineering
# - New features created:
#   - Hydrology_Euclid_Dist = sqrt(Horizontal_Distance_To_Hydrology^2 + Vertical_Distance_To_Hydrology^2)
#   - Elevation_minus_VertHydro = Elevation - Vertical_Distance_To_Hydrology
#   - Elevation_plus_VertHydro = Elevation + Vertical_Distance_To_Hydrology
#   - Sum_Horizontal_Distances = Horizontal_Distance_To_Hydrology + Horizontal_Distance_To_Roadways + Horizontal_Distance_To_Fire_Points
#   - Road_Fire_Diff = Horizontal_Distance_To_Roadways - Horizontal_Distance_To_Fire_Points
#   - Hillshade_Mean = mean(Hillshade_9am, Hillshade_Noon, Hillshade_3pm)
#   - Hillshade_Range = max(Hillshade_9am, Hillshade_Noon, Hillshade_3pm) - min(...)
#   - Aspect_Sin = sin(Aspect in radians)
#   - Aspect_Cos = cos(Aspect in radians)
#   - Aspect_Transformed = Aspect if ≤ 180 else Aspect - 360
#   - Elev_Slope_Product = Elevation * Slope
#   - Elev_Slope_Ratio = Elevation / (Slope + 1.0)
#   - Wilderness_Sum = sum of Wilderness_Area* one-hot columns
#   - Soil_Sum = sum of Soil_Type* one-hot columns
# - Feature selection / dimensionality reduction:
#   - Uses all columns except 'Id' and 'Cover_Type'; no dimensionality reduction.
# - Domain-specific transforms:
#   - Circular transforms for Aspect (sin/cos and wrap-around).
#   - Euclidean distance to hydrology.
#   - Hillshade aggregations and elevation-slope interactions.
#   - Aggregations of distance features and sums of one-hot wilderness/soil indicators.
# - Notes if none:
#   - None.
#
# 3) Model Selection
# - Algorithm(s) used (exact class/function names):
#   - xgboost.DMatrix
#   - xgboost.train
#   - sklearn.model_selection.train_test_split
# - Key hyperparameters (list from code):
#   - objective='multi:softprob'
#   - num_class (derived from y.unique())
#   - eval_metric='mlogloss'
#   - tree_method='gpu_hist' (fallback to 'hist' on error)
#   - predictor='gpu_predictor' (removed on CPU fallback)
#   - max_depth=10
#   - eta=0.1
#   - subsample=0.8
#   - colsample_bytree=0.8
#   - min_child_weight=1.0
#   - lambda=1.0
#   - gamma=0.0
#   - verbosity=1
#   - num_boost_round=800 (80 in debug or overridden by env MAX_ROUNDS)
#   - early_stopping_rounds=50 (20 in debug or overridden by env EARLY_STOPPING_ROUNDS)
#   - verbose_eval=50
# - Ensemble architecture (stacking/blending/voting) and number of models:
#   - None; single XGBoost model. After early stopping, retrains a single model on full data with best iteration.
# - Pretrained models (if any):
#   - None.
#
# 4) Training Methodology
# - Hyperparameter selection method:
#   - Fixed values in code; num_boost_round and early_stopping_rounds optionally overridden via environment variables. Early stopping selects best_iteration.
# - Training configuration details (splits, folds, early stopping, regularization):
#   - Train/valid split: 90/10 via train_test_split; stratified if feasible (min class count ≥ 2), random_state=42.
#   - Early stopping on the validation set with eval_metric mlogloss.
#   - Regularization: lambda=1.0, min_child_weight=1.0, gamma=0.0; subsample and colsample_bytree set to 0.8.
#   - Labels shifted to 0-based (y - 1) for XGBoost; num_class inferred from y.unique().
#   - Retrains on full training data with best_iteration after early stopping.
# - Other training details:
#   - Converts features to DMatrix for training/validation/testing.
#   - GPU training attempted; CPU hist fallback if GPU errors occur.
#
# 5) Evaluation & Submission
# - Final prediction method (mean/median/weighted/etc.):
#   - Predicts class probabilities on test; selects argmax per row and adds +1 to map back to 1..num_class.
# - Post-processing of predictions (rounding/clipping/logit/inverse, etc.):
#   - Casts Id and Cover_Type to int; sorts submission by Id.
# - How submission CSV is written:
#   - Writes to /workspace/submission.csv with columns ['Id', 'Cover_Type'], index=False. Ensures directory exists via os.makedirs.
#
# 6) Notable Implementation Details
# - Computational considerations (GPU/CPU, runtime):
#   - Uses GPU-accelerated XGBoost (gpu_hist, gpu_predictor); explicit CPU fallback to hist on XGBoostError.
#   - Casts features to float32 for memory/performance.
#   - Supports debug sampling (FAST_DEV_RUN) to reduce training time; logs end-to-end runtime in minutes.
# - Unique approaches or techniques:
#   - Retrains on full data using best_iteration found via early stopping.
#   - Robust feature alignment: reindexes test to training feature columns.
#   - Conditional stratification based on minimal class counts.
#   - Aspect circular handling (sin/cos and wrap-around transform).
# - Other significant aspects:
#   - Replaces infinities with NaN before modeling; converts booleans to int8 and objects to numeric.
#   - Environment-variable control over boosting rounds and early stopping.
#
# Solution ID: tabular-playground-series-dec-2021__row7
# Score Percentile: 1.0
#
# Solution ID: tabular-playground-series-dec-2021__row7
# Score Percentile: 1.0
#
# 1) Data Preprocessing
# - Data loading and splitting approaches:
#   - Loads train.csv and test.csv from specified paths using pandas.read_csv.
#   - Casts dtypes: Cover_Type -> int32, Id -> int64, all other features -> float32.
#   - Splits training into train/valid via train_test_split with test_size=0.1, random_state=42, stratified if each class has at least 2 samples; otherwise non-stratified.
# - Cleaning strategies (missing values, outliers, filtering):
#   - Missing columns handled in feature engineering via safe_get (uses zeros if column missing).
#   - No explicit missing value imputation, outlier handling, or filtering.
# - Transformations (scaling, encoding, type conversions):
#   - Type conversions as above.
#   - Label mapping: Cover_Type values mapped to 0..num_classes-1 for training; stored index_to_class for inverse mapping.
# - Data augmentation (if any):
#   - None.
# - Other preprocessing steps:
#   - Feature set excludes 'Id' and 'Cover_Type'.
#
# 2) Feature Engineering
# - New features created:
#   - Mean_Hillshade = (Hillshade_9am + Hillshade_Noon + Hillshade_3pm) / 3
#   - Hydrology_Distance_Sum = Horizontal_Distance_To_Hydrology + Vertical_Distance_To_Hydrology
#   - Hydrology_Distance_Diff = Horizontal_Distance_To_Hydrology - Vertical_Distance_To_Hydrology
#   - Abs_Vertical_Distance_To_Hydrology = |Vertical_Distance_To_Hydrology|
#   - Elevation_minus_Vertical = Elevation - Vertical_Distance_To_Hydrology
#   - Elevation_plus_Vertical = Elevation + Vertical_Distance_To_Hydrology
#   - Road_Fire_Sum = Horizontal_Distance_To_Roadways + Horizontal_Distance_To_Fire_Points
#   - Hydro_Fire_Sum = Horizontal_Distance_To_Hydrology + Horizontal_Distance_To_Fire_Points
#   - Road_Hydro_Sum = Horizontal_Distance_To_Roadways + Horizontal_Distance_To_Hydrology
#   - Slope_Aspect_Interaction = Slope * cos(deg2rad(Aspect))
#   - Elevation_Slope_Product = Elevation * Slope
#   - Hydrology_Ratio = Horizontal_Distance_To_Hydrology / (|Vertical_Distance_To_Hydrology| + 1e-3), else 0 if |VDH|==0
# - Feature selection / dimensionality reduction:
#   - None beyond excluding 'Id' and 'Cover_Type'.
# - Domain-specific transforms:
#   - Yes, features tailored to Forest Cover dataset (hydrology, hillshade, distances).
# - Notes if none:
#   - N/A.
#
# 3) Model Selection
# - Algorithm(s) used (exact class/function names):
#   - xgboost.train with booster 'gbtree' (DMatrix API).
# - Key hyperparameters (list from code):
#   - booster='gbtree'
#   - objective='multi:softprob'
#   - eval_metric='merror'
#   - num_class=len(unique(y))
#   - max_depth=8
#   - eta=0.05
#   - subsample=0.8
#   - colsample_bytree=0.8
#   - tree_method='gpu_hist' if USE_GPU=1 else 'hist' (with CPU fallback on failure)
#   - predictor='gpu_predictor' if USE_GPU=1 else 'auto'
#   - max_bin=256
#   - lambda=1.0
#   - alpha=0.0
#   - min_child_weight=1.0
#   - gamma=0.0
#   - nthread=12
#   - seed=42
#   - num_boost_round=n_estimators (200 if FAST_DEV=1 else 1500)
#   - early_stopping_rounds=30 if FAST_DEV=1 else 100
# - Ensemble architecture (stacking/blending/voting) and number of models:
#   - None; single XGBoost model.
# - Pretrained models (if any):
#   - None.
#
# 4) Training Methodology
# - Hyperparameter selection method:
#   - Fixed manual settings with environment-variable toggles (FAST_DEV, USE_GPU); no search/tuning shown.
# - Training configuration details (splits, folds, early stopping, regularization):
#   - Train/valid split: 90%/10%, random_state=42, stratified if feasible.
#   - Early stopping with validation set (rounds as above).
#   - Regularization parameters: lambda=1.0, alpha=0.0, min_child_weight=1.0, gamma=0.0.
#   - evals=[(train, 'train'), (valid, 'valid')], verbose_eval=50.
# - Other training details:
#   - GPU training attempted first if USE_GPU=1; on failure, falls back to CPU 'hist'.
#   - Logs training duration and best_iteration (if available).
#
# 5) Evaluation & Submission
# - Final prediction method (mean/median/weighted/etc.):
#   - Argmax over predicted class probabilities (multi:softprob).
# - Post-processing of predictions (rounding/clipping/logit/inverse, etc.):
#   - Map predicted class indices back to original Cover_Type labels via index_to_class; no clipping/rounding beyond integer casting.
# - How submission CSV is written:
#   - DataFrame with columns ['Id', 'Cover_Type'], sorted by 'Id'; saved to /workspace/submission.csv with index=False. Ensures directory exists via os.makedirs.
#
# 6) Notable Implementation Details
# - Computational considerations (GPU/CPU, runtime):
#   - Optional GPU via 'gpu_hist' and 'gpu_predictor' controlled by USE_GPU env var; fallback to CPU 'hist'.
#   - Dtype casting to float32/int32 to reduce memory footprint.
#   - nthread=12.
#   - Prints training time in minutes.
# - Unique approaches or techniques:
#   - Robust feature creation using safe_get to handle potentially missing columns.
#   - Automatic installation of required packages at runtime if missing.
#   - Label remapping to contiguous indices for multi-class training and inverse mapping for submission.
# - Other significant aspects:
#   - Logs with [LOG] for progress.
#   - Feature engineering explicitly tailored to Forest Cover Type dataset.
#
# Solution ID: tabular-playground-series-dec-2021__row8
# Score Percentile: 1.0
#
# Solution ID: tabular-playground-series-dec-2021__row8
# Score Percentile: 1.0
#
# 1) Data Preprocessing
# - Data loading and splitting approaches:
#   - Loads train.csv and test.csv from DATA_DIR using pandas.read_csv.
#   - Train/validation split via sklearn.model_selection.train_test_split with test_size=0.1, random_state=RANDOM_STATE, stratify=y0 (falls back to non-stratified if stratified split fails).
# - Cleaning strategies (missing values, outliers, filtering):
#   - In engineer_features: replaces [np.inf, -np.inf] with NaN and then fills NaN with 0.0.
#   - safe_ratio function avoids zero denominators by adding 1.0, replaces non-finite values with 0.0.
#   - No outlier removal or row filtering.
# - Transformations (scaling, encoding, type conversions):
#   - Type conversions: integer features cast to np.int32, float features to np.float32.
#   - Target labels converted from 1-based to 0-based integers for XGBoost.
#   - No scaling; no categorical encoding shown (original one-hots preserved).
# - Data augmentation (if any):
#   - None.
# - Other preprocessing steps:
#   - Excludes 'Id' from feature columns.
#   - Checks engineered/raw features exist in test; raises error if missing.
#   - Logs class distribution.
#   - XGBoost DMatrix created with missing=np.nan.
#
# 2) Feature Engineering
# - New features created:
#   - Aspect_sin, Aspect_cos (sin/cos of Aspect in radians).
#   - Hydro_Euclid_Dist = sqrt(Horizontal_Distance_To_Hydrology^2 + Vertical_Distance_To_Hydrology^2).
#   - Vertical_Distance_Is_Neg (int8 flag for vdh < 0).
#   - Vertical_Distance_Abs = abs(Vertical_Distance_To_Hydrology).
#   - Hydro_Vert_Ratio = safe_ratio(Vertical_Distance_To_Hydrology, Horizontal_Distance_To_Hydrology, add=1.0).
#   - Hydro_Horiz_Ratio = safe_ratio(Horizontal_Distance_To_Hydrology, abs(Vertical_Distance_To_Hydrology), add=1.0).
#   - Hillshade_mean, Hillshade_min, Hillshade_max, Hillshade_range (from Hillshade_9am, Hillshade_Noon, Hillshade_3pm).
#   - Road_Fire_Ratio = safe_ratio(Horizontal_Distance_To_Roadways, Horizontal_Distance_To_Fire_Points, add=1.0).
#   - Fire_Road_Ratio = safe_ratio(Horizontal_Distance_To_Fire_Points, Horizontal_Distance_To_Roadways, add=1.0).
#   - Elev_minus_VertHydro = Elevation - Vertical_Distance_To_Hydrology.
# - Feature selection / dimensionality reduction:
#   - Uses all engineered and original features except 'Id'. No explicit selection or dimensionality reduction.
# - Domain-specific transforms:
#   - Terrain-related transforms (aspect trig, hydrology distance/ratios, hillshade aggregates, road/fire distance ratios, elevation-hydrology difference).
# - Notes if none:
#   - None.
#
# 3) Model Selection
# - Algorithm(s) used (exact class/function names):
#   - xgboost.train
#   - xgboost.DMatrix
# - Key hyperparameters (list from code):
#   - objective='multi:softprob'
#   - num_class=num_classes
#   - eval_metric='mlogloss'
#   - learning_rate=0.1
#   - max_depth=8
#   - min_child_weight=3
#   - subsample=0.8
#   - colsample_bytree=0.8
#   - reg_lambda=1.0
#   - gamma=0.0
#   - tree_method='gpu_hist' if GPU detected else 'hist' (fallback to 'hist' if GPU training fails)
#   - max_bin=256
#   - nthread=12
#   - verbosity=1
#   - num_boost_round=1200 (or 200 if FAST_DEV_RUN)
#   - early_stopping_rounds=50 (or 20 if FAST_DEV_RUN)
# - Ensemble architecture (stacking/blending/voting) and number of models:
#   - None; single XGBoost model.
# - Pretrained models (if any):
#   - None.
#
# 4) Training Methodology
# - Hyperparameter selection method:
#   - Fixed hyperparameters in code; no tuning/search.
# - Training configuration details (splits, folds, early stopping, regularization):
#   - Train/validation split: 90/10 with stratification on y0 (fallback non-stratified).
#   - Early stopping with early_stopping_rounds.
#   - Regularization via reg_lambda and gamma in params.
#   - Uses watchlist [('train'), ('val')] with verbose_eval=50.
#   - Optional subsampling of rows if FAST_DEV_RUN is set (DEV_N_ROWS env var, default 300000).
# - Other training details:
#   - GPU detection via nvidia-smi; uses 'gpu_hist' if available, otherwise 'hist'.
#   - Saves model to CACHE_DIR/xgb_model.json.
#   - Logs training time and best_iteration.
#
# 5) Evaluation & Submission
# - Final prediction method (mean/median/weighted/etc.):
#   - Predicts class probabilities (multi:softprob) and uses argmax to select class.
# - Post-processing of predictions (rounding/clipping/logit/inverse, etc.):
#   - Converts 0-based predicted labels back to 1-based by adding 1.
#   - Casts Id to int64 and Cover_Type to int32.
# - How submission CSV is written:
#   - Creates DataFrame with columns ['Id', 'Cover_Type'] and writes to SUBMISSION_PATH with index=False.
#
# 6) Notable Implementation Details
# - Computational considerations (GPU/CPU, runtime):
#   - Attempts GPU via 'gpu_hist' if nvidia-smi is available; falls back to CPU 'hist' if GPU not available or fails.
#   - nthread=12 set for XGBoost.
#   - FAST_DEV_RUN mode to reduce training data size and boosting rounds.
# - Unique approaches or techniques:
#   - safe_ratio function to handle division robustly (add 1 to denominator, replace non-finite).
#   - Rich terrain-specific feature engineering (aspect trig, hydrology/elevation/hillshade).
#   - Automatic installation of xgboost if missing.
# - Other significant aspects:
#   - Uses environment variables SEED, FAST_DEV_RUN, DEV_N_ROWS.
#   - Ensures test contains all engineered features; raises error if missing.
#   - Logs class distribution and pipeline timings.
#
# Solution ID: tabular-playground-series-dec-2021__row9
# Score Percentile: 1.0
#
# Solution ID: tabular-playground-series-dec-2021__row9
# Score Percentile: 1.0
#
# 1) Data Preprocessing
# - Data loading and splitting approaches:
#   - Loads train.csv and test.csv from /root/data using pandas.read_csv.
#   - Splits training data into train/valid via sklearn.model_selection.train_test_split.
#   - Stratified split on y_raw (original labels) with test_size=0.1 (or 0.2 if FAST_DEV). Falls back to non-stratified split if an exception occurs.
#   - Optional FAST_DEV subsampling: randomly selects a fraction of rows (ENV DEV_FRAC, default 0.03) using numpy RandomState(SEED).
# - Cleaning strategies (missing values, outliers, filtering):
#   - Replaces inf/-inf with NaN, then fills NaN with 0.0 in feature_engineering.
#   - Outlier handling and filtering: Not shown.
# - Transformations (scaling, encoding, type conversions):
#   - Casts several numeric columns to float to avoid integer overflow.
# ...
# - Key strengths:
#   - Practical regularization (min_child_weight=3, lambda=2.0) and sampling (subsample/colsample=0.8) to manage variance.
#   - Careful best_iteration handling across xgboost versions (iteration_range).
# - Alignment:
#   - Uses eval_metric=mlogloss but final decision is argmax on probabilities, aligning to accuracy-based leaderboard.
#
# Solution tabular-playground-series-dec-2021__row1 (percentile=1.0, high)
# - Why it likely works:
#   - XGBoost tuned for accuracy (eval_metric='merror') with early stopping on a stratified split.
#   - Strong feature set (Euclid hydrology, hillshade diffs/means, elevation-hydrology differences, road/fire combos).
# - Key strengths:
#   - Memory-conscious dtype mapping and float32 conversion allow training stability at scale.
#   - GPU probe and fallback ensure performance portability.
# - Alignment:
#   - Directly optimizes merror (accuracy), matching the competition metric; proper 0-based label handling and argmax predictions.
#
# Solution tabular-playground-series-dec-2021__row2 (percentile=1.0, high)
# - Why it likely works:
#   - XGBoost with early stopping and both mlogloss/merror tracked; robust stratified split logic.
#   - Sensible features: hydrology Euclid, hillshade mean/diff, distance sums/diffs.
# - Key strengths:
#   - GPU/CPU fallback, float32 features, and 0-based labels; prediction constrained to best_iteration.
# - Alignment:
#   - Argmax over softprob aligns with accuracy evaluation; careful handling of label offset (min_class).
#
# Solution tabular-playground-series-dec-2021__row3 (percentile=1.0, high)
# - Why it likely works:
#   - Rich, domain-specific features including hydrology/elevation interactions, hillshade stats, and recovered categorical indices (Wilderness_Idx, Soil_Idx).
#   - XGBoost with early stopping on a stratified holdout (5–10%).
# - Key strengths:
#   - GPU acceleration with fallback; strict feature alignment between train/test.
#   - Uses best_ntree_limit for inference, avoiding over-iteration.
# - Alignment:
#   - Final argmax over softprob suits accuracy; features mirror known high-performing transforms for this dataset.
#
# Solution tabular-playground-series-dec-2021__row4 (percentile=1.0, high)
# - Why it likely works:
#   - Strong terrain features (aspect sin/cos, hillshade mean/range, multiple distance sums/diffs).
#   - XGBoost with early stopping and stratified split.
# - Key strengths:
#   - Explicit train/test feature alignment and float32 features; robust handling of xgboost versions for best_iteration usage.
# - Alignment:
#   - Predicts soft probabilities and argmax, appropriate for accuracy; regularization and sampling parameters are sensible.
#
# Solution tabular-playground-series-dec-2021__row5 (percentile=1.0, high)
# - Why it likely works:
#   - 3-fold stratified CV XGBoost with probability averaging reduces variance versus single holdout.
#   - Comprehensive feature engineering (aspect sin/cos, hydrology Euclid, hillshade stats, distance interactions).
# - Key strengths:
#   - Column alignment between train/test; downcasting boolean features to uint8; GPU fallback.
# - Alignment:
#   - Eval metric merror and argmax final label selections match accuracy objective; CV ensemble improves generalization.
#
# Solution tabular-playground-series-dec-2021__row6 (percentile=1.0, high)
# - Why it likely works:
#   - Strong FE (aspect sin/cos plus wrap-around transform; hydrology Euclid; hillshade range/mean; elevation-slope interactions).
#   - Early-stopped XGBoost then refit on full data with best_iteration—good bias/variance balance.
# - Key strengths:
#   - Robust column alignment and types; GP U‘gpu_hist’ with fallback; replaces inf with NaN.
# - Alignment:
#   - Uses mlogloss for early stopping but final argmax addresses accuracy; retraining stabilizes final model.
#
# Solution tabular-playground-series-dec-2021__row7 (percentile=1.0, high)
# - Why it likely works:
#   - Domain-aware features (hydrology sums/diffs/ratios, elevation ± vertical hydrology, slope-aspect interactions).
#   - XGBoost with merror evaluation and early stopping on a stratified split.
# - Key strengths:
#   - Safe feature creation and dtype management; GPU usage when available.
# - Alignment:
#   - Optimizes accuracy proxy (merror) and uses argmax for final labels, directly matching the task metric.
#
# Solution tabular-playground-series-dec-2021__row8 (percentile=1.0, high)
# - Why it likely works:
#   - Extensive FE including safe_ratio functions to avoid instability (div-by-zero/infs), hydrology/elevation/hillshade transformations, aspect sin/cos.
#   - XGBoost with early stopping, GPU detection, and NaN handling.
# - Key strengths:
#   - Ensures engineered features exist in test; robust dtype control and logging; uses best_iteration for prediction.
# - Alignment:
#   - Final argmax after optimizing mlogloss is standard and effective for accuracy on this dataset.
#
# Solution tabular-playground-series-dec-2021__row9 (percentile=1.0, high)
# - Why it likely works:
#   - Solid FE (hydrology Euclid, hillshade stats, distance interactions, safe ratios, aspect circular encoding).
#   - XGBoost with early stopping (mlogloss) and GPU acceleration.
# - Key strengths:
#   - Replaces inf/-inf then fills NaN; conservative regularization; thorough timing/logging.
# - Alignment:
#   - Argmax softprob yields accuracy-optimized predictions; stratified holdout suits early stopping reliability.
#
# Solution tabular-playground-series-dec-2021__row10 (percentile=1.0, high)
# - Why it likely works:
#   - Strong FE set (slope/elevation interactions; hydrology Euclid; aspect sin/cos; distance combos) plus compact dtypes.
#   - XGBoost with early stopping and GPU; label encoding for clean class mapping.
# - Key strengths:
#   - Tracking best_iteration; proper type casting; sanity checks for required columns.
# - Alignment:
#   - Evaluates with merror; final argmax predictions align with accuracy.
#
# Solution tabular-playground-series-dec-2021__row11 (percentile=1.0, high)
# - Why it likely works:
#   - LightGBM baseline with careful memory reduction and early stopping performs strongly even without FE on this structured dataset.
#   - XGBoost fallback preserves robustness.
# - Key strengths:
#   - Stratified validation; reduce_mem_usage; correct 0-based label shift and restoration.
# - Alignment:
#   - Multi-class logloss early stopping and argmax final labels produce strong accuracy on Forest Cover data.
#
# Solution tabular-playground-series-dec-2021__row12 (percentile=1.0, high)
# - Why it likely works:
#   - Compact dtypes and rich FE (hydrology Euclid; multiple distance aggregates; hillshade ranges; aspect sin/cos; wilderness/soil indices).
#   - XGBoost with early stopping and GPU.
# - Key strengths:
#   - Explicit column alignment and label shifting; long patience early stopping (200) stabilizes best_iteration selection.
# - Alignment:
#   - Softprob + argmax finalization suits accuracy; stratified validation ensures reliable early stopping.
#
# Solution tabular-playground-series-dec-2021__row13 (percentile=1.0, high)
# - Why it likely works:
#   - 3-fold CV XGBoost ensemble; FE mirrors dataset-specific winners (distance sums/diffs, hydrology Euclid, slope*hydro, hillshade, elevation−VDH).
#   - Wilderness/Soil indices recovered while retaining one-hots.
# - Key strengths:
#   - GPU histogram; dtype-optimized (int8/int32/float32); per-fold best_iteration and OOF accuracy.
# - Alignment:
#   - Averages soft probabilities and argmax—standard for accuracy; CV reduces overfitting.
#
# Solution tabular-playground-series-dec-2021__row14 (percentile=1.0, high)
# - Why it likely works:
#   - Two-stage XGBoost training: early-stopped to pick optimal rounds, then refit on full data—strong practice.
#   - FE includes cyclic Aspect, hydrology distances (Euclidean/Manhattan), hillshade aggregates, slope interactions.
# - Key strengths:
#   - GPU with fallback; stratified fold used to select val; label offset handled.
# - Alignment:
#   - Early stopping on mlogloss + argmax prediction is effective for accuracy; engineered features fit the terrain domain.
#
# Solution tabular-playground-series-dec-2021__row15 (percentile=1.0, high)
# - Why it likely works:
#   - XGBoost + FE (hillshade mean/diff, elevation ± VDH, distance combos, wilderness/soil sums).
#   - Stratified validation with early stopping and correct label remap.
# - Key strengths:
#   - Dtype downcasting and float32 arrays; robust GPU/CPU fallback.
# - Alignment:
#   - mlogloss-driven early stopping with argmax aligns with accuracy; features target known signal in this dataset.
#
# Solution tabular-playground-series-dec-2021__row16 (percentile=1.0, high)
# - Why it likely works:
#   - Good FE (hydrology Euclid/abs vertical, elevation minus VDH, slope interactions, road/fire combos).
#   - XGBoost with early stopping, GPU, and robust prediction range logic (iteration_range / best_ntree_limit).
# - Key strengths:
#   - Clean dtype casting (int8/int32/float32), zero-based labels, and logging; optional stratified dev sampling.
# - Alignment:
#   - Argmax on softprob suits accuracy; settings (subsample/colsample) mitigate overfitting.
#
# Solution tabular-playground-series-dec-2021__row17 (percentile=0.058, low)
# - Likely failure points (with code evidence) and fixes:
#   - Single holdout vs. CV: Uses a single 90/10 holdout split with early stopping; no cross-validation or ensembling, unlike many high-scoring solutions that average across folds. Change: switch to StratifiedKFold (e.g., 3–5 folds), average soft probabilities, and use best_iteration per fold.
#   - Misaligned optimization vs. metric: Trains with eval_metric="mlogloss" then argmax. Many top entries optimize merror (accuracy) explicitly. Change: set eval_metric='merror' (or include both) to align early stopping with the leaderboard metric.
#   - Potentially harmful class weighting: Computes sample weights inversely proportional to class frequency and passes to DMatrix. For this dataset, class imbalance is modest; such weighting can distort decision boundaries. Change: remove weights or validate their effect via OOF; if needed, use milder weighting (e.g., sqrt inverse-frequency).
#   - Thin feature set vs. top solutions: Missing several high-signal transforms repeatedly used by stronger entries (e.g., Elevation ± Vertical_Distance_To_Hydrology, road–hydrology/fire sums/diffs, hillshade min/max/range variants beyond mean/range, wilderness/soil indices). Change: add domain features explicitly seen in high performers:
#     - Elevation_minus_VertHydro, Elevation_plus_VertHydro
#     - Road_Hydro_Sum/Diff, Fire_Hydro_Sum/Diff, All-Distances Sum/Mean
#     - Hillshade_Mean/Min/Max/Range and time differences
#     - Aspect sin/cos are present; also consider slope-aspect interactions (e.g., Slope * cos(Aspect))
#     - Wilderness_Idx and Soil_Idx from one-hot argmax
#   - Hyperparameter robustness: Learning rate eta=0.08, depth=8 are reasonable, but without CV and with weights, over/underfitting risk rises. Change: reduce eta (0.05–0.06), keep early stopping 50–100, and consider min_child_weight > 1 and small L2 (lambda 1–2) as in strong solutions.
#   - Implementation fixes:
#     - Keep robust GPU/CPU fallback.
#     - Ensure engineered features are applied identically to test and verified for presence; handle inf/NaN (several high solutions replace inf with NaN and fill/let XGB handle).
#     - Use iteration_range or best_ntree_limit for inference at best_iteration.
#
# Solution tabular-playground-series-dec-2021__row18 (percentile=1.0, high)
# - Why it likely works:
#   - 3-fold CV XGBoost ensemble; FE includes log1p-transformed distances, multiple hillshade deltas, distance sums/diffs, elevation ± VDH.
#   - GPU training with proper early stopping and iteration_range at inference.
# - Key strengths:
#   - Train+test concatenation ensures consistent FE; handles division edge cases and memory via float32.
# - Alignment:
#   - Averaging soft probabilities and argmax targets accuracy reliably.
#
# Solution tabular-playground-series-dec-2021__row19 (percentile=1.0, high)
# - Why it likely works:
#   - 4-fold stratified CV XGBoost, averaging test soft probabilities: strong generalization.
#   - FE includes hydrology/Elevation features, hillshade aggregates, aspect sin/cos, and recovery of wilderness/soil indices.
# - Key strengths:
#   - Inf→NaN handling; GPU with fallback; thorough OOF accuracy tracking.
# - Alignment:
#   - Eval merror and argmax fit accuracy; conservative regularization and sampling.
#
# Solution tabular-playground-series-dec-2021__row20 (percentile=1.0, high)
# - Why it likely works:
#   - Strong FE (hydrology Euclid/combined, slope–aspect projections, aspect sin/cos, road/fire sums/diffs).
#   - Early-stopped XGBoost with best_iteration; attempts GPU via device='cuda'.
# - Key strengths:
#   - LabelEncoder-based mapping; stratified split with checks.
# - Alignment:
#   - mlogloss early stopping plus argmax neatly serves accuracy; depth/regularization settings are reasonable.
#
# Solution tabular-playground-series-dec-2021__row21 (percentile=1.0, high)
# - Why it likely works:
#   - Multiple strong learners with stratified K-fold averaging (LightGBM priority, CatBoost/RandomForest fallbacks) provide robust performance even without FE.
#   - Early stopping for LGB/CatBoost and careful dtype downcasting.
# - Key strengths:
#   - Trainer selection with fallbacks; probability averaging across folds; robust Id handling and column alignment.
# - Alignment:
#   - Argmax of averaged probabilities targets accuracy; CV reduces variance.
#
# Solution tabular-playground-series-dec-2021__row22 (percentile=1.0, high)
# - Why it likely works:
#   - K-fold CV averaging with LightGBM/XGBoost/CatBoost (LightGBM preferred) and early stopping.
#   - FE aligns with domain: aspect sin/cos, hydrology Euclid, distance ratios/sums, elevation ± VDH.
# - Key strengths:
#   - Safe division handling; robust per-fold accuracy logging; GPU for XGB when available.
# - Alignment:
#   - Mean soft probabilities + argmax matches accuracy; parameters and regularization are in common effective ranges.
#
# Solution tabular-playground-series-dec-2021__row23 (percentile=1.0, high)
# - Why it likely works:
#   - LightGBM with early stopping and a strong FE set (distance/elevation/hillshade interactions and ratios).
#   - Downcasting to control memory; stratified split via StratifiedShuffleSplit.
# - Key strengths:
#   - Tracks multi_logloss and multi_error; uses best_iteration for prediction.
# - Alignment:
#   - Argmax on probabilities aligns with accuracy metric; features map to dataset physics.
#
# Solution tabular-playground-series-dec-2021__row24 (percentile=1.0, high)
# - Why it likely works:
#   - LightGBM with early stopping on a class-stratified split and well-chosen learning rate/num_leaves.
#   - FE strongly matches top patterns (hydrology Euclid, hillshade mean/range, distance sums/abs diffs, elevation−VDH).
# - Key strengths:
#   - Float32 casts; manual per-class stratified split; robust logging.
# - Alignment:
#   - Multi_logloss early stopping plus argmax finalization produces high accuracy.
#
# Solution tabular-playground-series-dec-2021__row25 (percentile=1.0, high)
# - Why it likely works:
#   - 5-fold stratified CV LightGBM with averaging; even without FE, the original feature set (including many informative one-hot binaries) is sufficient for strong performance.
#   - Early stopping and solid regularization/bagging settings.
# - Key strengths:
#   - OOF accuracy tracking; robust label mapping and column checks; num_threads tuned to CPU.
# - Alignment:
#   - Averaged probabilities and argmax suit accuracy-based evaluation.
#
# Solution tabular-playground-series-dec-2021__row26 (percentile=1.0, high)
# - Why it likely works:
#   - 5-fold stratified CV LightGBM and extensive FE (aspect sin/cos, hydrology Euclid/abs vertical, hillshade differences, elevation − VDH, slope*HDH, distance sums/diffs).
#   - Early stopping with memory-efficient dtypes and force_col_wise.
# - Key strengths:
#   - Fallback from StratifiedKFold to KFold when needed; OOF accuracy computed; fast-dev subsampling maintains class balance.
# - Alignment:
#   - Averaging fold probabilities and argmax yields robust accuracy; parameter set mirrors winning practices.
