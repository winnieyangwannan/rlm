# %% [markdown]
# # LOG:
#
# /checkpoint/maui_sft/winnieyangwn/rlm_dumps/archive/gpt5/comparison/gpt-5_comparison_513_iwildcam-2019-fgvc6_2026-02-10_08-53-34_9720b385.jsonl

# %%
import sys
import importlib


sys.path.append('/home/winnieyangwn/rlm/analysis')
import rlm_log_utils
importlib.reload(rlm_log_utils)
from rlm_log_utils import *

# %% [markdown]
# ## Usage Example
#
# Load the log file and extract key information:

# %% [markdown]
# # Load

# %%
import glob
import os

run_id = 520
job_name = "post-improvement-diveristy_520-rlm-comparison-argparse-xray"  # Note: typo in original filename "diveristy"
log_dir = "/checkpoint/maui_sft/winnieyangwn/rlm_dumps/post-improvement"
codebase_extensions = [".jsonl"]

# Option 1: Provide a specific log name to load directly
log_name = ""  # Leave empty to auto-find most recent

if log_name:
    # Directly load the specified log file
    LOG_PATH = os.path.join(log_dir, log_name)
    if not os.path.exists(LOG_PATH):
        raise FileNotFoundError(f"Specified log file not found: {LOG_PATH}")
    print(f"Loading specified log: {LOG_PATH}")
else:
    # Find logs matching the prefix pattern
    LOG_PATH_PREFIX = f"{log_dir}/gpt-5_{job_name}"

    # Find all log files matching the prefix pattern (only .jsonl files)
    matching_logs = glob.glob(f"{LOG_PATH_PREFIX}*.jsonl")

    if not matching_logs:
        raise FileNotFoundError(f"No log files found matching prefix: {LOG_PATH_PREFIX}*.jsonl")

    # Get the most recent log file by modification time
    LOG_PATH = max(matching_logs, key=os.path.getmtime)
    print(f"Found {len(matching_logs)} matching log file(s)")
    print(f"Loading most recent: {LOG_PATH}")

# Load the log - first entry is metadata, rest are iterations
entries = load_rlm_log(LOG_PATH)
metadata = entries[0]
iterations = entries[1:]

print(f"Loaded {len(iterations)} iterations")
# Out:
# Found 1 matching log file(s)
# Loading most recent: /checkpoint/maui_sft/winnieyangwn/rlm_dumps/post-improvement/gpt-5_post-improvement-diveristy_520-rlm-comparison-argparse-xray_vinbigdata-chest-xray-abnormalities-detection_2026-02-11_01-46-55_85814eb7.jsonl
# Loaded 5 iterations

# %% [markdown]
# # Metadata

# %%
# View metadata
print("=== METADATA ===")
for k, v in metadata.items():
    if k != "backend_kwargs":
        print(f"{k}: {v}")
# Out:
# === METADATA ===
# type: metadata
# timestamp: 2026-02-11T01:46:55.406583
# root_model: gpt-5
# max_depth: 2
# max_iterations: 10
# backend: azure_openai
# environment_type: local
# environment_kwargs: {'setup_code': '\nimport pandas as pd\n\n# Load solution summaries as DataFrame\nsummaries_df = pd.read_json(\'/checkpoint/maui_sft/winnieyangwn/rlm_dumps/post-improvement/gpt-5_post-improvement_summarization_520-rlm-comparison-argparse-xray_vinbigdata-chest-xray-abnormalities-detection_2026-02-11_01-16-17_2e0b82b1_extracted.jsonl\', lines=True)\nprint(f"Loaded {len(summaries_df)} solution summaries")\nprint(f"Columns: {summaries_df.columns.tolist()}")\n'}
# other_backends: None

# %%
# Compare with timestamp-based runtime
runtime = get_total_runtime(entries)
print(f"Timestamp-based runtime: {runtime.total_seconds():.2f}s")
# Out:
# Timestamp-based runtime: 177.53s

# %%
# Check number of iterations actually taken by model
num_iterations = len(iterations)
print(f"Number of iterations taken: {num_iterations}")

# You can also use extract_all for a comprehensive summary
summary = extract_all(LOG_PATH)
print(f"Number of iterations (from extract_all): {summary['num_iterations']}")
# Out:
# Number of iterations taken: 5
# Number of iterations (from extract_all): 5

# %% [markdown]
# # Final Answer

# %%
# Get the final answer
final_answer = get_final_answer(iterations)
print("=== FINAL ANSWER ===")
print(final_answer if final_answer else "No final answer found")
# print(f"\n(Total length: {len(final_answer) if final_answer else 0} chars)")
# Out:
# === FINAL ANSWER ===
# # Solution Diversity Analysis
#
# ## Overview
# - Total number of solutions analyzed: 55
# - Summary of overall diversity: Overall diversity is low to medium, with many solutions converging on a similar baseline.
#
# ## Per-Axis Analysis
#
# ### 1. Model Architecture Diversity
# - Assessment of diversity: Low
# - **Faster R-CNN**: 55 solutions (100%)
#
# ### 2. Backbone Diversity
# - Assessment of diversity: Low
# - **ResNet50 FPN v2**: 55 solutions (100%)
#
# ### 3. Preprocessing Pipeline Diversity
# - Assessment of diversity: Low
# - **DICOM_LUTs (modality/VOI)**: 55 solutions (100%)
# - **MONOCHROME1_inversion**: 55 solutions (100%)
# - **Stack_Grayscale_to_3ch**: 55 solutions (100%)
# - **Resize_Letterbox_Square**: 45 solutions (82%)
# - **MinMax_Normalization**: 36 solutions (65%)
# - **Percentile_Normalization**: 20 solutions (36%)
# - **CLAHE**: 20 solutions (36%)
# - **Convert_to_uint8**: 14 solutions (25%)
# - **Resize_AspectPreserve**: 9 solutions (16%)
# - **ImageNet_Normalization**: 5 solutions (9%)
# - **No_Resize**: 3 solutions (5%)
#
# ### 4. Augmentation Diversity
# - Assessment of diversity: Low
# - **None**: 47 solutions (85%)
# - **HFlip**: 8 solutions (15%)
#
# ### 5. Training Recipe Diversity
# - Assessment of diversity: Low
# Optimizer usage:
# - **SGD**: 55 solutions (100%)
# Scheduler usage:
# - **StepLR**: 25 solutions (45%)
# - **None**: 22 solutions (40%)
# - **MultiStepLR**: 6 solutions (11%)
# - **Other**: 2 solutions (4%)
# AMP usage:
# - **Yes**: 55 solutions (100%)
# Warmup usage:
# - **Yes**: 42 solutions (76%)
# - **No**: 7 solutions (13%)
# - **Unknown/Unclear**: 6 solutions (11%)
#
# ### 6. Post-processing Diversity
# - Assessment of diversity: Low
# - **Fallback_NoFinding**: 55 solutions (100%)
# - **ScoreThresh_Low(<=0.15)**: 52 solutions (95%)
# - **TopK60**: 51 solutions (93%)
# - **ClipBoxes**: 51 solutions (93%)
# - **LabelRemap**: 46 solutions (84%)
# - **PerClassNMS**: 3 solutions (5%)
# - **ScoreThresh_Med(0.15-0.3)**: 3 solutions (5%)
#
# ### 7. Ensemble Strategy Diversity
# - Assessment of diversity: Low
# - **None**: 55 solutions (100%)
#
# ### 8. Validation Strategy Diversity
# - Assessment of diversity: High
# - **Holdout_Stratified_has_box_5pct**: 32 solutions (58%)
# - **Holdout_Stratified**: 21 solutions (38%)
# - **Other**: 1 solutions (2%)
# - **None/Unclear**: 1 solutions (2%)
#
# ## Key Findings
# - Most diverse axis: Validation Strategy
# - Most homogeneous axis: Model Architecture
# - Notable patterns or clusters:
#   - A dominant Faster R-CNN ResNet-50 FPN baseline appears across many solutions.
#   - Common DICOM preprocessing (modality/VOI LUTs, MONOCHROME1 inversion, percentile normalization) and stacking grayscale to 3 channels for ImageNet-pretrained backbones are prevalent.
#   - Augmentation is typically minimal (horizontal flip) with few heavy augmentations reported.
#   - Post-processing commonly includes per-class NMS, low score thresholds (≤0.15), TopK=60, label remapping, clipping, and a fallback 'No finding'.
#
# ## Redundant Solutions
# - Identified 2 groups of near-duplicate solutions (same architecture, backbone, preprocessing/augmentation sets, optimizer/scheduler/AMP/warmup, post-processing, ensemble, and validation).
# - Group sizes (top 10): 3, 2
# - Examples of near-duplicate fingerprints:
# - Group size 3 with fingerprint: (Faster R-CNN, ResNet50 FPN v2, pre=[CLAHE, DICOM_LUTs (modality/VOI), MONOCHROME1_inversion, MinMax_Normalization, Resize_Letterbox_Square, Stack_Grayscale_to_3ch], aug=[], opt=SGD, sch=StepLR, amp=Yes, warmup=Yes, post=[ClipBoxes, Fallback_NoFinding, LabelRemap, ScoreThresh_Low(<=0.15), TopK60], ens=None, val=Holdout_Stratified_has_box_5pct)
# - Group size 2 with fingerprint: (Faster R-CNN, ResNet50 FPN v2, pre=[DICOM_LUTs (modality/VOI), MONOCHROME1_inversion, Percentile_Normalization, Resize_Letterbox_Square, Stack_Grayscale_to_3ch], aug=[], opt=SGD, sch=None, amp=Yes, warmup=Yes, post=[ClipBoxes, Fallback_NoFinding, LabelRemap, ScoreThresh_Low(<=0.15), TopK60], ens=None, val=Holdout_Stratified)
# - Justification: These clusters share nearly identical end-to-end design choices and differ, if at all, only in minor thresholds or constants.
#
# ## Gaps in Solution Space
# - Notable alternatives that are rare or absent and could improve diversity:
#   - Architectures: YOLOv5/YOLOv8/YOLOX, DETR/Deformable DETR, RetinaNet/FCOS, Cascade R-CNN, EfficientDet.
#   - Backbones: Swin Transformer, ConvNeXt, EfficientNet, ResNet101/ResNeXt.
#   - Augmentation: Mosaic/CutMix/MixUp, rotations/scaling, color jitter (when applicable), richer Albumentations pipelines.
#   - Training recipes: AdamW with CosineAnnealing/OneCycle, longer training, EMA, label smoothing or focal loss where appropriate.
#   - Post-processing: Soft-NMS or WBF, per-class calibration/threshold optimization, TTA.
#   - Validation: K-fold or stratified CV with OOF metrics (e.g., mAP) rather than loss-only holdout.
#   - Ensembling: Cross-fold or heterogeneous model ensembling with weighted blending.
